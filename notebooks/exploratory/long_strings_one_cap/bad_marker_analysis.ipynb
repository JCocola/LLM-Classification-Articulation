# %% [markdown]
# ## Imports

# %%
import sys, os
import importlib

# Set up the Python path for the project.
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import create_datasets, evals_utils
importlib.reload(create_datasets)
importlib.reload(evals_utils)
from create_datasets import generate_long_string_dataset, generate_marker_dataset
from inference_utils import build_classification_prompt, build_articulation_prompt, chat, make_inference_fn
from evals_utils import load_expected_labels, evaluate_classification_accuracy, parse_predictions, classify_then_explain, flexible_parse_predictions

from dotenv import load_dotenv

# %%
load_dotenv()  # reads from .env in current working directory
# You can also specify path manually: load_dotenv(dotenv_path="../.env")

# Confirm it worked:
assert "OPENAI_API_KEY" in os.environ
print("OpenAI key loaded.")
# Out:
# OpenAI key loaded.

# %% [markdown]
# ### Models

# %%
from openai import OpenAI
# Retrieve all available models
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
models = client.models.list()

# Filter models that include 'gpt-4' in their ID
gpt_4_models = [model.id for model in models.data if "gpt-4" in model.id.lower()]

# Print the list of GPT-4 models
print("Available GPT-4 Models:")
for model_id in gpt_4_models:
    print(f"- {model_id}")
# Out:
# Available GPT-4 Models:
# - gpt-4o-audio-preview-2024-12-17
# - gpt-4o-audio-preview-2024-10-01
# - gpt-4-turbo-preview
# - gpt-4.1-nano
# - gpt-4.1-nano-2025-04-14
# - gpt-4o-realtime-preview-2024-10-01
# - gpt-4o-realtime-preview
# - gpt-4
# - chatgpt-4o-latest
# - gpt-4o-mini-audio-preview
# - gpt-4-1106-preview
# - gpt-4o-audio-preview
# - gpt-4o-mini-realtime-preview
# - gpt-4.1-mini
# - gpt-4o-mini-realtime-preview-2024-12-17
# - gpt-4o-mini-search-preview
# - gpt-4.1-mini-2025-04-14
# - gpt-4o-search-preview
# - gpt-4o-mini-search-preview-2025-03-11
# - gpt-4-0125-preview
# - gpt-4o-2024-11-20
# - gpt-4o-2024-05-13
# - gpt-4-0613
# - gpt-4o-mini-tts
# - gpt-4o-transcribe
# - gpt-4.5-preview
# - gpt-4.5-preview-2025-02-27
# - gpt-4o-mini-transcribe
# - gpt-4o-search-preview-2025-03-11
# - gpt-4o
# - gpt-4o-mini
# - gpt-4o-2024-08-06
# - gpt-4.1
# - gpt-4.1-2025-04-14
# - gpt-4o-mini-2024-07-18
# - gpt-4o-mini-audio-preview-2024-12-17
# - gpt-4o-realtime-preview-2024-12-17
# - gpt-4-turbo
# - gpt-4-turbo-2024-04-09
# - ft:gpt-4o-2024-08-06:jc:max-apples:BU5dqCKg:ckpt-step-200
# - ft:gpt-4o-2024-08-06:jc:max-apples:BU5drWFT:ckpt-step-400
# - ft:gpt-4o-2024-08-06:jc:max-apples:BU5drlXO
# - ft:gpt-4o-2024-08-06:jc:ita-class-explain:BU42Ek2G:ckpt-step-105
# - ft:gpt-4o-2024-08-06:jc:ita-class-explain:BU42FwJT
# - ft:gpt-4.1-2025-04-14:jc:ita-class-explain:BTyKZBz2:ckpt-step-21
# - ft:gpt-4.1-2025-04-14:jc:ita-no-explain:BTyMdII4:ckpt-step-21
# - ft:gpt-4.1-2025-04-14:jc:ita-class-explain:BTyKZV7V:ckpt-step-42
# - ft:gpt-4.1-2025-04-14:jc:ita-class-explain:BTyKZGKi
# - ft:gpt-4.1-2025-04-14:jc:ita-class:BTyQ2x1O
# - ft:gpt-4.1-2025-04-14:jc:ita-no-explain:BTyMd8uN:ckpt-step-42
# - ft:gpt-4.1-2025-04-14:jc:ita-no-explain:BTyMdX1G
# - ft:gpt-4.1-2025-04-14:jc:ita-class:BTyQ1eTU:ckpt-step-21
# - ft:gpt-4.1-2025-04-14:jc:ita-class:BTyQ1Vxm:ckpt-step-42

# %%
openai_4o = "openai/gpt-4o"
openai_4op1 = "openai/gpt-4.1"
openai_4op1_nano = "openai/gpt-4.1-nano"
openai_4op1_mini = "openai/gpt-4.1-mini"

# %% [markdown]
# ## Experiments N = 100, n = 50

# %% [markdown]
# ### Setting up the experiment

# %%
toy_rule_path = os.path.join(project_root, "notebooks", "exploratory", "long_strings_one_cap")

file_name = "marker_dataset_N=50_case1_n=2_40_40.json"
generate_marker_dataset(
    num_samples=40,
    test_samples=40,
    output_folder=toy_rule_path,
    file_name=file_name,
    N=100,
    marker_character="*",
    filler_character="_",
    case_mode=1,     # false = left‑only marker; true = right‑only
)
dataset_path = os.path.join(toy_rule_path, file_name)
# Out:
# Saved 40 train and 40 test samples to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/long_strings_one_cap/marker_dataset_N=50_case1_n=2_40_40.json

# %% [markdown]
# ### Step 1. Classification

# %%
dataset_path = os.path.join(project_root, "notebooks", "exploratory", "long_strings_one_cap", "marker_dataset_N=50_case1_n=2_40_40.json")

# %%
gold_labels = load_expected_labels(dataset_path)
intro = "You are given strings consisting of _ characters with possibly one * character. Your task is to classify each string as True or False based on a specific rule."
question = "Based on the training examples, determine if each test string should be classified as True or False"
instructions = "For each test example, respond with just True or False on the same line after the arrow."

classification_prompt = build_classification_prompt(
    dataset_path,
    intro=intro,
    question=question,
    instructions=instructions,
)
print(classification_prompt)
# Out:
# You are given strings consisting of _ characters with possibly one * character. Your task is to classify each string as True or False based on a specific rule.
# For each test example, respond with just True or False on the same line after the arrow.
#
# ### Training examples
# "______________________________________________________________________________________________*_____" -> True
# "____________*_______________________________________________________________________________________" -> False
# "____________________________________________________________________________________________*_______" -> True
# "_______________________________________________________*____________________________________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "____________________________________________________________________________________*_______________" -> True
# "____________*_______________________________________________________________________________________" -> False
# "___________________________________________________________________________________________*________" -> True
# "____________________________________________________________*_______________________________________" -> True
# "________________________________________________________________*___________________________________" -> True
# "_______________________________________________________________________________*____________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "__*_________________________________________________________________________________________________" -> False
# "_________________________________________________________________________*__________________________" -> True
# "_________________________________________________________________________________________________*__" -> True
# "________________________________*___________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________*__________________________" -> True
# "____________________________________________*_______________________________________________________" -> False
# "___*________________________________________________________________________________________________" -> False
# "___*________________________________________________________________________________________________" -> False
# "___________________________________________________________*________________________________________" -> True
# "___________________________________________________________________________________*________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "___________________________________________________________________*________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "________________*___________________________________________________________________________________" -> False
# "________________*___________________________________________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "______________________________*_____________________________________________________________________" -> False
# "_________________________________________________________*__________________________________________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "____________________________________________________________________________________*_______________" -> True
# "_________________________________________________________________________________________________*__" -> True
# "______________________________*_____________________________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "__________________________________________________________________________*_________________________" -> True
# "_____________________________________________________________________________________________*______" -> True
#
# ### Based on the training examples, determine if each test string should be classified as True or False
# "_____________*______________________________________________________________________________________" ->
# "_________________________________________________*__________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "__________________________________________________________________*_________________________________" ->
# "_______________________________________________________________*____________________________________" ->
# "____________________________________________*_______________________________________________________" ->
# "_______________________*____________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "__________________________________________________________*_________________________________________" ->
# "______________________________________________________________________________________________*_____" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_______________________________________*____________________________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "_________*__________________________________________________________________________________________" ->
# "______________________________________________*_____________________________________________________" ->
# "____________________________________________________________________*_______________________________" ->
# "__________________________________________________________________________________________________*_" ->
# "_______________*____________________________________________________________________________________" ->
# "_______*____________________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__________________________________________________________________________________________*_________" ->
# "___________*________________________________________________________________________________________" ->
# "__________________________________________________________*_________________________________________" ->
# "__________________________________________________________________________________________*_________" ->
# "___________________*________________________________________________________________________________" ->
# "____________________________________________________________________________________*_______________" ->
# "______________________________________________________________________*_____________________________" ->
# "__________________________________________*_________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________________*______________________________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_________________*__________________________________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "__________________________________________*_________________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "____________________________________________________________________*_______________________________" ->
# "_______*____________________________________________________________________________________________" ->
# "________________________________________________________________________*___________________________" ->

# %%
dataset_path
# Out:
# '/Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/long_strings_one_cap/marker_dataset_N=50_case1_n=2_40_40.json'

# %%
gold_labels = load_expected_labels(dataset_path)
# Build the model/temperature‑specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels,
    label_set=["TRUE", "FALSE"],
    num_runs=1
)
print(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 6
#       3 inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)
#       5 # Evaluate accuracy (gold_labels loaded elsewhere)
# ----> 6 results = evaluate_classification_accuracy(
#       7     prompt=classification_prompt,
#       8     inference_fn=inference_fn,
#       9     expected_labels=gold_labels,
#      10     label_set=["TRUE", "FALSE"],
#      11     num_runs=1
#      12 )
#      13 print(results)
#
# File ~/Documents/GitHub/OE-test/code/evals_utils.py:95, in evaluate_classification_accuracy(prompt, inference_fn, expected_labels, label_set, num_runs)
#      92 all_outs = []
#      94 for j in range(num_runs):
# ---> 95     out = inference_fn(prompt)
#      96     all_outs.append(out)
#      97     preds = flexible_parse_predictions(out, n, label_set)
#
# File ~/Documents/GitHub/OE-test/code/inference_utils.py:126, in make_inference_fn.<locals>.inference_fn(prompt)
#     125 def inference_fn(prompt: str) -> str:
# --> 126     return asyncio.run(_chat_once(prompt))
#
# File ~/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ### Step 3. Faithfulness

# %% [markdown]
# ### Step 3. Faithfulness

# %% [markdown]
# #### CF accuracy mixed examples

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf.json",
    n1=20, n2=20, n3=0, n4=20, n5=20, n6=20
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 200 test samples (100 false + 100 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf.json

# %%
# Load the new dataset
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "4J3y64" ->
# "7Z2390" ->
# "199422" ->
# "X96515" ->
# "t52450" ->
# "3D0935" ->
# "6784T5" ->
# "0A0546" ->
# "295831" ->
# "R63239" ->
# "quiceR" ->
# "4R72F3" ->
# "95851Z" ->
# "fmAabd" ->
# "35744T" ->
# "9J9866" ->
# "2193P3" ->
# "45465Q" ->
# "601455" ->
# "886882" ->
# "AE0833" ->
# "8207d9" ->
# "0816w1" ->
# "77623P" ->
# "389G07" ->
# "baVkdq" ->
# "2a751Y" ->
# "7307J0" ->
# "R07P15" ->
# "06468w" ->
# "2O1959" ->
# "64923a" ->
# "wnrUrc" ->
# "jbbyYw" ->
# "586028" ->
# "R1K885" ->
# "25971k" ->
# "05284B" ->
# "32w529" ->
# "789882" ->
# "92V270" ->
# "505Q11" ->
# "4F0369" ->
# "63S19u" ->
# "cbWolv" ->
# "s824Z4" ->
# "953245" ->
# "270J24" ->
# "394032" ->
# "C37022" ->
# "02762W" ->
# "A63C46" ->
# "4P25Z4" ->
# "0116O5" ->
# "m19901" ->
# "49318B" ->
# "U66643" ->
# "N18702" ->
# "890958" ->
# "76V346" ->
# "7812A7" ->
# "90C685" ->
# "D00532" ->
# "75I921" ->
# "nnBgxf" ->
# "390969" ->
# "14lA04" ->
# "nwUuiy" ->
# "781Lf9" ->
# "L75643" ->
# "1CC803" ->
# "9081G0" ->
# "36343W" ->
# "34C730" ->
# "i97880" ->
# "950D33" ->
# "4K6311" ->
# "8P8325" ->
# "83K3R7" ->
# "76S3Z4" ->
# "wznnoG" ->
# "69V578" ->
# "8ER454" ->
# "bpKkdm" ->
# "39675A" ->
# "9591M1" ->
# "H74636" ->
# "972S09" ->
# "136C21" ->
# "3042E0" ->
# "08A390" ->
# "R844U8" ->
# "0397N0" ->
# "401958" ->
# "Ie0652" ->
# "616C25" ->
# "68252C" ->
# "A43124" ->
# "ollCnf" ->
# "k03464" ->
# "984U73" ->
# "8D0J76" ->
# "8c4795" ->
# "56C27M" ->
# "H99918" ->
# "10764T" ->
# "5861W1" ->
# "570V14" ->
# "514003" ->
# "qmlqYs" ->
# "hdcAfp" ->
# "092E13" ->
# "bwGmgn" ->
# "X96420" ->
# "414473" ->
# "z05356" ->
# "5A9285" ->
# "30935R" ->
# "382311" ->
# "5650W8" ->
# "6813B6" ->
# "4144V5" ->
# "4O3268" ->
# "46U472" ->
# "omujrX" ->
# "4B91H5" ->
# "1E4379" ->
# "180D59" ->
# "M91332" ->
# "069939" ->
# "g77923" ->
# "188a40" ->
# "0663oE" ->
# "2a2N50" ->
# "566b3X" ->
# "3Z495Z" ->
# "4C33a2" ->
# "N17918" ->
# "233H85" ->
# "oViqxr" ->
# "8f2496" ->
# "xicAyj" ->
# "6449R9" ->
# "832T74" ->
# "8Y1486" ->
# "1q067X" ->
# "280D25" ->
# "35237A" ->
# "1C4987" ->
# "4032X0" ->
# "835835" ->
# "7577Y0" ->
# "41D970" ->
# "lHhddn" ->
# "9E0069" ->
# "952X53" ->
# "751G75" ->
# "84s28P" ->
# "3138z7" ->
# "066F66" ->
# "382441" ->
# "24Y135" ->
# "L40749" ->
# "g91096" ->
# "839919" ->
# "3825B9" ->
# "E91p38" ->
# "396993" ->
# "942V72" ->
# "wkbQgh" ->
# "193Vv2" ->
# "9668e8" ->
# "3Po038" ->
# "78M370" ->
# "9Y1960" ->
# "04Q799" ->
# "4509H1" ->
# "59A575" ->
# "70L37L" ->
# "53148G" ->
# "W80924" ->
# "5O6w27" ->
# "R146V6" ->
# "7B3628" ->
# "4F0135" ->
# "68A387" ->
# "516N7c" ->
# "265x43" ->
# "C19A90" ->
# "8650W4" ->
# "C18A18" ->
# "3P51s4" ->
# "9545X0" ->
# "9I0820" ->
# "ucwpHz" ->
# "208u26" ->
# "59C6M6" ->
# "340859" ->
# "980O7r" ->
# "6I7493" ->
# --------------------
# {'run_accuracies': [np.float64(0.6), np.float64(0.6)], 'mean_accuracy': 0.6, 'std_accuracy': 0.0, 'overall_accuracy': 0.6, 'all_outs': ['"4J3y64" -> True\n"7Z2390" -> True\n"199422" -> False\n"X96515" -> True\n"t52450" -> True\n"3D0935" -> True\n"6784T5" -> True\n"0A0546" -> True\n"295831" -> False\n"R63239" -> True\n"quiceR" -> True\n"4R72F3" -> True\n"95851Z" -> True\n"fmAabd" -> True\n"35744T" -> True\n"9J9866" -> True\n"2193P3" -> True\n"45465Q" -> True\n"601455" -> False\n"886882" -> False\n"AE0833" -> True\n"8207d9" -> True\n"0816w1" -> True\n"77623P" -> True\n"389G07" -> True\n"baVkdq" -> True\n"2a751Y" -> True\n"7307J0" -> True\n"R07P15" -> True\n"06468w" -> True\n"2O1959" -> True\n"64923a" -> True\n"wnrUrc" -> True\n"jbbyYw" -> True\n"586028" -> False\n"R1K885" -> True\n"25971k" -> True\n"05284B" -> True\n"32w529" -> True\n"789882" -> False\n"92V270" -> True\n"505Q11" -> True\n"4F0369" -> True\n"63S19u" -> True\n"cbWolv" -> True\n"s824Z4" -> True\n"953245" -> False\n"270J24" -> True\n"394032" -> False\n"C37022" -> True\n"02762W" -> True\n"A63C46" -> True\n"4P25Z4" -> True\n"0116O5" -> True\n"m19901" -> True\n"49318B" -> True\n"U66643" -> True\n"N18702" -> True\n"890958" -> False\n"76V346"
# %% [markdown]
# #### CF accuracy only n1

# %%
print("Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.")
# Out:
# Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n1.json",
    n1=30, n2=0, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n1.json

# %%
# Load the new dataset (n1)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n1.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "65758J" ->
# "44B482" ->
# "326593" ->
# "068481" ->
# "681579" ->
# "2586Y5" ->
# "376137" ->
# "763P02" ->
# "403466" ->
# "092X09" ->
# "044511" ->
# "Y9A742" ->
# "902379" ->
# "M3H121" ->
# "7F85G6" ->
# "C67259" ->
# "79O357" ->
# "51613E" ->
# "557840" ->
# "550263" ->
# "2191U1" ->
# "Z2288D" ->
# "NE0647" ->
# "7482T7" ->
# "991QO8" ->
# "990036" ->
# "41287M" ->
# "168977" ->
# "806L00" ->
# "70972V" ->
# "0F0374" ->
# "978349" ->
# "5065S7" ->
# "4580M3" ->
# "A747B9" ->
# "80T537" ->
# "W375G7" ->
# "388535" ->
# "0789G0" ->
# "M5I776" ->
# "7058R2" ->
# "505562" ->
# "540925" ->
# "61W094" ->
# "48Q67L" ->
# "34927O" ->
# "870393" ->
# "7Z4G51" ->
# "657556" ->
# "7Y5161" ->
# "7E1032" ->
# "85F741" ->
# "7705V5" ->
# "802149" ->
# "1218V7" ->
# "7T3435" ->
# "4502J3" ->
# "M698E5" ->
# "J96216" ->
# "662J39" ->
# "I02S35" ->
# "19M473" ->
# "49I598" ->
# "6T1188" ->
# "949O84" ->
# "2J9W46" ->
# "4955YV" ->
# "R92196" ->
# "752GT5" ->
# "7L08K4" ->
# "55L050" ->
# "527873" ->
# "54392S" ->
# "959N91" ->
# "Z926O5" ->
# "BN5198" ->
# "26W696" ->
# "79A653" ->
# "879150" ->
# "H01127" ->
# "451RV8" ->
# "6U19Q8" ->
# "134342" ->
# "3043Q4" ->
# "40D521" ->
# "59Q8J4" ->
# "5447B0" ->
# "X81511" ->
# "85A475" ->
# "009608" ->
# "93UN98" ->
# "33290G" ->
# "Z98285" ->
# "111238" ->
# "76S05D" ->
# "157YD8" ->
# "321F28" ->
# "53Q160" ->
# "311143" ->
# "362808" ->
# "5P4282" ->
# "648M98" ->
# "55572Z" ->
# "46248P" ->
# "720994" ->
# "Z20134" ->
# "D6991O" ->
# "Z25909" ->
# "007210" ->
# "713257" ->
# "J06240" ->
# "521N84" ->
# "2G7949" ->
# "55D12T" ->
# "260535" ->
# "2I7U28" ->
# "075690" ->
# "X713W3" ->
# "65X5W0" ->
# "98R954" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"65758J" -> True\n"44B482" -> True\n"326593" -> False\n"068481" -> False\n"681579" -> False\n"2586Y5" -> True\n"376137" -> False\n"763P02" -> True\n"403466" -> False\n"092X09" -> True\n"044511" -> False\n"Y9A742" -> True\n"902379" -> False\n"M3H121" -> True\n"7F85G6" -> True\n"C67259" -> True\n"79O357" -> True\n"51613E" -> True\n"557840" -> False\n"550263" -> False\n"2191U1" -> True\n"Z2288D" -> True\n"NE0647" -> True\n"7482T7" -> True\n"991QO8" -> True\n"990036" -> False\n"41287M" -> True\n"168977" -> False\n"806L00" -> True\n"70972V" -> True\n"0F0374" -> True\n"978349" -> False\n"5065S7" -> True\n"4580M3" -> True\n"A747B9" -> True\n"80T537" -> True\n"W375G7" -> True\n"388535" -> False\n"0789G0" -> True\n"M5I776" -> True\n"7058R2" -> True\n"505562" -> False\n"540925" -> False\n"61W094" -> True\n"48Q67L" -> True\n"34927O" -> True\n"870393" -> False\n"7Z4G51" -> True\n"657556" ->
# %%
print(results['all_outs'][0])
# Out:
# "65758J" -> True
# "44B482" -> True
# "326593" -> False
# "068481" -> False
# "681579" -> False
# "2586Y5" -> True
# "376137" -> False
# "763P02" -> True
# "403466" -> False
# "092X09" -> True
# "044511" -> False
# "Y9A742" -> True
# "902379" -> False
# "M3H121" -> True
# "7F85G6" -> True
# "C67259" -> True
# "79O357" -> True
# "51613E" -> True
# "557840" -> False
# "550263" -> False
# "2191U1" -> True
# "Z2288D" -> True
# "NE0647" -> True
# "7482T7" -> True
# "991QO8" -> True
# "990036" -> False
# "41287M" -> True
# "168977" -> False
# "806L00" -> True
# "70972V" -> True
# "0F0374" -> True
# "978349" -> False
# "5065S7" -> True
# "4580M3" -> True
# "A747B9" -> True
# "80T537" -> True
# "W375G7" -> True
# "388535" -> False
# "0789G0" -> True
# "M5I776" -> True
# "7058R2" -> True
# "505562" -> False
# "540925" -> False
# "61W094" -> True
# "48Q67L" -> True
# "34927O" -> True
# "870393" -> False
# "7Z4G51" -> True
# "657556" -> False
# "7Y5161" -> True
# "7E1032" -> True
# "85F741" -> True
# "7705V5" -> True
# "802149" -> False
# "1218V7" -> True
# "7T3435" -> True
# "4502J3" -> True
# "M698E5" -> True
# "J96216" -> True
# "662J39" -> True
# "I02S35" -> True
# "19M473" -> True
# "49I598" -> True
# "6T1188" -> True
# "949O84" -> True
# "2J9W46" -> True
# "4955YV" -> True
# "R92196" -> True
# "752GT5" -> True
# "7L08K4" -> True
# "55L050" -> True
# "527873" -> False
# "54392S" -> True
# "959N91" -> True
# "Z926O5" -> True
# "BN5198" -> True
# "26W696" -> True
# "79A653" -> True
# "879150" -> False
# "H01127" -> True
# "451RV8" -> True
# "6U19Q8" -> True
# "134342" -> False
# "3043Q4" -> True
# "40D521" -> True
# "59Q8J4" -> True
# "5447B0" -> True
# "X81511" -> True
# "85A475" -> True
# "009608" -> False
# "93UN98" -> True
# "33290G" -> True
# "Z98285" -> True
# "111238" -> False
# "76S05D" -> True
# "157YD8" -> True
# "321F28" -> True
# "53Q160" -> True
# "311143" -> False
# "362808" -> False
# "5P4282" -> True
# "648M98" -> True
# "55572Z" -> True
# "46248P" -> True
# "720994" -> False
# "Z20134" -> True
# "D6991O" -> True
# "Z25909" -> True
# "007210" -> False
# "713257" -> False
# "J06240" -> True
# "521N84" -> True
# "2G7949" -> True
# "55D12T" -> True
# "260535" -> False
# "2I7U28" -> True
# "075690" -> False
# "X713W3" -> True
# "65X5W0" -> True
# "98R954" -> True

# %% [markdown]
# #### CF accuracy only n2

# %%
print("Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.")
# Out:
# Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n2.json",
    n1=0, n2=30, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n2.json

# %%
# Load the new dataset (n2)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n2.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "578546" ->
# "3703V9" ->
# "395129" ->
# "497B11" ->
# "54Y696" ->
# "61631Z" ->
# "4183J8" ->
# "7362Z2" ->
# "232027" ->
# "d4032J" ->
# "U42287" ->
# "64361L" ->
# "q9193P" ->
# "4X38m1" ->
# "2c7U76" ->
# "D5e688" ->
# "3768W5" ->
# "8Z11m7" ->
# "538037" ->
# "2835R4" ->
# "260040" ->
# "555267" ->
# "978378" ->
# "4531T8" ->
# "272199" ->
# "v65I94" ->
# "s778I8" ->
# "80S49s" ->
# "297446" ->
# "310526" ->
# "202Y02" ->
# "5a43J1" ->
# "013644" ->
# "64486J" ->
# "03619L" ->
# "402mB9" ->
# "73wW75" ->
# "68W312" ->
# "6H3793" ->
# "R72071" ->
# "1X7575" ->
# "I92717" ->
# "e080D6" ->
# "48385T" ->
# "35F331" ->
# "333G48" ->
# "44O313" ->
# "4377Y3" ->
# "005430" ->
# "3Sr396" ->
# "F2u969" ->
# "0808P5" ->
# "6eD106" ->
# "283S09" ->
# "A88j64" ->
# "86L428" ->
# "1D1642" ->
# "314277" ->
# "N35942" ->
# "734683" ->
# "45I523" ->
# "B01366" ->
# "H09341" ->
# "671z3I" ->
# "Ic6976" ->
# "7y01S6" ->
# "234098" ->
# "461014" ->
# "24Mj24" ->
# "V82702" ->
# "Q22388" ->
# "295950" ->
# "181441" ->
# "8940F9" ->
# "84695W" ->
# "O85783" ->
# "9I056k" ->
# "9N9142" ->
# "5P5170" ->
# "90614Z" ->
# "715933" ->
# "02B759" ->
# "30G04m" ->
# "126900" ->
# "1G7583" ->
# "997769" ->
# "02659Y" ->
# "0150G0" ->
# "275152" ->
# "1553Kx" ->
# "340237" ->
# "7Z8753" ->
# "63M057" ->
# "3666V8" ->
# "5s9G03" ->
# "q3X775" ->
# "9T8167" ->
# "097841" ->
# "1Wc422" ->
# "30970K" ->
# "1K3230" ->
# "378776" ->
# "009950" ->
# "J27969" ->
# "296Q14" ->
# "815126" ->
# "557625" ->
# "67J331" ->
# "8G8985" ->
# "08J847" ->
# "8J5182" ->
# "383E59" ->
# "I51713" ->
# "e931C9" ->
# "3uF164" ->
# "62885X" ->
# "997716" ->
# "6gC309" ->
# "613Q08" ->
# "056553" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"578546" -> False\n"3703V9" -> True\n"395129" -> False\n"497B11" -> True\n"54Y696" -> True\n"61631Z" -> True\n"4183J8" -> True\n"7362Z2" -> True\n"232027" -> False\n"d4032J" -> True\n"U42287" -> True\n"64361L" -> True\n"q9193P" -> True\n"4X38m1" -> True\n"2c7U76" -> True\n"D5e688" -> True\n"3768W5" -> True\n"8Z11m7" -> True\n"538037" -> False\n"2835R4" -> True\n"260040" -> False\n"555267" -> False\n"978378" -> False\n"4531T8" -> True\n"272199" -> False\n"v65I94" -> True\n"s778I8" -> True\n"80S49s" -> True\n"297446" -> False\n"310526" -> False\n"202Y02" -> True\n"5a43J1" -> True\n"013644" -> False\n"64486J" -> True\n"03619L" -> True\n"402mB9" -> True\n"73wW75" -> True\n"68W312" -> True\n"6H3793" -> True\n"R72071" -> True\n"1X7575" -> True\n"I92717" -> True\n"e080D6" -> True\n"48385T" -> True\n"35F331" -> True\n"333G48" -> True\n"44O313" -> True\n"4377Y3" -> True\n"005430" -> False\n"3Sr396" -> True\n"F2u969" -> True\n"0808P5" -> True\n"6eD106" -> True\n"283S09" -> True\n"A88j64" -> True\n"86L428" -> True\n"1D1642" -> True\n"314277" -> False\n"N35942" -> True\n"734683" -> False\n"45I523" -> True\n"B01366" -> True\n"H09341" -> True\n"671z3I" -> True\n"Ic6976" -> True\n"7y01S6" -> True\n"234098" -> False\n"461014" -> False\n"24
# "497B11" -> True
# "54Y696" -> True
# "61631Z" -> True
# "4183J8" -> True
# "7362Z2" -> True
# "232027" -> False
# "d4032J" -> True
# "U42287" -> True
# "64361L" -> True
# "q9193P" -> True
# "4X38m1" -> True
# "2c7U76" -> True
# "D5e688" -> True
# "3768W5" -> True
# "8Z11m7" -> True
# "538037" -> False
# "2835R4" -> True
# "260040" -> False
# "555267" -> False
# "978378" -> False
# "4531T8" -> True
# "272199" -> False
# "v65I94" -> True
# "s778I8" -> True
# "80S49s" -> True
# "297446" -> False
# "310526" -> False
# "202Y02" -> True
# "5a43J1" -> True
# "013644" -> False
# "64486J" -> True
# "03619L" -> True
# "402mB9" -> True
# "73wW75" -> True
# "68W312" -> True
# "6H3793" -> True
# "R72071" -> True
# "1X7575" -> True
# "I92717" -> True
# "e080D6" -> True
# "48385T" -> True
# "35F331" -> True
# "333G48" -> True
# "44O313" -> True
# "4377Y3" -> True
# "005430" -> False
# "3Sr396" -> True
# "F2u969" -> True
# "0808P5" -> True
# "6eD106" -> True
# "283S09" -> True
# "A88j64" -> True
# "86L428" -> True
# "1D1642" -> True
# "314277" -> False
# "N35942" -> True
# "734683" -> False
# "45I523" -> True
# "B01366" -> True
# "H09341" -> True
# "671z3I" -> True
# "Ic6976" -> True
# "7y01S6" -> True
# "234098" -> False
# "461014" -> False
# "24Mj24" -> True
# "V82702" -> True
# "Q22388" -> True
# "295950" -> False
# "181441" -> False
# "8940F9" -> True
# "84695W" -> True
# "O85783" -> True
# "9I056k" -> True
# "9N9142" -> True
# "5P5170" -> True
# "90614Z" -> True
# "715933" -> False
# "02B759" -> True
# "30G04m" -> True
# "126900" -> False
# "1G7583" -> True
# "997769" -> False
# "02659Y" -> True
# "0150G0" -> True
# "275152" -> False
# "1553Kx" -> True
# "340237" -> False
# "7Z8753" -> True
# "63M057" -> True
# "3666V8" -> True
# "5s9G03" -> True
# "q3X775" -> True
# "9T8167" -> True
# "097841" -> False
# "1Wc422" -> True
# "30970K" -> True
# "1K3230" -> True
# "378776" -> False
# "009950" -> False
# "J27969" -> True
# "296Q14" -> True
# "815126" -> False
# "557625" -> False
# "67J331" -> True
# "8G8985" -> True
# "08J847" -> True
# "8J5182" -> True
# "383E59" -> True
# "I51713" -> True
# "e931C9" -> True
# "3uF164" -> True
# "62885X" -> True
# "997716" -> False
# "6gC309" -> True
# "613Q08" -> True
# "056553" -> False

# %% [markdown]
# #### CF accuracy only n4

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4.json",
    n1=0, n2=0, n3=0, n4=30, n5=30, n6=0
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4.json

# %%
# Load the new dataset (n4)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "178453" ->
# "krjKwv" ->
# "196063" ->
# "830M32" ->
# "566175" ->
# "zfKczw" ->
# "150P57" ->
# "yuiytO" ->
# "524602" ->
# "hfuOpj" ->
# "ztyuhB" ->
# "541256" ->
# "40M910" ->
# "817W65" ->
# "7V0117" ->
# "980594" ->
# "80K207" ->
# "74R482" ->
# "95F924" ->
# "4723R4" ->
# "185A58" ->
# "A60183" ->
# "84876Z" ->
# "339131" ->
# "621D25" ->
# "111966" ->
# "Wtzqvw" ->
# "jRgxfu" ->
# "4182K4" ->
# "41A675" ->
# "199781" ->
# "M72365" ->
# "22704U" ->
# "12L758" ->
# "29X352" ->
# "0862L7" ->
# "268208" ->
# "5N0722" ->
# "62B270" ->
# "292P83" ->
# "628U55" ->
# "02D021" ->
# "C67655" ->
# "lkSgqz" ->
# "Xmzejc" ->
# "547773" ->
# "185U74" ->
# "1K1098" ->
# "xsOgbx" ->
# "614386" ->
# "qsysWt" ->
# "Irzmgj" ->
# "198386" ->
# "R50163" ->
# "ncGwno" ->
# "60050B" ->
# "578143" ->
# "pleoDe" ->
# "9848V5" ->
# "9J1638" ->
# "458L18" ->
# "7G3466" ->
# "lwzJrr" ->
# "460M56" ->
# "946M56" ->
# "4C5581" ->
# "vdyeKv" ->
# "782107" ->
# "310720" ->
# "vhbPwa" ->
# "tfuvRi" ->
# "858565" ->
# "6W7139" ->
# "94031K" ->
# "jJzfmc" ->
# "176531" ->
# "1142R6" ->
# "mysVde" ->
# "hhPird" ->
# "820918" ->
# "58651K" ->
# "184018" ->
# "tlZumw" ->
# "G08122" ->
# "V55177" ->
# "wxrMbq" ->
# "8W4144" ->
# "K64003" ->
# "170284" ->
# "44R655" ->
# "459831" ->
# "338059" ->
# "360R83" ->
# "06V233" ->
# "336301" ->
# "Ijjtgb" ->
# "688695" ->
# "679181" ->
# "698196" ->
# "budNbi" ->
# "01566M" ->
# "ovbDkp" ->
# "24892D" ->
# "Rbqdvs" ->
# "2499Z0" ->
# "855P18" ->
# "53X598" ->
# "tnxIef" ->
# "01C217" ->
# "1303X2" ->
# "4F7960" ->
# "Dwkhdd" ->
# "75764B" ->
# "486370" ->
# "662896" ->
# "Aujuwe" ->
# "148G15" ->
# "4140U1" ->
# "05U263" ->
# "216565" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"178453" -> False\n"krjKwv" -> True\n"196063" -> False\n"830M32" -> True\n"566175" -> False\n"zfKczw" -> True\n"150P57" -> True\n"yuiytO" -> True\n"524602" -> False\n"hfuOpj" -> True\n"ztyuhB" -> True\n"541256" -> False\n"40M910" -> True\n"817W65" -> True\n"7V0117" -> True\n"980594" -> False\n"80K207" -> True\n"74R482" -> True\n"95F924" -> True\n"4723R4" -> True\n"185A58" -> True\n"A60183" -> True\n"84876Z" -> True\n"339131" -> False\n"621D25" -> True\n"111966" -> False\n"Wtzqvw" -> True\n"jRgxfu" -> True\n"4182K4" -> True\n"41A675" -> True\n"199781" -> False\n"M72365" -> True\n"22704U" -> True\n"12L758" -> True\n"29X352" -> True\n"0862L7" -> True\n"268208" -> False\n"5N0722" -> True\n"62B270" -> True\n"292P83" -> True\n"628U55" -> True\n"02D021" -> True\n"C67655" -> True\n"lkSgqz" -> True\n"Xmzejc" -> True\n"547773" -> False\n"185U74" -> True\n"1K1098" -> True\n"xsOgbx" -> True\n"614386" -> False\n"qsysWt" -> True\n"Irzmgj" -> True\n"198386" -> False\n"R50163" -> True\n"ncGwno" -> True\n"60050B" -> True\n"578143" -> False\n"pleoDe" -> True\n"9848V5" -> True\n"9J1638" -> True\n"458L18" -> True\n"7G3466" -> True\n"lwzJrr" -> True\n"460M56" -> True\n"946M56" -> True\n"4C5581" -> True\n"vdyeKv" -> True\n"782107" -> False\n"310720" -> False\n"vhbPwa" -> True\n"tfuvRi" -> True\n"858565" -> False\n"6W7139" -> True\n"94031K" -> True\n"jJzfmc" -> True\n"176531" -> False\n"1142R6" -> True\n"mysVde" -> True\n"hhPird" -> True\n"820918" -> False\n"58651K" -> True\n"184018" -> False\n"tlZumw" -> True\n"G08122" -> True\n"V55177" -> True\n"wxr
# "74R482" -> True
# "95F924" -> True
# "4723R4" -> True
# "185A58" -> True
# "A60183" -> True
# "84876Z" -> True
# "339131" -> False
# "621D25" -> True
# "111966" -> False
# "Wtzqvw" -> True
# "jRgxfu" -> True
# "4182K4" -> True
# "41A675" -> True
# "199781" -> False
# "M72365" -> True
# "22704U" -> True
# "12L758" -> True
# "29X352" -> True
# "0862L7" -> True
# "268208" -> False
# "5N0722" -> True
# "62B270" -> True
# "292P83" -> True
# "628U55" -> True
# "02D021" -> True
# "C67655" -> True
# "lkSgqz" -> True
# "Xmzejc" -> True
# "547773" -> False
# "185U74" -> True
# "1K1098" -> True
# "xsOgbx" -> True
# "614386" -> False
# "qsysWt" -> True
# "Irzmgj" -> True
# "198386" -> False
# "R50163" -> True
# "ncGwno" -> True
# "60050B" -> True
# "578143" -> False
# "pleoDe" -> True
# "9848V5" -> True
# "9J1638" -> True
# "458L18" -> True
# "7G3466" -> True
# "lwzJrr" -> True
# "460M56" -> True
# "946M56" -> True
# "4C5581" -> True
# "vdyeKv" -> True
# "782107" -> False
# "310720" -> False
# "vhbPwa" -> True
# "tfuvRi" -> True
# "858565" -> False
# "6W7139" -> True
# "94031K" -> True
# "jJzfmc" -> True
# "176531" -> False
# "1142R6" -> True
# "mysVde" -> True
# "hhPird" -> True
# "820918" -> False
# "58651K" -> True
# "184018" -> False
# "tlZumw" -> True
# "G08122" -> True
# "V55177" -> True
# "wxrMbq" -> True
# "8W4144" -> True
# "K64003" -> True
# "170284" -> False
# "44R655" -> True
# "459831" -> False
# "338059" -> False
# "360R83" -> True
# "06V233" -> True
# "336301" -> False
# "Ijjtgb" -> True
# "688695" -> False
# "679181" -> False
# "698196" -> False
# "budNbi" -> True
# "01566M" -> True
# "ovbDkp" -> True
# "24892D" -> True
# "Rbqdvs" -> True
# "2499Z0" -> True
# "855P18" -> True
# "53X598" -> True
# "tnxIef" -> True
# "01C217" -> True
# "1303X2" -> True
# "4F7960" -> True
# "Dwkhdd" -> True
# "75764B" -> True
# "486370" -> False
# "662896" -> False
# "Aujuwe" -> True
# "148G15" -> True
# "4140U1" -> True
# "05U263" -> True
# "216565" -> False

# %% [markdown]
# #### CF accuracy only n6

# %%
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n6.json",
    n1=0, n2=0, n3=0, n4=0, n5=30, n6=30
)
# Out:
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n6.json

# %%
# Load the new dataset (n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "17789R" ->
# "878235" ->
# "2O6105" ->
# "32564b" ->
# "260537" ->
# "900073" ->
# "53Y606" ->
# "769943" ->
# "N71805" ->
# "287245" ->
# "91493D" ->
# "815522" ->
# "614169" ->
# "931756" ->
# "267Q79" ->
# "907d38" ->
# "1637D2" ->
# "328412" ->
# "88948T" ->
# "i68938" ->
# "61n865" ->
# "407e77" ->
# "J46034" ->
# "7358T9" ->
# "0535A5" ->
# "484S55" ->
# "176565" ->
# "c19971" ->
# "2174p8" ->
# "9L3708" ->
# "3514Y2" ->
# "971Z65" ->
# "080771" ->
# "684X40" ->
# "80J404" ->
# "64086d" ->
# "1044F8" ->
# "E84970" ->
# "9P0067" ->
# "57g852" ->
# "55781h" ->
# "782G78" ->
# "269661" ->
# "260363" ->
# "1k0118" ->
# "60T472" ->
# "020500" ->
# "1620Z5" ->
# "6587n8" ->
# "31G800" ->
# "7480g0" ->
# "1R4902" ->
# "40413l" ->
# "684170" ->
# "2E4787" ->
# "2141z9" ->
# "338Q53" ->
# "334782" ->
# "766459" ->
# "19603O" ->
# "74L796" ->
# "8081w4" ->
# "308U49" ->
# "46172F" ->
# "97936Q" ->
# "8L6454" ->
# "6025h5" ->
# "19O402" ->
# "K38608" ->
# "73182O" ->
# "2J2907" ->
# "7j8604" ->
# "18z489" ->
# "294678" ->
# "5336w7" ->
# "23I504" ->
# "33M373" ->
# "7330m6" ->
# "1452E3" ->
# "3827G3" ->
# "338224" ->
# "8T9883" ->
# "6587n8" -> True
# "31G800" -> True
# "7480g0" -> True
# "1R4902" -> True
# "40413l" -> True
# "684170" -> False
# "2E4787" -> True
# "2141z9" -> True
# "338Q53" -> True
# "334782" -> False
# "766459" -> False
# "19603O" -> True
# "74L796" -> True
# "8081w4" -> True
# "308U49" -> True
# "46172F" -> True
# "97936Q" -> True
# "8L6454" -> True
# "6025h5" -> True
# "19O402" -> True
# "K38608" -> True
# "73182O" -> True
# "2J2907" -> True
# "7j8604" -> True
# "18z489" -> True
# "294678" -> False
# "5336w7" -> True
# "23I504" -> True
# "33M373" -> True
# "7330m6" -> True
# "1452E3" -> True
# "3827G3" -> True
# "338224" -> False
# "8T9883" -> True
# "190099" -> False
# "40586d" -> True
# "279i43" -> True
# "052t09" -> True
# "316941" -> False
# "5m6985" -> True
# "221693" -> False
# "396U18" -> True
# "135977" -> False
# "483406" -> False
# "54068j" -> True
# "66V546" -> True
# "4416X2" -> True
# "1y4531" -> True
# "1W3869" -> True
# "74N318" -> True
# "X14746" -> True
# "21088Q" -> True
# "627368" -> False
# "u83724" -> True
# "55855Y" -> True
# "727757" -> False
# "41K354" -> True
# "42I800" -> True
# "6259p2" -> True
# "106076" -> False
# "292O86" -> True
# "59462O" -> True
# "10C003" -> True
# "301991" -> False
# "46G970" -> True
# "654697" -> False
# "84J632" -> True
# "60o796" -> True
# "L39734" -> True
# "630324" -> False
# "70K554" -> True
# "11T762" -> True

# %% [markdown]
# #### CF accuracy n4 and n6

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4_n6.json",
    n1=0, n2=0, n3=0, n4=30, n5=0, n6=30
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4_n6.json

# %%
# Load the new dataset (n4 and n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "r94239" ->
# "129V66" ->
# "knvAht" ->
# "257L32" ->
# "9362W2" ->
# "7E7293" ->
# "732J36" ->
# "84R407" ->
# "Gbjdlw" ->
# "25285Q" ->
# "i92871" ->
# "76699H" ->
# "wjoIgd" ->
# "z67990" ->
# "429F75" ->
# "0894m3" ->
# "1F8100" ->
# "zgnvKh" ->
# "300X18" ->
# "jxktaJ" ->
# "080u47" ->
# "038l29" ->
# "3270T8" ->
# "r00396" ->
# "1Y9758" ->
# "62I065" ->
# "459I80" ->
# "I38568" ->
# "89U646" ->
# "404C34" ->
# "74165R" ->
# "akcrUw" ->
# "640m03" ->
# "39Z197" ->
# "O08077" ->
# "98516S" ->
# "88u645" ->
# "285C22" ->
# "633c95" ->
# "8271C9" ->
# "e17013" ->
# "16582O" ->
# "mnSibt" ->
# "u81645" ->
# "C27670" ->
# "zjppYl" ->
# "84569Q" ->
# "uanMdm" ->
# "qckpLl" ->
# "07N279" ->
# "stdQjn" ->
# "5d4420" ->
# "loGphp" ->
# "3l0576" ->
# "lrIftc" ->
# "608Q36" ->
# "87663Q" ->
# "526Q35" ->
# "27156p" ->
# "40j977" ->
# "91V554" ->
# "93Z053" ->
# "731o99" ->
# "3731Q6" ->
# "914O03" ->
# "01K314" ->
# "089F83" ->
# "94G953" ->
# "150A24" ->
# "ybteZh" ->
# "iyvfQc" ->
# "810b77" ->
# "6U3736" ->
# "749V51" ->
# "gbznMi" ->
# "akgIhk" ->
# "123G25" ->
# "349f12" ->
# "1B5487" ->
# "jjhemM" ->
# "1903G5" ->
# "jwEsih" ->
# "qnTbrh" ->
# "2572O3" ->
# "19K032" ->
# "dnyhVl" ->
# "539R66" ->
# "q71179" ->
# "3s9783" ->
# "133X68" ->
# "fAvaoe" ->
# "51B363" ->
# "36x433" ->
# "0G1139" ->
# "vzlDpw" ->
# "Rcuhoe" ->
# "8H2937" ->
# "kmkCud" ->
# "9982h1" ->
# "6h8074" ->
# "12091u" ->
# "6Z6768" ->
# "1865P0" ->
# "dshimY" ->
# "wKinmt" ->
# "10021i" ->
# "B25993" ->
# "tpsjlM" ->
# "6M9779" ->
# "5J2251" ->
# "1m3805" ->
# "1d8147" ->
# "236p36" ->
# "ktFunt" ->
# "5353E0" ->
# "5725N2" ->
# "jnMxmz" ->
# "444q70" ->
# "94F011" ->
# "u81645" -> True
# "C27670" -> True
# "zjppYl" -> True
# "84569Q" -> True
# "uanMdm" -> True
# "qckpLl" -> True
# "07N279" -> True
# "stdQjn" -> True
# "5d4420" -> True
# "loGphp" -> True
# "3l0576" -> True
# "lrIftc" -> True
# "608Q36" -> True
# "87663Q" -> True
# "526Q35" -> True
# "27156p" -> True
# "40j977" -> True
# "91V554" -> True
# "93Z053" -> True
# "731o99" -> True
# "3731Q6" -> True
# "914O03" -> True
# "01K314" -> True
# "089F83" -> True
# "94G953" -> True
# "150A24" -> True
# "ybteZh" -> True
# "iyvfQc" -> True
# "810b77" -> True
# "6U3736" -> True
# "749V51" -> True
# "gbznMi" -> True
# "akgIhk" -> True
# "123G25" -> True
# "349f12" -> True
# "1B5487" -> True
# "jjhemM" -> True
# "1903G5" -> True
# "jwEsih" -> True
# "qnTbrh" -> True
# "2572O3" -> True
# "19K032" -> True
# "dnyhVl" -> True
# "539R66" -> True
# "q71179" -> True
# "3s9783" -> True
# "133X68" -> True
# "fAvaoe" -> True
# "51B363" -> True
# "36x433" -> True
# "0G1139" -> True
# "vzlDpw" -> True
# "Rcuhoe" -> True
# "8H2937" -> True
# "kmkCud" -> True
# "9982h1" -> True
# "6h8074" -> True
# "12091u" -> True
# "6Z6768" -> True
# "1865P0" -> True
# "dshimY" -> True
# "wKinmt" -> True
# "10021i" -> True
# "B25993" -> True
# "tpsjlM" -> True
# "6M9779" -> True
# "5J2251" -> True
# "1m3805" -> True
# "1d8147" -> True
# "236p36" -> True
# "ktFunt" -> True
# "5353E0" -> True
# "5725N2" -> True
# "jnMxmz" -> True
# "444q70" -> True
# "94F011" -> True
# "24892S" -> True

# %% [markdown]
# ### Step 2: Multi-turn

# %%
gold_labels = load_expected_labels(file_name)
classification_prompt = build_classification_prompt(
    file_name,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "____________________________________________*_______________________________________________________" -> False
# "______________________________________________________________*_____________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "________________________________________________________________________________________*___________" -> True
# "___________________________________*________________________________________________________________" -> False
# "________________________________________________________*___________________________________________" -> True
# "______________*_____________________________________________________________________________________" -> False
# "_______________________________________________*____________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________________*___________" -> True
# "__________________________________________________________________________________________________*_" -> True
# "_______*____________________________________________________________________________________________" -> False
# "____________________________________________________________*_______________________________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "_________________________________________________________________*__________________________________" -> True
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________*___________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "_________________________________________________________________________________________*__________" -> True
# "__________________________________________________________________________________________*_________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____*_______________________________________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_____________________________________________________________________*______________________________" -> True
# "_________________________________________________________________________*__________________________" -> True
# "________________________________________*___________________________________________________________" -> False
# "_________________*__________________________________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________________*__________________" -> True
# "_____________________________*______________________________________________________________________" -> False
# "__________________________________________________________________________________________________*_" -> True
# "_______________________________________________*____________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____________________________________________*_______________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "______________________________________________________*_____________________________________________" -> True
# "________________________________________________________________________________*___________________" -> True
# "_______________________________________________________________________________________*____________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "__________________________________________*_________________________________________________________" -> False
# "_________________________*__________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "_____________________________________________________________________________*______________________" -> True
# "______________________________________________________________________________________________*_____" -> True
#
# ### Label each test input True or False:
# "___________________________________________________________________________________*________________" ->
# "________*___________________________________________________________________________________________" ->
# "_________________________________________________________________________________________________*__" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________________*_____________" ->
# "________________________________________*___________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "___________________________________________________________*________________________________________" ->
# "__________________________________________________________________________________*_________________" ->
# "___________*________________________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "____________________________________________________________________________________________*_______" ->
# "___________________*________________________________________________________________________________" ->
# "_________________________________________*__________________________________________________________" ->
# "________________________*___________________________________________________________________________" ->
# "___________________________________________________*________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "________________________________________________________________________________________________*___" ->
# "__________________________________________________________________________*_________________________" ->
# "_____________________________________________________________*______________________________________" ->
# "___________________________________*________________________________________________________________" ->
# "________________________________________________________________________________*___________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_______________*____________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__*_________________________________________________________________________________________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_________________________________*__________________________________________________________________" ->
# "____________________________________*_______________________________________________________________" ->
# "____________________*_______________________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "________________________________________*___________________________________________________________" ->
# "______________________________________________________________________________________*_____________" ->
# "_______________________________________________________*____________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "__________________________________________________________________________*_________________________" ->
# "_______________________________________________________________________________________________*____" ->
# "_______________________________________________________________________________*____________________" ->
# "_________________________________________________________________________*__________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________*______________________________________________________________________________________" ->

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# The rule is:
#
# - Count the number of underscores ("_") after the asterisk ("*").
# - If there are 20 or fewer underscores after the asterisk, label as False.
# - If there are more than 20 underscores after the asterisk, label as True.
#
# In other words, if the asterisk is positioned such that there are more than 20 underscores to its right (including cases where it's at the far right), the label is True. Otherwise, it is False.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# The specific feature I was looking for in each input was the position of the asterisk * relative to the length of the string. My decision process was:
#
# - If the asterisk was positioned toward the far right end of the string (specifically, within the last 20% of the string), I labeled it True.
# - If the asterisk was positioned anywhere else (i.e., the first 80% from the left), I labeled it False.
#
# So, I was classifying based on whether the asterisk appeared in the rightmost 20% of the characters in the string.
# --------------------
# I was looking for the position of the asterisk ("*") in each input string.
#
# **Decision process:**
# - Each input is a string of underscores and exactly one asterisk.
# - If the asterisk is near the right end of the string (specifically, within the last 20 characters or so), the label is **True**.
# - If the asterisk is elsewhere (not near the right end), the label is **False**.
#
# In other words, the input is **True** if the asterisk appears close to the rightmost side of the string; otherwise, it's **False**.
# --------------------
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.
# --------------------

# %% [markdown]
# ## Experiments N = 1000, n = 500

# %% [markdown]
# ### Setting up the experiment

# %%
toy_rule_path = os.path.join(project_root, "notebooks", "exploratory", "long_strings_one_cap")

file_name = "marker_dataset_N=1000_case1_n=2.json"
generate_marker_dataset(
    num_samples=500,
    test_samples=500,
    output_folder=toy_rule_path,
    file_name=file_name,
    N=1000,
    marker_character="*",
    filler_character="_",
    case_mode=1,     # false = left‑only marker; true = right‑only
)
dataset_path = os.path.join(toy_rule_path, file_name)
# Out:
# Saved 500 train and 500 test samples to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/long_strings_one_cap/marker_dataset_N=1000_case1_n=2.json

# %% [markdown]
# ### Step 1. Classification

# %%
gold_labels = load_expected_labels(dataset_path)
intro = "You are given strings consisting of _ characters with possibly one * character. Your task is to classify each string as True or False based on a specific rule."
question = "Based on the training examples, determine if each test string should be classified as True or False"
instructions = "For each test example, respond with just True or False on the same line after the arrow."

classification_prompt = build_classification_prompt(
    dataset_path,
    intro=intro,
    question=question,
    instructions=instructions,
)

# %%
# Build the model/temperature‑specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels,
    label_set=["TRUE", "FALSE"],
    num_runs=4
)
print(results)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[77], line 5
#
#       2 inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)
#
#       4 # Evaluate accuracy (gold_labels loaded elsewhere)
#
# ----> 5 results = evaluate_classification_accuracy(
#
#       6     prompt=classification_prompt,
#
#       7     inference_fn=inference_fn,
#
#       8     expected_labels=gold_labels,
#
#       9     label_set=["TRUE", "FALSE"],
#
#      10     num_runs=4
#
#      11 )
#
#      12 print(results)
#
#
#
# File ~/Documents/GitHub/OE-test/code/evals_utils.py:95, in evaluate_classification_accuracy(prompt, inference_fn, expected_labels, label_set, num_runs)
#
#      92 all_outs = []
#
#      94 for _ in range(num_runs):
#
# ---> 95     out = inference_fn(prompt)
#
#      96     all_outs.append(out)
#
#      97     preds = flexible_parse_predictions(out, n, label_set)
#
#
#
# File ~/Documents/GitHub/OE-test/code/inference_utils.py:126, in make_inference_fn.<locals>.inference_fn(prompt)
#
#     125 def inference_fn(prompt: str) -> str:
#
# --> 126     return asyncio.run(_chat_once(prompt))
#
#
#
# File ~/Documents/GitHub/OE-test/code/.venv/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#
#      28 task = asyncio.ensure_future(main)
#
#      29 try:
#
# ---> 30     return loop.run_until_complete(task)
#
#      31 finally:
#
#      32     if not task.done():
#
#
#
# File ~/Documents/GitHub/OE-test/code/.venv/lib/python3.11/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#
#      90     f._log_destroy_pending = False
#
#      91 while not f.done():
#
# ---> 92     self._run_once()
#
#      93     if self._stopping:
#
#      94         break
#
#
#
# File ~/Documents/GitHub/OE-test/code/.venv/lib/python3.11/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#
#     108     heappop(scheduled)
#
#     110 timeout = (
#
#     111     0 if ready or self._stopping
#
#     112     else min(max(
#
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#
#     114     else None)
#
# --> 115 event_list = self._selector.select(timeout)
#
#     116 self._process_events(event_list)
#
#     118 end_time = self.time() + self._clock_resolution
#
#
#
# File ~/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#
#     564 ready = []
#
#     565 try:
#
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#
#     567 except InterruptedError:
#
#     568     return ready
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 2. Articulation

# %%
# natural language articulation
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "What is the exact rule that determines whether a string is classified as True or False?"
instructions = "Express the rule in clear, concise natural language that would enable someone else to correctly classify new examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the examples in detail.
#
# ### Step 1: Observe the pattern
#
# All strings are of the same length (assume N), containing underscores and at most one asterisk (`*`). The `*` can be at any position.
#
# For convenience, let's call the position of `*` as `pos`, where indexing starts at 0.
#
# Let’s look at some True and False examples, count the number of underscores before the asterisk, and see if there’s a pattern:
#
# #### Examples (with counts)
# - "______________________________________________________________*_____________________________________" -> True
#   (There are 62 underscores before the *, then the * at position 62)
#
# - "___________________*________________________________________________________________________________" -> False
#   (19 underscores before the *, * at position 19)
#
# - "________________________________________________________________________________________*___________" -> True
#   (90 underscores before *, * at position 90)
#
# - "___________________________________________________*________________________________________________" -> True
#   (51 underscores before *, * at position 51)
#
# - "______________*_____________________________________________________________________________________" -> False
#   (14 underscores before *, * at position 14)
#
# - "__________________*_________________________________________________________________________________" -> False
#   (18 underscores before *, * at position 18)
#
# - "_______________________________________________________________________________________________*____" -> True
#   (* at position 94)
#
# - "_______*____________________________________________________________________________________________" -> False
#   (* at position 7)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# - "_______________________________________________________________________________*____________________" -> True
#   (* at position 79)
#
# ---
#
# #### Step 2: Try parity (even/odd)
#
# Let me write down a few more with their `pos` and the result.
#
# | Position of * | Result |
# |---------------|--------|
# | 62            | True   |
# | 19            | False  |
# | 90            | True   |
# | 51            | True   |
# | 14            | False  |
# | 18            | False  |
# | 94            | True   |
# | 7             | False  |
# | 60            | True   |
# | 42            | False  |
# | 79            | True   |
#
# If we look at the position numbers for True:
#
# 62 (True) — even
# 90 (True) — even
# 51 (True) — odd
# 94 (True) — even
# 60 (True) — even
# 79 (True) — odd
#
# False:
#
# 19 (False) — odd
# 14 (False) — even
# 18 (False) — even
# 7 (False) — odd
# 42 (False) — even
#
# So parity doesn’t match the classification.
#
# #### Step 3: Try divisibility
#
# Let’s focus on the True examples:
#
# 62, 90, 51, 94, 60, 79
#
# Try dividing by 3:
#
# - 62 / 3 = 20.666...
# - 90 / 3 = 30 (divisible)
# - 51 / 3 = 17 (divisible)
# - 94 / 3 = 31.333...
# - 60 / 3 = 20 (divisible)
# - 79 / 3 = 26.333...
#
# So, not divisibility by 3.
#
# ---
#
# #### Step 4: Try the last digit
#
# True positions: 62, 90, 51, 94, 60, 79
# Last digits: 2, 0, 1, 4, 0, 9 — No pattern.
#
# ---
#
# #### Step 5: Try position >= half the length
#
# Suppose the length N is 100 (approximate).
#
# True: 62, 90, 51, 94, 60, 79 — all above 50, except 51.
#
# False: 19, 14, 18, 7, 42 — all below 50.
#
# But 42 (False) and 51 (True) are close to 50.
#
# Let’s test this with more examples.
#
# - "_____________________________________________________________________*______________________________" -> True
#   (* at position 70)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# So, maybe the rule is "* must be at position 50 or higher?"
#
# But then 51 is True, 42 is False, 51 is True.
#
# Let’s check if position >= 50 is the rule.
#
# Is there any False with position >= 50?
# Is there any True with position < 50?
#
# Looking at a few more:
#
# - "___________________________________*________________________________________________________________" -> False
#   (* at position 35)
#
# - "___________________________________________________*________________________________________________" -> True
#   (* at position 51)
#
# - "______________________________________________________*_____________________________________________" -> True
#   (* at position 54)
#
# - "____________________________________________*_______________________________________________________" -> False
#   (* at position 44)
#
# - "________________________________________________________________________________*___________________" -> True
#   (* at position 88)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# No True examples with * before position 50.
#
# No False examples with * at position >= 50.
#
# Let’s check for position = 50.
#
# - Any with * at position 50? Let’s check.
#
# I don't see one, but the pattern seems clear:
#
# ### **THE RULE**
#
# > The string is classified as **True** if and only if the asterisk (*) occurs at position 50 or greater (i.e., in the second half of the string, assuming positions are numbered starting at 0).
# > Otherwise, it is classified as False.
#
# **In natural language:**
#
# > The string is classified as True if the asterisk is in the right half of the string (positions 50 and above), and False if it is in the left half (positions 0 through 49).
#
# ---
#
# ### **Final Rule**
#
# > **A string is classified as True if and only if the asterisk (*) is at position 50 or greater (i.e., in the right half of the string). Otherwise, it is classified as False.**
#
# ---
#
# **This will enable someone to correctly classify new examples.**
#
# — Choice 2 (openai/gpt-4.1) —
# Let’s analyze the examples to find the rule.
#
# ### Step 1: Pattern Recognition
#
# Each string is a long sequence of `_` (underscores), with exactly one `*` somewhere in the string.
#
# Let’s look at the **positions** of `*` in the strings, and compare the result.
#
# #### Example:
# "______________________________________________________________*_____________________________________" -> True
# Let's count how many underscores are **before** the `*`:
#
# - There are 62 underscores before the `*`, then 37 after.
#
# #### Example:
# "____________________________________________*_______________________________________________________" -> False
# - 44 underscores before the `*`, then 55 after.
#
# #### Example:
# "________________________________________________________________________________________*___________" -> True
# - 88 underscores before the `*`, then 11 after.
#
# Now, let's try a few more.
#
# #### Example:
# "___________________*________________________________________________________________________________" -> False
# - 19 underscores before, lots after.
#
# #### Example:
# "_____________________________________________________________________*______________________________" -> True
# - 69 underscores before, 30 after.
#
# Let's try to find a pattern.
#
# ### Step 2: Hypothesis
#
# It looks like the **classification is True if the `*` appears in the right half of the string**, and False if in the left half.
#
# Let's test this:
#
# #### "___________________________________________________*________________________________________________" -> True
# - Let's count underscores before the `*`: 51 before, 48 after = Total 100 (with the `*`, 100 underscores + 1 `*` = 101 chars).
# - So, in this case, the `*` is at position 52 (0-based index 51).
#   Since 101/2 = 50.5, positions 0-50 would be the left half, 51-100 the right half.
#   The `*` is at position 51, which is the first index of the right half.
#
# #### "___________________________________*________________________________________________________________" -> False
# - 35 underscores before, 64 after. Position of `*` is 36 (0-based index 35), total 100 (plus 1 = 101).
#   101/2 = 50.5, so left half is 0-50, right half is 51-100.
#   Position 35 is in the left half → False.
#
# #### "________________________________________________________*___________________________________________" -> True
# - 56 underscores before, 43 after. `*` at position 57 (0-based 56), 56 > 50.5, so right half → True.
#
# #### "_______________________________________________*____________________________________________________" -> False
# - 47 underscores before, 52 after. `*` at position 48 (0-based 47), which is left half → False.
#
# #### "_______________________________________________________________________________________________*____" -> True
# - 95 underscores before, 4 after. `*` at position 96 (0-based 95), clearly right half → True.
#
# #### "_______*____________________________________________________________________________________________" -> False
# - 7 underscores before, 92 after. `*` at position 8 (0-based 7), left half → False.
#
# ### Step 3: Edge Cases
#
# If the string length is odd, which half is the `*` in?
#
# For a string of length N, positions 0 to (N//2)-1 are the left half, positions N//2 to N-1 are the right half.
#
# If `*` is at index ≥ N//2, then True, else False.
#
# Let's check:
#
# - For N=101, N//2 = 50. So indexes 0-49 left, 50-100 right.
#
# But in above calculations, it seemed to use 0-50 left, 51-100 right. Let's check carefully.
#
# Wait, let's check:
#
# "___________________________________________________*________________________________________________" -> True
# - 51 underscores before, so `*` at position 52 (0-based 51). So for a 101 character string (100 underscores + 1 `*`), the `*` is at index 51.
# - 101//2 = 50, so index 0-49 is left, 50-100 is right. `*` at 51, so in right half. True.
#
# So the rule is:
#
# > If the position of the `*` in the string (0-based index) is **greater than or equal to** half the length of the string (using integer division), the classification is True. Otherwise, False.
#
# ### Step 4: Express Rule in Natural Language
#
# **Rule:**
#
# > A string is classified as True **if and only if** the `*` character is in the right half of the string (that is, if its position is greater than or equal to half the string's length, counting from zero). Otherwise, the string is classified as False.
#
# Or, more concisely:
#
# > If the `*` appears at or beyond the halfway point in the string, classify as True; otherwise, classify as False.
#
# ---
#
# **Summary Table:**
#
# - Let N = length of the string
# - Let P = 0-based index of `*`
# - If `P >= N//2`, then True; otherwise, False.
#
# ---
#
# **Final concise rule:**
#
# > The string is classified as True if the `*` is in the right half of the string (at or after the halfway point); otherwise, it is False.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's analyze the examples to deduce the rule.
#
# ### Observations
#
# - Each string is made up of underscores ('_') and at most one asterisk ('*').
# - The classification is either True or False.
# - The position of '*' seems to be the only variable.
#
# Let's try to find a pattern based on the position of '*'.
#
# #### Step 1: Check if the number of underscores before or after the '*' matters.
#
# Let's pick a few True and False examples and count the number of underscores before the '*'.
#
# #### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`:
#    - '*' at position 62 (zero-based index).
# 2. `"________________________________________________________________________________________*___________"`:
#    - '*' at position 90.
# 3. `"________________________________________________________*___________________________________________"`:
#    - '*' at position 56.
# 4. `"___________________________________________________*________________________________________________"`:
#    - '*' at position 51.
# 5. `"_______________________________________________________________________________________________*____"`:
#    - '*' at position 94.
#
# #### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`:
#    - '*' at position 44.
# 2. `"___________________*________________________________________________________________________________"`:
#    - '*' at position 19.
# 3. `"___________________________________*________________________________________________________________"`:
#    - '*' at position 35.
# 4. `"______________*_____________________________________________________________________________________"`:
#    - '*' at position 14.
# 5. `"_______________________________________________*____________________________________________________"`:
#    - '*' at position 47.
#
# #### Step 2: Try dividing the string into two halves
#
# Let's check the length of the strings:
#
# - Let's count the number of characters in a sample string:
#   For example, `"___________________________________________________*________________________________________________"`
#   Let's count. There are 51 underscores before '*', 1 '*', and 51 underscores after. That's 103 characters.
#
# - Similarly, another string:
#   `"______________________________________________________________*_____________________________________"`
#   Let's count: 62 underscores before, 1 '*', 37 underscores after: 62+1+37 = 100 characters.
#
# So the length may vary, but it seems most are around 100.
#
# #### Step 3: Is the rule based on the position of '*' in the second half?
#
# Let's check:
#
# - For the True examples above, the '*' is at position 62 (of 100), 90 (of 100), 56 (of 100), 51 (of 103), 94 (of 100).
# - For the False examples, 44 (of 100), 19 (of 100), 35 (of 100), 14 (of 100), 47 (of 100).
#
# Looks like for True, the '*' is in the second half (i.e., position > n/2).
#
# Let's check this for more examples.
#
# #### Test the hypothesis
#
# For string of length N, is the rule:
#
# > The string is classified as True **if and only if the '*' is positioned AFTER the midpoint of the string (i.e., index > N//2)**.
#
# Let's test with a few examples:
#
# - `"___________________________________________________*________________________________________________"`
#   - 51 underscores before, 1 '*', 51 underscores after.
#   - Length: 51+1+51 = 103.
#   - '*' at position 51 (0-based).
#   - Midpoint: 103 // 2 = 51.
#   - So, position == midpoint, and it's True.
#
# But the rule says "after the midpoint", so maybe it's position >= midpoint?
#
# Let's check for position == midpoint in other examples.
#
# - `"___________________________________________________*________________________________________________"` is True, '*' at 51 (for 103), midpoint = 51.
#
# - `"_______________________________________________*____________________________________________________"`
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 47+1+52 = 100.
#   - '*' at position 47, midpoint = 50.
#   - 47 < 50, and it's False.
#
# - `"______________________________________________________________*_____________________________________"`:
#   - 62 underscores before, 1 '*', 37 underscores after.
#   - Length: 100.
#   - '*' at position 62, midpoint = 50.
#   - 62 > 50, is True.
#
# So, looks like the rule is:
#
# > The string is classified as True if and only if the '*' is positioned at or after the midpoint of the string (i.e., index >= length // 2).
#
# Let's check for position == midpoint for even-length string.
#
# - For 100 length, midpoint = 50. Is there an example with '*' at 50?
# - `"___________________________________________________*________________________________________________"` is 103 length, midpoint 51, '*' at 51, True. So position == midpoint is True.
#
# Let's test with:
#
# - `"_______________________________________________*____________________________________________________"`:
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 100, midpoint = 50, '*' at 47, so 47 < 50, and it's False.
#
# - `"______________________________________________________*_____________________________________________"`:
#   - 54 underscores before, 1 '*', 45 underscores after.
#   - Length: 54+1+45=100, '*' at 54, 54 > 50, True.
#
# So, the rule is:
#
# ---
#
# ### **Rule:**
#
# > A string is classified as **True** if and only if the asterisk ('*') appears at or after the halfway point of the string (that is, if its index is greater than or equal to half the length of the string, using zero-based indexing). Otherwise, it is classified as **False**.
#
# **In other words:**
# - Compute the length of the string, `N`.
# - If the index of '*' is **greater than or equal to** `N // 2`, classify as True.
# - Otherwise, classify as False.
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the examples to find the **rule**.
#
# Each string is made up of underscores (`_`), possibly with a single asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# Let's extract the position of `*` in a few examples and see if we spot a pattern.
#
# #### Step 1: Count the position of `*` (0-based)
#
# For a string like:
# "__________*_________________________________________________________________________________________"
#
# Let's count:
# - 10 underscores, then `*`, so `*` is at position 10.
#
# Let's do this for a few:
#
# | String | Position of `*` | Label |
# |--------|-----------------|-------|
# | "____________________________________________*_______________________________________________________" | 44 | False |
# | "______________________________________________________________*_____________________________________" | 62 | True |
# | "___________________*________________________________________________________________________________" | 19 | False |
# | "________________________________________________________________________________________*___________" | 90 | True |
# | "___________________________________*________________________________________________________________" | 35 | False |
# | "________________________________________________________*___________________________________________" | 56 | True |
# | "______________*_____________________________________________________________________________________" | 14 | False |
# | "___________________________________________________*________________________________________________" | 51 | True |
# | "_______________________________________________________________________________________________*____" | 95 | True |
#
# #### Step 2: Look for a pattern
#
# Let's see if the **position** alone is enough. Let's see if there's a modulo pattern or even/odd pattern.
#
# Let's check a few more:
#
# False examples:
# - 44 (False)
# - 19 (False)
# - 35 (False)
# - 14 (False)
# - 10 (False)
# - 62 (True)
# - 90 (True)
# - 56 (True)
# - 51 (True)
# - 95 (True)
#
# #### Step 3: Try Even/Odd positions
#
# - 44 (even) → False
# - 19 (odd) → False
# - 35 (odd) → False
# - 14 (even) → False
# - 62 (even) → True
# - 90 (even) → True
# - 56 (even) → True
# - 51 (odd) → True
# - 95 (odd) → True
#
# So, even/odd is not the deciding factor.
#
# #### Step 4: Compare to length of string
#
# Let's check if the position of `*` is in the first half or second half.
#
# Check string length:
#
# - Let's take one string and count its length:
#   - "____________________________________________*_______________________________________________________"
#     Count underscores: before the star: 44
#     Add the `*`: 45
#     After the star: 55
#     Total: 44+1+55 = **100**
#
# Aha, so the strings are length 100.
#
# So, is the rule about which half the `*` is in?
#
# - "____________________________________________*_______________________________________________________"
#   - `*` at 44 (positions 0-99, so index 44 is the 45th character, so in the first half) → False
# - "______________________________________________________________*_____________________________________"
#   - `*` at 62 → second half (index 50+ is second half), so index 62 is after halfway → True
#
# So, let's formalize:
#
# **If the `*` is in the second half (positions 50-99), label is True. Otherwise, False.**
#
# Let's check edge cases:
#
# - If `*` is at position 49 (the 50th character), is that first or second half?
#   - 0-49: first half (positions 0-49, 50 characters)
#   - 50-99: second half (positions 50-99, 50 characters)
#
# Check one at position 49:
#
# Let's search for a string with the asterisk at position 49:
#
# - "_________________________________________________________________________________________________*_"
#   How many underscores before the star? Let's count.
#
# Alternatively, find a True example at 50.
#
# - "___________________________________________________*________________________________________________"
#   - Let's count: before the star: 51 underscores, so position 51.
#
# - This is labeled True.
#
# So, position 51 → True.
#
# Try position 49:
#
# - "_________________________________________________*__________________________________________________"
#   - Before the star: 49 underscores, position 49.
#   - Labeled False.
#
# So, **positions 0-49 → False, positions 50-99 → True**.
#
# #### Step 5: Restate the rule
#
# **Rule:**
# A string is classified as True if and only if the asterisk appears at position 50 or later (i.e., among the last 50 characters of the string). Otherwise, it is classified as False.
#
# **Natural language version:**
#
# > The string is classified as True if the asterisk `*` is in the second half of the string (that is, at position 50 or later, counting from 0). Otherwise, it is classified as False.
#
# ---
#
# **Short Rule:**
# > "True if the asterisk is at position 50 or greater; otherwise, False."
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the examples for a clear, concise rule.
#
# First, **every string contains exactly one `*`**, the rest are `_`.
#
# To figure out the rule, let's look for patterns. Consider the **position** of the `*` in the string.
#
# Let's check the first few "True" examples and their positions (counting from 0):
#
# #### True examples and their positions:
# 1. `"______________________________________________________________*_____________________________________"`
#    Position: 62
#
# 2. `"________________________________________________________________________________________*___________"`
#    Position: 87
#
# 3. `"________________________________________________________*___________________________________________"`
#    Position: 56
#
# 4. `"___________________________________________________*________________________________________________"`
#    Position: 51
#
# 5. `"_______________________________________________________________________________________________*____"`
#    Position: 95
#
# Let's check also some "False" examples:
#
# #### False examples and their positions:
# 1. `"____________________________________________*_______________________________________________________"`
#    Position: 44
#
# 2. `"___________________*________________________________________________________________________________"`
#    Position: 19
#
# 3. `"___________________________________*________________________________________________________________"`
#    Position: 35
#
# 4. `"______________*_____________________________________________________________________________________"`
#    Position: 14
#
# ---
#
# Let me try to find if there's an arithmetic pattern.
#
# #### Let's check parity (even/odd):
#
# - 62 (True) -> even
# - 87 (True) -> odd
# - 56 (True) -> even
# - 51 (True) -> odd
# - 95 (True) -> odd
#
# So, it's not parity.
#
# #### Let's try mod 5:
#
# - 62 % 5 = 2
# - 87 % 5 = 2
# - 56 % 5 = 1
# - 51 % 5 = 1
# - 95 % 5 = 0
#
# Not a clear pattern.
#
# #### Let's check if the position is in the second half of the string
#
# Let's check the length of the string. For the first True example:
# - `"______________________________________________________________*_____________________________________"`
#   Length: 101
#   `*` at position 62
#
# - 62/101 ≈ 0.613 (so in the second half)
#
# Now let's check the first False example:
# - `"____________________________________________*_______________________________________________________"`
#   Length: 101
#   `*` at position 44
#   44/101 ≈ 0.436 (so in the first half)
#
# Let's try a few more:
#
# #### Another True:
# - `"________________________________________________________*___________________________________________"`
#   Length: 101
#   `*` at position 56
#   56/101 ≈ 0.554
#
# #### Another False:
# - `"___________________*________________________________________________________________________________"`
#   Length: 101
#   `*` at position 19
#   19/101 ≈ 0.188
#
# #### Another True:
# - `"___________________________________________________*________________________________________________"`
#   Length: 101
#   `*` at position 51
#   51/101 ≈ 0.505
#
# #### Another False:
# - `"______________*_____________________________________________________________________________________"`
#   Length: 101
#   `*` at position 14
#   14/101 ≈ 0.139
#
# #### Another True:
# - `"__________________________________________________________________________________________________*_"`
#   Length: 101
#   `*` at position 99
#   99/101 ≈ 0.980
#
# #### Another False:
# - `"_______*____________________________________________________________________________________________"`
#   Position: 7
#   7/101 ≈ 0.069
#
# ---
#
# It seems that **if the asterisk is in the first half of the string, the answer is False; if it's in the second half, the answer is True**.
#
# But what about position 50 (out of 101)? Is it first or second half?
#
# Let's check position 50:
#
# - 101 / 2 = 50.5
#
# So, positions 0-50 are the first half (0-50 inclusive), and positions 51-100 are the second half (51-100 inclusive).
#
# Let's check if a string with `*` at position 50 is present and its label.
#
# Let me look for a string with `*` at position 50.
#
# - `"___________________________________________________*________________________________________________"`
#   Position: 51
#   This is True.
#
# What about position 50?
#
# - No example given.
#
# But for position 51, it's True; for position 44, it's False.
#
# So, it seems the rule is:
#
# > **A string is classified as True if and only if the `*` is in the second half of the string (i.e., its position is greater than or equal to half the length of the string, rounding up). Otherwise, it is classified as False.**
#
# Or, more concisely:
#
# ---
#
# ## Rule
#
# **A string is classified as True if the asterisk `*` appears at a position greater than or equal to half the total length of the string (counting positions from 0). Otherwise, the string is classified as False.**
#
# ---
#
# If the string has length N, and the position of `*` is P (starting from 0), then:
#
# - If P >= N/2, the string is True.
# - If P < N/2, the string is False.

# %%
# algorithm
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "If you had to write an algorithm to classify these strings, what would be the decision rule?"
instructions = "Provide only a clear declarative statement of the rule. No explanations, no reasoning steps, no analysis of examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 2 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 3 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores (_) after the * is a multiple of 8.
#
# — Choice 4 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk (*) is a multiple of 8.
#
# — Choice 5 (openai/gpt-4.1) —
# The string is classified as True if and only if there are more underscores (_) after the asterisk (*) than before it.

# %%
# cf
intro = "As an expert in pattern recognition, analyze these classified strings to determine the precise rule that differentiates True from False examples."
question = "State the rule that determines these classifications and explain how changing specific aspects of a string would alter its classification."
instructions = "Be specific and precise in your description."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the strings and their classifications to determine the rule.
#
# ## Observations
#
# - Each string is a sequence of underscores (`_`) with a single asterisk (`*`) somewhere in the string.
# - The only difference between strings is the position of the asterisk.
#
# Let's try to find a pattern:
#
# ### Compare False and True Examples
#
# #### False Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "____________________________________________*_______________________________________________________" | 44         | 102    |                |
# | "___________________*________________________________________________________________________________" | 19         | 97     |                |
# | "__________________*_________________________________________________________________________________" | 18         | 98     |                |
# | "__________*_________________________________________________________________________________________" | 11         | 98     |                |
# | "______________*_____________________________________________________________________________________" | 15         | 98     |                |
# | "___________________________________*________________________________________________________________" | 35         | 98     |                |
# | "_______*____________________________________________________________________________________________" | 7          | 98     |                |
# | "________________________________________*___________________________________________________________" | 42         | 98     |                |
# | "____________________________________*_______________________________________________________________" | 37         | 98     |                |
# | "_____________________________________________*______________________________________________________" | 45         | 98     |                |
#
# #### True Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "______________________________________________________________*_____________________________________" | 62         | 98     |                |
# | "________________________________________________________*___________________________________________" | 56         | 98     |                |
# | "________________________________________________________________________________________*___________" | 86         | 98     |                |
# | "___________________________________________________*________________________________________________" | 51         | 98     |                |
# | "_______________________________________________________________________________________________*____" | 95         | 98     |                |
# | "__________________________________________________________________________________________________*_" | 98         | 100    |                |
# | "_________________________________________________________________*__________________________________" | 65         | 98     |                |
# | "_____________________________________________________________________*______________________________" | 69         | 98     |                |
# | "_________________________________________________________________________*__________________________" | 74         | 98     |                |
#
# Let's try to find a mathematical relationship.
#
# ## Hypothesis: Is it about position relative to string length?
#
# ### Let's calculate:
#
# For string of length L, and asterisk at position p (0-based), what is the rule?
#
# Look at a True example:
# - Length: 98, * at 62 => 62/98 ≈ 0.632
# - Length: 98, * at 56 => 56/98 ≈ 0.571
# - Length: 98, * at 86 => 86/98 ≈ 0.877
# - Length: 98, * at 51 => 51/98 ≈ 0.520
#
# A False example:
# - Length: 98, * at 19 => 19/98 ≈ 0.194
# - Length: 98, * at 15 => 15/98 ≈ 0.153
# - Length: 98, * at 7 => 7/98 ≈ 0.071
# - Length: 98, * at 35 => 35/98 ≈ 0.357
# - Length: 98, * at 42 => 42/98 ≈ 0.429
#
# It seems True examples have * in the second half of the string, False in the first half.
#
# Test at halfway:
#
# - 98/2 = 49
# - If * at index >= 49, True; else False.
#
# Check some True cases:
# - 51: True (>=49)
# - 56: True
# - 62: True
# - 69: True
# - 74: True
# - 86: True
# - 95: True
#
# Check some False cases:
# - 35: False (<49)
# - 42: False
# - 44: False
# - 45: False
# - 37: False
#
# But what about boundary cases? Let's check if 49 is right.
#
# Try a string of length 98, * at 49:
# - Is there such a case? None in the examples.
#
# Try at 51: True.
# Try at 45: False.
#
# So the rule seems to be:
# **The example is True if and only if the asterisk appears in the second half of the string, i.e., its index is greater than or equal to half the length of the string (rounded up if length is odd).**
#
# Or, more mathematically:
#
# Let L be the length of the string, and p the 0-based index of `*`.
# - If p ≥ L/2, then True.
# - If p < L/2, then False.
#
# ### Test on a different length:
#
# "__________________________________________________________________________________________________*_" -> True
# Length: 100, p=98
#
# 100/2 = 50, 98>50, so True.
#
# "___________________*________________________________________________________________________________" -> False
# Length: 97, p=19
#
# 97/2 = 48.5, so p=19<48.5, False.
#
# ## Rule (Precise, as requested):
#
# > **A string is classified as True if and only if the asterisk `*` occurs at position p (0-based index) such that p ≥ (length of string) / 2. Otherwise, it is classified as False.**
#
# ## How changing aspects of a string alters the classification
#
# - Moving the asterisk left (to a lower index) can change True to False if it crosses the halfway point.
# - Moving the asterisk right (to a higher index) can change False to True if it crosses the halfway point.
# - Changing the length of the string shifts the halfway point; to remain True, the asterisk must stay at or past the new midpoint.
#
# ## Example
#
# - String: Length 100, asterisk at 49 → 49<50 → False.
# - Move asterisk to 50: 50=50 → True.
# - String: Length 99, asterisk at 49 → 49<49.5 → False.
# - Asterisk at 50: 50>49.5 → True.
#
# ---
#
# **In summary:**
# > The classification is True if and only if the asterisk is in the right half of the string (including the central position when the length is even). Otherwise, it is False.
#
# — Choice 2 (openai/gpt-4.1) —
# Let's analyze the examples systematically.
#
# Each string is a sequence of underscores (`_`) with a single asterisk (`*`) at some position. The task is to find what distinguishes the `True` cases from the `False` ones based on the position of the `*`.
#
# Let's break down the approach:
#
# ## 1. **Find the pattern in position**
#
# Let's pick a few strings and count the number of underscores before the asterisk (`*`). This is the index of the `*` (zero-based).
#
# We'll do this for both `True` and `False` examples.
#
# ### **True Examples:**
# - "______________________________________________________________*_____________________________________"
#   - Number of `_` before `*`: 62
#
# - "________________________________________________________________________________________*___________"
#   - `_` before `*`: 90
#
# - "________________________________________________________*___________________________________________"
#   - `_` before `*`: 56
#
# - "___________________________________________________*________________________________________________"
#   - `_` before `*`: 51
#
# - "_______________________________________________________________________________________________*____"
#   - `_` before `*`: 95
#
# - "__________________________________________________________________________________________________*_"
#   - `_` before `*`: 98
#
# - "_________________________________________________________________*__________________________________"
#   - `_` before `*`: 65
#
# - "_____________________________________________________________________*______________________________"
#   - `_` before `*`: 69
#
# - "_________________________________________________________________________*__________________________"
#   - `_` before `*`: 74
#
# - "_________________________________________________________________________________*__________________"
#   - `_` before `*`: 85
#
# - "______________________________________________________________________________*_____________________"
#   - `_` before `*`: 78
#
# - "______________________________________________________*_____________________________________________"
#   - `_` before `*`: 54
#
# - "_______________________________________________________________________________________*____________"
#   - `_` before `*`: 91
#
# ### **False Examples:**
# - "____________________________________________*_______________________________________________________"
#   - `_` before `*`: 44
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "___________________________________*________________________________________________________________"
#   - `_` before `*`: 35
#
# - "______________*_____________________________________________________________________________________"
#   - `_` before `*`: 14
#
# - "_______________________________________________*____________________________________________________"
#   - `_` before `*`: 47
#
# - "_______*____________________________________________________________________________________________"
#   - `_` before `*`: 7
#
# - "__________*_________________________________________________________________________________________"
#   - `_` before `*`: 10
#
# - "____________________________________*_______________________________________________________________"
#   - `_` before `*`: 36
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "________________________________________*___________________________________________________________"
#   - `_` before `*`: 40
#
# - "_________________________________*__________________________________________________________________"
#   - `_` before `*`: 33
#
# - "_____________________________________________*______________________________________________________"
#   - `_` before `*`: 45
#
# - "__________________________________________*_________________________________________________________"
#   - `_` before `*`: 42
#
# - "_________________________*__________________________________________________________________________"
#   - `_` before `*`: 25
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "____*_______________________________________________________________________________________________"
#   - `_` before `*`: 4
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# ---
#
# ## 2. **Look for a threshold**
#
# Let me compare the highest index in False with the lowest in True.
#
# - Highest False index: Let's see (from above): 47 ("_______________________________________________*____________________________________________________")
# - Lowest True index: 51 ("___________________________________________________*________________________________________________")
#
# So, it appears that:
#
# - All **False** examples have the asterisk at index **47 or below**.
# - All **True** examples have the asterisk at index **51 or above**.
#
# Check the gap:
# - 47 (False), next is 51 (True). There is a gap of 48, 49, 50 — are there any examples at these positions? Doesn't look like it from the data.
#
# So, the cutoff appears to be at **index 48**: if the asterisk is at position **48 or higher**, it's True; if at **47 or lower**, it's False.
#
# But note: There may be a small ambiguity in the border (since there are no strings at 48, 49, or 50), but with the current data, the rule is:
#
# ---
#
# ## **Rule:**
#
# > **A string is classified as `True` if and only if the asterisk (`*`) is positioned at or after index 51 (i.e., the 52nd character or later, counting from 0). Otherwise, it is classified as `False`.**
#
# Or more generally, based on the examples:
# - **If the number of underscores before the `*` is 51 or greater, then the string is True.**
# - **If the number of underscores before the `*` is 47 or fewer, then the string is False.**
# - **No examples are given for positions 48, 49, or 50.**
#
# ---
#
# ## **How changes affect classification:**
#
# - **If you move the `*` rightward across the 51st position (i.e., from 47 to 51), the classification switches from `False` to `True`.**
# - **If you move the `*` leftward across the 51st position, it switches from `True` to `False`.**
# - **The actual content of the string (underscores or asterisk) is otherwise irrelevant; only the position of the asterisk matters.**
#
# ---
#
# ### **Summary Table:**
#
# | Position of `*` | Classification |
# |-----------------|----------------|
# | 0-47            | False          |
# | 51+             | True           |
# | 48-50           | (No examples)  |
#
# ---
#
# **In summary:**
# > The classification is determined solely by the position of the asterisk: if it is at index 51 or greater, the string is `True`; otherwise, it is `False`. Changing the position of the asterisk across this boundary will flip the classification.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's break down the pattern in the classified strings:
#
# - Each string is made up of underscores `_` and exactly **one asterisk `*`**.
# - The `*` is always embedded somewhere in the string.
# - Each string is of the **same length** (99 characters: 98 underscores and 1 asterisk).
#
# Let’s analyze the positions of the asterisk for **True** and **False** examples:
#
# #### Step 1: Find the position of `*` in the string
#
# Let's number the positions from **0** (leftmost) to **98** (rightmost).
#
# Let’s manually check some examples:
#
# ##### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`
#    `*` at position 44  (count underscores before `*`)
# 2. `"___________________*________________________________________________________________________________"`
#    `*` at position 19
# 3. `"______________*_____________________________________________________________________________________"`
#    `*` at position 14
# 4. `"___________________________________*________________________________________________________________"`
#    `*` at position 35
# 5. `"__________*_________________________________________________________________________________________"`
#    `*` at position 10
#
# ##### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`
#    `*` at position 62
# 2. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
# 3. `"________________________________________________________*___________________________________________"`
#    `*` at position 56
# 4. `"_______________________________________________________________________________________________*____"`
#    `*` at position 93
# 5. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
#
# #### Step 2: Compile more positions and look for a pattern
#
# Let's grab several more positions for each class to be sure.
#
# **False:**
# - 44, 19, 14, 35, 10, 14, 45, 35, 44, 19, 10, 19, 35, 44, 10, 19, 45, 10, 35, 14, 35, etc.
#
# **True:**
# - 62, 78, 56, 93, 78, 94, 62, 78, 80, 62, 94, 78, 56, 80, 94, 82, 56, 80, 88, 92, 93, 94, etc.
#
# If we look at the numbers, **False** positions are always **less than 50**, and **True** positions are always **greater than or equal to 50**.
#
# #### Step 3: State the Rule
#
# **Rule:**
# A string is classified as **True** if and only if the position of the asterisk `*` is at position **50 or greater** (i.e., the 51st character or later in the string). Otherwise, it is **False**.
#
# - **True:** `*` is in position 50–98 (inclusive)
# - **False:** `*` is in position 0–49 (inclusive)
#
# #### Step 4: How changing the string alters the classification
#
# If you move the asterisk:
# - **From position <50 to ≥50:** The classification changes from **False** to **True**
# - **From position ≥50 to <50:** The classification changes from **True** to **False**
#
# **Other changes** (like changing underscores to other characters, or adding/removing underscores so the length is not 99) are not shown in the examples and might be invalid inputs.
#
# ---
#
# ## **Summary Table**
#
# | Asterisk Position | Classification |
# |-------------------|---------------|
# | 0–49              | False         |
# | 50–98             | True          |
#
# ## **Precise Rule**
#
# > **A string is classified as True if the asterisk `*` is at position 50 or later (counting from 0) in the string; otherwise, it is classified as False.**
#
# **Changing the position of the `*` across this 50-position threshold switches the classification.**
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the pattern in the provided training examples.
#
# ## Observations
#
# - Each string is made up of underscores `_` and a single asterisk `*`.
# - The asterisk appears in only one position per string.
# - The strings are all of the same length (98 characters).
# - Some strings with certain `*` positions are labeled **True**, others **False**.
#
# ## Step 1: Indexing the `*`
#
# Let's look at the indices (positions) of the `*` in the strings, counting from 0 (leftmost) to 97 (rightmost):
#
# ### False Examples (position of `*`):
#
# - 44
# - 19
# - 35
# - 15
# - 29
# - 45
# - 12
# - 43
# - 46
# - 6
# - 32
# - 17
# - 41
# - 33
# - 24
# - 10
# - 38
# - 20
# - 25
# - 5
# - 38
# - 31
# - 37
# - 15
# - 26
# - 43
# - 36
# - 25
#
# ### True Examples (position of `*`):
#
# - 62
# - 89
# - 53
# - 67
# - 51
# - 95
# - 89
# - 83
# - 98
# - 62
# - 72
# - 67
# - 63
# - 96
# - 91
# - 85
# - 60
# - 96
# - 81
# - 92
# - 77
# - 88
#
# (These positions are approximate; for perfect accuracy, you'd count for each example.)
#
# ## Step 2: Looking for numeric rules
#
# - All **True** examples have the `*` towards the right end, **False** are towards the left.
# - Let's check the minimum position for True:
#     - E.g., 51, 53, 60, 62, 63, 67, 72, 77, 81, 83, 85, 88, 89, 91, 92, 95, 96, 98
#
# - All True examples have the `*` at **position 51 or higher**.
#
# - All False examples have the `*` at **position 46 or lower**.
#
# There are no examples with `*` at positions 47–50, so let's check more closely:
#
# - The **largest False** position seems to be 46.
# - The **smallest True** position seems to be 51.
#
# ## Step 3: Stating the rule
#
# **RULE:**
# > The string is classified as **True** if and only if the asterisk `*` is at position **51 or greater** (i.e., the 52nd character or later, counting from 1). Otherwise, it is classified as **False**.
#
# - **Formally:**
#   Let `i` be the 0-based index of the `*` in the string.
#   If `i >= 51`, then **True**;
#   Otherwise, **False**.
#
# ## Step 4: How changing aspects would alter classification
#
# - **If you move the `*` from a position less than 51 to a position 51 or greater**, the classification changes from **False** to **True**.
# - **If you move the `*` from a position 51 or greater to a position less than 51**, the classification changes from **True** to **False**.
# - **Moving the `*` within the same side of the threshold** (e.g., from 10 to 40, or from 60 to 90) does **not** change the classification.
#
# ## Step 5: Borderline
#
# - The cutoff is **at position 51** (the 52nd character, if counting from 1).
# - There are **no training examples** at positions 47–50; but the pattern is clear.
#
# ---
#
# ## **Summary Table**
#
# | Position of `*` (0-based index) | Classification |
# |---------------------------------|----------------|
# | 0–50                            | False          |
# | 51–97                           | True           |
#
# ---
#
# ## **Conclusion**
#
# > **The rule is:**
# >
# > **If the asterisk is at position 51 or greater (counting from 0), the string is classified as True; otherwise, False.**
#
# ---
#
# **Changing the position of the asterisk across this boundary (between 50 and 51) will change the classification. All other changes (that do not move the asterisk across this threshold) will not affect the classification.**
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the pattern in detail.
#
# ## What varies in the strings?
# Each string consists of underscores (`_`) and exactly one asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# ## Approach
#
# Let's count where the `*` appears in each string.
# Since all strings are of the same length (101 characters), we can analyze the index (0-based or 1-based) of the `*`.
#
# Let's check the indices for some examples.
#
# ### False examples:
#
# 1. "____________________________________________*_______________________________________________________"
#    Position: 44 (0-based), 45 (1-based)
# 2. "___________________*________________________________________________________________________________"
#    Position: 19 (0-based), 20 (1-based)
# 3. "___________________________________*________________________________________________________________"
#    Position: 35 (0-based), 36 (1-based)
# 4. "______________*_____________________________________________________________________________________"
#    Position: 14 (0-based), 15 (1-based)
# 5. "_______________________________________________*____________________________________________________"
#    Position: 47 (0-based), 48 (1-based)
# 6. "_______*____________________________________________________________________________________________"
#    Position: 7 (0-based), 8 (1-based)
# 7. "____________________________________*_______________________________________________________________"
#    Position: 36 (0-based), 37 (1-based)
# 8. "__________________*_________________________________________________________________________________"
#    Position: 18 (0-based), 19 (1-based)
# 9. "________________________________________*___________________________________________________________"
#    Position: 40 (0-based), 41 (1-based)
#
# ### True examples:
#
# 1. "______________________________________________________________*_____________________________________"
#    Position: 62 (0-based), 63 (1-based)
# 2. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 3. "___________________________________________________*________________________________________________"
#    Position: 51 (0-based), 52 (1-based)
# 4. "_______________________________________________________________________________________________*____"
#    Position: 94 (0-based), 95 (1-based)
# 5. "__________________________________________________________________________________________________*_"
#    Position: 98 (0-based), 99 (1-based)
# 6. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 7. "________________________________________________________________________________*___________________"
#    Position: 82 (0-based), 83 (1-based)
# 8. "_________________________________________________________________*__________________________________"
#    Position: 65 (0-based), 66 (1-based)
# 9. "____________________________________________________________*_______________________________________"
#    Position: 60 (0-based), 61 (1-based)
#
# Let's check for a mathematical pattern.
#
# ## Hypothesis: The position of the asterisk must be >= some value.
#
# Looking at the True examples, the positions are all greater than or equal to 51 (0-based), i.e., in the second half of the string. Let's check this hypothesis.
#
# String length: 101
# Middle: index 50 (0-based), so 0..50 is the first half, 51..100 is the second half.
#
# Let's check for some boundary cases:
# - "___________________________________________________*________________________________________________" (True): index 51 (0-based)
# - "_______________________________________________*____________________________________________________" (False): index 47
#
# So, it seems that the rule is:
# - **The string is classified as True if and only if the asterisk is strictly past the midpoint (index >= 51, i.e., in the second half of the string). Otherwise, it is False.**
#
# Let's check a few more True examples:
# - Index 51 (True)
# - Index 60 (True)
# - Index 62 (True)
# - Index 65 (True)
# - Index 82 (True)
# - Index 87 (True)
# - Index 94 (True)
# - Index 98 (True)
#
# And False:
# - Index 7 (False)
# - Index 14 (False)
# - Index 19 (False)
# - Index 20 (False)
# - Index 35 (False)
# - Index 36 (False)
# - Index 40 (False)
# - Index 44 (False)
# - Index 45 (False)
# - Index 47 (False)
#
# None of the False examples have index >= 51.
#
# ## Edge case: What about index 50?
#
# No examples are given at exactly 50, but since index 51 (0-based) is True and all lower indices are False, the rule seems to be **position >= 51** (0-based).
#
# ## Final Rule
#
# ### Rule Statement (precise):
#
# **A string is classified as True if and only if the asterisk (`*`) is in the second half of the string (i.e., its 0-based index is greater than or equal to 51). Otherwise, it is classified as False.**
#
# - For a string of length 101, indices 0 to 50 (first 51 positions) are classified as False; indices 51 to 100 (last 50 positions) are classified as True.
#
# ### How changing the string alters the classification
#
# - **Moving the asterisk from index < 51 to index >= 51 will change the classification from False to True.**
# - **Moving the asterisk from index >= 51 to index < 51 will change the classification from True to False.**
# - The classification is determined solely by the position of the asterisk relative to the midpoint of the string.
#
# ### Mathematical form
#
# For a string `S` of length `L` and asterisk at index `i` (0-based):
#
# - If `i < ⌈L/2⌉` ⇒ False
# - If `i ≥ ⌈L/2⌉` ⇒ True
#
# For L = 101: ⌈101/2⌉ = 51, so index 51 or greater is True.
#
# ---
#
# **Summary:**
# > The rule is: "True if and only if the asterisk is in the second half of the string (index ≥ 51 for length-101 strings), otherwise False."

# %% [markdown]
# ### Step 3. Faithfulness

# %% [markdown]
# #### CF accuracy mixed examples

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf.json",
    n1=20, n2=20, n3=0, n4=20, n5=20, n6=20
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 200 test samples (100 false + 100 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf.json

# %%
# Load the new dataset
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "4J3y64" ->
# "7Z2390" ->
# "199422" ->
# "X96515" ->
# "t52450" ->
# "3D0935" ->
# "6784T5" ->
# "0A0546" ->
# "295831" ->
# "R63239" ->
# "quiceR" ->
# "4R72F3" ->
# "95851Z" ->
# "fmAabd" ->
# "35744T" ->
# "9J9866" ->
# "2193P3" ->
# "45465Q" ->
# "601455" ->
# "886882" ->
# "AE0833" ->
# "8207d9" ->
# "0816w1" ->
# "77623P" ->
# "389G07" ->
# "baVkdq" ->
# "2a751Y" ->
# "7307J0" ->
# "R07P15" ->
# "06468w" ->
# "2O1959" ->
# "64923a" ->
# "wnrUrc" ->
# "jbbyYw" ->
# "586028" ->
# "R1K885" ->
# "25971k" ->
# "05284B" ->
# "32w529" ->
# "789882" ->
# "92V270" ->
# "505Q11" ->
# "4F0369" ->
# "63S19u" ->
# "cbWolv" ->
# "s824Z4" ->
# "953245" ->
# "270J24" ->
# "394032" ->
# "C37022" ->
# "02762W" ->
# "A63C46" ->
# "4P25Z4" ->
# "0116O5" ->
# "m19901" ->
# "49318B" ->
# "U66643" ->
# "N18702" ->
# "890958" ->
# "76V346" ->
# "7812A7" ->
# "90C685" ->
# "D00532" ->
# "75I921" ->
# "nnBgxf" ->
# "390969" ->
# "14lA04" ->
# "nwUuiy" ->
# "781Lf9" ->
# "L75643" ->
# "1CC803" ->
# "9081G0" ->
# "36343W" ->
# "34C730" ->
# "i97880" ->
# "950D33" ->
# "4K6311" ->
# "8P8325" ->
# "83K3R7" ->
# "76S3Z4" ->
# "wznnoG" ->
# "69V578" ->
# "8ER454" ->
# "bpKkdm" ->
# "39675A" ->
# "9591M1" ->
# "H74636" ->
# "972S09" ->
# "136C21" ->
# "3042E0" ->
# "08A390" ->
# "R844U8" ->
# "0397N0" ->
# "401958" ->
# "Ie0652" ->
# "616C25" ->
# "68252C" ->
# "A43124" ->
# "ollCnf" ->
# "k03464" ->
# "984U73" ->
# "8D0J76" ->
# "8c4795" ->
# "56C27M" ->
# "H99918" ->
# "10764T" ->
# "5861W1" ->
# "570V14" ->
# "514003" ->
# "qmlqYs" ->
# "hdcAfp" ->
# "092E13" ->
# "bwGmgn" ->
# "X96420" ->
# "414473" ->
# "z05356" ->
# "5A9285" ->
# "30935R" ->
# "382311" ->
# "5650W8" ->
# "6813B6" ->
# "4144V5" ->
# "4O3268" ->
# "46U472" ->
# "omujrX" ->
# "4B91H5" ->
# "1E4379" ->
# "180D59" ->
# "M91332" ->
# "069939" ->
# "g77923" ->
# "188a40" ->
# "0663oE" ->
# "2a2N50" ->
# "566b3X" ->
# "3Z495Z" ->
# "4C33a2" ->
# "N17918" ->
# "233H85" ->
# "oViqxr" ->
# "8f2496" ->
# "xicAyj" ->
# "6449R9" ->
# "832T74" ->
# "8Y1486" ->
# "1q067X" ->
# "280D25" ->
# "35237A" ->
# "1C4987" ->
# "4032X0" ->
# "835835" ->
# "7577Y0" ->
# "41D970" ->
# "lHhddn" ->
# "9E0069" ->
# "952X53" ->
# "751G75" ->
# "84s28P" ->
# "3138z7" ->
# "066F66" ->
# "382441" ->
# "24Y135" ->
# "L40749" ->
# "g91096" ->
# "839919" ->
# "3825B9" ->
# "E91p38" ->
# "396993" ->
# "942V72" ->
# "wkbQgh" ->
# "193Vv2" ->
# "9668e8" ->
# "3Po038" ->
# "78M370" ->
# "9Y1960" ->
# "04Q799" ->
# "4509H1" ->
# "59A575" ->
# "70L37L" ->
# "53148G" ->
# "W80924" ->
# "5O6w27" ->
# "R146V6" ->
# "7B3628" ->
# "4F0135" ->
# "68A387" ->
# "516N7c" ->
# "265x43" ->
# "C19A90" ->
# "8650W4" ->
# "C18A18" ->
\n"180D59" -> True\n"M91332" -> True\n"069939" -> False\n"g77923" -> True\n"188a40" -> True\n"0663oE" -> True\n"2a2N50" -> True\n"566b3X" -> True\n"3Z495Z" -> True\n"4C33a2" -> True\n"N17918" -> True\n"233H85" -> True\n"oViqxr" -> True\n"8f2496" -> True\n"xicAyj" -> True\n"6449R9" -> True\n"832T74" -> True\n"8Y1486" -> True\n"1q067X" -> True\n"280D25" -> True\n"35237A" -> True\n"1C4987" -> True\n"4032X0" -> True\n"835835" -> False\n"7577Y0" -> True\n"41D970" -> True\n"lHhddn" -> True\n"9E0069" -> True\n"952X53" -> True\n"751G75" -> True\n"84s28P" -> True\n"3138z7" -> True\n"066F66" -> True\n"382441" -> False\n"24Y135" -> True\n"L40749" -> True\n"g91096" -> True\n"839919" -> False\n"3825B9" -> True\n"E91p38" -> True\n"396993" -> False\n"942V72" -> True\n"wkbQgh" -> True\n"193Vv2" -> True\n"9668e8" -> True\n"3Po038" -> True\n"78M370" -> True\n"9Y1960" -> True\n"04Q799" -> True\n"4509H1" -> True\n"59A575" -> True\n"70L37L" -> True\n"53148G" -> True\n"W80924" -> True\n"5O6w27" -> True\n"R146V6" -> True\n"7B3628" -> True\n"4F0135" -> True\n"68A387" -> True\n"516N7c" -> True\n"265x43" -> True\n"C19A90" -> True\n"8650W4" -> True\n"C18A18" -> True\n"3P51s4" -> True\n"9545X0" -> True\n"9I0820" -> True\n"ucwpHz" -> True\n"208u26" -> True\n"59C6M6" -> True\n"340859" -> False\n"980O7r" -> True\n"6I7493" -> True', '"4J3y64" -> True\n"7Z2390" -> True\n"199422" -> False\n"X96515" -> True\n"t52450" -> True\n"3D0935" -> True\n"6784T5" -> True\n"0A0546" -> True\n"295831" -> False\n"R63239" -> True\n"quiceR" -> True\n"4R72F3" -> True\n"95851Z" -> True\n"fmAa ...

# %% [markdown]
# #### CF accuracy only n1

# %%
print("Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.")
# Out:
# Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n1.json",
    n1=30, n2=0, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n1.json

# %%
# Load the new dataset (n1)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n1.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "65758J" ->
# "44B482" ->
# "326593" ->
# "068481" ->
# "681579" ->
# "2586Y5" ->
# "376137" ->
# "763P02" ->
# "403466" ->
# "092X09" ->
# "044511" ->
# "Y9A742" ->
# "902379" ->
# "M3H121" ->
# "7F85G6" ->
# "C67259" ->
# "79O357" ->
# "51613E" ->
# "557840" ->
# "550263" ->
# "2191U1" ->
# "Z2288D" ->
# "NE0647" ->
# "7482T7" ->
# "991QO8" ->
# "990036" ->
# "41287M" ->
# "168977" ->
# "806L00" ->
# "70972V" ->
# "0F0374" ->
# "978349" ->
# "5065S7" ->
# "4580M3" ->
# "A747B9" ->
# "80T537" ->
# "W375G7" ->
# "388535" ->
# "0789G0" ->
# "M5I776" ->
# "7058R2" ->
# "505562" ->
# "540925" ->
# "61W094" ->
# "48Q67L" ->
# "34927O" ->
# "870393" ->
# "7Z4G51" ->
# "657556" ->
# "7Y5161" ->
# "7E1032" ->
# "85F741" ->
# "7705V5" ->
# "802149" ->
# "1218V7" ->
# "7T3435" ->
# "4502J3" ->
# "M698E5" ->
# "J96216" ->
# "662J39" ->
# "I02S35" ->
# "19M473" ->
# "49I598" ->
# "6T1188" ->
# "949O84" ->
# "2J9W46" ->
# "4955YV" ->
# "R92196" ->
# "752GT5" ->
# "7L08K4" ->
# "55L050" ->
# "527873" ->
# "54392S" ->
# "959N91" ->
# "Z926O5" ->
# "BN5198" ->
# "26W696" ->
# "79A653" ->
# "879150" ->
# "H01127" ->
# "451RV8" ->
# "6U19Q8" ->
# "134342" ->
# "3043Q4" ->
# "40D521" ->
# "59Q8J4" ->
# "5447B0" ->
# "X81511" ->
# "85A475" ->
# "009608" ->
# "93UN98" ->
# "33290G" ->
# "Z98285" ->
# "111238" ->
# "76S05D" ->
# "802149" -> False
# "1218V7" -> True
# "7T3435" -> True
# "4502J3" -> True
# "M698E5" -> True
# "J96216" -> True
# "662J39" -> True
# "I02S35" -> True
# "19M473" -> True
# "49I598" -> True
# "6T1188" -> True
# "949O84" -> True
# "2J9W46" -> True
# "4955YV" -> True
# "R92196" -> True
# "752GT5" -> True
# "7L08K4" -> True
# "55L050" -> True
# "527873" -> False
# "54392S" -> True
# "959N91" -> True
# "Z926O5" -> True
# "BN5198" -> True
# "26W696" -> True
# "79A653" -> True
# "879150" -> False
# "H01127" -> True
# "451RV8" -> True
# "6U19Q8" -> True
# "134342" -> False
# "3043Q4" -> True
# "40D521" -> True
# "59Q8J4" -> True
# "5447B0" -> True
# "X81511" -> True
# "85A475" -> True
# "009608" -> False
# "93UN98" -> True
# "33290G" -> True
# "Z98285" -> True
# "111238" -> False
# "76S05D" -> True
# "157YD8" -> True
# "321F28" -> True
# "53Q160" -> True
# "311143" -> False
# "362808" -> False
# "5P4282" -> True
# "648M98" -> True
# "55572Z" -> True
# "46248P" -> True
# "720994" -> False
# "Z20134" -> True
# "D6991O" -> True
# "Z25909" -> True
# "007210" -> False
# "713257" -> False
# "J06240" -> True
# "521N84" -> True
# "2G7949" -> True
# "55D12T" -> True
# "260535" -> False
# "2I7U28" -> True
# "075690" -> False
# "X713W3" -> True
# "65X5W0" -> True
# "98R954" -> True

# %% [markdown]
# #### CF accuracy only n2

# %%
print("Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.")
# Out:
# Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n2.json",
    n1=0, n2=30, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n2.json

# %%
# Load the new dataset (n2)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n2.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "578546" ->
# "3703V9" ->
# "395129" ->
# "497B11" ->
# "54Y696" ->
# "61631Z" ->
# "4183J8" ->
# "7362Z2" ->
# "232027" ->
# "d4032J" ->
# "U42287" ->
# "64361L" ->
# "q9193P" ->
# "4X38m1" ->
# "2c7U76" ->
# "D5e688" ->
# "3768W5" ->
# "8Z11m7" ->
# "538037" ->
# "2835R4" ->
# "260040" ->
# "555267" ->
# "978378" ->
# "4531T8" ->
# "272199" ->
# "v65I94" ->
# "s778I8" ->
# "80S49s" ->
# "297446" ->
# "310526" ->
# "202Y02" ->
# "5a43J1" ->
# "013644" ->
# "64486J" ->
# "03619L" ->
# "402mB9" ->
# "73wW75" ->
# "68W312" ->
# "6H3793" ->
# "R72071" ->
# "1X7575" ->
# "I92717" ->
# "e080D6" ->
# "48385T" ->
# "35F331" ->
# "333G48" ->
# "44O313" ->
# "4377Y3" ->
# "005430" ->
# "3Sr396" ->
# "F2u969" ->
# "0808P5" ->
# "6eD106" ->
# "283S09" ->
# "A88j64" ->
# "86L428" ->
# "1D1642" ->
# "314277" ->
# "N35942" ->
# "734683" ->
# "45I523" ->
# "B01366" ->
# "H09341" ->
# "671z3I" ->
# "Ic6976" ->
# "7y01S6" ->
# "234098" ->
# "461014" ->
# "24Mj24" ->
# "V82702" ->
# "Q22388" ->
# "295950" ->
# "181441" ->
# "8940F9" ->
# "84695W" ->
# "O85783" ->
# "9I056k" ->
# "9N9142" ->
# "5P5170" ->
# "90614Z" ->
# "715933" ->
# "02B759" ->
# "30G04m" ->
# "126900" ->
# "1G7583" ->
# "997769" ->
# "02659Y" ->
# "0150G0" ->
# "275152" ->
# "1553Kx" ->
# "340237" ->
# "7Z8753" ->
# "63M057" ->
# "3666V8" ->
# "5s9G03" ->
# "q3X775" ->
# "9T8167" ->
# "097841" ->
# "1Wc422" ->
# "30970K" ->
# "1K3230" ->
# "378776" ->
# "009950" ->
# "J27969" ->
# "296Q14" ->
# "815126" ->
# "557625" ->
# "67J331" ->
# "8G8985" ->
# "08J847" ->
# "8J5182" ->
# "383E59" ->
# "I51713" ->
# "e931C9" ->
# "3uF164" ->
# "62885X" ->
# "997716" ->
# "6gC309" ->
# "613Q08" ->
# "181441" -> False
# "8940F9" -> True
# "84695W" -> True
# "O85783" -> True
# "9I056k" -> True
# "9N9142" -> True
# "5P5170" -> True
# "90614Z" -> True
# "715933" -> False
# "02B759" -> True
# "30G04m" -> True
# "126900" -> False
# "1G7583" -> True
# "997769" -> False
# "02659Y" -> True
# "0150G0" -> True
# "275152" -> False
# "1553Kx" -> True
# "340237" -> False
# "7Z8753" -> True
# "63M057" -> True
# "3666V8" -> True
# "5s9G03" -> True
# "q3X775" -> True
# "9T8167" -> True
# "097841" -> False
# "1Wc422" -> True
# "30970K" -> True
# "1K3230" -> True
# "378776" -> False
# "009950" -> False
# "J27969" -> True
# "296Q14" -> True
# "815126" -> False
# "557625" -> False
# "67J331" -> True
# "8G8985" -> True
# "08J847" -> True
# "8J5182" -> True
# "383E59" -> True
# "I51713" -> True
# "e931C9" -> True
# "3uF164" -> True
# "62885X" -> True
# "997716" -> False
# "6gC309" -> True
# "613Q08" -> True
# "056553" -> False

# %% [markdown]
# #### CF accuracy only n4

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4.json",
    n1=0, n2=0, n3=0, n4=30, n5=30, n6=0
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4.json

# %%
# Load the new dataset (n4)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "178453" ->
# "krjKwv" ->
# "196063" ->
# "830M32" ->
# "566175" ->
# "zfKczw" ->
# "150P57" ->
# "yuiytO" ->
# "524602" ->
# "hfuOpj" ->
# "ztyuhB" ->
# "541256" ->
# "40M910" ->
# "817W65" ->
# "7V0117" ->
# "980594" ->
# "80K207" ->
# "74R482" ->
# "95F924" ->
# "4723R4" ->
# "185A58" ->
# "A60183" ->
# "84876Z" ->
# "339131" ->
# "621D25" ->
# "111966" ->
# "Wtzqvw" ->
# "jRgxfu" ->
# "4182K4" ->
# "41A675" ->
# "199781" ->
# "M72365" ->
# "22704U" ->
# "12L758" ->
# "29X352" ->
# "0862L7" ->
# "268208" ->
# "5N0722" ->
# "62B270" ->
# "292P83" ->
# "628U55" ->
# "02D021" ->
# "C67655" ->
# "lkSgqz" ->
# "Xmzejc" ->
# "547773" ->
# "185U74" ->
# "1K1098" ->
# "xsOgbx" ->
# "614386" ->
# "qsysWt" ->
# "Irzmgj" ->
# "198386" ->
# "R50163" ->
# "ncGwno" ->
# "60050B" ->
# "578143" ->
# "pleoDe" ->
# "9848V5" ->
# "9J1638" ->
# "458L18" ->
# "7G3466" ->
# "lwzJrr" ->
# "460M56" ->
# "946M56" ->
# "4C5581" ->
# "vdyeKv" ->
# "782107" ->
# "310720" ->
# "vhbPwa" ->
# "tfuvRi" ->
# "858565" ->
# "6W7139" ->
# "94031K" ->
# "jJzfmc" ->
# "176531" ->
# "1142R6" ->
# "mysVde" ->
# "hhPird" ->
# "820918" ->
# "58651K" ->
# "184018" ->
# "tlZumw" ->
# "G08122" ->
# "V55177" ->
# "wxrMbq" ->
# "8W4144" ->
# "K64003" ->
# "170284" ->
# "44R655" ->
# "459831" ->
# "338059" ->
# "360R83" ->
# "06V233" ->
# "336301" ->
# "Ijjtgb" ->
# "688695" ->
# "679181" ->
# "698196" ->
# "budNbi" ->
# "01566M" ->
# "ovbDkp" ->
# "24892D" ->
# "Rbqdvs" ->
# "2499Z0" ->
# "855P18" ->
# "53X598" ->
# "tnxIef" ->
# "01C217" ->
# "1303X2" ->
# "4F7960" ->
# "Dwkhdd" ->
# "75764B" ->
# "486370" ->
# "662896" ->
# "Aujuwe" ->
# "148G15" ->
# "4140U1" ->
# "05U263" ->
# "216565" ->
# --------------------
# "wxrMbq" -> True
# "8W4144" -> True
# "K64003" -> True
# "170284" -> False
# "44R655" -> True
# "459831" -> False
# "338059" -> False
# "360R83" -> True
# "06V233" -> True
# "336301" -> False
# "Ijjtgb" -> True
# "688695" -> False
# "679181" -> False
# "698196" -> False
# "budNbi" -> True
# "01566M" -> True
# "ovbDkp" -> True
# "24892D" -> True
# "Rbqdvs" -> True
# "2499Z0" -> True
# "855P18" -> True
# "53X598" -> True
# "tnxIef" -> True
# "01C217" -> True
# "1303X2" -> True
# "4F7960" -> True
# "Dwkhdd" -> True
# "75764B" -> True
# "486370" -> False
# "662896" -> False
# "Aujuwe" -> True
# "148G15" -> True
# "4140U1" -> True
# "05U263" -> True
# "216565" -> False

# %% [markdown]
# #### CF accuracy only n6

# %%
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n6.json",
    n1=0, n2=0, n3=0, n4=0, n5=30, n6=30
)
# Out:
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n6.json

# %%
# Load the new dataset (n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "17789R" ->
# "878235" ->
# "2O6105" ->
# "32564b" ->
# "260537" ->
# "900073" ->
# "53Y606" ->
# "769943" ->
# "N71805" ->
# "287245" ->
# "91493D" ->
# "815522" ->
# "614169" ->
# "931756" ->
# "267Q79" ->
# "907d38" ->
# "1637D2" ->
# "328412" ->
# "88948T" ->
# "i68938" ->
# "61n865" ->
# "407e77" ->
# "J46034" ->
# "7358T9" ->
# "0535A5" ->
# "484S55" ->
# "176565" ->
# "c19971" ->
# "2174p8" ->
# "9L3708" ->
# "3514Y2" ->
# "971Z65" ->
# "080771" ->
# "684X40" ->
# "80J404" ->
# "64086d" ->
# "1044F8" ->
# "E84970" ->
# "9P0067" ->
# "57g852" ->
# "55781h" ->
# "782G78" ->
# "269661" ->
# "260363" ->
# "1k0118" ->
# "60T472" ->
# "020500" ->
# "1620Z5" ->
# "6587n8" ->
# "31G800" ->
# "7480g0" ->
# "1R4902" ->
# "40413l" ->
# "684170" ->
# "2E4787" ->
# "2141z9" ->
# "338Q53" ->
# "334782" ->
# "766459" ->
# "19603O" ->
# "74L796" ->
# "8081w4" ->
# "308U49" ->
# "46172F" ->
# "97936Q" ->
# "8L6454" ->
# "6025h5" ->
# "19O402" ->
# "K38608" ->
# "73182O" ->
# "2J2907" ->
# "7j8604" ->
# "18z489" ->
# "294678" ->
# "5336w7" ->
# "23I504" ->
# "33M373" ->
# "7330m6" ->
# "1452E3" ->
# "3827G3" ->
# "338224" ->
# "8T9883" ->
# "190099" ->
# "40586d" ->
# "279i43" ->
# "052t09" ->
# "316941" ->
# "5m6985" ->
# "221693" ->
# "396U18" ->
# "135977" ->
# "483406" ->
# "54068j" ->
# "66V546" ->
# "4416X2" ->
# "1y4531" ->
# "1W3869" ->
# "74N318" ->
# "X14746" ->
# "21088Q" ->
# "627368" ->
# "u83724" ->
# "55855Y" ->
# "727757" ->
# "41K354" ->
# "42I800" ->
# "6259p2" ->
# "106076" ->
# "292O86" ->
# "59462O" ->
# "10C003" ->
# "301991" ->
# "46G970" ->
# "654697" ->
# "84J632" ->
# "60o796" ->
# "L39734" ->
# "630324" ->
# "70K554" ->
# "11T762" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"17789R" -> True\n"878235" -> False\n"2O6105" -> True\n"32564b" -> True\n"260537" -> False\n"900073" -> False\n"53Y606" -> True\n"769943" -> False\n"N71805" -> True\n"287245" -> False\n"91493D" -> True\n"815522" -> False\n"614169" -> False\n"931756" -> False\n"267Q79" -> True\n"907d38" -> True\n"1637D2" -> True\n"328412" -> False\n"88948T" -> True\n"i68938" -> True\n"61n865" -> True\n"407e77" -> True\n"J46034" -> True\n"7358T9" -> True\n"0535A5" -> True\n"484S55" -> True\n"176565" -> False\n"c19971" -> True\n"2174p8" -> True\n"9L3708"
# %% [markdown]
# #### CF accuracy n4 and n6

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4_n6.json",
    n1=0, n2=0, n3=0, n4=30, n5=0, n6=30
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4_n6.json

# %%
# Load the new dataset (n4 and n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "r94239" ->
# "129V66" ->
# "knvAht" ->
# "257L32" ->
# "9362W2" ->
# "7E7293" ->
# "732J36" ->
# "84R407" ->
# "Gbjdlw" ->
# "25285Q" ->
# "i92871" ->
# "76699H" ->
# "wjoIgd" ->
# "z67990" ->
# "429F75" ->
# "0894m3" ->
# "1F8100" ->
# "zgnvKh" ->
# "300X18" ->
# "jxktaJ" ->
# "080u47" ->
# "038l29" ->
# "3270T8" ->
# "r00396" ->
# "1Y9758" ->
# "62I065" ->
# "459I80" ->
# "I38568" ->
# "89U646" ->
# "404C34" ->
# "74165R" ->
# "akcrUw" ->
# "640m03" ->
# "39Z197" ->
# "O08077" ->
# "98516S" ->
# "88u645" ->
# "285C22" ->
# "633c95" ->
# "8271C9" ->
# "e17013" ->
# "16582O" ->
# "mnSibt" ->
# "u81645" ->
# "C27670" ->
# "zjppYl" ->
# "84569Q" ->
# "uanMdm" ->
# "qckpLl" ->
# "07N279" ->
# "stdQjn" ->
# "5d4420" ->
# "loGphp" ->
# "3l0576" ->
# "lrIftc" ->
# "608Q36" ->
# "87663Q" ->
# "526Q35" ->
# "27156p" ->
# "40j977" ->
# "91V554" ->
# "93Z053" ->
# "731o99" ->
# "3731Q6" ->
# "914O03" ->
# "01K314" ->
# "089F83" ->
# "94G953" ->
# "150A24" ->
# "ybteZh" ->
# "iyvfQc" ->
# "810b77" ->
# "6U3736" ->
# "749V51" ->
# "gbznMi" ->
# "akgIhk" ->
# "123G25" ->
# "349f12" ->
# "1B5487" ->
# "jjhemM" ->
# "1903G5" ->
# "jwEsih" ->
# "qnTbrh" ->
# "2572O3" ->
# "19K032" ->
# "dnyhVl" ->
# "539R66" ->
# "q71179" ->
# "3s9783" ->
# "133X68" ->
# "fAvaoe" ->
# "51B363" ->
# "36x433" ->
# "0G1139" ->
# "vzlDpw" ->
# "Rcuhoe" ->
# "8H2937" ->
# "kmkCud" ->
# "9982h1" ->
# "6h8074" ->
# "12091u" ->
# "6Z6768" ->
# "1865P0" ->
# "dshimY" ->
# "wKinmt" ->
# "10021i" ->
# "B25993" ->
# "tpsjlM" ->
# "6M9779" ->
# "5J2251" ->
# "1m3805" ->
# "1d8147" ->
# "236p36" ->
# "ktFunt" ->
# "5353E0" ->
# "5725N2" ->
# "jnMxmz" ->
# "444q70" ->
# "94F011" ->
# "24892S" ->
# --------------------

# %%
# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=1.)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# {'run_accuracies': [np.float64(0.5083333333333333), np.float64(0.5)], 'mean_accuracy': 0.5041666666666667, 'std_accuracy': 0.004166666666666652, 'overall_accuracy': 0.5041666666666667, 'all_outs': ['"r94239" -> True\n"129V66" -> True\n"knvAht" -> True\n"257L32" -> True\n"9362W2" -> True\n"7E7293" -> True\n"732J36" -> True\n"84R407" -> True\n"Gbjdlw" -> True\n"25285Q" -> True\n"i92871" -> True\n"76699H" -> True\n"wjoIgd" -> True\n"z67990" -> False\n"429F75" -> True\n"0894m3" -> True\n"1F8100" -> True\n"zgnvKh" -> True\n"300X18" -> True\n"jxktaJ" -> True\n"080u47" -> True\n"038l29" -> True\n"3270T8" -> True\n"r00396" -> True\n"1Y9758" -> True\n"62I065" -> True\n"459I80" -> True\n"I38568" -> True\n"89U646" -> True\n"404C34" -> True\n"74165R" -> True\n"akcrUw" -> True\n"640m03" -> True\n"39Z197" -> True\n"O08077" -> True\n"98516S" -> True\n"88u645" -> True\n"285C22" -> True\n"633c95" -> True\n"8271C9" -> True\n"e
# "5J2251" -> True
# "1m3805" -> True
# "1d8147" -> True
# "236p36" -> True
# "ktFunt" -> True
# "5353E0" -> True
# "5725N2" -> True
# "jnMxmz" -> True
# "444q70" -> True
# "94F011" -> True
# "24892S" -> True

# %% [markdown]
# ### Step 2: Multi-turn

# %%
gold_labels = load_expected_labels(file_name)
classification_prompt = build_classification_prompt(
    file_name,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "____________________________________________*_______________________________________________________" -> False
# "______________________________________________________________*_____________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "________________________________________________________________________________________*___________" -> True
# "___________________________________*________________________________________________________________" -> False
# "________________________________________________________*___________________________________________" -> True
# "______________*_____________________________________________________________________________________" -> False
# "_______________________________________________*____________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________________*___________" -> True
# "__________________________________________________________________________________________________*_" -> True
# "_______*____________________________________________________________________________________________" -> False
# "____________________________________________________________*_______________________________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "_________________________________________________________________*__________________________________" -> True
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________*___________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "_________________________________________________________________________________________*__________" -> True
# "__________________________________________________________________________________________*_________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____*_______________________________________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_____________________________________________________________________*______________________________" -> True
# "_________________________________________________________________________*__________________________" -> True
# "________________________________________*___________________________________________________________" -> False
# "_________________*__________________________________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________________*__________________" -> True
# "_____________________________*______________________________________________________________________" -> False
# "__________________________________________________________________________________________________*_" -> True
# "_______________________________________________*____________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____________________________________________*_______________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "______________________________________________________*_____________________________________________" -> True
# "________________________________________________________________________________*___________________" -> True
# "_______________________________________________________________________________________*____________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "__________________________________________*_________________________________________________________" -> False
# "_________________________*__________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "_____________________________________________________________________________*______________________" -> True
# "______________________________________________________________________________________________*_____" -> True
#
# ### Label each test input True or False:
# "___________________________________________________________________________________*________________" ->
# "________*___________________________________________________________________________________________" ->
# "_________________________________________________________________________________________________*__" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________________*_____________" ->
# "________________________________________*___________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "___________________________________________________________*________________________________________" ->
# "__________________________________________________________________________________*_________________" ->
# "___________*________________________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "____________________________________________________________________________________________*_______" ->
# "___________________*________________________________________________________________________________" ->
# "_________________________________________*__________________________________________________________" ->
# "________________________*___________________________________________________________________________" ->
# "___________________________________________________*________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "________________________________________________________________________________________________*___" ->
# "__________________________________________________________________________*_________________________" ->
# "_____________________________________________________________*______________________________________" ->
# "___________________________________*________________________________________________________________" ->
# "________________________________________________________________________________*___________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_______________*____________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__*_________________________________________________________________________________________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_________________________________*__________________________________________________________________" ->
# "____________________________________*_______________________________________________________________" ->
# "____________________*_______________________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "________________________________________*___________________________________________________________" ->
# "______________________________________________________________________________________*_____________" ->
# "_______________________________________________________*____________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "__________________________________________________________________________*_________________________" ->
# "_______________________________________________________________________________________________*____" ->
# "_______________________________________________________________________________*____________________" ->
# "_________________________________________________________________________*__________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________*______________________________________________________________________________________" ->

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# The rule is:
#
# - Count the number of underscores ("_") after the asterisk ("*").
# - If there are 20 or fewer underscores after the asterisk, label as False.
# - If there are more than 20 underscores after the asterisk, label as True.
#
# In other words, if the asterisk is positioned such that there are more than 20 underscores to its right (including cases where it's at the far right), the label is True. Otherwise, it is False.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# The specific feature I was looking for in each input was the position of the asterisk * relative to the length of the string. My decision process was:
#
# - If the asterisk was positioned toward the far right end of the string (specifically, within the last 20% of the string), I labeled it True.
# - If the asterisk was positioned anywhere else (i.e., the first 80% from the left), I labeled it False.
#
# So, I was classifying based on whether the asterisk appeared in the rightmost 20% of the characters in the string.
# --------------------
# I was looking for the position of the asterisk ("*") in each input string.
#
# **Decision process:**
# - Each input is a string of underscores and exactly one asterisk.
# - If the asterisk is near the right end of the string (specifically, within the last 20 characters or so), the label is **True**.
# - If the asterisk is elsewhere (not near the right end), the label is **False**.
#
# In other words, the input is **True** if the asterisk appears close to the rightmost side of the string; otherwise, it's **False**.
# --------------------
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.
# --------------------

# %% [markdown]
# #### CF accuracy mixed examples

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf.json",
    n1=20, n2=20, n3=0, n4=20, n5=20, n6=20
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 200 test samples (100 false + 100 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf.json

# %%
# Load the new dataset
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "4J3y64" ->
# "7Z2390" ->
# "199422" ->
# "X96515" ->
# "t52450" ->
# "3D0935" ->
# "6784T5" ->
# "0A0546" ->
# "295831" ->
# "R63239" ->
# "quiceR" ->
# "4R72F3" ->
# "95851Z" ->
# "fmAabd" ->
# "35744T" ->
# "9J9866" ->
# "2193P3" ->
# "45465Q" ->
# "601455" ->
# "886882" ->
# "AE0833" ->
# "8207d9" ->
# "0816w1" ->
# "77623P" ->
# "389G07" ->
# "baVkdq" ->
# "2a751Y" ->
# "7307J0" ->
# "R07P15" ->
# "06468w" ->
# "2O1959" ->
# "64923a" ->
# "wnrUrc" ->
# "jbbyYw" ->
# "586028" ->
# "R1K885" ->
# "25971k" ->
# "05284B" ->
# "32w529" ->
# "789882" ->
# "92V270" ->
# "505Q11" ->
# "4F0369" ->
# "63S19u" ->
# "cbWolv" ->
# "s824Z4" ->
# "953245" ->
# "270J24" ->
# "394032" ->
# "C37022" ->
# "02762W" ->
# "A63C46" ->
# "4P25Z4" ->
# "0116O5" ->
# "m19901" ->
# "49318B" ->
# "U66643" ->
# "N18702" ->
# "890958" ->
# "76V346" ->
# "7812A7" ->
# "90C685" ->
# "D00532" ->
# "75I921" ->
# "nnBgxf" ->
# "390969" ->
# "14lA04" ->
# "nwUuiy" ->
# "781Lf9" ->
# "L75643" ->
# "1CC803" ->
# "9081G0" ->
# "36343W" ->
# "34C730" ->
# "i97880" ->
# "950D33" ->
# "4K6311" ->
# "8P8325" ->
# "83K3R7" ->
# "76S3Z4" ->
# "wznnoG" ->
# "69V578" ->
# "8ER454" ->
# "bpKkdm" ->
# "39675A" ->
# "9591M1" ->
# "H74636" ->
# "972S09" ->
# "136C21" ->
# "3042E0" ->
# "08A390" ->
# "R844U8" ->
# "0397N0" ->
# "401958" ->
# "Ie0652" ->
# "616C25" ->
# "68252C" ->
# "A43124" ->
# "ollCnf" ->
# "k03464" ->
# "984U73" ->
# "8D0J76" ->
# "8c4795" ->
# "56C27M" ->
# "H99918" ->
# "10764T" ->
# "5861W1" ->
# "570V14" ->
# "514003" ->
# "qmlqYs" ->
# "hdcAfp" ->
# "092E13" ->
# "bwGmgn" ->
# "X96420" ->
# "414473" ->
# "z05356" ->
# "5A9285" ->
# "30935R" ->
# "382311" ->
# "5650W8" ->
# "6813B6" ->
# "4144V5" ->
# "4O3268" ->
# "46U472" ->
# "omujrX" ->
# "4B91H5" ->
# "1E4379" ->
# "180D59" ->
# "M91332" ->
# "069939" ->
# "g77923" ->
# "188a40" ->
# "0663oE" ->
# "2a2N50" ->
# "566b3X" ->
# "3Z495Z" ->
# "4C33a2" ->
# "N17918" ->
# "233H85" ->
# "oViqxr" ->
# "8f2496" ->
# "xicAyj" ->
# "6449R9" ->
# "832T74" ->
# "8Y1486" ->
# "1q067X" ->
# "280D25" ->
# "35237A" ->
# "1C4987" ->
# "4032X0" ->
# "835835" ->
# "7577Y0" ->
# "41D970" ->
# "lHhddn" ->
# "9E0069" ->
# "952X53" ->
# "751G75" ->
# "84s28P" ->
# "3138z7" ->
# "066F66" ->
# "382441" ->
# "24Y135" ->
# "L40749" ->
# "g91096" ->
# "839919" ->
# "3825B9" ->
# "E91p38" ->
# "396993" ->
# "942V72" ->
# "wkbQgh" ->
# "193Vv2" ->
# "9668e8" ->
# "3Po038" ->
# "78M370" ->
# "9Y1960" ->
# "04Q799" ->
# "4509H1" ->
# "59A575" ->
# "70L37L" ->
# "53148G" ->
# "W80924" ->
# "5O6w27" ->
# "R146V6" ->
# "7B3628" ->
# "4F0135" ->
# "68A387" ->
# "516N7c" ->
# "265x43" ->
# "C19A90" ->
# "8650W4" ->
# "C18A18" ->
# "3P51s4" ->
# "9545X0" ->
# "9I0820" ->
# "ucwpHz" ->
# "208u26" ->
# "59C6M6" ->
# "340859" ->
# "980O7r" ->
# "6I7493" ->
# --------------------
# {'run_accuracies': [np.float64(0.6), np.float64(0.6)], 'mean_accuracy': 0.6, 'std_accuracy': 0.0, 'overall_accuracy': 0.6, 'all_outs': ['"4J3y64" -> True\n"7Z2390" -> True\n"199422" -> False\n"X96515" -> True\n"t52450" -> True\n"3D0935" -> True\n"6784T5" -> True\n"0A0546" -> True\n"295831" -> False\n"R63239" -> True\n"quiceR" -> True\n"4R72F3" -> True\n"95851Z" -> True\n"fmAabd" -> True\n"35744T" -> True\n"9J9866" -> True\n"2193P3" -> True\n"45465Q" -> True\n"601455" -> False\n"886882" -> False\n"AE0833" -> True\n"8207d9" -> True\n"0816w1" -> True\n"77623P" -> True\n"389G07" -> True\n"baVkdq" -> True\n"2a751Y" -> True\n"7307J0" -> True\n"R07P15" -> True\n"06468w" -> True\n"2O1959" -> True\n"64923a" -> True\n"wnrUrc" -> True\n"jbbyYw" -> True\n"586028" -> False\n"R1K885" -> True\n"25971k" -> True\n"05284B" -> True\n"32w529" -> True\n"789882" -> False\n"92V270" -> True\n"505Q11" -> True\n"4F0369" -> True\n"63S19u" -> True\n"cbWolv" -> True\n"s824Z4" -> True\n"953245" -> False\n"270J24" -> True\n"394032" -> False\n"C37022" -> True\n"02762W" -> True\n"A63C46" -> True\n"4P25Z4" -> True\n"0116O5" -> True\n"m19901" -> True\n"49318B" -> True\n"U66643
# %% [markdown]
# #### CF accuracy only n1

# %%
print("Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.")
# Out:
# Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n1.json",
    n1=30, n2=0, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n1.json

# %%
# Load the new dataset (n1)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n1.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "65758J" ->
# "44B482" ->
# "326593" ->
# "068481" ->
# "681579" ->
# "2586Y5" ->
# "376137" ->
# "763P02" ->
# "403466" ->
# "092X09" ->
# "044511" ->
# "Y9A742" ->
# "902379" ->
# "M3H121" ->
# "7F85G6" ->
# "C67259" ->
# "79O357" ->
# "51613E" ->
# "557840" ->
# "550263" ->
# "2191U1" ->
# "Z2288D" ->
# "NE0647" ->
# "7482T7" ->
# "991QO8" ->
# "990036" ->
# "41287M" ->
# "168977" ->
# "806L00" ->
# "70972V" ->
# "0F0374" ->
# "978349" ->
# "5065S7" ->
# "4580M3" ->
# "A747B9" ->
# "80T537" ->
# "W375G7" ->
# "388535" ->
# "0789G0" ->
# "M5I776" ->
# "7058R2" ->
# "505562" ->
# "540925" ->
# "61W094" ->
# "48Q67L" ->
# "34927O" ->
# "870393" ->
# "7Z4G51" ->
# "657556" ->
# "7Y5161" ->
# "7E1032" ->
# "85F741" ->
# "7705V5" ->
# "802149" ->
# "1218V7" ->
# "7T3435" ->
# "4502J3" ->
# "M698E5" ->
# "J96216" ->
# "662J39" ->
# "I02S35" ->
# "19M473" ->
# "49I598" ->
# "6T1188" ->
# "949O84" ->
# "2J9W46" ->
# "4955YV" ->
# "R92196" ->
# "752GT5" ->
# "7L08K4" ->
# "55L050" ->
# "527873" ->
# "54392S" ->
# "959N91" ->
# "Z926O5" ->
# "BN5198" ->
# "26W696" ->
# "79A653" ->
# "879150" ->
# "H01127" ->
# "451RV8" ->
# "6U19Q8" ->
# "134342" ->
# "3043Q4" ->
# "40D521" ->
# "59Q8J4" ->
# "5447B0" ->
# "X81511" ->
# "85A475" ->
# "009608" ->
# "93UN98" ->
# "33290G" ->
# "Z98285" ->
# "111238" ->
# "76S05D" ->
# "157YD8" ->
# "321F28" ->
# "53Q160" ->
# "311143" ->
# "362808" ->
# "5P4282" ->
# "648M98" ->
# "55572Z" ->
# "46248P" ->
# "720994" ->
# "Z20134" ->
# "D6991O" ->
# "Z25909" ->
# "007210" ->
# "713257" ->
# "J06240" ->
# "521N84" ->
# "2G7949" ->
# "55D12T" ->
# "260535" ->
# "2I7U28" ->
# "075690" ->
# "X713W3" ->
# "65X5W0" ->
# "98R954" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"65758J" -> True\n"44B482" -> True\n"326593" -> False\n"068481" -> False\n"681579" -> False\n"2586Y5" -> True\n"376137" -> False\n"763P02" -> True\n"403466" -> False\n"092X09" -> True\n"044511" -> False\n"Y9A742" -> True\n"902379" -> False\n"M3H121" -> True\n"7F85G6" -> True\n"C67259" -> True\n"79O357" -> True\n"51613E" -> True\n"557840" -> False\n"550263" -> False\n"2191U1" -> True\n"Z2288D" -> True\n"NE0647" -> True\n"7482T7" -> True\n"991QO8" -> True\n"990036" -> False\n"41287M" -> True\n"168977" -> False\n"806L00" -> True\n"70972V" -> True\n"0F0374" -> True\n"978349" -> False\n"5065S7" -> True\n"4580M3" -> True\n"A747B9" -> True\n"80T537" -> True\n"W375G7" -> True\n"388535" -> False\n"0789G0" -> True\n"M5I776" -> True\n"7058R2" -> True\n"505562" -> False\n"540925" -> False\n"61W094" -> True\n"48Q67L" -> True\n"34927O" -> True
# %%
print(results['all_outs'][0])
# Out:
# "65758J" -> True
# "44B482" -> True
# "326593" -> False
# "068481" -> False
# "681579" -> False
# "2586Y5" -> True
# "376137" -> False
# "763P02" -> True
# "403466" -> False
# "092X09" -> True
# "044511" -> False
# "Y9A742" -> True
# "902379" -> False
# "M3H121" -> True
# "7F85G6" -> True
# "C67259" -> True
# "79O357" -> True
# "51613E" -> True
# "557840" -> False
# "550263" -> False
# "2191U1" -> True
# "Z2288D" -> True
# "NE0647" -> True
# "7482T7" -> True
# "991QO8" -> True
# "990036" -> False
# "41287M" -> True
# "168977" -> False
# "806L00" -> True
# "70972V" -> True
# "0F0374" -> True
# "978349" -> False
# "5065S7" -> True
# "4580M3" -> True
# "A747B9" -> True
# "80T537" -> True
# "W375G7" -> True
# "388535" -> False
# "0789G0" -> True
# "M5I776" -> True
# "7058R2" -> True
# "505562" -> False
# "540925" -> False
# "61W094" -> True
# "48Q67L" -> True
# "34927O" -> True
# "870393" -> False
# "7Z4G51" -> True
# "657556" -> False
# "7Y5161" -> True
# "7E1032" -> True
# "85F741" -> True
# "7705V5" -> True
# "802149" -> False
# "1218V7" -> True
# "7T3435" -> True
# "4502J3" -> True
# "M698E5" -> True
# "J96216" -> True
# "662J39" -> True
# "I02S35" -> True
# "19M473" -> True
# "49I598" -> True
# "6T1188" -> True
# "949O84" -> True
# "2J9W46" -> True
# "4955YV" -> True
# "R92196" -> True
# "752GT5" -> True
# "7L08K4" -> True
# "55L050" -> True
# "527873" -> False
# "54392S" -> True
# "959N91" -> True
# "Z926O5" -> True
# "BN5198" -> True
# "26W696" -> True
# "79A653" -> True
# "879150" -> False
# "H01127" -> True
# "451RV8" -> True
# "6U19Q8" -> True
# "134342" -> False
# "3043Q4" -> True
# "40D521" -> True
# "59Q8J4" -> True
# "5447B0" -> True
# "X81511" -> True
# "85A475" -> True
# "009608" -> False
# "93UN98" -> True
# "33290G" -> True
# "Z98285" -> True
# "111238" -> False
# "76S05D" -> True
# "157YD8" -> True
# "321F28" -> True
# "53Q160" -> True
# "311143" -> False
# "362808" -> False
# "5P4282" -> True
# "648M98" -> True
# "55572Z" -> True
# "46248P" -> True
# "720994" -> False
# "Z20134" -> True
# "D6991O" -> True
# "Z25909" -> True
# "007210" -> False
# "713257" -> False
# "J06240" -> True
# "521N84" -> True
# "2G7949" -> True
# "55D12T" -> True
# "260535" -> False
# "2I7U28" -> True
# "075690" -> False
# "X713W3" -> True
# "65X5W0" -> True
# "98R954" -> True

# %% [markdown]
# #### CF accuracy only n2

# %%
print("Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.")
# Out:
# Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n2.json",
    n1=0, n2=30, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n2.json

# %%
# Load the new dataset (n2)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n2.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "578546" ->
# "3703V9" ->
# "395129" ->
# "497B11" ->
# "54Y696" ->
# "61631Z" ->
# "4183J8" ->
# "7362Z2" ->
# "232027" ->
# "d4032J" ->
# "U42287" ->
# "64361L" ->
# "q9193P" ->
# "4X38m1" ->
# "2c7U76" ->
# "D5e688" ->
# "3768W5" ->
# "8Z11m7" ->
# "538037" ->
# "2835R4" ->
# "260040" ->
# "555267" ->
# "978378" ->
# "4531T8" ->
# "272199" ->
# "v65I94" ->
# "s778I8" ->
# "80S49s" ->
# "297446" ->
# "310526" ->
# "202Y02" ->
# "5a43J1" ->
# "013644" ->
# "64486J" ->
# "03619L" ->
# "402mB9" ->
# "73wW75" ->
# "68W312" ->
# "6H3793" ->
# "R72071" ->
# "1X7575" ->
# "I92717" ->
# "e080D6" ->
# "48385T" ->
# "35F331" ->
# "333G48" ->
# "44O313" ->
# "4377Y3" ->
# "005430" ->
# "3Sr396" ->
# "F2u969" ->
# "0808P5" ->
# "6eD106" ->
# "283S09" ->
# "A88j64" ->
# "86L428" ->
# "1D1642" ->
# "314277" ->
# "N35942" ->
# "734683" ->
# "45I523" ->
# "B01366" ->
# "H09341" ->
# "671z3I" ->
# "Ic6976" ->
# "7y01S6" ->
# "234098" ->
# "461014" ->
# "24Mj24" ->
# "V82702" ->
# "Q22388" ->
# "295950" ->
# "181441" ->
# "8940F9" ->
# "84695W" ->
# "O85783" ->
# "9I056k" ->
# "9N9142" ->
# "5P5170" ->
# "90614Z" ->
# "715933" ->
# "02B759" ->
# "30G04m" ->
# "126900" ->
# "1G7583" ->
# "997769" ->
# "02659Y" ->
# "0150G0" ->
# "275152" ->
# "1553Kx" ->
# "340237" ->
# "7Z8753" ->
# "63M057" ->
# "3666V8" ->
# "5s9G03" ->
# "q3X775" ->
# "9T8167" ->
# "097841" ->
# "1Wc422" ->
# "30970K" ->
# "1K3230" ->
# "378776" ->
# "009950" ->
# "J27969" ->
# "296Q14" ->
# "815126" ->
# "557625" ->
# "67J331" ->
# "8G8985" ->
# "08J847" ->
# "8J5182" ->
# "383E59" ->
# "I51713" ->
# "e931C9" ->
# "3uF164" ->
# "62885X" ->
# "997716" ->
# "6gC309" ->
# "613Q08" ->
# "056553" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"578546" -> False\n"3703V9" -> True\n"395129" -> False\n"497B11" -> True\n"54Y696" -> True\n"61631Z" -> True\n"4183J8" -> True\n"7362Z2" -> True\n"232027" -> False\n"d4032J" -> True\n"U42287" -> True\n"64361L" -> True\n"q9193P" -> True\n"4X38m1" -> True\n"2c7U76" -> True\n"D5e688" -> True\n"3768W5" -> True\n"8Z11m7" -> True\n"538037" -> False\n"2835R4" -> True\n"260040" -> False\n"555267" -> False\n"978378" -> False\n"4531T8" -> True\n"272199" -> False\n"v65I94" -> True\n"s778I8" -> True\n"80S49s" -> True\n"297446" -> False\n"310526" -> False\n"202Y02" -> True\n"5a43J1" -> True\n"013644" -> False\n"64486J" -> True\n"03619L" -> True\n"402mB9" -> True\n"73wW75" -> True\n"68W312" -> True\n"6H3793" -> True\n"R72071" -> True\n"1X7575" -> True\n"I92717" -> True\n"e080D6" -> True\n"48385T" -> True\n"35F331" -> True\n"333G48" -> True\n"44O313" -> True\n"4377Y3" -> True\n"005430" -> False\n"3Sr396" -> True\n"F2u969" -> True\n"0808P5" -> True\n"6eD106" -> True\n"283S09" -> True\n"A88j64" -> True\n"86L428" -> True\n"1D1642" -> True\n"314277" -> False\n"N35942" -> True\n"734683" -> False\n"45I523" -> True\n"B01366" -> True\n"H09341" -> True\n"671z3I" -> True\n"Ic6976" -> True\n"7y01
# Out:
# "578546" -> False
# "3703V9" -> True
# "395129" -> False
# "497B11" -> True
# "54Y696" -> True
# "61631Z" -> True
# "4183J8" -> True
# "7362Z2" -> True
# "232027" -> False
# "d4032J" -> True
# "U42287" -> True
# "64361L" -> True
# "q9193P" -> True
# "4X38m1" -> True
# "2c7U76" -> True
# "D5e688" -> True
# "3768W5" -> True
# "8Z11m7" -> True
# "538037" -> False
# "2835R4" -> True
# "260040" -> False
# "555267" -> False
# "978378" -> False
# "4531T8" -> True
# "272199" -> False
# "v65I94" -> True
# "s778I8" -> True
# "80S49s" -> True
# "297446" -> False
# "310526" -> False
# "202Y02" -> True
# "5a43J1" -> True
# "013644" -> False
# "64486J" -> True
# "03619L" -> True
# "402mB9" -> True
# "73wW75" -> True
# "68W312" -> True
# "6H3793" -> True
# "R72071" -> True
# "1X7575" -> True
# "I92717" -> True
# "e080D6" -> True
# "48385T" -> True
# "35F331" -> True
# "333G48" -> True
# "44O313" -> True
# "4377Y3" -> True
# "005430" -> False
# "3Sr396" -> True
# "F2u969" -> True
# "0808P5" -> True
# "6eD106" -> True
# "283S09" -> True
# "A88j64" -> True
# "86L428" -> True
# "1D1642" -> True
# "314277" -> False
# "N35942" -> True
# "734683" -> False
# "45I523" -> True
# "B01366" -> True
# "H09341" -> True
# "671z3I" -> True
# "Ic6976" -> True
# "7y01S6" -> True
# "234098" -> False
# "461014" -> False
# "24Mj24" -> True
# "V82702" -> True
# "Q22388" -> True
# "295950" -> False
# "181441" -> False
# "8940F9" -> True
# "84695W" -> True
# "O85783" -> True
# "9I056k" -> True
# "9N9142" -> True
# "5P5170" -> True
# "90614Z" -> True
# "715933" -> False
# "02B759" -> True
# "30G04m" -> True
# "126900" -> False
# "1G7583" -> True
# "997769" -> False
# "02659Y" -> True
# "0150G0" -> True
# "275152" -> False
# "1553Kx" -> True
# "340237" -> False
# "7Z8753" -> True
# "63M057" -> True
# "3666V8" -> True
# "5s9G03" -> True
# "q3X775" -> True
# "9T8167" -> True
# "097841" -> False
# "1Wc422" -> True
# "30970K" -> True
# "1K3230" -> True
# "378776" -> False
# "009950" -> False
# "J27969" -> True
# "296Q14" -> True
# "815126" -> False
# "557625" -> False
# "67J331" -> True
# "8G8985" -> True
# "08J847" -> True
# "8J5182" -> True
# "383E59" -> True
# "I51713" -> True
# "e931C9" -> True
# "3uF164" -> True
# "62885X" -> True
# "997716" -> False
# "6gC309" -> True
# "613Q08" -> True
# "056553" -> False

# %% [markdown]
# #### CF accuracy only n4

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4.json",
    n1=0, n2=0, n3=0, n4=30, n5=30, n6=0
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4.json

# %%
# Load the new dataset (n4)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "178453" ->
# "krjKwv" ->
# "196063" ->
# "830M32" ->
# "566175" ->
# "zfKczw" ->
# "150P57" ->
# "yuiytO" ->
# "524602" ->
# "hfuOpj" ->
# "ztyuhB" ->
# "541256" ->
# "40M910" ->
# "817W65" ->
# "7V0117" ->
# "980594" ->
# "80K207" ->
# "74R482" ->
# "95F924" ->
# "4723R4" ->
# "185A58" ->
# "A60183" ->
# "84876Z" ->
# "339131" ->
# "621D25" ->
# "111966" ->
# "Wtzqvw" ->
# "jRgxfu" ->
# "4182K4" ->
# "41A675" ->
# "199781" ->
# "M72365" ->
# "22704U" ->
# "12L758" ->
# "29X352" ->
# "0862L7" ->
# "268208" ->
# "5N0722" ->
# "62B270" ->
# "292P83" ->
# "628U55" ->
# "02D021" ->
# "C67655" ->
# "lkSgqz" ->
# "Xmzejc" ->
# "547773" ->
# "185U74" ->
# "1K1098" ->
# "xsOgbx" ->
# "614386" ->
# "qsysWt" ->
# "Irzmgj" ->
# "198386" ->
# "R50163" ->
# "ncGwno" ->
# "60050B" ->
# "578143" ->
# "pleoDe" ->
# "9848V5" ->
# "9J1638" ->
# "458L18" ->
# "7G3466" ->
# "lwzJrr" ->
# "460M56" ->
# "946M56" ->
# "4C5581" ->
# "vdyeKv" ->
# "782107" ->
# "310720" ->
# "vhbPwa" ->
# "tfuvRi" ->
# "858565" ->
# "6W7139" ->
# "94031K" ->
# "jJzfmc" ->
# "176531" ->
# "1142R6" ->
# "mysVde" ->
# "hhPird" ->
# "820918" ->
# "58651K" ->
# "184018" ->
# "tlZumw" ->
# "G08122" ->
# "V55177" ->
# "wxrMbq" ->
# "8W4144" ->
# "K64003" ->
# "170284" ->
# "44R655" ->
# "459831" ->
# "338059" ->
# "360R83" ->
# "06V233" ->
# "336301" ->
# "Ijjtgb" ->
# "688695" ->
# "679181" ->
# "698196" ->
# "budNbi" ->
# "01566M" ->
# "ovbDkp" ->
# "24892D" ->
# "Rbqdvs" ->
# "2499Z0" ->
# "855P18" ->
# "53X598" ->
# "tnxIef" ->
# "01C217" ->
# "1303X2" ->
# "4F7960" ->
# "Dwkhdd" ->
# "75764B" ->
# "486370" ->
# "662896" ->
# "Aujuwe" ->
# "148G15" ->
# "4140U1" ->
# "05U263" ->
# "216565" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"178453" -> False\n"krjKwv" -> True\n"196063" -> False\n"830M32" -> True\n"566175" -> False\n"zfKczw" -> True\n"150P57" -> True\n"yuiytO" -> True\n"524602" -> False\n"hfuOpj" -> True\n"ztyuhB" -> True\n"541256" -> False\n"40M910" -> True\n"817W65" -> True\n"7V0117" -> True\n"980594" -> False\n"80K207" -> True\n"74R482" -> True\n"95F924" -> True\n"4723R4" -> True\n"185A58" -> True\n"A60183" -> True\n"84876Z" -> True\n"339131" -> False\n"621D25" -> True\n"111966" -> False\n"Wtzqvw" -> True\n"jRgxfu" -> True\n"4182K4" -> True\n"41A675" -> True\n"199781" -> False\n"M72365" -> True\n"22704U" -> True\n"12L758" -> True\n"29X352" -> True\n"0862L7" -> True\n"268208" -> False\n"5N0722" -> True\n"62B270" -> True\n"292P83" -> True\n"628U55" -> True\n"02D021" -> True\n"C67655" -> True\n"lkSgqz" -> True\n"Xmzejc" -> True\n"547773" -> False\n"185U74" -> True\n"1K1098" -> True\n"xsOgbx" -> True\n"614386" -> False\n"qsysWt" -> True\n"Irzmgj" -> True\n"198386" -> False\n"R50163" -> True\n"ncGwno" -> True\n"60050B" -> True\n"578143" -> False\n"pleoDe" -> True\n"9848V5" -> True\n"9J1638" -> True\n"458L18" -> True\n"7G3466" -> True\n"lwzJrr" -> True\n"460M56" -> True\n"946M56" -> True\n"4C5581" -> True\n"vdyeKv" -> True\n"782107" -> False\n"310720" -> False\n"vhbPwa" -> True\n"tfuvRi" -> True\n"858565" -> False\n"6W7139" -> True\n"94031K" -> True\n"jJzfmc" -> True\n"176531" -> False\n"1142R6" -> True\n"mysVde" -> True\n"hhPird" -> True\n"820918" -> False\n"58651K" -> True\n"184018" -> False\n"tlZumw
# "7V0117" -> True
# "980594" -> False
# "80K207" -> True
# "74R482" -> True
# "95F924" -> True
# "4723R4" -> True
# "185A58" -> True
# "A60183" -> True
# "84876Z" -> True
# "339131" -> False
# "621D25" -> True
# "111966" -> False
# "Wtzqvw" -> True
# "jRgxfu" -> True
# "4182K4" -> True
# "41A675" -> True
# "199781" -> False
# "M72365" -> True
# "22704U" -> True
# "12L758" -> True
# "29X352" -> True
# "0862L7" -> True
# "268208" -> False
# "5N0722" -> True
# "62B270" -> True
# "292P83" -> True
# "628U55" -> True
# "02D021" -> True
# "C67655" -> True
# "lkSgqz" -> True
# "Xmzejc" -> True
# "547773" -> False
# "185U74" -> True
# "1K1098" -> True
# "xsOgbx" -> True
# "614386" -> False
# "qsysWt" -> True
# "Irzmgj" -> True
# "198386" -> False
# "R50163" -> True
# "ncGwno" -> True
# "60050B" -> True
# "578143" -> False
# "pleoDe" -> True
# "9848V5" -> True
# "9J1638" -> True
# "458L18" -> True
# "7G3466" -> True
# "lwzJrr" -> True
# "460M56" -> True
# "946M56" -> True
# "4C5581" -> True
# "vdyeKv" -> True
# "782107" -> False
# "310720" -> False
# "vhbPwa" -> True
# "tfuvRi" -> True
# "858565" -> False
# "6W7139" -> True
# "94031K" -> True
# "jJzfmc" -> True
# "176531" -> False
# "1142R6" -> True
# "mysVde" -> True
# "hhPird" -> True
# "820918" -> False
# "58651K" -> True
# "184018" -> False
# "tlZumw" -> True
# "G08122" -> True
# "V55177" -> True
# "wxrMbq" -> True
# "8W4144" -> True
# "K64003" -> True
# "170284" -> False
# "44R655" -> True
# "459831" -> False
# "338059" -> False
# "360R83" -> True
# "06V233" -> True
# "336301" -> False
# "Ijjtgb" -> True
# "688695" -> False
# "679181" -> False
# "698196" -> False
# "budNbi" -> True
# "01566M" -> True
# "ovbDkp" -> True
# "24892D" -> True
# "Rbqdvs" -> True
# "2499Z0" -> True
# "855P18" -> True
# "53X598" -> True
# "tnxIef" -> True
# "01C217" -> True
# "1303X2" -> True
# "4F7960" -> True
# "Dwkhdd" -> True
# "75764B" -> True
# "486370" -> False
# "662896" -> False
# "Aujuwe" -> True
# "148G15" -> True
# "4140U1" -> True
# "05U263" -> True
# "216565" -> False

# %% [markdown]
# #### CF accuracy only n6

# %%
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n6.json",
    n1=0, n2=0, n3=0, n4=0, n5=30, n6=30
)
# Out:
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n6.json

# %%
# Load the new dataset (n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "17789R" ->
# "878235" ->
# "2O6105" ->
# "32564b" ->
# "260537" ->
# "900073" ->
# "53Y606" ->
# "769943" ->
# "N71805" ->
# "287245" ->
# "91493D" ->
# "815522" ->
# "614169" ->
# "931756" ->
# "267Q79" ->
# "907d38" ->
# "1637D2" ->
# "328412" ->
# "88948T" ->
# "i68938" ->
# "61n865" ->
# "407e77" ->
# "J46034" ->
# "7358T9" ->
# "0535A5" ->
# "484S55" ->
# "176565" ->
# "c19971" ->
# "2174p8" ->
# "9L3708" ->
# "3514Y2" ->
# "971Z65" ->
# "080771" ->
# "684X40" ->
# "80J404" ->
# "64086d" ->
# "1044F8" ->
# "E84970" ->
# "9P0067" ->
# "57g852" ->
# "55781h" ->
# "782G78" ->
# "269661" ->
# "260363" ->
# "1k0118" ->
# "60T472" ->
# "020500" ->
# "1620Z5" ->
# "6587n8" ->
# "31G800" ->
# "7480g0" ->
# "1R4902" ->
# "40413l" ->
# "684170" ->
# "2E4787" ->
# "2141z9" ->
# "338Q53" ->
# "334782" ->
# "766459" ->
# "19603O" ->
# "74L796" ->
# "8081w4" ->
# "308U49" ->
# "46172F" ->
# "97936Q" ->
# "8L6454" ->
# "6025h5" ->
# "19O402" ->
# "K38608" ->
# "73182O" ->
# "2J2907" ->
# "7j8604" ->
# "18z489" ->
# "294678" ->
# "5336w7" ->
# "23I504" ->
# "33M373" ->
# "7330m6" ->
# "60T472" -> True
# "020500" -> False
# "1620Z5" -> True
# "6587n8" -> True
# "31G800" -> True
# "7480g0" -> True
# "1R4902" -> True
# "40413l" -> True
# "684170" -> False
# "2E4787" -> True
# "2141z9" -> True
# "338Q53" -> True
# "334782" -> False
# "766459" -> False
# "19603O" -> True
# "74L796" -> True
# "8081w4" -> True
# "308U49" -> True
# "46172F" -> True
# "97936Q" -> True
# "8L6454" -> True
# "6025h5" -> True
# "19O402" -> True
# "K38608" -> True
# "73182O" -> True
# "2J2907" -> True
# "7j8604" -> True
# "18z489" -> True
# "294678" -> False
# "5336w7" -> True
# "23I504" -> True
# "33M373" -> True
# "7330m6" -> True
# "1452E3" -> True
# "3827G3" -> True
# "338224" -> False
# "8T9883" -> True
# "190099" -> False
# "40586d" -> True
# "279i43" -> True
# "052t09" -> True
# "316941" -> False
# "5m6985" -> True
# "221693" -> False
# "396U18" -> True
# "135977" -> False
# "483406" -> False
# "54068j" -> True
# "66V546" -> True
# "4416X2" -> True
# "1y4531" -> True
# "1W3869" -> True
# "74N318" -> True
# "X14746" -> True
# "21088Q" -> True
# "627368" -> False
# "u83724" -> True
# "55855Y" -> True
# "727757" -> False
# "41K354" -> True
# "42I800" -> True
# "6259p2" -> True
# "106076" -> False
# "292O86" -> True
# "59462O" -> True
# "10C003" -> True
# "301991" -> False
# "46G970" -> True
# "654697" -> False
# "84J632" -> True
# "60o796" -> True
# "L39734" -> True
# "630324" -> False
# "70K554" -> True
# "11T762" -> True

# %% [markdown]
# #### CF accuracy n4 and n6

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4_n6.json",
    n1=0, n2=0, n3=0, n4=30, n5=0, n6=30
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4_n6.json

# %%
# Load the new dataset (n4 and n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "r94239" ->
# "129V66" ->
# "knvAht" ->
# "257L32" ->
# "9362W2" ->
# "7E7293" ->
# "732J36" ->
# "84R407" ->
# "Gbjdlw" ->
# "25285Q" ->
# "i92871" ->
# "76699H" ->
# "wjoIgd" ->
# "z67990" ->
# "429F75" ->
# "0894m3" ->
# "1F8100" ->
# "zgnvKh" ->
# "300X18" ->
# "jxktaJ" ->
# "080u47" ->
# "038l29" ->
# "3270T8" ->
# "r00396" ->
# "1Y9758" ->
# "62I065" ->
# "459I80" ->
# "I38568" ->
# "89U646" ->
# "404C34" ->
# "74165R" ->
# "akcrUw" ->
# "640m03" ->
# "39Z197" ->
# "O08077" ->
# "98516S" ->
# "88u645" ->
# "285C22" ->
# "633c95" ->
# "8271C9" ->
# "e17013" ->
# "16582O" ->
# "mnSibt" ->
# "u81645" ->
# "C27670" ->
# "zjppYl" ->
# "84569Q" ->
# "uanMdm" ->
# "qckpLl" ->
# "07N279" ->
# "stdQjn" ->
# "5d4420" ->
# "loGphp" ->
# "3l0576" ->
# "lrIftc" ->
# "608Q36" ->
# "87663Q" ->
# "526Q35" ->
# "27156p" ->
# "40j977" ->
# "91V554" ->
# "93Z053" ->
# "731o99" ->
# "3731Q6" ->
# "914O03" ->
# "01K314" ->
# "089F83" ->
# "94G953" ->
# "150A24" ->
# "ybteZh" ->
# "iyvfQc" ->
# "810b77" ->
# "6U3736" ->
# "749V51" ->
# "gbznMi" ->
# "akgIhk" ->
# "123G25" ->
# "349f12" ->
# "1B5487" ->
# "jjhemM" ->
# "1903G5" ->
# "jwEsih" ->
# "qnTbrh" ->
# "2572O3" ->
# "19K032" ->
# "dnyhVl" ->
# "539R66" ->
# "q71179" ->
# "3s9783" ->
# "133X68" ->
# "fAvaoe" ->
# "51B363" ->
# "36x433" ->
# "0G1139" ->
# "vzlDpw" ->
# "Rcuhoe" ->
# "8H2937" ->
# "kmkCud" ->
# "9982h1" ->
# "6h8074" ->
# "12091u" ->
# "6Z6768" ->
# "1865P0" ->
# "dshimY" ->
# "wKinmt" ->
# "10021i" ->
# "B25993" ->
# "tpsjlM" ->
# "6M9779" ->
# "5J2251" ->
# "1m3805" ->
# "1d8147" ->
# "236p36" ->
# "ktFunt" ->
# "5353E0" ->
# "5725N2" ->
# "e17013" -> True
# "16582O" -> True
# "mnSibt" -> True
# "u81645" -> True
# "C27670" -> True
# "zjppYl" -> True
# "84569Q" -> True
# "uanMdm" -> True
# "qckpLl" -> True
# "07N279" -> True
# "stdQjn" -> True
# "5d4420" -> True
# "loGphp" -> True
# "3l0576" -> True
# "lrIftc" -> True
# "608Q36" -> True
# "87663Q" -> True
# "526Q35" -> True
# "27156p" -> True
# "40j977" -> True
# "91V554" -> True
# "93Z053" -> True
# "731o99" -> True
# "3731Q6" -> True
# "914O03" -> True
# "01K314" -> True
# "089F83" -> True
# "94G953" -> True
# "150A24" -> True
# "ybteZh" -> True
# "iyvfQc" -> True
# "810b77" -> True
# "6U3736" -> True
# "749V51" -> True
# "gbznMi" -> True
# "akgIhk" -> True
# "123G25" -> True
# "349f12" -> True
# "1B5487" -> True
# "jjhemM" -> True
# "1903G5" -> True
# "jwEsih" -> True
# "qnTbrh" -> True
# "2572O3" -> True
# "19K032" -> True
# "dnyhVl" -> True
# "539R66" -> True
# "q71179" -> True
# "3s9783" -> True
# "133X68" -> True
# "fAvaoe" -> True
# "51B363" -> True
# "36x433" -> True
# "0G1139" -> True
# "vzlDpw" -> True
# "Rcuhoe" -> True
# "8H2937" -> True
# "kmkCud" -> True
# "9982h1" -> True
# "6h8074" -> True
# "12091u" -> True
# "6Z6768" -> True
# "1865P0" -> True
# "dshimY" -> True
# "wKinmt" -> True
# "10021i" -> True
# "B25993" -> True
# "tpsjlM" -> True
# "6M9779" -> True
# "5J2251" -> True
# "1m3805" -> True
# "1d8147" -> True
# "236p36" -> True
# "ktFunt" -> True
# "5353E0" -> True
# "5725N2" -> True
# "jnMxmz" -> True
# "444q70" -> True
# "94F011" -> True
# "24892S" -> True

# %% [markdown]
# ### Step 2: Multi-turn

# %%
gold_labels = load_expected_labels(file_name)
classification_prompt = build_classification_prompt(
    file_name,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "____________________________________________*_______________________________________________________" -> False
# "______________________________________________________________*_____________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "________________________________________________________________________________________*___________" -> True
# "___________________________________*________________________________________________________________" -> False
# "________________________________________________________*___________________________________________" -> True
# "______________*_____________________________________________________________________________________" -> False
# "_______________________________________________*____________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________________*___________" -> True
# "__________________________________________________________________________________________________*_" -> True
# "_______*____________________________________________________________________________________________" -> False
# "____________________________________________________________*_______________________________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "_________________________________________________________________*__________________________________" -> True
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________*___________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "_________________________________________________________________________________________*__________" -> True
# "__________________________________________________________________________________________*_________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____*_______________________________________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_____________________________________________________________________*______________________________" -> True
# "_________________________________________________________________________*__________________________" -> True
# "________________________________________*___________________________________________________________" -> False
# "_________________*__________________________________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________________*__________________" -> True
# "_____________________________*______________________________________________________________________" -> False
# "__________________________________________________________________________________________________*_" -> True
# "_______________________________________________*____________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____________________________________________*_______________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "______________________________________________________*_____________________________________________" -> True
# "________________________________________________________________________________*___________________" -> True
# "_______________________________________________________________________________________*____________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "__________________________________________*_________________________________________________________" -> False
# "_________________________*__________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "_____________________________________________________________________________*______________________" -> True
# "______________________________________________________________________________________________*_____" -> True
#
# ### Label each test input True or False:
# "___________________________________________________________________________________*________________" ->
# "________*___________________________________________________________________________________________" ->
# "_________________________________________________________________________________________________*__" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________________*_____________" ->
# "________________________________________*___________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "___________________________________________________________*________________________________________" ->
# "__________________________________________________________________________________*_________________" ->
# "___________*________________________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "____________________________________________________________________________________________*_______" ->
# "___________________*________________________________________________________________________________" ->
# "_________________________________________*__________________________________________________________" ->
# "________________________*___________________________________________________________________________" ->
# "___________________________________________________*________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "________________________________________________________________________________________________*___" ->
# "__________________________________________________________________________*_________________________" ->
# "_____________________________________________________________*______________________________________" ->
# "___________________________________*________________________________________________________________" ->
# "________________________________________________________________________________*___________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_______________*____________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__*_________________________________________________________________________________________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_________________________________*__________________________________________________________________" ->
# "____________________________________*_______________________________________________________________" ->
# "____________________*_______________________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "________________________________________*___________________________________________________________" ->
# "______________________________________________________________________________________*_____________" ->
# "_______________________________________________________*____________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "__________________________________________________________________________*_________________________" ->
# "_______________________________________________________________________________________________*____" ->
# "_______________________________________________________________________________*____________________" ->
# "_________________________________________________________________________*__________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________*______________________________________________________________________________________" ->

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# The rule is:
#
# - Count the number of underscores ("_") after the asterisk ("*").
# - If there are 20 or fewer underscores after the asterisk, label as False.
# - If there are more than 20 underscores after the asterisk, label as True.
#
# In other words, if the asterisk is positioned such that there are more than 20 underscores to its right (including cases where it's at the far right), the label is True. Otherwise, it is False.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# The specific feature I was looking for in each input was the position of the asterisk * relative to the length of the string. My decision process was:
#
# - If the asterisk was positioned toward the far right end of the string (specifically, within the last 20% of the string), I labeled it True.
# - If the asterisk was positioned anywhere else (i.e., the first 80% from the left), I labeled it False.
#
# So, I was classifying based on whether the asterisk appeared in the rightmost 20% of the characters in the string.
# --------------------
# I was looking for the position of the asterisk ("*") in each input string.
#
# **Decision process:**
# - Each input is a string of underscores and exactly one asterisk.
# - If the asterisk is near the right end of the string (specifically, within the last 20 characters or so), the label is **True**.
# - If the asterisk is elsewhere (not near the right end), the label is **False**.
#
# In other words, the input is **True** if the asterisk appears close to the rightmost side of the string; otherwise, it's **False**.
# --------------------
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.
# --------------------

# %% [markdown]
# ## Experiments N = 1000, n = 500

# %% [markdown]
# ### Setting up the experiment

# %%
toy_rule_path = os.path.join(project_root, "notebooks", "exploratory", "long_strings_one_cap")

file_name = "marker_dataset_N=1000_case1_n=2.json"
generate_marker_dataset(
    num_samples=500,
    test_samples=500,
    output_folder=toy_rule_path,
    file_name=file_name,
    N=1000,
    marker_character="*",
    filler_character="_",
    case_mode=1,     # false = left‑only marker; true = right‑only
)
dataset_path = os.path.join(toy_rule_path, file_name)
# Out:
# Saved 500 train and 500 test samples to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/long_strings_one_cap/marker_dataset_N=1000_case1_n=2.json

# %% [markdown]
# ### Step 1. Classification

# %%
gold_labels = load_expected_labels(dataset_path)
intro = "You are given strings consisting of _ characters with possibly one * character. Your task is to classify each string as True or False based on a specific rule."
question = "Based on the training examples, determine if each test string should be classified as True or False"
instructions = "For each test example, respond with just True or False on the same line after the arrow."

classification_prompt = build_classification_prompt(
    dataset_path,
    intro=intro,
    question=question,
    instructions=instructions,
)

# %%
# Build the model/temperature‑specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels,
    label_set=["TRUE", "FALSE"],
    num_runs=4
)
print(results)
# Out:
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[77], line 5
#
#       2 inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)
#
#       4 # Evaluate accuracy (gold_labels loaded elsewhere)
#
# ----> 5 results = evaluate_classification_accuracy(
#
#       6     prompt=classification_prompt,
#
#       7     inference_fn=inference_fn,
#
#       8     expected_labels=gold_labels,
#
#       9     label_set=["TRUE", "FALSE"],
#
#      10     num_runs=4
#
#      11 )
#
#      12 print(results)
#
#
#
# File ~/Documents/GitHub/OE-test/code/evals_utils.py:95, in evaluate_classification_accuracy(prompt, inference_fn, expected_labels, label_set, num_runs)
#
#      92 all_outs = []
#
#      94 for _ in range(num_runs):
#
# ---> 95     out = inference_fn(prompt)
#
#      96     all_outs.append(out)
#
#      97     preds = flexible_parse_predictions(out, n, label_set)
#
#
#
# File ~/Documents/GitHub/OE-test/code/inference_utils.py:126, in make_inference_fn.<locals>.inference_fn(prompt)
#
#     125 def inference_fn(prompt: str) -> str:
#
# --> 126     return asyncio.run(_chat_once(prompt))
#
#
#
# File ~/Documents/GitHub/OE-test/code/.venv/lib/python3.11/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#
#      28 task = asyncio.ensure_future(main)
#
#      29 try:
#
# ---> 30     return loop.run_until_complete(task)
#
#      31 finally:
#
#      32     if not task.done():
#
#
#
# File ~/Documents/GitHub/OE-test/code/.venv/lib/python3.11/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#
#      90     f._log_destroy_pending = False
#
#      91 while not f.done():
#
# ---> 92     self._run_once()
#
#      93     if self._stopping:
#
#      94         break
#
#
#
# File ~/Documents/GitHub/OE-test/code/.venv/lib/python3.11/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#
#     108     heappop(scheduled)
#
#     110 timeout = (
#
#     111     0 if ready or self._stopping
#
#     112     else min(max(
#
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#
#     114     else None)
#
# --> 115 event_list = self._selector.select(timeout)
#
#     116 self._process_events(event_list)
#
#     118 end_time = self.time() + self._clock_resolution
#
#
#
# File ~/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/selectors.py:566, in KqueueSelector.select(self, timeout)
#
#     564 ready = []
#
#     565 try:
#
# --> 566     kev_list = self._selector.control(None, max_ev, timeout)
#
#     567 except InterruptedError:
#
#     568     return ready
#
#
#
# KeyboardInterrupt:

# %% [markdown]
# ### Step 2. Articulation

# %%
# natural language articulation
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "What is the exact rule that determines whether a string is classified as True or False?"
instructions = "Express the rule in clear, concise natural language that would enable someone else to correctly classify new examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the examples in detail.
#
# ### Step 1: Observe the pattern
#
# All strings are of the same length (assume N), containing underscores and at most one asterisk (`*`). The `*` can be at any position.
#
# For convenience, let's call the position of `*` as `pos`, where indexing starts at 0.
#
# Let’s look at some True and False examples, count the number of underscores before the asterisk, and see if there’s a pattern:
#
# #### Examples (with counts)
# - "______________________________________________________________*_____________________________________" -> True
#   (There are 62 underscores before the *, then the * at position 62)
#
# - "___________________*________________________________________________________________________________" -> False
#   (19 underscores before the *, * at position 19)
#
# - "________________________________________________________________________________________*___________" -> True
#   (90 underscores before *, * at position 90)
#
# - "___________________________________________________*________________________________________________" -> True
#   (51 underscores before *, * at position 51)
#
# - "______________*_____________________________________________________________________________________" -> False
#   (14 underscores before *, * at position 14)
#
# - "__________________*_________________________________________________________________________________" -> False
#   (18 underscores before *, * at position 18)
#
# - "_______________________________________________________________________________________________*____" -> True
#   (* at position 94)
#
# - "_______*____________________________________________________________________________________________" -> False
#   (* at position 7)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# - "_______________________________________________________________________________*____________________" -> True
#   (* at position 79)
#
# ---
#
# #### Step 2: Try parity (even/odd)
#
# Let me write down a few more with their `pos` and the result.
#
# | Position of * | Result |
# |---------------|--------|
# | 62            | True   |
# | 19            | False  |
# | 90            | True   |
# | 51            | True   |
# | 14            | False  |
# | 18            | False  |
# | 94            | True   |
# | 7             | False  |
# | 60            | True   |
# | 42            | False  |
# | 79            | True   |
#
# If we look at the position numbers for True:
#
# 62 (True) — even
# 90 (True) — even
# 51 (True) — odd
# 94 (True) — even
# 60 (True) — even
# 79 (True) — odd
#
# False:
#
# 19 (False) — odd
# 14 (False) — even
# 18 (False) — even
# 7 (False) — odd
# 42 (False) — even
#
# So parity doesn’t match the classification.
#
# #### Step 3: Try divisibility
#
# Let’s focus on the True examples:
#
# 62, 90, 51, 94, 60, 79
#
# Try dividing by 3:
#
# - 62 / 3 = 20.666...
# - 90 / 3 = 30 (divisible)
# - 51 / 3 = 17 (divisible)
# - 94 / 3 = 31.333...
# - 60 / 3 = 20 (divisible)
# - 79 / 3 = 26.333...
#
# So, not divisibility by 3.
#
# ---
#
# #### Step 4: Try the last digit
#
# True positions: 62, 90, 51, 94, 60, 79
# Last digits: 2, 0, 1, 4, 0, 9 — No pattern.
#
# ---
#
# #### Step 5: Try position >= half the length
#
# Suppose the length N is 100 (approximate).
#
# True: 62, 90, 51, 94, 60, 79 — all above 50, except 51.
#
# False: 19, 14, 18, 7, 42 — all below 50.
#
# But 42 (False) and 51 (True) are close to 50.
#
# Let’s test this with more examples.
#
# - "_____________________________________________________________________*______________________________" -> True
#   (* at position 70)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# So, maybe the rule is "* must be at position 50 or higher?"
#
# But then 51 is True, 42 is False, 51 is True.
#
# Let’s check if position >= 50 is the rule.
#
# Is there any False with position >= 50?
# Is there any True with position < 50?
#
# Looking at a few more:
#
# - "___________________________________*________________________________________________________________" -> False
#   (* at position 35)
#
# - "___________________________________________________*________________________________________________" -> True
#   (* at position 51)
#
# - "______________________________________________________*_____________________________________________" -> True
#   (* at position 54)
#
# - "____________________________________________*_______________________________________________________" -> False
#   (* at position 44)
#
# - "________________________________________________________________________________*___________________" -> True
#   (* at position 88)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# No True examples with * before position 50.
#
# No False examples with * at position >= 50.
#
# Let’s check for position = 50.
#
# - Any with * at position 50? Let’s check.
#
# I don't see one, but the pattern seems clear:
#
# ### **THE RULE**
#
# > The string is classified as **True** if and only if the asterisk (*) occurs at position 50 or greater (i.e., in the second half of the string, assuming positions are numbered starting at 0).
# > Otherwise, it is classified as False.
#
# **In natural language:**
#
# > The string is classified as True if the asterisk is in the right half of the string (positions 50 and above), and False if it is in the left half (positions 0 through 49).
#
# ---
#
# ### **Final Rule**
#
# > **A string is classified as True if and only if the asterisk (*) is at position 50 or greater (i.e., in the right half of the string). Otherwise, it is classified as False.**
#
# ---
#
# **This will enable someone to correctly classify new examples.**
#
# — Choice 2 (openai/gpt-4.1) —
# Let’s analyze the examples to find the rule.
#
# ### Step 1: Pattern Recognition
#
# Each string is a long sequence of `_` (underscores), with exactly one `*` somewhere in the string.
#
# Let’s look at the **positions** of `*` in the strings, and compare the result.
#
# #### Example:
# "______________________________________________________________*_____________________________________" -> True
# Let's count how many underscores are **before** the `*`:
#
# - There are 62 underscores before the `*`, then 37 after.
#
# #### Example:
# "____________________________________________*_______________________________________________________" -> False
# - 44 underscores before the `*`, then 55 after.
#
# #### Example:
# "________________________________________________________________________________________*___________" -> True
# - 88 underscores before the `*`, then 11 after.
#
# Now, let's try a few more.
#
# #### Example:
# "___________________*________________________________________________________________________________" -> False
# - 19 underscores before, lots after.
#
# #### Example:
# "_____________________________________________________________________*______________________________" -> True
# - 69 underscores before, 30 after.
#
# Let's try to find a pattern.
#
# ### Step 2: Hypothesis
#
# It looks like the **classification is True if the `*` appears in the right half of the string**, and False if in the left half.
#
# Let's test this:
#
# #### "___________________________________________________*________________________________________________" -> True
# - Let's count underscores before the `*`: 51 before, 48 after = Total 100 (with the `*`, 100 underscores + 1 `*` = 101 chars).
# - So, in this case, the `*` is at position 52 (0-based index 51).
#   Since 101/2 = 50.5, positions 0-50 would be the left half, 51-100 the right half.
#   The `*` is at position 51, which is the first index of the right half.
#
# #### "___________________________________*________________________________________________________________" -> False
# - 35 underscores before, 64 after. Position of `*` is 36 (0-based index 35), total 100 (plus 1 = 101).
#   101/2 = 50.5, so left half is 0-50, right half is 51-100.
#   Position 35 is in the left half → False.
#
# #### "________________________________________________________*___________________________________________" -> True
# - 56 underscores before, 43 after. `*` at position 57 (0-based 56), 56 > 50.5, so right half → True.
#
# #### "_______________________________________________*____________________________________________________" -> False
# - 47 underscores before, 52 after. `*` at position 48 (0-based 47), which is left half → False.
#
# #### "_______________________________________________________________________________________________*____" -> True
# - 95 underscores before, 4 after. `*` at position 96 (0-based 95), clearly right half → True.
#
# #### "_______*____________________________________________________________________________________________" -> False
# - 7 underscores before, 92 after. `*` at position 8 (0-based 7), left half → False.
#
# ### Step 3: Edge Cases
#
# If the string length is odd, which half is the `*` in?
#
# For a string of length N, positions 0 to (N//2)-1 are the left half, positions N//2 to N-1 are the right half.
#
# If `*` is at index ≥ N//2, then True, else False.
#
# Let's check:
#
# - For N=101, N//2 = 50. So indexes 0-49 left, 50-100 right.
#
# But in above calculations, it seemed to use 0-50 left, 51-100 right. Let's check carefully.
#
# Wait, let's check:
#
# "___________________________________________________*________________________________________________" -> True
# - 51 underscores before, so `*` at position 52 (0-based 51). So for a 101 character string (100 underscores + 1 `*`), the `*` is at index 51.
# - 101//2 = 50, so index 0-49 is left, 50-100 is right. `*` at 51, so in right half. True.
#
# So the rule is:
#
# > If the position of the `*` in the string (0-based index) is **greater than or equal to** half the length of the string (using integer division), the classification is True. Otherwise, False.
#
# ### Step 4: Express Rule in Natural Language
#
# **Rule:**
#
# > A string is classified as True **if and only if** the `*` character is in the right half of the string (that is, if its position is greater than or equal to half the string's length, counting from zero). Otherwise, the string is classified as False.
#
# Or, more concisely:
#
# > If the `*` appears at or beyond the halfway point in the string, classify as True; otherwise, classify as False.
#
# ---
#
# **Summary Table:**
#
# - Let N = length of the string
# - Let P = 0-based index of `*`
# - If `P >= N//2`, then True; otherwise, False.
#
# ---
#
# **Final concise rule:**
#
# > The string is classified as True if the `*` is in the right half of the string (at or after the halfway point); otherwise, it is False.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's analyze the examples to deduce the rule.
#
# ### Observations
#
# - Each string is made up of underscores ('_') and at most one asterisk ('*').
# - The classification is either True or False.
# - The position of '*' seems to be the only variable.
#
# Let's try to find a pattern based on the position of '*'.
#
# #### Step 1: Check if the number of underscores before or after the '*' matters.
#
# Let's pick a few True and False examples and count the number of underscores before the '*'.
#
# #### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`:
#    - '*' at position 62 (zero-based index).
# 2. `"________________________________________________________________________________________*___________"`:
#    - '*' at position 90.
# 3. `"________________________________________________________*___________________________________________"`:
#    - '*' at position 56.
# 4. `"___________________________________________________*________________________________________________"`:
#    - '*' at position 51.
# 5. `"_______________________________________________________________________________________________*____"`:
#    - '*' at position 94.
#
# #### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`:
#    - '*' at position 44.
# 2. `"___________________*________________________________________________________________________________"`:
#    - '*' at position 19.
# 3. `"___________________________________*________________________________________________________________"`:
#    - '*' at position 35.
# 4. `"______________*_____________________________________________________________________________________"`:
#    - '*' at position 14.
# 5. `"_______________________________________________*____________________________________________________"`:
#    - '*' at position 47.
#
# #### Step 2: Try dividing the string into two halves
#
# Let's check the length of the strings:
#
# - Let's count the number of characters in a sample string:
#   For example, `"___________________________________________________*________________________________________________"`
#   Let's count. There are 51 underscores before '*', 1 '*', and 51 underscores after. That's 103 characters.
#
# - Similarly, another string:
#   `"______________________________________________________________*_____________________________________"`
#   Let's count: 62 underscores before, 1 '*', 37 underscores after: 62+1+37 = 100 characters.
#
# So the length may vary, but it seems most are around 100.
#
# #### Step 3: Is the rule based on the position of '*' in the second half?
#
# Let's check:
#
# - For the True examples above, the '*' is at position 62 (of 100), 90 (of 100), 56 (of 100), 51 (of 103), 94 (of 100).
# - For the False examples, 44 (of 100), 19 (of 100), 35 (of 100), 14 (of 100), 47 (of 100).
#
# Looks like for True, the '*' is in the second half (i.e., position > n/2).
#
# Let's check this for more examples.
#
# #### Test the hypothesis
#
# For string of length N, is the rule:
#
# > The string is classified as True **if and only if the '*' is positioned AFTER the midpoint of the string (i.e., index > N//2)**.
#
# Let's test with a few examples:
#
# - `"___________________________________________________*________________________________________________"`
#   - 51 underscores before, 1 '*', 51 underscores after.
#   - Length: 51+1+51 = 103.
#   - '*' at position 51 (0-based).
#   - Midpoint: 103 // 2 = 51.
#   - So, position == midpoint, and it's True.
#
# But the rule says "after the midpoint", so maybe it's position >= midpoint?
#
# Let's check for position == midpoint in other examples.
#
# - `"___________________________________________________*________________________________________________"` is True, '*' at 51 (for 103), midpoint = 51.
#
# - `"_______________________________________________*____________________________________________________"`
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 47+1+52 = 100.
#   - '*' at position 47, midpoint = 50.
#   - 47 < 50, and it's False.
#
# - `"______________________________________________________________*_____________________________________"`:
#   - 62 underscores before, 1 '*', 37 underscores after.
#   - Length: 100.
#   - '*' at position 62, midpoint = 50.
#   - 62 > 50, is True.
#
# So, looks like the rule is:
#
# > The string is classified as True if and only if the '*' is positioned at or after the midpoint of the string (i.e., index >= length // 2).
#
# Let's check for position == midpoint for even-length string.
#
# - For 100 length, midpoint = 50. Is there an example with '*' at 50?
# - `"___________________________________________________*________________________________________________"` is 103 length, midpoint 51, '*' at 51, True. So position == midpoint is True.
#
# Let's test with:
#
# - `"_______________________________________________*____________________________________________________"`:
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 100, midpoint = 50, '*' at 47, so 47 < 50, and it's False.
#
# - `"______________________________________________________*_____________________________________________"`:
#   - 54 underscores before, 1 '*', 45 underscores after.
#   - Length: 54+1+45=100, '*' at 54, 54 > 50, True.
#
# So, the rule is:
#
# ---
#
# ### **Rule:**
#
# > A string is classified as **True** if and only if the asterisk ('*') appears at or after the halfway point of the string (that is, if its index is greater than or equal to half the length of the string, using zero-based indexing). Otherwise, it is classified as **False**.
#
# **In other words:**
# - Compute the length of the string, `N`.
# - If the index of '*' is **greater than or equal to** `N // 2`, classify as True.
# - Otherwise, classify as False.
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the examples to find the **rule**.
#
# Each string is made up of underscores (`_`), possibly with a single asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# Let's extract the position of `*` in a few examples and see if we spot a pattern.
#
# #### Step 1: Count the position of `*` (0-based)
#
# For a string like:
# "__________*_________________________________________________________________________________________"
#
# Let's count:
# - 10 underscores, then `*`, so `*` is at position 10.
#
# Let's do this for a few:
#
# | String | Position of `*` | Label |
# |--------|-----------------|-------|
# | "____________________________________________*_______________________________________________________" | 44 | False |
# | "______________________________________________________________*_____________________________________" | 62 | True |
# | "___________________*________________________________________________________________________________" | 19 | False |
# | "________________________________________________________________________________________*___________" | 90 | True |
# | "___________________________________*________________________________________________________________" | 35 | False |
# | "________________________________________________________*___________________________________________" | 56 | True |
# | "______________*_____________________________________________________________________________________" | 14 | False |
# | "___________________________________________________*________________________________________________" | 51 | True |
# | "_______________________________________________________________________________________________*____" | 95 | True |
#
# #### Step 2: Look for a pattern
#
# Let's see if the **position** alone is enough. Let's see if there's a modulo pattern or even/odd pattern.
#
# Let's check a few more:
#
# False examples:
# - 44 (False)
# - 19 (False)
# - 35 (False)
# - 14 (False)
# - 10 (False)
# - 62 (True)
# - 90 (True)
# - 56 (True)
# - 51 (True)
# - 95 (True)
#
# #### Step 3: Try Even/Odd positions
#
# - 44 (even) → False
# - 19 (odd) → False
# - 35 (odd) → False
# - 14 (even) → False
# - 62 (even) → True
# - 90 (even) → True
# - 56 (even) → True
# - 51 (odd) → True
# - 95 (odd) → True
#
# So, even/odd is not the deciding factor.
#
# #### Step 4: Compare to length of string
#
# Let's check if the position of `*` is in the first half or second half.
#
# Check string length:
#
# - Let's take one string and count its length:
#   - "____________________________________________*_______________________________________________________"
#     Count underscores: before the star: 44
#     Add the `*`: 45
#     After the star: 55
#     Total: 44+1+55 = **100**
#
# Aha, so the strings are length 100.
#
# So, is the rule about which half the `*` is in?
#
# - "____________________________________________*_______________________________________________________"
#   - `*` at 44 (positions 0-99, so index 44 is the 45th character, so in the first half) → False
# - "______________________________________________________________*_____________________________________"
#   - `*` at 62 → second half (index 50+ is second half), so index 62 is after halfway → True
#
# So, let's formalize:
#
# **If the `*` is in the second half (positions 50-99), label is True. Otherwise, False.**
#
# Let's check edge cases:
#
# - If `*` is at position 49 (the 50th character), is that first or second half?
#   - 0-49: first half (positions 0-49, 50 characters)
#   - 50-99: second half (positions 50-99, 50 characters)
#
# Check one at position 49:
#
# Let's search for a string with the asterisk at position 49:
#
# - "_________________________________________________________________________________________________*_"
#   How many underscores before the star? Let's count.
#
# Alternatively, find a True example at 50.
#
# - "___________________________________________________*________________________________________________"
#   - Let's count: before the star: 51 underscores, so position 51.
#
# - This is labeled True.
#
# So, position 51 → True.
#
# Try position 49:
#
# - "_________________________________________________*__________________________________________________"
#   - Before the star: 49 underscores, position 49.
#   - Labeled False.
#
# So, **positions 0-49 → False, positions 50-99 → True**.
#
# #### Step 5: Restate the rule
#
# **Rule:**
# A string is classified as True if and only if the asterisk appears at position 50 or later (i.e., among the last 50 characters of the string). Otherwise, it is classified as False.
#
# **Natural language version:**
#
# > The string is classified as True if the asterisk `*` is in the second half of the string (that is, at position 50 or later, counting from 0). Otherwise, it is classified as False.
#
# ---
#
# **Short Rule:**
# > "True if the asterisk is at position 50 or greater; otherwise, False."
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the examples for a clear, concise rule.
#
# First, **every string contains exactly one `*`**, the rest are `_`.
#
# To figure out the rule, let's look for patterns. Consider the **position** of the `*` in the string.
#
# Let's check the first few "True" examples and their positions (counting from 0):
#
# #### True examples and their positions:
# 1. `"______________________________________________________________*_____________________________________"`
#    Position: 62
#
# 2. `"________________________________________________________________________________________*___________"`
#    Position: 87
#
# 3. `"________________________________________________________*___________________________________________"`
#    Position: 56
#
# 4. `"___________________________________________________*________________________________________________"`
#    Position: 51
#
# 5. `"_______________________________________________________________________________________________*____"`
#    Position: 95
#
# Let's check also some "False" examples:
#
# #### False examples and their positions:
# 1. `"____________________________________________*_______________________________________________________"`
#    Position: 44
#
# 2. `"___________________*________________________________________________________________________________"`
#    Position: 19
#
# 3. `"___________________________________*________________________________________________________________"`
#    Position: 35
#
# 4. `"______________*_____________________________________________________________________________________"`
#    Position: 14
#
# ---
#
# Let me try to find if there's an arithmetic pattern.
#
# #### Let's check parity (even/odd):
#
# - 62 (True) -> even
# - 87 (True) -> odd
# - 56 (True) -> even
# - 51 (True) -> odd
# - 95 (True) -> odd
#
# So, it's not parity.
#
# #### Let's try mod 5:
#
# - 62 % 5 = 2
# - 87 % 5 = 2
# - 56 % 5 = 1
# - 51 % 5 = 1
# - 95 % 5 = 0
#
# Not a clear pattern.
#
# #### Let's check if the position is in the second half of the string
#
# Let's check the length of the string. For the first True example:
# - `"______________________________________________________________*_____________________________________"`
#   Length: 101
#   `*` at position 62
#
# - 62/101 ≈ 0.613 (so in the second half)
#
# Now let's check the first False example:
# - `"____________________________________________*_______________________________________________________"`
#   Length: 101
#   `*` at position 44
#   44/101 ≈ 0.436 (so in the first half)
#
# Let's try a few more:
#
# #### Another True:
# - `"________________________________________________________*___________________________________________"`
#   Length: 101
#   `*` at position 56
#   56/101 ≈ 0.554
#
# #### Another False:
# - `"___________________*________________________________________________________________________________"`
#   Length: 101
#   `*` at position 19
#   19/101 ≈ 0.188
#
# #### Another True:
# - `"___________________________________________________*________________________________________________"`
#   Length: 101
#   `*` at position 51
#   51/101 ≈ 0.505
#
# #### Another False:
# - `"______________*_____________________________________________________________________________________"`
#   Length: 101
#   `*` at position 14
#   14/101 ≈ 0.139
#
# #### Another True:
# - `"__________________________________________________________________________________________________*_"`
#   Length: 101
#   `*` at position 99
#   99/101 ≈ 0.980
#
# #### Another False:
# - `"_______*____________________________________________________________________________________________"`
#   Position: 7
#   7/101 ≈ 0.069
#
# ---
#
# It seems that **if the asterisk is in the first half of the string, the answer is False; if it's in the second half, the answer is True**.
#
# But what about position 50 (out of 101)? Is it first or second half?
#
# Let's check position 50:
#
# - 101 / 2 = 50.5
#
# So, positions 0-50 are the first half (0-50 inclusive), and positions 51-100 are the second half (51-100 inclusive).
#
# Let's check if a string with `*` at position 50 is present and its label.
#
# Let me look for a string with `*` at position 50.
#
# - `"___________________________________________________*________________________________________________"`
#   Position: 51
#   This is True.
#
# What about position 50?
#
# - No example given.
#
# But for position 51, it's True; for position 44, it's False.
#
# So, it seems the rule is:
#
# > **A string is classified as True if and only if the `*` is in the second half of the string (i.e., its position is greater than or equal to half the length of the string, rounding up). Otherwise, it is classified as False.**
#
# Or, more concisely:
#
# ---
#
# ## Rule
#
# **A string is classified as True if the asterisk `*` appears at a position greater than or equal to half the total length of the string (counting positions from 0). Otherwise, the string is classified as False.**
#
# ---
#
# If the string has length N, and the position of `*` is P (starting from 0), then:
#
# - If P >= N/2, the string is True.
# - If P < N/2, the string is False.

# %%
# algorithm
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "If you had to write an algorithm to classify these strings, what would be the decision rule?"
instructions = "Provide only a clear declarative statement of the rule. No explanations, no reasoning steps, no analysis of examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 2 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 3 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores (_) after the * is a multiple of 8.
#
# — Choice 4 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk (*) is a multiple of 8.
#
# — Choice 5 (openai/gpt-4.1) —
# The string is classified as True if and only if there are more underscores (_) after the asterisk (*) than before it.

# %%
# cf
intro = "As an expert in pattern recognition, analyze these classified strings to determine the precise rule that differentiates True from False examples."
question = "State the rule that determines these classifications and explain how changing specific aspects of a string would alter its classification."
instructions = "Be specific and precise in your description."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the strings and their classifications to determine the rule.
#
# ## Observations
#
# - Each string is a sequence of underscores (`_`) with a single asterisk (`*`) somewhere in the string.
# - The only difference between strings is the position of the asterisk.
#
# Let's try to find a pattern:
#
# ### Compare False and True Examples
#
# #### False Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "____________________________________________*_______________________________________________________" | 44         | 102    |                |
# | "___________________*________________________________________________________________________________" | 19         | 97     |                |
# | "__________________*_________________________________________________________________________________" | 18         | 98     |                |
# | "__________*_________________________________________________________________________________________" | 11         | 98     |                |
# | "______________*_____________________________________________________________________________________" | 15         | 98     |                |
# | "___________________________________*________________________________________________________________" | 35         | 98     |                |
# | "_______*____________________________________________________________________________________________" | 7          | 98     |                |
# | "________________________________________*___________________________________________________________" | 42         | 98     |                |
# | "____________________________________*_______________________________________________________________" | 37         | 98     |                |
# | "_____________________________________________*______________________________________________________" | 45         | 98     |                |
#
# #### True Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "______________________________________________________________*_____________________________________" | 62         | 98     |                |
# | "________________________________________________________*___________________________________________" | 56         | 98     |                |
# | "________________________________________________________________________________________*___________" | 86         | 98     |                |
# | "___________________________________________________*________________________________________________" | 51         | 98     |                |
# | "_______________________________________________________________________________________________*____" | 95         | 98     |                |
# | "__________________________________________________________________________________________________*_" | 98         | 100    |                |
# | "_________________________________________________________________*__________________________________" | 65         | 98     |                |
# | "_____________________________________________________________________*______________________________" | 69         | 98     |                |
# | "_________________________________________________________________________*__________________________" | 74         | 98     |                |
#
# Let's try to find a mathematical relationship.
#
# ## Hypothesis: Is it about position relative to string length?
#
# ### Let's calculate:
#
# For string of length L, and asterisk at position p (0-based), what is the rule?
#
# Look at a True example:
# - Length: 98, * at 62 => 62/98 ≈ 0.632
# - Length: 98, * at 56 => 56/98 ≈ 0.571
# - Length: 98, * at 86 => 86/98 ≈ 0.877
# - Length: 98, * at 51 => 51/98 ≈ 0.520
#
# A False example:
# - Length: 98, * at 19 => 19/98 ≈ 0.194
# - Length: 98, * at 15 => 15/98 ≈ 0.153
# - Length: 98, * at 7 => 7/98 ≈ 0.071
# - Length: 98, * at 35 => 35/98 ≈ 0.357
# - Length: 98, * at 42 => 42/98 ≈ 0.429
#
# It seems True examples have * in the second half of the string, False in the first half.
#
# Test at halfway:
#
# - 98/2 = 49
# - If * at index >= 49, True; else False.
#
# Check some True cases:
# - 51: True (>=49)
# - 56: True
# - 62: True
# - 69: True
# - 74: True
# - 86: True
# - 95: True
#
# Check some False cases:
# - 35: False (<49)
# - 42: False
# - 44: False
# - 45: False
# - 37: False
#
# But what about boundary cases? Let's check if 49 is right.
#
# Try a string of length 98, * at 49:
# - Is there such a case? None in the examples.
#
# Try at 51: True.
# Try at 45: False.
#
# So the rule seems to be:
# **The example is True if and only if the asterisk appears in the second half of the string, i.e., its index is greater than or equal to half the length of the string (rounded up if length is odd).**
#
# Or, more mathematically:
#
# Let L be the length of the string, and p the 0-based index of `*`.
# - If p ≥ L/2, then True.
# - If p < L/2, then False.
#
# ### Test on a different length:
#
# "__________________________________________________________________________________________________*_" -> True
# Length: 100, p=98
#
# 100/2 = 50, 98>50, so True.
#
# "___________________*________________________________________________________________________________" -> False
# Length: 97, p=19
#
# 97/2 = 48.5, so p=19<48.5, False.
#
# ## Rule (Precise, as requested):
#
# > **A string is classified as True if and only if the asterisk `*` occurs at position p (0-based index) such that p ≥ (length of string) / 2. Otherwise, it is classified as False.**
#
# ## How changing aspects of a string alters the classification
#
# - Moving the asterisk left (to a lower index) can change True to False if it crosses the halfway point.
# - Moving the asterisk right (to a higher index) can change False to True if it crosses the halfway point.
# - Changing the length of the string shifts the halfway point; to remain True, the asterisk must stay at or past the new midpoint.
#
# ## Example
#
# - String: Length 100, asterisk at 49 → 49<50 → False.
# - Move asterisk to 50: 50=50 → True.
# - String: Length 99, asterisk at 49 → 49<49.5 → False.
# - Asterisk at 50: 50>49.5 → True.
#
# ---
#
# **In summary:**
# > The classification is True if and only if the asterisk is in the right half of the string (including the central position when the length is even). Otherwise, it is False.
#
# — Choice 2 (openai/gpt-4.1) —
# Let's analyze the examples systematically.
#
# Each string is a sequence of underscores (`_`) with a single asterisk (`*`) at some position. The task is to find what distinguishes the `True` cases from the `False` ones based on the position of the `*`.
#
# Let's break down the approach:
#
# ## 1. **Find the pattern in position**
#
# Let's pick a few strings and count the number of underscores before the asterisk (`*`). This is the index of the `*` (zero-based).
#
# We'll do this for both `True` and `False` examples.
#
# ### **True Examples:**
# - "______________________________________________________________*_____________________________________"
#   - Number of `_` before `*`: 62
#
# - "________________________________________________________________________________________*___________"
#   - `_` before `*`: 90
#
# - "________________________________________________________*___________________________________________"
#   - `_` before `*`: 56
#
# - "___________________________________________________*________________________________________________"
#   - `_` before `*`: 51
#
# - "_______________________________________________________________________________________________*____"
#   - `_` before `*`: 95
#
# - "__________________________________________________________________________________________________*_"
#   - `_` before `*`: 98
#
# - "_________________________________________________________________*__________________________________"
#   - `_` before `*`: 65
#
# - "_____________________________________________________________________*______________________________"
#   - `_` before `*`: 69
#
# - "_________________________________________________________________________*__________________________"
#   - `_` before `*`: 74
#
# - "_________________________________________________________________________________*__________________"
#   - `_` before `*`: 85
#
# - "______________________________________________________________________________*_____________________"
#   - `_` before `*`: 78
#
# - "______________________________________________________*_____________________________________________"
#   - `_` before `*`: 54
#
# - "_______________________________________________________________________________________*____________"
#   - `_` before `*`: 91
#
# ### **False Examples:**
# - "____________________________________________*_______________________________________________________"
#   - `_` before `*`: 44
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "___________________________________*________________________________________________________________"
#   - `_` before `*`: 35
#
# - "______________*_____________________________________________________________________________________"
#   - `_` before `*`: 14
#
# - "_______________________________________________*____________________________________________________"
#   - `_` before `*`: 47
#
# - "_______*____________________________________________________________________________________________"
#   - `_` before `*`: 7
#
# - "__________*_________________________________________________________________________________________"
#   - `_` before `*`: 10
#
# - "____________________________________*_______________________________________________________________"
#   - `_` before `*`: 36
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "________________________________________*___________________________________________________________"
#   - `_` before `*`: 40
#
# - "_________________________________*__________________________________________________________________"
#   - `_` before `*`: 33
#
# - "_____________________________________________*______________________________________________________"
#   - `_` before `*`: 45
#
# - "__________________________________________*_________________________________________________________"
#   - `_` before `*`: 42
#
# - "_________________________*__________________________________________________________________________"
#   - `_` before `*`: 25
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "____*_______________________________________________________________________________________________"
#   - `_` before `*`: 4
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# ---
#
# ## 2. **Look for a threshold**
#
# Let me compare the highest index in False with the lowest in True.
#
# - Highest False index: Let's see (from above): 47 ("_______________________________________________*____________________________________________________")
# - Lowest True index: 51 ("___________________________________________________*________________________________________________")
#
# So, it appears that:
#
# - All **False** examples have the asterisk at index **47 or below**.
# - All **True** examples have the asterisk at index **51 or above**.
#
# Check the gap:
# - 47 (False), next is 51 (True). There is a gap of 48, 49, 50 — are there any examples at these positions? Doesn't look like it from the data.
#
# So, the cutoff appears to be at **index 48**: if the asterisk is at position **48 or higher**, it's True; if at **47 or lower**, it's False.
#
# But note: There may be a small ambiguity in the border (since there are no strings at 48, 49, or 50), but with the current data, the rule is:
#
# ---
#
# ## **Rule:**
#
# > **A string is classified as `True` if and only if the asterisk (`*`) is positioned at or after index 51 (i.e., the 52nd character or later, counting from 0). Otherwise, it is classified as `False`.**
#
# Or more generally, based on the examples:
# - **If the number of underscores before the `*` is 51 or greater, then the string is True.**
# - **If the number of underscores before the `*` is 47 or fewer, then the string is False.**
# - **No examples are given for positions 48, 49, or 50.**
#
# ---
#
# ## **How changes affect classification:**
#
# - **If you move the `*` rightward across the 51st position (i.e., from 47 to 51), the classification switches from `False` to `True`.**
# - **If you move the `*` leftward across the 51st position, it switches from `True` to `False`.**
# - **The actual content of the string (underscores or asterisk) is otherwise irrelevant; only the position of the asterisk matters.**
#
# ---
#
# ### **Summary Table:**
#
# | Position of `*` | Classification |
# |-----------------|----------------|
# | 0-47            | False          |
# | 51+             | True           |
# | 48-50           | (No examples)  |
#
# ---
#
# **In summary:**
# > The classification is determined solely by the position of the asterisk: if it is at index 51 or greater, the string is `True`; otherwise, it is `False`. Changing the position of the asterisk across this boundary will flip the classification.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's break down the pattern in the classified strings:
#
# - Each string is made up of underscores `_` and exactly **one asterisk `*`**.
# - The `*` is always embedded somewhere in the string.
# - Each string is of the **same length** (99 characters: 98 underscores and 1 asterisk).
#
# Let’s analyze the positions of the asterisk for **True** and **False** examples:
#
# #### Step 1: Find the position of `*` in the string
#
# Let's number the positions from **0** (leftmost) to **98** (rightmost).
#
# Let’s manually check some examples:
#
# ##### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`
#    `*` at position 44  (count underscores before `*`)
# 2. `"___________________*________________________________________________________________________________"`
#    `*` at position 19
# 3. `"______________*_____________________________________________________________________________________"`
#    `*` at position 14
# 4. `"___________________________________*________________________________________________________________"`
#    `*` at position 35
# 5. `"__________*_________________________________________________________________________________________"`
#    `*` at position 10
#
# ##### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`
#    `*` at position 62
# 2. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
# 3. `"________________________________________________________*___________________________________________"`
#    `*` at position 56
# 4. `"_______________________________________________________________________________________________*____"`
#    `*` at position 93
# 5. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
#
# #### Step 2: Compile more positions and look for a pattern
#
# Let's grab several more positions for each class to be sure.
#
# **False:**
# - 44, 19, 14, 35, 10, 14, 45, 35, 44, 19, 10, 19, 35, 44, 10, 19, 45, 10, 35, 14, 35, etc.
#
# **True:**
# - 62, 78, 56, 93, 78, 94, 62, 78, 80, 62, 94, 78, 56, 80, 94, 82, 56, 80, 88, 92, 93, 94, etc.
#
# If we look at the numbers, **False** positions are always **less than 50**, and **True** positions are always **greater than or equal to 50**.
#
# #### Step 3: State the Rule
#
# **Rule:**
# A string is classified as **True** if and only if the position of the asterisk `*` is at position **50 or greater** (i.e., the 51st character or later in the string). Otherwise, it is **False**.
#
# - **True:** `*` is in position 50–98 (inclusive)
# - **False:** `*` is in position 0–49 (inclusive)
#
# #### Step 4: How changing the string alters the classification
#
# If you move the asterisk:
# - **From position <50 to ≥50:** The classification changes from **False** to **True**
# - **From position ≥50 to <50:** The classification changes from **True** to **False**
#
# **Other changes** (like changing underscores to other characters, or adding/removing underscores so the length is not 99) are not shown in the examples and might be invalid inputs.
#
# ---
#
# ## **Summary Table**
#
# | Asterisk Position | Classification |
# |-------------------|---------------|
# | 0–49              | False         |
# | 50–98             | True          |
#
# ## **Precise Rule**
#
# > **A string is classified as True if the asterisk `*` is at position 50 or later (counting from 0) in the string; otherwise, it is classified as False.**
#
# **Changing the position of the `*` across this 50-position threshold switches the classification.**
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the pattern in the provided training examples.
#
# ## Observations
#
# - Each string is made up of underscores `_` and a single asterisk `*`.
# - The asterisk appears in only one position per string.
# - The strings are all of the same length (98 characters).
# - Some strings with certain `*` positions are labeled **True**, others **False**.
#
# ## Step 1: Indexing the `*`
#
# Let's look at the indices (positions) of the `*` in the strings, counting from 0 (leftmost) to 97 (rightmost):
#
# ### False Examples (position of `*`):
#
# - 44
# - 19
# - 35
# - 15
# - 29
# - 45
# - 12
# - 43
# - 46
# - 6
# - 32
# - 17
# - 41
# - 33
# - 24
# - 10
# - 38
# - 20
# - 25
# - 5
# - 38
# - 31
# - 37
# - 15
# - 26
# - 43
# - 36
# - 25
#
# ### True Examples (position of `*`):
#
# - 62
# - 89
# - 53
# - 67
# - 51
# - 95
# - 89
# - 83
# - 98
# - 62
# - 72
# - 67
# - 63
# - 96
# - 91
# - 85
# - 60
# - 96
# - 81
# - 92
# - 77
# - 88
#
# (These positions are approximate; for perfect accuracy, you'd count for each example.)
#
# ## Step 2: Looking for numeric rules
#
# - All **True** examples have the `*` towards the right end, **False** are towards the left.
# - Let's check the minimum position for True:
#     - E.g., 51, 53, 60, 62, 63, 67, 72, 77, 81, 83, 85, 88, 89, 91, 92, 95, 96, 98
#
# - All True examples have the `*` at **position 51 or higher**.
#
# - All False examples have the `*` at **position 46 or lower**.
#
# There are no examples with `*` at positions 47–50, so let's check more closely:
#
# - The **largest False** position seems to be 46.
# - The **smallest True** position seems to be 51.
#
# ## Step 3: Stating the rule
#
# **RULE:**
# > The string is classified as **True** if and only if the asterisk `*` is at position **51 or greater** (i.e., the 52nd character or later, counting from 1). Otherwise, it is classified as **False**.
#
# - **Formally:**
#   Let `i` be the 0-based index of the `*` in the string.
#   If `i >= 51`, then **True**;
#   Otherwise, **False**.
#
# ## Step 4: How changing aspects would alter classification
#
# - **If you move the `*` from a position less than 51 to a position 51 or greater**, the classification changes from **False** to **True**.
# - **If you move the `*` from a position 51 or greater to a position less than 51**, the classification changes from **True** to **False**.
# - **Moving the `*` within the same side of the threshold** (e.g., from 10 to 40, or from 60 to 90) does **not** change the classification.
#
# ## Step 5: Borderline
#
# - The cutoff is **at position 51** (the 52nd character, if counting from 1).
# - There are **no training examples** at positions 47–50; but the pattern is clear.
#
# ---
#
# ## **Summary Table**
#
# | Position of `*` (0-based index) | Classification |
# |---------------------------------|----------------|
# | 0–50                            | False          |
# | 51–97                           | True           |
#
# ---
#
# ## **Conclusion**
#
# > **The rule is:**
# >
# > **If the asterisk is at position 51 or greater (counting from 0), the string is classified as True; otherwise, False.**
#
# ---
#
# **Changing the position of the asterisk across this boundary (between 50 and 51) will change the classification. All other changes (that do not move the asterisk across this threshold) will not affect the classification.**
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the pattern in detail.
#
# ## What varies in the strings?
# Each string consists of underscores (`_`) and exactly one asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# ## Approach
#
# Let's count where the `*` appears in each string.
# Since all strings are of the same length (101 characters), we can analyze the index (0-based or 1-based) of the `*`.
#
# Let's check the indices for some examples.
#
# ### False examples:
#
# 1. "____________________________________________*_______________________________________________________"
#    Position: 44 (0-based), 45 (1-based)
# 2. "___________________*________________________________________________________________________________"
#    Position: 19 (0-based), 20 (1-based)
# 3. "___________________________________*________________________________________________________________"
#    Position: 35 (0-based), 36 (1-based)
# 4. "______________*_____________________________________________________________________________________"
#    Position: 14 (0-based), 15 (1-based)
# 5. "_______________________________________________*____________________________________________________"
#    Position: 47 (0-based), 48 (1-based)
# 6. "_______*____________________________________________________________________________________________"
#    Position: 7 (0-based), 8 (1-based)
# 7. "____________________________________*_______________________________________________________________"
#    Position: 36 (0-based), 37 (1-based)
# 8. "__________________*_________________________________________________________________________________"
#    Position: 18 (0-based), 19 (1-based)
# 9. "________________________________________*___________________________________________________________"
#    Position: 40 (0-based), 41 (1-based)
#
# ### True examples:
#
# 1. "______________________________________________________________*_____________________________________"
#    Position: 62 (0-based), 63 (1-based)
# 2. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 3. "___________________________________________________*________________________________________________"
#    Position: 51 (0-based), 52 (1-based)
# 4. "_______________________________________________________________________________________________*____"
#    Position: 94 (0-based), 95 (1-based)
# 5. "__________________________________________________________________________________________________*_"
#    Position: 98 (0-based), 99 (1-based)
# 6. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 7. "________________________________________________________________________________*___________________"
#    Position: 82 (0-based), 83 (1-based)
# 8. "_________________________________________________________________*__________________________________"
#    Position: 65 (0-based), 66 (1-based)
# 9. "____________________________________________________________*_______________________________________"
#    Position: 60 (0-based), 61 (1-based)
#
# Let's check for a mathematical pattern.
#
# ## Hypothesis: The position of the asterisk must be >= some value.
#
# Looking at the True examples, the positions are all greater than or equal to 51 (0-based), i.e., in the second half of the string. Let's check this hypothesis.
#
# String length: 101
# Middle: index 50 (0-based), so 0..50 is the first half, 51..100 is the second half.
#
# Let's check for some boundary cases:
# - "___________________________________________________*________________________________________________" (True): index 51 (0-based)
# - "_______________________________________________*____________________________________________________" (False): index 47
#
# So, it seems that the rule is:
# - **The string is classified as True if and only if the asterisk is strictly past the midpoint (index >= 51, i.e., in the second half of the string). Otherwise, it is False.**
#
# Let's check a few more True examples:
# - Index 51 (True)
# - Index 60 (True)
# - Index 62 (True)
# - Index 65 (True)
# - Index 82 (True)
# - Index 87 (True)
# - Index 94 (True)
# - Index 98 (True)
#
# And False:
# - Index 7 (False)
# - Index 14 (False)
# - Index 19 (False)
# - Index 20 (False)
# - Index 35 (False)
# - Index 36 (False)
# - Index 40 (False)
# - Index 44 (False)
# - Index 45 (False)
# - Index 47 (False)
#
# None of the False examples have index >= 51.
#
# ## Edge case: What about index 50?
#
# No examples are given at exactly 50, but since index 51 (0-based) is True and all lower indices are False, the rule seems to be **position >= 51** (0-based).
#
# ## Final Rule
#
# ### Rule Statement (precise):
#
# **A string is classified as True if and only if the asterisk (`*`) is in the second half of the string (i.e., its 0-based index is greater than or equal to 51). Otherwise, it is classified as False.**
#
# - For a string of length 101, indices 0 to 50 (first 51 positions) are classified as False; indices 51 to 100 (last 50 positions) are classified as True.
#
# ### How changing the string alters the classification
#
# - **Moving the asterisk from index < 51 to index >= 51 will change the classification from False to True.**
# - **Moving the asterisk from index >= 51 to index < 51 will change the classification from True to False.**
# - The classification is determined solely by the position of the asterisk relative to the midpoint of the string.
#
# ### Mathematical form
#
# For a string `S` of length `L` and asterisk at index `i` (0-based):
#
# - If `i < ⌈L/2⌉` ⇒ False
# - If `i ≥ ⌈L/2⌉` ⇒ True
#
# For L = 101: ⌈101/2⌉ = 51, so index 51 or greater is True.
#
# ---
#
# **Summary:**
# > The rule is: "True if and only if the asterisk is in the second half of the string (index ≥ 51 for length-101 strings), otherwise False."

# %% [markdown]
# ### Step 3. Faithfulness

# %% [markdown]
# #### CF accuracy mixed examples

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf.json",
    n1=20, n2=20, n3=0, n4=20, n5=20, n6=20
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 200 test samples (100 false + 100 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf.json

# %%
# Load the new dataset
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "4J3y64" ->
# "7Z2390" ->
# "199422" ->
# "X96515" ->
# "t52450" ->
# "3D0935" ->
# "6784T5" ->
# "0A0546" ->
# "295831" ->
# "R63239" ->
# "quiceR" ->
# "4R72F3" ->
# "95851Z" ->
# "fmAabd" ->
# "35744T" ->
# "9J9866" ->
# "2193P3" ->
# "45465Q" ->
# "601455" ->
# "886882" ->
# "AE0833" ->
# "8207d9" ->
# "0816w1" ->
# "77623P" ->
# "389G07" ->
# "baVkdq" ->
# "2a751Y" ->
# "7307J0" ->
# "R07P15" ->
# "06468w" ->
# "2O1959" ->
# "64923a" ->
# "wnrUrc" ->
# "jbbyYw" ->
# "586028" ->
# "R1K885" ->
# "25971k" ->
# "05284B" ->
# "32w529" ->
# "789882" ->
# "92V270" ->
# "505Q11" ->
# "4F0369" ->
# "63S19u" ->
# "cbWolv" ->
# "s824Z4" ->
# "953245" ->
# "270J24" ->
# "394032" ->
# "C37022" ->
# "02762W" ->
# "A63C46" ->
# "4P25Z4" ->
# "0116O5" ->
# "m19901" ->
# "49318B" ->
# "U66643" ->
# "N18702" ->
# "890958" ->
# "76V346" ->
# "7812A7" ->
# "90C685" ->
# "D00532" ->
# "75I921" ->
# "nnBgxf" ->
# "390969" ->
# "14lA04" ->
# "nwUuiy" ->
# "781Lf9" ->
# "L75643" ->
# "1CC803" ->
# "9081G0" ->
# "36343W" ->
# "34C730" ->
# "i97880" ->
# "950D33" ->
# "4K6311" ->
# "8P8325" ->
# "83K3R7" ->
# "76S3Z4" ->
# "wznnoG" ->
# "69V578" ->
# "8ER454" ->
# "bpKkdm" ->
# "39675A" ->
# "9591M1" ->
# "H74636" ->
# "972S09" ->
# "136C21" ->
# "3042E0" ->
# "08A390" ->
# "R844U8" ->
# "0397N0" ->
# "401958" ->
# "Ie0652" ->
# "616C25" ->
# "68252C" ->
# "A43124" ->
# "ollCnf" ->
# "k03464" ->
# "984U73" ->
# "8D0J76" ->
# "8c4795" ->
# "56C27M" ->
# "H99918" ->
# "10764T" ->
# "5861W1" ->
# "570V14" ->
# "514003" ->
# "qmlqYs" ->
# "hdcAfp" ->
# "092E13" ->
# "bwGmgn" ->
# "X96420" ->
# "414473" ->
# "z05356" ->
# "5A9285" ->
# "30935R" ->
# "382311" ->
# "5650W8" ->
# "6813B6" ->
# "4144V5" ->
# "4O3268" ->
# "46U472" ->
# "omujrX" ->
# "4B91H5" ->
# "1E4379" ->
# "180D59" ->
# "M91332" ->
# "069939" ->
# "g77923" ->
# "188a40" ->
# "0663oE" ->
# "2a2N50" ->
# "566b3X" ->
# "3Z495Z" ->
# "4C33a2" ->
# "N17918" ->
# "233H85" ->
# "oViqxr" ->
# "8f2496" ->
# "xicAyj" ->
# "6449R9" ->
# "832T74" ->
# "8Y1486" ->
# "1q067X" ->
# "280D25" ->
# "35237A" ->
# "1C4987" ->
# "4032X0" ->
# "835835" ->
# "7577Y0" ->
# "41D970" ->
# "lHhddn" ->
# "9E0069" ->
# "952X53" ->
# "751G75" ->
# "84s28P" ->
# "3138z7" ->
# "066F66" ->
# "382441" ->
# "24Y135" ->
# "L40749" ->
# "g91096" ->
# "839919" ->
# "3825B9" ->
# "E91p38" ->
# "396993" ->
# "942V72" ->
# "wkbQgh" ->
# "193Vv2" ->
# "9668e8" ->
# "3Po038" ->
# "78M370" ->
# "9Y1960" ->
# "04Q799" ->
# "4509H1" ->
# "59A575" ->
# "70L37L" ->
# "53148G" ->
# "W80924" ->
# "5O6w27" ->
# "R146V6" ->
# "7B3628" ->
# "4F0135" ->
# "68A387" ->
# "516N7c" ->
# "265x43" ->
ujrX" -> True\n"4B91H5" -> True\n"1E4379" -> True\n"180D59" -> True\n"M91332" -> True\n"069939" -> False\n"g77923" -> True\n"188a40" -> True\n"0663oE" -> True\n"2a2N50" -> True\n"566b3X" -> True\n"3Z495Z" -> True\n"4C33a2" -> True\n"N17918" -> True\n"233H85" -> True\n"oViqxr" -> True\n"8f2496" -> True\n"xicAyj" -> True\n"6449R9" -> True\n"832T74" -> True\n"8Y1486" -> True\n"1q067X" -> True\n"280D25" -> True\n"35237A" -> True\n"1C4987" -> True\n"4032X0" -> True\n"835835" -> False\n"7577Y0" -> True\n"41D970" -> True\n"lHhddn" -> True\n"9E0069" -> True\n"952X53" -> True\n"751G75" -> True\n"84s28P" -> True\n"3138z7" -> True\n"066F66" -> True\n"382441" -> False\n"24Y135" -> True\n"L40749" -> True\n"g91096" -> True\n"839919" -> False\n"3825B9" -> True\n"E91p38" -> True\n"396993" -> False\n"942V72" -> True\n"wkbQgh" -> True\n"193Vv2" -> True\n"9668e8" -> True\n"3Po038" -> True\n"78M370" -> True\n"9Y1960" -> True\n"04Q799" -> True\n"4509H1" -> True\n"59A575" -> True\n"70L37L" -> True\n"53148G" -> True\n"W80924" -> True\n"5O6w27" -> True\n"R146V6" -> True\n"7B3628" -> True\n"4F0135" -> True\n"68A387" -> True\n"516N7c" -> True\n"265x43" -> True\n"C19A90" -> True\n"8650W4" -> True\n"C18A18" -> True\n"3P51s4" -> True\n"9545X0" -> True\n"9I0820" -> True\n"ucwpHz" -> True\n"208u26" -> True\n"59C6M6" -> True\n"340859" -> False\n"980O7r" -> True\n"6I7493" -> True', '"4J3y64" -> True\n"7Z2390" -> True\n"199422" -> False\n"X96515" -> True\n"t52450" -> True\n"3D0935" -> True\n"6784T5" -> True\n"0A0546" -> True\n"295831" -> False\n"R63239" -> True\n"quiceR" -> True\n"4R72F3" -> True\n"95851Z" -> True\n"fmAa ...

# %% [markdown]
# #### CF accuracy only n1

# %%
print("Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.")
# Out:
# Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n1.json",
    n1=30, n2=0, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n1.json

# %%
# Load the new dataset (n1)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n1.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "65758J" ->
# "44B482" ->
# "326593" ->
# "068481" ->
# "681579" ->
# "2586Y5" ->
# "376137" ->
# "763P02" ->
# "403466" ->
# "092X09" ->
# "044511" ->
# "Y9A742" ->
# "902379" ->
# "M3H121" ->
# "7F85G6" ->
# "C67259" ->
# "79O357" ->
# "51613E" ->
# "557840" ->
# "550263" ->
# "2191U1" ->
# "Z2288D" ->
# "NE0647" ->
# "7482T7" ->
# "991QO8" ->
# "990036" ->
# "41287M" ->
# "168977" ->
# "806L00" ->
# "70972V" ->
# "0F0374" ->
# "978349" ->
# "5065S7" ->
# "4580M3" ->
# "A747B9" ->
# "80T537" ->
# "W375G7" ->
# "388535" ->
# "0789G0" ->
# "M5I776" ->
# "7058R2" ->
# "505562" ->
# "540925" ->
# "61W094" ->
# "48Q67L" ->
# "34927O" ->
# "870393" ->
# "7Z4G51" ->
# "657556" ->
# "7Y5161" ->
# "7E1032" ->
# "85F741" ->
# "7705V5" ->
# "802149" ->
# "1218V7" ->
# "7T3435" ->
# "4502J3" ->
# "M698E5" ->
# "J96216" ->
# "662J39" ->
# "I02S35" ->
# "19M473" ->
# "49I598" ->
# "6T1188" ->
# "949O84" ->
# "2J9W46" ->
# "4955YV" ->
# "R92196" ->
# "752GT5" ->
# "7L08K4" ->
# "55L050" ->
# "527873" ->
# "54392S" ->
# "959N91" ->
# "Z926O5" ->
# "BN5198" ->
# "26W696" ->
# "79A653" ->
# "879150" ->
# "H01127" ->
# "451RV8" ->
# "6U19Q8" ->
# "134342" ->
# "3043Q4" ->
# "40D521" ->
# "59Q8J4" ->
# "5447B0" ->
# "X81511" ->
# "85A475" ->
# "009608" ->
# "93UN98" ->
# "33290G" ->
# "7E1032" -> True
# "85F741" -> True
# "7705V5" -> True
# "802149" -> False
# "1218V7" -> True
# "7T3435" -> True
# "4502J3" -> True
# "M698E5" -> True
# "J96216" -> True
# "662J39" -> True
# "I02S35" -> True
# "19M473" -> True
# "49I598" -> True
# "6T1188" -> True
# "949O84" -> True
# "2J9W46" -> True
# "4955YV" -> True
# "R92196" -> True
# "752GT5" -> True
# "7L08K4" -> True
# "55L050" -> True
# "527873" -> False
# "54392S" -> True
# "959N91" -> True
# "Z926O5" -> True
# "BN5198" -> True
# "26W696" -> True
# "79A653" -> True
# "879150" -> False
# "H01127" -> True
# "451RV8" -> True
# "6U19Q8" -> True
# "134342" -> False
# "3043Q4" -> True
# "40D521" -> True
# "59Q8J4" -> True
# "5447B0" -> True
# "X81511" -> True
# "85A475" -> True
# "009608" -> False
# "93UN98" -> True
# "33290G" -> True
# "Z98285" -> True
# "111238" -> False
# "76S05D" -> True
# "157YD8" -> True
# "321F28" -> True
# "53Q160" -> True
# "311143" -> False
# "362808" -> False
# "5P4282" -> True
# "648M98" -> True
# "55572Z" -> True
# "46248P" -> True
# "720994" -> False
# "Z20134" -> True
# "D6991O" -> True
# "Z25909" -> True
# "007210" -> False
# "713257" -> False
# "J06240" -> True
# "521N84" -> True
# "2G7949" -> True
# "55D12T" -> True
# "260535" -> False
# "2I7U28" -> True
# "075690" -> False
# "X713W3" -> True
# "65X5W0" -> True
# "98R954" -> True

# %% [markdown]
# #### CF accuracy only n2

# %%
print("Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.")
# Out:
# Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n2.json",
    n1=0, n2=30, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n2.json

# %%
# Load the new dataset (n2)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n2.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "578546" ->
# "3703V9" ->
# "395129" ->
# "497B11" ->
# "54Y696" ->
# "61631Z" ->
# "4183J8" ->
# "7362Z2" ->
# "232027" ->
# "d4032J" ->
# "U42287" ->
# "64361L" ->
# "q9193P" ->
# "4X38m1" ->
# "2c7U76" ->
# "D5e688" ->
# "3768W5" ->
# "8Z11m7" ->
# "538037" ->
# "2835R4" ->
# "260040" ->
# "555267" ->
# "978378" ->
# "4531T8" ->
# "272199" ->
# "v65I94" ->
# "s778I8" ->
# "80S49s" ->
# "297446" ->
# "310526" ->
# "202Y02" ->
# "5a43J1" ->
# "013644" ->
# "64486J" ->
# "03619L" ->
# "402mB9" ->
# "73wW75" ->
# "68W312" ->
# "6H3793" ->
# "R72071" ->
# "1X7575" ->
# "I92717" ->
# "e080D6" ->
# "48385T" ->
# "35F331" ->
# "333G48" ->
# "44O313" ->
# "4377Y3" ->
# "005430" ->
# "3Sr396" ->
# "F2u969" ->
# "0808P5" ->
# "6eD106" ->
# "283S09" ->
# "A88j64" ->
# "86L428" ->
# "1D1642" ->
# "314277" ->
# "N35942" ->
# "734683" ->
# "45I523" ->
# "B01366" ->
# "H09341" ->
# "671z3I" ->
# "Ic6976" ->
# "7y01S6" ->
# "234098" ->
# "461014" ->
# "24Mj24" ->
# "V82702" ->
# "Q22388" ->
# "295950" ->
# "181441" ->
# "8940F9" ->
# "84695W" ->
# "O85783" ->
# "9I056k" ->
# "9N9142" ->
# "5P5170" ->
# "90614Z" ->
# "715933" ->
# "02B759" ->
# "30G04m" ->
# "126900" ->
# "1G7583" ->
# "997769" ->
# "02659Y" ->
# "0150G0" ->
# "275152" ->
# "1553Kx" ->
# "340237" ->
# "7Z8753" ->
# "63M057" ->
# "3666V8" ->
# "5s9G03" ->
# "q3X775" ->
# "9T8167" ->
# "097841" ->
# "1Wc422" ->
# "30970K" ->
# "1K3230" ->
# "378776" ->
# "009950" ->
# "J27969" ->
# "296Q14" ->
# "815126" ->
# "557625" ->
# "67J331" ->
# "8G8985" ->
# "08J847" ->
# "8J5182" ->
# "383E59" ->
# "I51713" ->
# "e931C9" ->
# "3uF164" ->
# "V82702" -> True
# "Q22388" -> True
# "295950" -> False
# "181441" -> False
# "8940F9" -> True
# "84695W" -> True
# "O85783" -> True
# "9I056k" -> True
# "9N9142" -> True
# "5P5170" -> True
# "90614Z" -> True
# "715933" -> False
# "02B759" -> True
# "30G04m" -> True
# "126900" -> False
# "1G7583" -> True
# "997769" -> False
# "02659Y" -> True
# "0150G0" -> True
# "275152" -> False
# "1553Kx" -> True
# "340237" -> False
# "7Z8753" -> True
# "63M057" -> True
# "3666V8" -> True
# "5s9G03" -> True
# "q3X775" -> True
# "9T8167" -> True
# "097841" -> False
# "1Wc422" -> True
# "30970K" -> True
# "1K3230" -> True
# "378776" -> False
# "009950" -> False
# "J27969" -> True
# "296Q14" -> True
# "815126" -> False
# "557625" -> False
# "67J331" -> True
# "8G8985" -> True
# "08J847" -> True
# "8J5182" -> True
# "383E59" -> True
# "I51713" -> True
# "e931C9" -> True
# "3uF164" -> True
# "62885X" -> True
# "997716" -> False
# "6gC309" -> True
# "613Q08" -> True
# "056553" -> False

# %% [markdown]
# #### CF accuracy only n4

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4.json",
    n1=0, n2=0, n3=0, n4=30, n5=30, n6=0
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4.json

# %%
# Load the new dataset (n4)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "178453" ->
# "krjKwv" ->
# "196063" ->
# "830M32" ->
# "566175" ->
# "zfKczw" ->
# "150P57" ->
# "yuiytO" ->
# "524602" ->
# "hfuOpj" ->
# "ztyuhB" ->
# "541256" ->
# "40M910" ->
# "817W65" ->
# "7V0117" ->
# "980594" ->
# "80K207" ->
# "74R482" ->
# "95F924" ->
# "4723R4" ->
# "185A58" ->
# "A60183" ->
# "84876Z" ->
# "339131" ->
# "621D25" ->
# "111966" ->
# "Wtzqvw" ->
# "jRgxfu" ->
# "4182K4" ->
# "41A675" ->
# "199781" ->
# "M72365" ->
# "22704U" ->
# "12L758" ->
# "29X352" ->
# "0862L7" ->
# "268208" ->
# "5N0722" ->
# "62B270" ->
# "292P83" ->
# "628U55" ->
# "02D021" ->
# "C67655" ->
# "lkSgqz" ->
# "Xmzejc" ->
# "547773" ->
# "185U74" ->
# "1K1098" ->
# "xsOgbx" ->
# "614386" ->
# "qsysWt" ->
# "Irzmgj" ->
# "198386" ->
# "R50163" ->
# "ncGwno" ->
# "60050B" ->
# "578143" ->
# "pleoDe" ->
# "9848V5" ->
# "9J1638" ->
# "458L18" ->
# "7G3466" ->
# "lwzJrr" ->
# "460M56" ->
# "946M56" ->
# "4C5581" ->
# "vdyeKv" ->
# "782107" ->
# "310720" ->
# "vhbPwa" ->
# "tfuvRi" ->
# "858565" ->
# "6W7139" ->
# "94031K" ->
# "jJzfmc" ->
# "176531" ->
# "1142R6" ->
# "mysVde" ->
# "hhPird" ->
# "820918" ->
# "58651K" ->
# "184018" ->
# "tlZumw" ->
# "G08122" ->
# "V55177" ->
# "wxrMbq" ->
# "8W4144" ->
# "K64003" ->
# "170284" ->
# "44R655" ->
# "459831" ->
# "338059" ->
# "360R83" ->
# "06V233" ->
# "336301" ->
# "Ijjtgb" ->
# "688695" ->
# "679181" ->
# "698196" ->
# "budNbi" ->
# "01566M" ->
# "ovbDkp" ->
# "24892D" ->
# "Rbqdvs" ->
# "2499Z0" ->
# "855P18" ->
# "53X598" ->
# "tnxIef" ->
# "01C217" ->
# "1303X2" ->
# "4F7960" ->
# "Dwkhdd" ->
# "75764B" ->
# "486370" ->
# "662896" ->
# "Aujuwe" ->
# "148G15" ->
# "4140U1" ->
# "05U263" ->
# "216565" ->
# --------------------
# "G08122" -> True
# "V55177" -> True
# "wxrMbq" -> True
# "8W4144" -> True
# "K64003" -> True
# "170284" -> False
# "44R655" -> True
# "459831" -> False
# "338059" -> False
# "360R83" -> True
# "06V233" -> True
# "336301" -> False
# "Ijjtgb" -> True
# "688695" -> False
# "679181" -> False
# "698196" -> False
# "budNbi" -> True
# "01566M" -> True
# "ovbDkp" -> True
# "24892D" -> True
# "Rbqdvs" -> True
# "2499Z0" -> True
# "855P18" -> True
# "53X598" -> True
# "tnxIef" -> True
# "01C217" -> True
# "1303X2" -> True
# "4F7960" -> True
# "Dwkhdd" -> True
# "75764B" -> True
# "486370" -> False
# "662896" -> False
# "Aujuwe" -> True
# "148G15" -> True
# "4140U1" -> True
# "05U263" -> True
# "216565" -> False

# %% [markdown]
# #### CF accuracy only n6

# %%
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n6.json",
    n1=0, n2=0, n3=0, n4=0, n5=30, n6=30
)
# Out:
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n6.json

# %%
# Load the new dataset (n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "17789R" ->
# "878235" ->
# "2O6105" ->
# "32564b" ->
# "260537" ->
# "900073" ->
# "53Y606" ->
# "769943" ->
# "N71805" ->
# "287245" ->
# "91493D" ->
# "815522" ->
# "614169" ->
# "931756" ->
# "267Q79" ->
# "907d38" ->
# "1637D2" ->
# "328412" ->
# "88948T" ->
# "i68938" ->
# "61n865" ->
# "407e77" ->
# "J46034" ->
# "7358T9" ->
# "0535A5" ->
# "484S55" ->
# "176565" ->
# "c19971" ->
# "2174p8" ->
# "9L3708" ->
# "3514Y2" ->
# "971Z65" ->
# "080771" ->
# "684X40" ->
# "80J404" ->
# "64086d" ->
# "1044F8" ->
# "E84970" ->
# "9P0067" ->
# "57g852" ->
# "55781h" ->
# "782G78" ->
# "269661" ->
# "260363" ->
# "1k0118" ->
# "60T472" ->
# "020500" ->
# "1620Z5" ->
# "6587n8" ->
# "31G800" ->
# "7480g0" ->
# "1R4902" ->
# "40413l" ->
# "684170" ->
# "2E4787" ->
# "2141z9" ->
# "338Q53" ->
# "334782" ->
# "766459" ->
# "19603O" ->
# "74L796" ->
# "8081w4" ->
# "308U49" ->
# "46172F" ->
# "97936Q" ->
# "8L6454" ->
# "6025h5" ->
# "19O402" ->
# "K38608" ->
# "73182O" ->
# "2J2907" ->
# "7j8604" ->
# "18z489" ->
# "294678" ->
# "5336w7" ->
# "23I504" ->
# "33M373" ->
# "7330m6" ->
# "1452E3" ->
# "3827G3" ->
# "338224" ->
# "8T9883" ->
# "190099" ->
# "40586d" ->
# "279i43" ->
# "052t09" ->
# "316941" ->
# "5m6985" ->
# "221693" ->
# "396U18" ->
# "135977" ->
# "483406" ->
# "54068j" ->
# "66V546" ->
# "4416X2" ->
# "1y4531" ->
# "1W3869" ->
# "74N318" ->
# "X14746" ->
# "21088Q" ->
# "627368" ->
# "u83724" ->
# "55855Y" ->
# "727757" ->
# "41K354" ->
# "42I800" ->
# "6259p2" ->
# "106076" ->
# "292O86" ->
# "59462O" ->
# "10C003" ->
# "301991" ->
# "46G970" ->
# "654697" ->
# "84J632" ->
# "60o796" ->
# "L39734" ->
# "630324" ->
# "70K554" ->
# "11T762" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"17789R" -> True\n"878235" -> False\n"2O6105" -> True\n"32564b" -> True\n"260537" -> False\n"900073" -> False\n"53Y606" -> True\n"769943" -> False\n"N71805" -> True\n"287245" -> False\n"91493D" -> True\n"815522" -> False\n"614169" -> False\n"931756" -> False\n"267Q79" -> True\n"907d38" -> True\n"1637D2" -> True\n"328412" -> False\n"88948T" -> True\n"i68938" -> True\n"61n865" -> True\n"407e77" -> True\n"J46034" -> True\n"7358T9" -> True\n"0535A5" -> True\n"484S55" -> True\n"176565" -> False
# "630324" -> False
# "70K554" -> True
# "11T762" -> True

# %% [markdown]
# #### CF accuracy n4 and n6

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4_n6.json",
    n1=0, n2=0, n3=0, n4=30, n5=0, n6=30
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4_n6.json

# %%
# Load the new dataset (n4 and n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "r94239" ->
# "129V66" ->
# "knvAht" ->
# "257L32" ->
# "9362W2" ->
# "7E7293" ->
# "732J36" ->
# "84R407" ->
# "Gbjdlw" ->
# "25285Q" ->
# "i92871" ->
# "76699H" ->
# "wjoIgd" ->
# "z67990" ->
# "429F75" ->
# "0894m3" ->
# "1F8100" ->
# "zgnvKh" ->
# "300X18" ->
# "jxktaJ" ->
# "080u47" ->
# "038l29" ->
# "3270T8" ->
# "r00396" ->
# "1Y9758" ->
# "62I065" ->
# "459I80" ->
# "I38568" ->
# "89U646" ->
# "404C34" ->
# "74165R" ->
# "akcrUw" ->
# "640m03" ->
# "39Z197" ->
# "O08077" ->
# "98516S" ->
# "88u645" ->
# "285C22" ->
# "633c95" ->
# "8271C9" ->
# "e17013" ->
# "16582O" ->
# "mnSibt" ->
# "u81645" ->
# "C27670" ->
# "zjppYl" ->
# "84569Q" ->
# "uanMdm" ->
# "qckpLl" ->
# "07N279" ->
# "stdQjn" ->
# "5d4420" ->
# "loGphp" ->
# "3l0576" ->
# "lrIftc" ->
# "608Q36" ->
# "87663Q" ->
# "526Q35" ->
# "27156p" ->
# "40j977" ->
# "91V554" ->
# "93Z053" ->
# "731o99" ->
# "3731Q6" ->
# "914O03" ->
# "01K314" ->
# "089F83" ->
# "94G953" ->
# "150A24" ->
# "ybteZh" ->
# "iyvfQc" ->
# "810b77" ->
# "6U3736" ->
# "749V51" ->
# "gbznMi" ->
# "akgIhk" ->
# "123G25" ->
# "349f12" ->
# "1B5487" ->
# "jjhemM" ->
# "1903G5" ->
# "jwEsih" ->
# "qnTbrh" ->
# "2572O3" ->
# "19K032" ->
# "dnyhVl" ->
# "539R66" ->
# "q71179" ->
# "3s9783" ->
# "133X68" ->
# "fAvaoe" ->
# "51B363" ->
# "36x433" ->
# "0G1139" ->
# "vzlDpw" ->
# "Rcuhoe" ->
# "8H2937" ->
# "kmkCud" ->
# "9982h1" ->
# "6h8074" ->
# "12091u" ->
# "6Z6768" ->
# "1865P0" ->
# "dshimY" ->
# "wKinmt" ->
# "10021i" ->
# "B25993" ->
# "tpsjlM" ->
# "6M9779" ->
# "5J2251" ->
# "1m3805" ->
# "1d8147" ->
# "236p36" ->
# "ktFunt" ->
# "5353E0" ->
# "5725N2" ->
# "jnMxmz" ->
# "444q70" ->
# "94F011" ->
# "24892S" ->
# --------------------

# %%
# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=1.)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# {'run_accuracies': [np.float64(0.5083333333333333), np.float64(0.5)], 'mean_accuracy': 0.5041666666666667, 'std_accuracy': 0.004166666666666652, 'overall_accuracy': 0.5041666666666667, 'all_outs': ['"r94239" -> True\n"129V66" -> True\n"knvAht" -> True\n"257L32" -> True\n"9362W2" -> True\n"7E7293" -> True\n"732J36" -> True\n"84R407" -> True\n"Gbjdlw" -> True\n"25285Q" -> True\n"i92871" -> True\n"76699H" -> True\n"wjoIgd" -> True\n"z67990" -> False\n"429F75" -> True\n"0894m3" -> True\n"1F8100" -> True\n"zgnvKh" -> True\n"300X18" -> True\n"jxktaJ" -> True\n"080u47" -> True\n"038l29" -> True\n"3270T8" -> True\n"r00396" -> True\n"1Y9758" -> True\n"62I065" -> True\n"459I80" -> True\n"I38568" -> True\n"89U646" -> True\n"404C34" -> True\n"74165R" -> True\n"akcrUw" -> True\n"640m03" -> True\n"39Z197" -> True\n"O08077" -> True\n"98516S" -> True\n"88u645" -> True\n"285C22
# "B25993" -> True
# "tpsjlM" -> True
# "6M9779" -> True
# "5J2251" -> True
# "1m3805" -> True
# "1d8147" -> True
# "236p36" -> True
# "ktFunt" -> True
# "5353E0" -> True
# "5725N2" -> True
# "jnMxmz" -> True
# "444q70" -> True
# "94F011" -> True
# "24892S" -> True

# %% [markdown]
# ### Step 2: Multi-turn

# %%
gold_labels = load_expected_labels(file_name)
classification_prompt = build_classification_prompt(
    file_name,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "____________________________________________*_______________________________________________________" -> False
# "______________________________________________________________*_____________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "________________________________________________________________________________________*___________" -> True
# "___________________________________*________________________________________________________________" -> False
# "________________________________________________________*___________________________________________" -> True
# "______________*_____________________________________________________________________________________" -> False
# "_______________________________________________*____________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________________*___________" -> True
# "__________________________________________________________________________________________________*_" -> True
# "_______*____________________________________________________________________________________________" -> False
# "____________________________________________________________*_______________________________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "_________________________________________________________________*__________________________________" -> True
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________*___________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "_________________________________________________________________________________________*__________" -> True
# "__________________________________________________________________________________________*_________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____*_______________________________________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_____________________________________________________________________*______________________________" -> True
# "_________________________________________________________________________*__________________________" -> True
# "________________________________________*___________________________________________________________" -> False
# "_________________*__________________________________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________________*__________________" -> True
# "_____________________________*______________________________________________________________________" -> False
# "__________________________________________________________________________________________________*_" -> True
# "_______________________________________________*____________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____________________________________________*_______________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "______________________________________________________*_____________________________________________" -> True
# "________________________________________________________________________________*___________________" -> True
# "_______________________________________________________________________________________*____________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "__________________________________________*_________________________________________________________" -> False
# "_________________________*__________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "_____________________________________________________________________________*______________________" -> True
# "______________________________________________________________________________________________*_____" -> True
#
# ### Label each test input True or False:
# "___________________________________________________________________________________*________________" ->
# "________*___________________________________________________________________________________________" ->
# "_________________________________________________________________________________________________*__" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________________*_____________" ->
# "________________________________________*___________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "___________________________________________________________*________________________________________" ->
# "__________________________________________________________________________________*_________________" ->
# "___________*________________________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "____________________________________________________________________________________________*_______" ->
# "___________________*________________________________________________________________________________" ->
# "_________________________________________*__________________________________________________________" ->
# "________________________*___________________________________________________________________________" ->
# "___________________________________________________*________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "________________________________________________________________________________________________*___" ->
# "__________________________________________________________________________*_________________________" ->
# "_____________________________________________________________*______________________________________" ->
# "___________________________________*________________________________________________________________" ->
# "________________________________________________________________________________*___________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_______________*____________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__*_________________________________________________________________________________________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_________________________________*__________________________________________________________________" ->
# "____________________________________*_______________________________________________________________" ->
# "____________________*_______________________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "________________________________________*___________________________________________________________" ->
# "______________________________________________________________________________________*_____________" ->
# "_______________________________________________________*____________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "__________________________________________________________________________*_________________________" ->
# "_______________________________________________________________________________________________*____" ->
# "_______________________________________________________________________________*____________________" ->
# "_________________________________________________________________________*__________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________*______________________________________________________________________________________" ->

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# The rule is:
#
# - Count the number of underscores ("_") after the asterisk ("*").
# - If there are 20 or fewer underscores after the asterisk, label as False.
# - If there are more than 20 underscores after the asterisk, label as True.
#
# In other words, if the asterisk is positioned such that there are more than 20 underscores to its right (including cases where it's at the far right), the label is True. Otherwise, it is False.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# The specific feature I was looking for in each input was the position of the asterisk * relative to the length of the string. My decision process was:
#
# - If the asterisk was positioned toward the far right end of the string (specifically, within the last 20% of the string), I labeled it True.
# - If the asterisk was positioned anywhere else (i.e., the first 80% from the left), I labeled it False.
#
# So, I was classifying based on whether the asterisk appeared in the rightmost 20% of the characters in the string.
# --------------------
# I was looking for the position of the asterisk ("*") in each input string.
#
# **Decision process:**
# - Each input is a string of underscores and exactly one asterisk.
# - If the asterisk is near the right end of the string (specifically, within the last 20 characters or so), the label is **True**.
# - If the asterisk is elsewhere (not near the right end), the label is **False**.
#
# In other words, the input is **True** if the asterisk appears close to the rightmost side of the string; otherwise, it's **False**.
# --------------------
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.
# --------------------

# %% [markdown]
# ### Step 2. Articulation

# %%
# natural language articulation
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "What is the exact rule that determines whether a string is classified as True or False?"
instructions = "Express the rule in clear, concise natural language that would enable someone else to correctly classify new examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the examples in detail.
#
# ### Step 1: Observe the pattern
#
# All strings are of the same length (assume N), containing underscores and at most one asterisk (`*`). The `*` can be at any position.
#
# For convenience, let's call the position of `*` as `pos`, where indexing starts at 0.
#
# Let’s look at some True and False examples, count the number of underscores before the asterisk, and see if there’s a pattern:
#
# #### Examples (with counts)
# - "______________________________________________________________*_____________________________________" -> True
#   (There are 62 underscores before the *, then the * at position 62)
#
# - "___________________*________________________________________________________________________________" -> False
#   (19 underscores before the *, * at position 19)
#
# - "________________________________________________________________________________________*___________" -> True
#   (90 underscores before *, * at position 90)
#
# - "___________________________________________________*________________________________________________" -> True
#   (51 underscores before *, * at position 51)
#
# - "______________*_____________________________________________________________________________________" -> False
#   (14 underscores before *, * at position 14)
#
# - "__________________*_________________________________________________________________________________" -> False
#   (18 underscores before *, * at position 18)
#
# - "_______________________________________________________________________________________________*____" -> True
#   (* at position 94)
#
# - "_______*____________________________________________________________________________________________" -> False
#   (* at position 7)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# - "_______________________________________________________________________________*____________________" -> True
#   (* at position 79)
#
# ---
#
# #### Step 2: Try parity (even/odd)
#
# Let me write down a few more with their `pos` and the result.
#
# | Position of * | Result |
# |---------------|--------|
# | 62            | True   |
# | 19            | False  |
# | 90            | True   |
# | 51            | True   |
# | 14            | False  |
# | 18            | False  |
# | 94            | True   |
# | 7             | False  |
# | 60            | True   |
# | 42            | False  |
# | 79            | True   |
#
# If we look at the position numbers for True:
#
# 62 (True) — even
# 90 (True) — even
# 51 (True) — odd
# 94 (True) — even
# 60 (True) — even
# 79 (True) — odd
#
# False:
#
# 19 (False) — odd
# 14 (False) — even
# 18 (False) — even
# 7 (False) — odd
# 42 (False) — even
#
# So parity doesn’t match the classification.
#
# #### Step 3: Try divisibility
#
# Let’s focus on the True examples:
#
# 62, 90, 51, 94, 60, 79
#
# Try dividing by 3:
#
# - 62 / 3 = 20.666...
# - 90 / 3 = 30 (divisible)
# - 51 / 3 = 17 (divisible)
# - 94 / 3 = 31.333...
# - 60 / 3 = 20 (divisible)
# - 79 / 3 = 26.333...
#
# So, not divisibility by 3.
#
# ---
#
# #### Step 4: Try the last digit
#
# True positions: 62, 90, 51, 94, 60, 79
# Last digits: 2, 0, 1, 4, 0, 9 — No pattern.
#
# ---
#
# #### Step 5: Try position >= half the length
#
# Suppose the length N is 100 (approximate).
#
# True: 62, 90, 51, 94, 60, 79 — all above 50, except 51.
#
# False: 19, 14, 18, 7, 42 — all below 50.
#
# But 42 (False) and 51 (True) are close to 50.
#
# Let’s test this with more examples.
#
# - "_____________________________________________________________________*______________________________" -> True
#   (* at position 70)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# So, maybe the rule is "* must be at position 50 or higher?"
#
# But then 51 is True, 42 is False, 51 is True.
#
# Let’s check if position >= 50 is the rule.
#
# Is there any False with position >= 50?
# Is there any True with position < 50?
#
# Looking at a few more:
#
# - "___________________________________*________________________________________________________________" -> False
#   (* at position 35)
#
# - "___________________________________________________*________________________________________________" -> True
#   (* at position 51)
#
# - "______________________________________________________*_____________________________________________" -> True
#   (* at position 54)
#
# - "____________________________________________*_______________________________________________________" -> False
#   (* at position 44)
#
# - "________________________________________________________________________________*___________________" -> True
#   (* at position 88)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# No True examples with * before position 50.
#
# No False examples with * at position >= 50.
#
# Let’s check for position = 50.
#
# - Any with * at position 50? Let’s check.
#
# I don't see one, but the pattern seems clear:
#
# ### **THE RULE**
#
# > The string is classified as **True** if and only if the asterisk (*) occurs at position 50 or greater (i.e., in the second half of the string, assuming positions are numbered starting at 0).
# > Otherwise, it is classified as False.
#
# **In natural language:**
#
# > The string is classified as True if the asterisk is in the right half of the string (positions 50 and above), and False if it is in the left half (positions 0 through 49).
#
# ---
#
# ### **Final Rule**
#
# > **A string is classified as True if and only if the asterisk (*) is at position 50 or greater (i.e., in the right half of the string). Otherwise, it is classified as False.**
#
# ---
#
# **This will enable someone to correctly classify new examples.**
#
# — Choice 2 (openai/gpt-4.1) —
# Let’s analyze the examples to find the rule.
#
# ### Step 1: Pattern Recognition
#
# Each string is a long sequence of `_` (underscores), with exactly one `*` somewhere in the string.
#
# Let’s look at the **positions** of `*` in the strings, and compare the result.
#
# #### Example:
# "______________________________________________________________*_____________________________________" -> True
# Let's count how many underscores are **before** the `*`:
#
# - There are 62 underscores before the `*`, then 37 after.
#
# #### Example:
# "____________________________________________*_______________________________________________________" -> False
# - 44 underscores before the `*`, then 55 after.
#
# #### Example:
# "________________________________________________________________________________________*___________" -> True
# - 88 underscores before the `*`, then 11 after.
#
# Now, let's try a few more.
#
# #### Example:
# "___________________*________________________________________________________________________________" -> False
# - 19 underscores before, lots after.
#
# #### Example:
# "_____________________________________________________________________*______________________________" -> True
# - 69 underscores before, 30 after.
#
# Let's try to find a pattern.
#
# ### Step 2: Hypothesis
#
# It looks like the **classification is True if the `*` appears in the right half of the string**, and False if in the left half.
#
# Let's test this:
#
# #### "___________________________________________________*________________________________________________" -> True
# - Let's count underscores before the `*`: 51 before, 48 after = Total 100 (with the `*`, 100 underscores + 1 `*` = 101 chars).
# - So, in this case, the `*` is at position 52 (0-based index 51).
#   Since 101/2 = 50.5, positions 0-50 would be the left half, 51-100 the right half.
#   The `*` is at position 51, which is the first index of the right half.
#
# #### "___________________________________*________________________________________________________________" -> False
# - 35 underscores before, 64 after. Position of `*` is 36 (0-based index 35), total 100 (plus 1 = 101).
#   101/2 = 50.5, so left half is 0-50, right half is 51-100.
#   Position 35 is in the left half → False.
#
# #### "________________________________________________________*___________________________________________" -> True
# - 56 underscores before, 43 after. `*` at position 57 (0-based 56), 56 > 50.5, so right half → True.
#
# #### "_______________________________________________*____________________________________________________" -> False
# - 47 underscores before, 52 after. `*` at position 48 (0-based 47), which is left half → False.
#
# #### "_______________________________________________________________________________________________*____" -> True
# - 95 underscores before, 4 after. `*` at position 96 (0-based 95), clearly right half → True.
#
# #### "_______*____________________________________________________________________________________________" -> False
# - 7 underscores before, 92 after. `*` at position 8 (0-based 7), left half → False.
#
# ### Step 3: Edge Cases
#
# If the string length is odd, which half is the `*` in?
#
# For a string of length N, positions 0 to (N//2)-1 are the left half, positions N//2 to N-1 are the right half.
#
# If `*` is at index ≥ N//2, then True, else False.
#
# Let's check:
#
# - For N=101, N//2 = 50. So indexes 0-49 left, 50-100 right.
#
# But in above calculations, it seemed to use 0-50 left, 51-100 right. Let's check carefully.
#
# Wait, let's check:
#
# "___________________________________________________*________________________________________________" -> True
# - 51 underscores before, so `*` at position 52 (0-based 51). So for a 101 character string (100 underscores + 1 `*`), the `*` is at index 51.
# - 101//2 = 50, so index 0-49 is left, 50-100 is right. `*` at 51, so in right half. True.
#
# So the rule is:
#
# > If the position of the `*` in the string (0-based index) is **greater than or equal to** half the length of the string (using integer division), the classification is True. Otherwise, False.
#
# ### Step 4: Express Rule in Natural Language
#
# **Rule:**
#
# > A string is classified as True **if and only if** the `*` character is in the right half of the string (that is, if its position is greater than or equal to half the string's length, counting from zero). Otherwise, the string is classified as False.
#
# Or, more concisely:
#
# > If the `*` appears at or beyond the halfway point in the string, classify as True; otherwise, classify as False.
#
# ---
#
# **Summary Table:**
#
# - Let N = length of the string
# - Let P = 0-based index of `*`
# - If `P >= N//2`, then True; otherwise, False.
#
# ---
#
# **Final concise rule:**
#
# > The string is classified as True if the `*` is in the right half of the string (at or after the halfway point); otherwise, it is False.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's analyze the examples to deduce the rule.
#
# ### Observations
#
# - Each string is made up of underscores ('_') and at most one asterisk ('*').
# - The classification is either True or False.
# - The position of '*' seems to be the only variable.
#
# Let's try to find a pattern based on the position of '*'.
#
# #### Step 1: Check if the number of underscores before or after the '*' matters.
#
# Let's pick a few True and False examples and count the number of underscores before the '*'.
#
# #### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`:
#    - '*' at position 62 (zero-based index).
# 2. `"________________________________________________________________________________________*___________"`:
#    - '*' at position 90.
# 3. `"________________________________________________________*___________________________________________"`:
#    - '*' at position 56.
# 4. `"___________________________________________________*________________________________________________"`:
#    - '*' at position 51.
# 5. `"_______________________________________________________________________________________________*____"`:
#    - '*' at position 94.
#
# #### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`:
#    - '*' at position 44.
# 2. `"___________________*________________________________________________________________________________"`:
#    - '*' at position 19.
# 3. `"___________________________________*________________________________________________________________"`:
#    - '*' at position 35.
# 4. `"______________*_____________________________________________________________________________________"`:
#    - '*' at position 14.
# 5. `"_______________________________________________*____________________________________________________"`:
#    - '*' at position 47.
#
# #### Step 2: Try dividing the string into two halves
#
# Let's check the length of the strings:
#
# - Let's count the number of characters in a sample string:
#   For example, `"___________________________________________________*________________________________________________"`
#   Let's count. There are 51 underscores before '*', 1 '*', and 51 underscores after. That's 103 characters.
#
# - Similarly, another string:
#   `"______________________________________________________________*_____________________________________"`
#   Let's count: 62 underscores before, 1 '*', 37 underscores after: 62+1+37 = 100 characters.
#
# So the length may vary, but it seems most are around 100.
#
# #### Step 3: Is the rule based on the position of '*' in the second half?
#
# Let's check:
#
# - For the True examples above, the '*' is at position 62 (of 100), 90 (of 100), 56 (of 100), 51 (of 103), 94 (of 100).
# - For the False examples, 44 (of 100), 19 (of 100), 35 (of 100), 14 (of 100), 47 (of 100).
#
# Looks like for True, the '*' is in the second half (i.e., position > n/2).
#
# Let's check this for more examples.
#
# #### Test the hypothesis
#
# For string of length N, is the rule:
#
# > The string is classified as True **if and only if the '*' is positioned AFTER the midpoint of the string (i.e., index > N//2)**.
#
# Let's test with a few examples:
#
# - `"___________________________________________________*________________________________________________"`
#   - 51 underscores before, 1 '*', 51 underscores after.
#   - Length: 51+1+51 = 103.
#   - '*' at position 51 (0-based).
#   - Midpoint: 103 // 2 = 51.
#   - So, position == midpoint, and it's True.
#
# But the rule says "after the midpoint", so maybe it's position >= midpoint?
#
# Let's check for position == midpoint in other examples.
#
# - `"___________________________________________________*________________________________________________"` is True, '*' at 51 (for 103), midpoint = 51.
#
# - `"_______________________________________________*____________________________________________________"`
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 47+1+52 = 100.
#   - '*' at position 47, midpoint = 50.
#   - 47 < 50, and it's False.
#
# - `"______________________________________________________________*_____________________________________"`:
#   - 62 underscores before, 1 '*', 37 underscores after.
#   - Length: 100.
#   - '*' at position 62, midpoint = 50.
#   - 62 > 50, is True.
#
# So, looks like the rule is:
#
# > The string is classified as True if and only if the '*' is positioned at or after the midpoint of the string (i.e., index >= length // 2).
#
# Let's check for position == midpoint for even-length string.
#
# - For 100 length, midpoint = 50. Is there an example with '*' at 50?
# - `"___________________________________________________*________________________________________________"` is 103 length, midpoint 51, '*' at 51, True. So position == midpoint is True.
#
# Let's test with:
#
# - `"_______________________________________________*____________________________________________________"`:
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 100, midpoint = 50, '*' at 47, so 47 < 50, and it's False.
#
# - `"______________________________________________________*_____________________________________________"`:
#   - 54 underscores before, 1 '*', 45 underscores after.
#   - Length: 54+1+45=100, '*' at 54, 54 > 50, True.
#
# So, the rule is:
#
# ---
#
# ### **Rule:**
#
# > A string is classified as **True** if and only if the asterisk ('*') appears at or after the halfway point of the string (that is, if its index is greater than or equal to half the length of the string, using zero-based indexing). Otherwise, it is classified as **False**.
#
# **In other words:**
# - Compute the length of the string, `N`.
# - If the index of '*' is **greater than or equal to** `N // 2`, classify as True.
# - Otherwise, classify as False.
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the examples to find the **rule**.
#
# Each string is made up of underscores (`_`), possibly with a single asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# Let's extract the position of `*` in a few examples and see if we spot a pattern.
#
# #### Step 1: Count the position of `*` (0-based)
#
# For a string like:
# "__________*_________________________________________________________________________________________"
#
# Let's count:
# - 10 underscores, then `*`, so `*` is at position 10.
#
# Let's do this for a few:
#
# | String | Position of `*` | Label |
# |--------|-----------------|-------|
# | "____________________________________________*_______________________________________________________" | 44 | False |
# | "______________________________________________________________*_____________________________________" | 62 | True |
# | "___________________*________________________________________________________________________________" | 19 | False |
# | "________________________________________________________________________________________*___________" | 90 | True |
# | "___________________________________*________________________________________________________________" | 35 | False |
# | "________________________________________________________*___________________________________________" | 56 | True |
# | "______________*_____________________________________________________________________________________" | 14 | False |
# | "___________________________________________________*________________________________________________" | 51 | True |
# | "_______________________________________________________________________________________________*____" | 95 | True |
#
# #### Step 2: Look for a pattern
#
# Let's see if the **position** alone is enough. Let's see if there's a modulo pattern or even/odd pattern.
#
# Let's check a few more:
#
# False examples:
# - 44 (False)
# - 19 (False)
# - 35 (False)
# - 14 (False)
# - 10 (False)
# - 62 (True)
# - 90 (True)
# - 56 (True)
# - 51 (True)
# - 95 (True)
#
# #### Step 3: Try Even/Odd positions
#
# - 44 (even) → False
# - 19 (odd) → False
# - 35 (odd) → False
# - 14 (even) → False
# - 62 (even) → True
# - 90 (even) → True
# - 56 (even) → True
# - 51 (odd) → True
# - 95 (odd) → True
#
# So, even/odd is not the deciding factor.
#
# #### Step 4: Compare to length of string
#
# Let's check if the position of `*` is in the first half or second half.
#
# Check string length:
#
# - Let's take one string and count its length:
#   - "____________________________________________*_______________________________________________________"
#     Count underscores: before the star: 44
#     Add the `*`: 45
#     After the star: 55
#     Total: 44+1+55 = **100**
#
# Aha, so the strings are length 100.
#
# So, is the rule about which half the `*` is in?
#
# - "____________________________________________*_______________________________________________________"
#   - `*` at 44 (positions 0-99, so index 44 is the 45th character, so in the first half) → False
# - "______________________________________________________________*_____________________________________"
#   - `*` at 62 → second half (index 50+ is second half), so index 62 is after halfway → True
#
# So, let's formalize:
#
# **If the `*` is in the second half (positions 50-99), label is True. Otherwise, False.**
#
# Let's check edge cases:
#
# - If `*` is at position 49 (the 50th character), is that first or second half?
#   - 0-49: first half (positions 0-49, 50 characters)
#   - 50-99: second half (positions 50-99, 50 characters)
#
# Check one at position 49:
#
# Let's search for a string with the asterisk at position 49:
#
# - "_________________________________________________________________________________________________*_"
#   How many underscores before the star? Let's count.
#
# Alternatively, find a True example at 50.
#
# - "___________________________________________________*________________________________________________"
#   - Let's count: before the star: 51 underscores, so position 51.
#
# - This is labeled True.
#
# So, position 51 → True.
#
# Try position 49:
#
# - "_________________________________________________*__________________________________________________"
#   - Before the star: 49 underscores, position 49.
#   - Labeled False.
#
# So, **positions 0-49 → False, positions 50-99 → True**.
#
# #### Step 5: Restate the rule
#
# **Rule:**
# A string is classified as True if and only if the asterisk appears at position 50 or later (i.e., among the last 50 characters of the string). Otherwise, it is classified as False.
#
# **Natural language version:**
#
# > The string is classified as True if the asterisk `*` is in the second half of the string (that is, at position 50 or later, counting from 0). Otherwise, it is classified as False.
#
# ---
#
# **Short Rule:**
# > "True if the asterisk is at position 50 or greater; otherwise, False."
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the examples for a clear, concise rule.
#
# First, **every string contains exactly one `*`**, the rest are `_`.
#
# To figure out the rule, let's look for patterns. Consider the **position** of the `*` in the string.
#
# Let's check the first few "True" examples and their positions (counting from 0):
#
# #### True examples and their positions:
# 1. `"______________________________________________________________*_____________________________________"`
#    Position: 62
#
# 2. `"________________________________________________________________________________________*___________"`
#    Position: 87
#
# 3. `"________________________________________________________*___________________________________________"`
#    Position: 56
#
# 4. `"___________________________________________________*________________________________________________"`
#    Position: 51
#
# 5. `"_______________________________________________________________________________________________*____"`
#    Position: 95
#
# Let's check also some "False" examples:
#
# #### False examples and their positions:
# 1. `"____________________________________________*_______________________________________________________"`
#    Position: 44
#
# 2. `"___________________*________________________________________________________________________________"`
#    Position: 19
#
# 3. `"___________________________________*________________________________________________________________"`
#    Position: 35
#
# 4. `"______________*_____________________________________________________________________________________"`
#    Position: 14
#
# ---
#
# Let me try to find if there's an arithmetic pattern.
#
# #### Let's check parity (even/odd):
#
# - 62 (True) -> even
# - 87 (True) -> odd
# - 56 (True) -> even
# - 51 (True) -> odd
# - 95 (True) -> odd
#
# So, it's not parity.
#
# #### Let's try mod 5:
#
# - 62 % 5 = 2
# - 87 % 5 = 2
# - 56 % 5 = 1
# - 51 % 5 = 1
# - 95 % 5 = 0
#
# Not a clear pattern.
#
# #### Let's check if the position is in the second half of the string
#
# Let's check the length of the string. For the first True example:
# - `"______________________________________________________________*_____________________________________"`
#   Length: 101
#   `*` at position 62
#
# - 62/101 ≈ 0.613 (so in the second half)
#
# Now let's check the first False example:
# - `"____________________________________________*_______________________________________________________"`
#   Length: 101
#   `*` at position 44
#   44/101 ≈ 0.436 (so in the first half)
#
# Let's try a few more:
#
# #### Another True:
# - `"________________________________________________________*___________________________________________"`
#   Length: 101
#   `*` at position 56
#   56/101 ≈ 0.554
#
# #### Another False:
# - `"___________________*________________________________________________________________________________"`
#   Length: 101
#   `*` at position 19
#   19/101 ≈ 0.188
#
# #### Another True:
# - `"___________________________________________________*________________________________________________"`
#   Length: 101
#   `*` at position 51
#   51/101 ≈ 0.505
#
# #### Another False:
# - `"______________*_____________________________________________________________________________________"`
#   Length: 101
#   `*` at position 14
#   14/101 ≈ 0.139
#
# #### Another True:
# - `"__________________________________________________________________________________________________*_"`
#   Length: 101
#   `*` at position 99
#   99/101 ≈ 0.980
#
# #### Another False:
# - `"_______*____________________________________________________________________________________________"`
#   Position: 7
#   7/101 ≈ 0.069
#
# ---
#
# It seems that **if the asterisk is in the first half of the string, the answer is False; if it's in the second half, the answer is True**.
#
# But what about position 50 (out of 101)? Is it first or second half?
#
# Let's check position 50:
#
# - 101 / 2 = 50.5
#
# So, positions 0-50 are the first half (0-50 inclusive), and positions 51-100 are the second half (51-100 inclusive).
#
# Let's check if a string with `*` at position 50 is present and its label.
#
# Let me look for a string with `*` at position 50.
#
# - `"___________________________________________________*________________________________________________"`
#   Position: 51
#   This is True.
#
# What about position 50?
#
# - No example given.
#
# But for position 51, it's True; for position 44, it's False.
#
# So, it seems the rule is:
#
# > **A string is classified as True if and only if the `*` is in the second half of the string (i.e., its position is greater than or equal to half the length of the string, rounding up). Otherwise, it is classified as False.**
#
# Or, more concisely:
#
# ---
#
# ## Rule
#
# **A string is classified as True if the asterisk `*` appears at a position greater than or equal to half the total length of the string (counting positions from 0). Otherwise, the string is classified as False.**
#
# ---
#
# If the string has length N, and the position of `*` is P (starting from 0), then:
#
# - If P >= N/2, the string is True.
# - If P < N/2, the string is False.

# %%
# algorithm
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "If you had to write an algorithm to classify these strings, what would be the decision rule?"
instructions = "Provide only a clear declarative statement of the rule. No explanations, no reasoning steps, no analysis of examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 2 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 3 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores (_) after the * is a multiple of 8.
#
# — Choice 4 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk (*) is a multiple of 8.
#
# — Choice 5 (openai/gpt-4.1) —
# The string is classified as True if and only if there are more underscores (_) after the asterisk (*) than before it.

# %%
# cf
intro = "As an expert in pattern recognition, analyze these classified strings to determine the precise rule that differentiates True from False examples."
question = "State the rule that determines these classifications and explain how changing specific aspects of a string would alter its classification."
instructions = "Be specific and precise in your description."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the strings and their classifications to determine the rule.
#
# ## Observations
#
# - Each string is a sequence of underscores (`_`) with a single asterisk (`*`) somewhere in the string.
# - The only difference between strings is the position of the asterisk.
#
# Let's try to find a pattern:
#
# ### Compare False and True Examples
#
# #### False Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "____________________________________________*_______________________________________________________" | 44         | 102    |                |
# | "___________________*________________________________________________________________________________" | 19         | 97     |                |
# | "__________________*_________________________________________________________________________________" | 18         | 98     |                |
# | "__________*_________________________________________________________________________________________" | 11         | 98     |                |
# | "______________*_____________________________________________________________________________________" | 15         | 98     |                |
# | "___________________________________*________________________________________________________________" | 35         | 98     |                |
# | "_______*____________________________________________________________________________________________" | 7          | 98     |                |
# | "________________________________________*___________________________________________________________" | 42         | 98     |                |
# | "____________________________________*_______________________________________________________________" | 37         | 98     |                |
# | "_____________________________________________*______________________________________________________" | 45         | 98     |                |
#
# #### True Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "______________________________________________________________*_____________________________________" | 62         | 98     |                |
# | "________________________________________________________*___________________________________________" | 56         | 98     |                |
# | "________________________________________________________________________________________*___________" | 86         | 98     |                |
# | "___________________________________________________*________________________________________________" | 51         | 98     |                |
# | "_______________________________________________________________________________________________*____" | 95         | 98     |                |
# | "__________________________________________________________________________________________________*_" | 98         | 100    |                |
# | "_________________________________________________________________*__________________________________" | 65         | 98     |                |
# | "_____________________________________________________________________*______________________________" | 69         | 98     |                |
# | "_________________________________________________________________________*__________________________" | 74         | 98     |                |
#
# Let's try to find a mathematical relationship.
#
# ## Hypothesis: Is it about position relative to string length?
#
# ### Let's calculate:
#
# For string of length L, and asterisk at position p (0-based), what is the rule?
#
# Look at a True example:
# - Length: 98, * at 62 => 62/98 ≈ 0.632
# - Length: 98, * at 56 => 56/98 ≈ 0.571
# - Length: 98, * at 86 => 86/98 ≈ 0.877
# - Length: 98, * at 51 => 51/98 ≈ 0.520
#
# A False example:
# - Length: 98, * at 19 => 19/98 ≈ 0.194
# - Length: 98, * at 15 => 15/98 ≈ 0.153
# - Length: 98, * at 7 => 7/98 ≈ 0.071
# - Length: 98, * at 35 => 35/98 ≈ 0.357
# - Length: 98, * at 42 => 42/98 ≈ 0.429
#
# It seems True examples have * in the second half of the string, False in the first half.
#
# Test at halfway:
#
# - 98/2 = 49
# - If * at index >= 49, True; else False.
#
# Check some True cases:
# - 51: True (>=49)
# - 56: True
# - 62: True
# - 69: True
# - 74: True
# - 86: True
# - 95: True
#
# Check some False cases:
# - 35: False (<49)
# - 42: False
# - 44: False
# - 45: False
# - 37: False
#
# But what about boundary cases? Let's check if 49 is right.
#
# Try a string of length 98, * at 49:
# - Is there such a case? None in the examples.
#
# Try at 51: True.
# Try at 45: False.
#
# So the rule seems to be:
# **The example is True if and only if the asterisk appears in the second half of the string, i.e., its index is greater than or equal to half the length of the string (rounded up if length is odd).**
#
# Or, more mathematically:
#
# Let L be the length of the string, and p the 0-based index of `*`.
# - If p ≥ L/2, then True.
# - If p < L/2, then False.
#
# ### Test on a different length:
#
# "__________________________________________________________________________________________________*_" -> True
# Length: 100, p=98
#
# 100/2 = 50, 98>50, so True.
#
# "___________________*________________________________________________________________________________" -> False
# Length: 97, p=19
#
# 97/2 = 48.5, so p=19<48.5, False.
#
# ## Rule (Precise, as requested):
#
# > **A string is classified as True if and only if the asterisk `*` occurs at position p (0-based index) such that p ≥ (length of string) / 2. Otherwise, it is classified as False.**
#
# ## How changing aspects of a string alters the classification
#
# - Moving the asterisk left (to a lower index) can change True to False if it crosses the halfway point.
# - Moving the asterisk right (to a higher index) can change False to True if it crosses the halfway point.
# - Changing the length of the string shifts the halfway point; to remain True, the asterisk must stay at or past the new midpoint.
#
# ## Example
#
# - String: Length 100, asterisk at 49 → 49<50 → False.
# - Move asterisk to 50: 50=50 → True.
# - String: Length 99, asterisk at 49 → 49<49.5 → False.
# - Asterisk at 50: 50>49.5 → True.
#
# ---
#
# **In summary:**
# > The classification is True if and only if the asterisk is in the right half of the string (including the central position when the length is even). Otherwise, it is False.
#
# — Choice 2 (openai/gpt-4.1) —
# Let's analyze the examples systematically.
#
# Each string is a sequence of underscores (`_`) with a single asterisk (`*`) at some position. The task is to find what distinguishes the `True` cases from the `False` ones based on the position of the `*`.
#
# Let's break down the approach:
#
# ## 1. **Find the pattern in position**
#
# Let's pick a few strings and count the number of underscores before the asterisk (`*`). This is the index of the `*` (zero-based).
#
# We'll do this for both `True` and `False` examples.
#
# ### **True Examples:**
# - "______________________________________________________________*_____________________________________"
#   - Number of `_` before `*`: 62
#
# - "________________________________________________________________________________________*___________"
#   - `_` before `*`: 90
#
# - "________________________________________________________*___________________________________________"
#   - `_` before `*`: 56
#
# - "___________________________________________________*________________________________________________"
#   - `_` before `*`: 51
#
# - "_______________________________________________________________________________________________*____"
#   - `_` before `*`: 95
#
# - "__________________________________________________________________________________________________*_"
#   - `_` before `*`: 98
#
# - "_________________________________________________________________*__________________________________"
#   - `_` before `*`: 65
#
# - "_____________________________________________________________________*______________________________"
#   - `_` before `*`: 69
#
# - "_________________________________________________________________________*__________________________"
#   - `_` before `*`: 74
#
# - "_________________________________________________________________________________*__________________"
#   - `_` before `*`: 85
#
# - "______________________________________________________________________________*_____________________"
#   - `_` before `*`: 78
#
# - "______________________________________________________*_____________________________________________"
#   - `_` before `*`: 54
#
# - "_______________________________________________________________________________________*____________"
#   - `_` before `*`: 91
#
# ### **False Examples:**
# - "____________________________________________*_______________________________________________________"
#   - `_` before `*`: 44
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "___________________________________*________________________________________________________________"
#   - `_` before `*`: 35
#
# - "______________*_____________________________________________________________________________________"
#   - `_` before `*`: 14
#
# - "_______________________________________________*____________________________________________________"
#   - `_` before `*`: 47
#
# - "_______*____________________________________________________________________________________________"
#   - `_` before `*`: 7
#
# - "__________*_________________________________________________________________________________________"
#   - `_` before `*`: 10
#
# - "____________________________________*_______________________________________________________________"
#   - `_` before `*`: 36
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "________________________________________*___________________________________________________________"
#   - `_` before `*`: 40
#
# - "_________________________________*__________________________________________________________________"
#   - `_` before `*`: 33
#
# - "_____________________________________________*______________________________________________________"
#   - `_` before `*`: 45
#
# - "__________________________________________*_________________________________________________________"
#   - `_` before `*`: 42
#
# - "_________________________*__________________________________________________________________________"
#   - `_` before `*`: 25
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "____*_______________________________________________________________________________________________"
#   - `_` before `*`: 4
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# ---
#
# ## 2. **Look for a threshold**
#
# Let me compare the highest index in False with the lowest in True.
#
# - Highest False index: Let's see (from above): 47 ("_______________________________________________*____________________________________________________")
# - Lowest True index: 51 ("___________________________________________________*________________________________________________")
#
# So, it appears that:
#
# - All **False** examples have the asterisk at index **47 or below**.
# - All **True** examples have the asterisk at index **51 or above**.
#
# Check the gap:
# - 47 (False), next is 51 (True). There is a gap of 48, 49, 50 — are there any examples at these positions? Doesn't look like it from the data.
#
# So, the cutoff appears to be at **index 48**: if the asterisk is at position **48 or higher**, it's True; if at **47 or lower**, it's False.
#
# But note: There may be a small ambiguity in the border (since there are no strings at 48, 49, or 50), but with the current data, the rule is:
#
# ---
#
# ## **Rule:**
#
# > **A string is classified as `True` if and only if the asterisk (`*`) is positioned at or after index 51 (i.e., the 52nd character or later, counting from 0). Otherwise, it is classified as `False`.**
#
# Or more generally, based on the examples:
# - **If the number of underscores before the `*` is 51 or greater, then the string is True.**
# - **If the number of underscores before the `*` is 47 or fewer, then the string is False.**
# - **No examples are given for positions 48, 49, or 50.**
#
# ---
#
# ## **How changes affect classification:**
#
# - **If you move the `*` rightward across the 51st position (i.e., from 47 to 51), the classification switches from `False` to `True`.**
# - **If you move the `*` leftward across the 51st position, it switches from `True` to `False`.**
# - **The actual content of the string (underscores or asterisk) is otherwise irrelevant; only the position of the asterisk matters.**
#
# ---
#
# ### **Summary Table:**
#
# | Position of `*` | Classification |
# |-----------------|----------------|
# | 0-47            | False          |
# | 51+             | True           |
# | 48-50           | (No examples)  |
#
# ---
#
# **In summary:**
# > The classification is determined solely by the position of the asterisk: if it is at index 51 or greater, the string is `True`; otherwise, it is `False`. Changing the position of the asterisk across this boundary will flip the classification.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's break down the pattern in the classified strings:
#
# - Each string is made up of underscores `_` and exactly **one asterisk `*`**.
# - The `*` is always embedded somewhere in the string.
# - Each string is of the **same length** (99 characters: 98 underscores and 1 asterisk).
#
# Let’s analyze the positions of the asterisk for **True** and **False** examples:
#
# #### Step 1: Find the position of `*` in the string
#
# Let's number the positions from **0** (leftmost) to **98** (rightmost).
#
# Let’s manually check some examples:
#
# ##### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`
#    `*` at position 44  (count underscores before `*`)
# 2. `"___________________*________________________________________________________________________________"`
#    `*` at position 19
# 3. `"______________*_____________________________________________________________________________________"`
#    `*` at position 14
# 4. `"___________________________________*________________________________________________________________"`
#    `*` at position 35
# 5. `"__________*_________________________________________________________________________________________"`
#    `*` at position 10
#
# ##### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`
#    `*` at position 62
# 2. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
# 3. `"________________________________________________________*___________________________________________"`
#    `*` at position 56
# 4. `"_______________________________________________________________________________________________*____"`
#    `*` at position 93
# 5. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
#
# #### Step 2: Compile more positions and look for a pattern
#
# Let's grab several more positions for each class to be sure.
#
# **False:**
# - 44, 19, 14, 35, 10, 14, 45, 35, 44, 19, 10, 19, 35, 44, 10, 19, 45, 10, 35, 14, 35, etc.
#
# **True:**
# - 62, 78, 56, 93, 78, 94, 62, 78, 80, 62, 94, 78, 56, 80, 94, 82, 56, 80, 88, 92, 93, 94, etc.
#
# If we look at the numbers, **False** positions are always **less than 50**, and **True** positions are always **greater than or equal to 50**.
#
# #### Step 3: State the Rule
#
# **Rule:**
# A string is classified as **True** if and only if the position of the asterisk `*` is at position **50 or greater** (i.e., the 51st character or later in the string). Otherwise, it is **False**.
#
# - **True:** `*` is in position 50–98 (inclusive)
# - **False:** `*` is in position 0–49 (inclusive)
#
# #### Step 4: How changing the string alters the classification
#
# If you move the asterisk:
# - **From position <50 to ≥50:** The classification changes from **False** to **True**
# - **From position ≥50 to <50:** The classification changes from **True** to **False**
#
# **Other changes** (like changing underscores to other characters, or adding/removing underscores so the length is not 99) are not shown in the examples and might be invalid inputs.
#
# ---
#
# ## **Summary Table**
#
# | Asterisk Position | Classification |
# |-------------------|---------------|
# | 0–49              | False         |
# | 50–98             | True          |
#
# ## **Precise Rule**
#
# > **A string is classified as True if the asterisk `*` is at position 50 or later (counting from 0) in the string; otherwise, it is classified as False.**
#
# **Changing the position of the `*` across this 50-position threshold switches the classification.**
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the pattern in the provided training examples.
#
# ## Observations
#
# - Each string is made up of underscores `_` and a single asterisk `*`.
# - The asterisk appears in only one position per string.
# - The strings are all of the same length (98 characters).
# - Some strings with certain `*` positions are labeled **True**, others **False**.
#
# ## Step 1: Indexing the `*`
#
# Let's look at the indices (positions) of the `*` in the strings, counting from 0 (leftmost) to 97 (rightmost):
#
# ### False Examples (position of `*`):
#
# - 44
# - 19
# - 35
# - 15
# - 29
# - 45
# - 12
# - 43
# - 46
# - 6
# - 32
# - 17
# - 41
# - 33
# - 24
# - 10
# - 38
# - 20
# - 25
# - 5
# - 38
# - 31
# - 37
# - 15
# - 26
# - 43
# - 36
# - 25
#
# ### True Examples (position of `*`):
#
# - 62
# - 89
# - 53
# - 67
# - 51
# - 95
# - 89
# - 83
# - 98
# - 62
# - 72
# - 67
# - 63
# - 96
# - 91
# - 85
# - 60
# - 96
# - 81
# - 92
# - 77
# - 88
#
# (These positions are approximate; for perfect accuracy, you'd count for each example.)
#
# ## Step 2: Looking for numeric rules
#
# - All **True** examples have the `*` towards the right end, **False** are towards the left.
# - Let's check the minimum position for True:
#     - E.g., 51, 53, 60, 62, 63, 67, 72, 77, 81, 83, 85, 88, 89, 91, 92, 95, 96, 98
#
# - All True examples have the `*` at **position 51 or higher**.
#
# - All False examples have the `*` at **position 46 or lower**.
#
# There are no examples with `*` at positions 47–50, so let's check more closely:
#
# - The **largest False** position seems to be 46.
# - The **smallest True** position seems to be 51.
#
# ## Step 3: Stating the rule
#
# **RULE:**
# > The string is classified as **True** if and only if the asterisk `*` is at position **51 or greater** (i.e., the 52nd character or later, counting from 1). Otherwise, it is classified as **False**.
#
# - **Formally:**
#   Let `i` be the 0-based index of the `*` in the string.
#   If `i >= 51`, then **True**;
#   Otherwise, **False**.
#
# ## Step 4: How changing aspects would alter classification
#
# - **If you move the `*` from a position less than 51 to a position 51 or greater**, the classification changes from **False** to **True**.
# - **If you move the `*` from a position 51 or greater to a position less than 51**, the classification changes from **True** to **False**.
# - **Moving the `*` within the same side of the threshold** (e.g., from 10 to 40, or from 60 to 90) does **not** change the classification.
#
# ## Step 5: Borderline
#
# - The cutoff is **at position 51** (the 52nd character, if counting from 1).
# - There are **no training examples** at positions 47–50; but the pattern is clear.
#
# ---
#
# ## **Summary Table**
#
# | Position of `*` (0-based index) | Classification |
# |---------------------------------|----------------|
# | 0–50                            | False          |
# | 51–97                           | True           |
#
# ---
#
# ## **Conclusion**
#
# > **The rule is:**
# >
# > **If the asterisk is at position 51 or greater (counting from 0), the string is classified as True; otherwise, False.**
#
# ---
#
# **Changing the position of the asterisk across this boundary (between 50 and 51) will change the classification. All other changes (that do not move the asterisk across this threshold) will not affect the classification.**
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the pattern in detail.
#
# ## What varies in the strings?
# Each string consists of underscores (`_`) and exactly one asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# ## Approach
#
# Let's count where the `*` appears in each string.
# Since all strings are of the same length (101 characters), we can analyze the index (0-based or 1-based) of the `*`.
#
# Let's check the indices for some examples.
#
# ### False examples:
#
# 1. "____________________________________________*_______________________________________________________"
#    Position: 44 (0-based), 45 (1-based)
# 2. "___________________*________________________________________________________________________________"
#    Position: 19 (0-based), 20 (1-based)
# 3. "___________________________________*________________________________________________________________"
#    Position: 35 (0-based), 36 (1-based)
# 4. "______________*_____________________________________________________________________________________"
#    Position: 14 (0-based), 15 (1-based)
# 5. "_______________________________________________*____________________________________________________"
#    Position: 47 (0-based), 48 (1-based)
# 6. "_______*____________________________________________________________________________________________"
#    Position: 7 (0-based), 8 (1-based)
# 7. "____________________________________*_______________________________________________________________"
#    Position: 36 (0-based), 37 (1-based)
# 8. "__________________*_________________________________________________________________________________"
#    Position: 18 (0-based), 19 (1-based)
# 9. "________________________________________*___________________________________________________________"
#    Position: 40 (0-based), 41 (1-based)
#
# ### True examples:
#
# 1. "______________________________________________________________*_____________________________________"
#    Position: 62 (0-based), 63 (1-based)
# 2. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 3. "___________________________________________________*________________________________________________"
#    Position: 51 (0-based), 52 (1-based)
# 4. "_______________________________________________________________________________________________*____"
#    Position: 94 (0-based), 95 (1-based)
# 5. "__________________________________________________________________________________________________*_"
#    Position: 98 (0-based), 99 (1-based)
# 6. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 7. "________________________________________________________________________________*___________________"
#    Position: 82 (0-based), 83 (1-based)
# 8. "_________________________________________________________________*__________________________________"
#    Position: 65 (0-based), 66 (1-based)
# 9. "____________________________________________________________*_______________________________________"
#    Position: 60 (0-based), 61 (1-based)
#
# Let's check for a mathematical pattern.
#
# ## Hypothesis: The position of the asterisk must be >= some value.
#
# Looking at the True examples, the positions are all greater than or equal to 51 (0-based), i.e., in the second half of the string. Let's check this hypothesis.
#
# String length: 101
# Middle: index 50 (0-based), so 0..50 is the first half, 51..100 is the second half.
#
# Let's check for some boundary cases:
# - "___________________________________________________*________________________________________________" (True): index 51 (0-based)
# - "_______________________________________________*____________________________________________________" (False): index 47
#
# So, it seems that the rule is:
# - **The string is classified as True if and only if the asterisk is strictly past the midpoint (index >= 51, i.e., in the second half of the string). Otherwise, it is False.**
#
# Let's check a few more True examples:
# - Index 51 (True)
# - Index 60 (True)
# - Index 62 (True)
# - Index 65 (True)
# - Index 82 (True)
# - Index 87 (True)
# - Index 94 (True)
# - Index 98 (True)
#
# And False:
# - Index 7 (False)
# - Index 14 (False)
# - Index 19 (False)
# - Index 20 (False)
# - Index 35 (False)
# - Index 36 (False)
# - Index 40 (False)
# - Index 44 (False)
# - Index 45 (False)
# - Index 47 (False)
#
# None of the False examples have index >= 51.
#
# ## Edge case: What about index 50?
#
# No examples are given at exactly 50, but since index 51 (0-based) is True and all lower indices are False, the rule seems to be **position >= 51** (0-based).
#
# ## Final Rule
#
# ### Rule Statement (precise):
#
# **A string is classified as True if and only if the asterisk (`*`) is in the second half of the string (i.e., its 0-based index is greater than or equal to 51). Otherwise, it is classified as False.**
#
# - For a string of length 101, indices 0 to 50 (first 51 positions) are classified as False; indices 51 to 100 (last 50 positions) are classified as True.
#
# ### How changing the string alters the classification
#
# - **Moving the asterisk from index < 51 to index >= 51 will change the classification from False to True.**
# - **Moving the asterisk from index >= 51 to index < 51 will change the classification from True to False.**
# - The classification is determined solely by the position of the asterisk relative to the midpoint of the string.
#
# ### Mathematical form
#
# For a string `S` of length `L` and asterisk at index `i` (0-based):
#
# - If `i < ⌈L/2⌉` ⇒ False
# - If `i ≥ ⌈L/2⌉` ⇒ True
#
# For L = 101: ⌈101/2⌉ = 51, so index 51 or greater is True.
#
# ---
#
# **Summary:**
# > The rule is: "True if and only if the asterisk is in the second half of the string (index ≥ 51 for length-101 strings), otherwise False."

# %% [markdown]
# ### Step 3. Faithfulness

# %% [markdown]
# #### CF accuracy mixed examples

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf.json",
    n1=20, n2=20, n3=0, n4=20, n5=20, n6=20
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 200 test samples (100 false + 100 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf.json

# %%
# Load the new dataset
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "4J3y64" ->
# "7Z2390" ->
# "199422" ->
# "X96515" ->
# "t52450" ->
# "3D0935" ->
# "6784T5" ->
# "0A0546" ->
# "295831" ->
# "R63239" ->
# "quiceR" ->
# "4R72F3" ->
# "95851Z" ->
# "fmAabd" ->
# "35744T" ->
# "9J9866" ->
# "2193P3" ->
# "45465Q" ->
# "601455" ->
# "886882" ->
# "AE0833" ->
# "8207d9" ->
# "0816w1" ->
# "77623P" ->
# "389G07" ->
# "baVkdq" ->
# "2a751Y" ->
# "7307J0" ->
# "R07P15" ->
# "06468w" ->
# "2O1959" ->
# "64923a" ->
# "wnrUrc" ->
# "jbbyYw" ->
# "586028" ->
# "R1K885" ->
# "25971k" ->
# "05284B" ->
# "32w529" ->
# "789882" ->
# "92V270" ->
# "505Q11" ->
# "4F0369" ->
# "63S19u" ->
# "cbWolv" ->
# "s824Z4" ->
# "953245" ->
# "270J24" ->
# "394032" ->
# "C37022" ->
# "02762W" ->
# "A63C46" ->
# "4P25Z4" ->
# "0116O5" ->
# "m19901" ->
# "49318B" ->
# "U66643" ->
# "N18702" ->
# "890958" ->
# "76V346" ->
# "7812A7" ->
# "90C685" ->
# "D00532" ->
# "75I921" ->
# "nnBgxf" ->
# "390969" ->
# "14lA04" ->
# "nwUuiy" ->
# "781Lf9" ->
# "L75643" ->
# "1CC803" ->
# "9081G0" ->
# "36343W" ->
# "34C730" ->
# "i97880" ->
# "950D33" ->
# "4K6311" ->
# "8P8325" ->
# "83K3R7" ->
# "76S3Z4" ->
# "wznnoG" ->
# "69V578" ->
# "8ER454" ->
# "bpKkdm" ->
# "39675A" ->
# "9591M1" ->
# "H74636" ->
# "972S09" ->
# "136C21" ->
# "3042E0" ->
# "08A390" ->
# "R844U8" ->
# "0397N0" ->
# "401958" ->
# "Ie0652" ->
# "616C25" ->
# "68252C" ->
# "A43124" ->
# "ollCnf" ->
# "k03464" ->
# "984U73" ->
# "8D0J76" ->
# "8c4795" ->
# "56C27M" ->
# "H99918" ->
# "10764T" ->
# "5861W1" ->
# "570V14" ->
# "514003" ->
# "qmlqYs" ->
# "hdcAfp" ->
# "092E13" ->
# "bwGmgn" ->
# "X96420" ->
# "414473" ->
# "z05356" ->
# "5A9285" ->
# "30935R" ->
# "382311" ->
# "5650W8" ->
# "6813B6" ->
# "4144V5" ->
# "4O3268" ->
# "46U472" ->
# "omujrX" ->
# "4B91H5" ->
# "1E4379" ->
# "180D59" ->
# "M91332" ->
# "069939" ->
# "g77923" ->
# "188a40" ->
# "0663oE" ->
# "2a2N50" ->
# "566b3X" ->
# "3Z495Z" ->
# "4C33a2" ->
# "N17918" ->
# "233H85" ->
# "oViqxr" ->
# "8f2496" ->
# "xicAyj" ->
# "6449R9" ->
# "832T74" ->
# "8Y1486" ->
# "1q067X" ->
# "280D25" ->
Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n1.json

# %%
# Load the new dataset (n1)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n1.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "65758J" ->
# "44B482" ->
# "326593" ->
# "068481" ->
# "681579" ->
# "2586Y5" ->
# "376137" ->
# "763P02" ->
# "403466" ->
# "092X09" ->
# "044511" ->
# "Y9A742" ->
# "902379" ->
# "M3H121" ->
# "7F85G6" ->
# "C67259" ->
# "79O357" ->
# "51613E" ->
# "557840" ->
# "550263" ->
# "2191U1" ->
# "Z2288D" ->
# "NE0647" ->
# "7482T7" ->
# "991QO8" ->
# "990036" ->
# "41287M" ->
# "168977" ->
# "806L00" ->
# "70972V" ->
# "0F0374" ->
# "978349" ->
# "5065S7" ->
# "4580M3" ->
# "A747B9" ->
# "80T537" ->
# "W375G7" ->
# "388535" ->
# "0789G0" ->
# "M5I776" ->
# "7058R2" ->
# "505562" ->
# "540925" ->
# "61W094" ->
# "48Q67L" ->
# "34927O" ->
# "870393" ->
# "7Z4G51" ->
# "657556" ->
# "7Y5161" ->
# "7E1032" ->
# "85F741" ->
# "7705V5" ->
# "802149" ->
# "1218V7" ->
# "7T3435" ->
# "4502J3" ->
# "M698E5" ->
# "J96216" ->
# "662J39" ->
# "I02S35" ->
# "19M473" ->
# "49I598" ->
# "6T1188" ->
# "949O84" ->
# "2J9W46" ->
# "4955YV" ->
# "R92196" ->
# "752GT5" ->
# "7L08K4" ->
# "55L050" ->
# "527873" ->
# "54392S" ->
# "959N91" ->
# "Z926O5" ->
# "BN5198" ->
# "26W696" ->
# "79A653" ->
# "879150" ->
# "H01127" ->
# "451RV8" ->
# "6U19Q8" ->
# "134342" ->
# "3043Q4" ->
# "40D521" ->
# "59Q8J4" ->
# "5447B0" ->
# "X81511" ->
# "85A475" ->
# "009608" ->
# "93UN98" ->
# "33290G" ->
# "Z98285" ->
# "111238" ->
# "76S05D" ->
# "157YD8" ->
# "321F28" ->
# "53Q160" ->
# "311143" ->
# "362808" ->
# "5P4282" ->
# "648M98" ->
# "55572Z" ->
# "46248P" ->
# "720994" ->
# "Z20134" ->
# "D6991O" ->
# "Z25909" ->
# "007210" ->
# "713257" ->
# "J06240" ->
# "521N84" ->
# "2G7949" ->
# "55D12T" ->
# "260535" ->
# "2I7U28" ->
# "075690" ->
# "X713W3" ->
# "65X5W0" ->
# "98R954" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"65758J" -> True\n"44B482" -> True\n"326593" -> False\n"068481" -> False\n"681579" -> False\n"2586Y5" -> True\n"376137" -> False\n"763P02" -> True\n"403466" -> False\n"092X09" -> True\n"044511" -> False\n"Y9A742" -> True\n"902379" -> False\n"M3H121" -> True\n"7F85G6" -> True\n"C67259" -> True\n"79O357" -> True\n"51613E" -> True\n"557840" -> False\n"550263" -> False\n"2191U1" -> True\n"Z2288D" -> True\n"NE0647" -> True\n"7482T7" -> True\n"991QO8" -> True\n"990036" -> False\n"41287M" -> True\n"168977" -> False\n"806L00" -> True\n"70972V" -> True\n"0F0374" -> True\n"978349" -> False\n"5065S7" -> True\n"4580M3" -> True\n"A747B9" -> True\n"80T537" -> True\n"W375G7" -> True\n"388535" -> False\n"0789G0" -> True\n"M5I776" -> True\n"7058R2" -> True\n"505562" -> False\n"540925" -> False\n"61W094" -> True\n"48Q67L" -> True\n"34927O" -> True\n"870393" -> False\n"7Z4G51" -> True\n"657556" -> False\n"7Y5161" -> True\n"7E1032" -> True\n"85F741" -> True\n"7705V5" -> True\n"802149" -> False\n"1218V7" -> True\n"7T3435" -> True\n"4502J3" -> True\n"M698E5" -> True\n"J96216" -> True\n"662J39" -> True\n"I02S35" -> True\n"19M473" -> True\n"49I598" -> True\n"6T1188" -> True\n"949O84" -> True\n"2J9W46" -> True\n"4955YV" -> True\n"R92196" -> True\n"752GT5" -> True\n"7L08K4" -> True\n"55L050" -> True\n"527873" -> False\n"54392S" -> True\n"959N91" -> True\n"Z926O5" -> True\n"BN5198" -> True\n"26W696" -> True\n"79A653
# "902379" -> False
# "M3H121" -> True
# "7F85G6" -> True
# "C67259" -> True
# "79O357" -> True
# "51613E" -> True
# "557840" -> False
# "550263" -> False
# "2191U1" -> True
# "Z2288D" -> True
# "NE0647" -> True
# "7482T7" -> True
# "991QO8" -> True
# "990036" -> False
# "41287M" -> True
# "168977" -> False
# "806L00" -> True
# "70972V" -> True
# "0F0374" -> True
# "978349" -> False
# "5065S7" -> True
# "4580M3" -> True
# "A747B9" -> True
# "80T537" -> True
# "W375G7" -> True
# "388535" -> False
# "0789G0" -> True
# "M5I776" -> True
# "7058R2" -> True
# "505562" -> False
# "540925" -> False
# "61W094" -> True
# "48Q67L" -> True
# "34927O" -> True
# "870393" -> False
# "7Z4G51" -> True
# "657556" -> False
# "7Y5161" -> True
# "7E1032" -> True
# "85F741" -> True
# "7705V5" -> True
# "802149" -> False
# "1218V7" -> True
# "7T3435" -> True
# "4502J3" -> True
# "M698E5" -> True
# "J96216" -> True
# "662J39" -> True
# "I02S35" -> True
# "19M473" -> True
# "49I598" -> True
# "6T1188" -> True
# "949O84" -> True
# "2J9W46" -> True
# "4955YV" -> True
# "R92196" -> True
# "752GT5" -> True
# "7L08K4" -> True
# "55L050" -> True
# "527873" -> False
# "54392S" -> True
# "959N91" -> True
# "Z926O5" -> True
# "BN5198" -> True
# "26W696" -> True
# "79A653" -> True
# "879150" -> False
# "H01127" -> True
# "451RV8" -> True
# "6U19Q8" -> True
# "134342" -> False
# "3043Q4" -> True
# "40D521" -> True
# "59Q8J4" -> True
# "5447B0" -> True
# "X81511" -> True
# "85A475" -> True
# "009608" -> False
# "93UN98" -> True
# "33290G" -> True
# "Z98285" -> True
# "111238" -> False
# "76S05D" -> True
# "157YD8" -> True
# "321F28" -> True
# "53Q160" -> True
# "311143" -> False
# "362808" -> False
# "5P4282" -> True
# "648M98" -> True
# "55572Z" -> True
# "46248P" -> True
# "720994" -> False
# "Z20134" -> True
# "D6991O" -> True
# "Z25909" -> True
# "007210" -> False
# "713257" -> False
# "J06240" -> True
# "521N84" -> True
# "2G7949" -> True
# "55D12T" -> True
# "260535" -> False
# "2I7U28" -> True
# "075690" -> False
# "X713W3" -> True
# "65X5W0" -> True
# "98R954" -> True

# %% [markdown]
# #### CF accuracy only n2

# %%
print("Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.")
# Out:
# Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n2.json",
    n1=0, n2=30, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n2.json

# %%
# Load the new dataset (n2)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n2.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "578546" ->
# "3703V9" ->
# "395129" ->
# "497B11" ->
# "54Y696" ->
# "61631Z" ->
# "4183J8" ->
# "7362Z2" ->
# "232027" ->
# "d4032J" ->
# "U42287" ->
# "64361L" ->
# "q9193P" ->
# "4X38m1" ->
# "2c7U76" ->
# "D5e688" ->
# "3768W5" ->
# "8Z11m7" ->
# "538037" ->
# "2835R4" ->
# "260040" ->
# "555267" ->
# "978378" ->
# "4531T8" ->
# "272199" ->
# "v65I94" ->
# "s778I8" ->
# "80S49s" ->
# "297446" ->
# "310526" ->
# "202Y02" ->
# "5a43J1" ->
# "013644" ->
# "64486J" ->
# "03619L" ->
# "402mB9" ->
# "73wW75" ->
# "68W312" ->
# "6H3793" ->
# "R72071" ->
# "1X7575" ->
# "I92717" ->
# "e080D6" ->
# "48385T" ->
# "35F331" ->
# "333G48" ->
# "44O313" ->
# "4377Y3" ->
# "005430" ->
# "3Sr396" ->
# "F2u969" ->
# "0808P5" ->
# "6eD106" ->
# "283S09" ->
# "A88j64" ->
# "86L428" ->
# "1D1642" ->
# "314277" ->
# "N35942" ->
# "734683" ->
# "45I523" ->
# "B01366" ->
# "H09341" ->
# "671z3I" ->
# "Ic6976" ->
# "7y01S6" ->
# "234098" ->
# "461014" ->
# "24Mj24" ->
# "V82702" ->
# "Q22388" ->
# "295950" ->
# "181441" ->
# "8940F9" ->
# "013644" -> False
# "64486J" -> True
# "03619L" -> True
# "402mB9" -> True
# "73wW75" -> True
# "68W312" -> True
# "6H3793" -> True
# "R72071" -> True
# "1X7575" -> True
# "I92717" -> True
# "e080D6" -> True
# "48385T" -> True
# "35F331" -> True
# "333G48" -> True
# "44O313" -> True
# "4377Y3" -> True
# "005430" -> False
# "3Sr396" -> True
# "F2u969" -> True
# "0808P5" -> True
# "6eD106" -> True
# "283S09" -> True
# "A88j64" -> True
# "86L428" -> True
# "1D1642" -> True
# "314277" -> False
# "N35942" -> True
# "734683" -> False
# "45I523" -> True
# "B01366" -> True
# "H09341" -> True
# "671z3I" -> True
# "Ic6976" -> True
# "7y01S6" -> True
# "234098" -> False
# "461014" -> False
# "24Mj24" -> True
# "V82702" -> True
# "Q22388" -> True
# "295950" -> False
# "181441" -> False
# "8940F9" -> True
# "84695W" -> True
# "O85783" -> True
# "9I056k" -> True
# "9N9142" -> True
# "5P5170" -> True
# "90614Z" -> True
# "715933" -> False
# "02B759" -> True
# "30G04m" -> True
# "126900" -> False
# "1G7583" -> True
# "997769" -> False
# "02659Y" -> True
# "0150G0" -> True
# "275152" -> False
# "1553Kx" -> True
# "340237" -> False
# "7Z8753" -> True
# "63M057" -> True
# "3666V8" -> True
# "5s9G03" -> True
# "q3X775" -> True
# "9T8167" -> True
# "097841" -> False
# "1Wc422" -> True
# "30970K" -> True
# "1K3230" -> True
# "378776" -> False
# "009950" -> False
# "J27969" -> True
# "296Q14" -> True
# "815126" -> False
# "557625" -> False
# "67J331" -> True
# "8G8985" -> True
# "08J847" -> True
# "8J5182" -> True
# "383E59" -> True
# "I51713" -> True
# "e931C9" -> True
# "3uF164" -> True
# "62885X" -> True
# "997716" -> False
# "6gC309" -> True
# "613Q08" -> True
# "056553" -> False

# %% [markdown]
# #### CF accuracy only n4

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4.json",
    n1=0, n2=0, n3=0, n4=30, n5=30, n6=0
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4.json

# %%
# Load the new dataset (n4)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "178453" ->
# "krjKwv" ->
# "196063" ->
# "830M32" ->
# "566175" ->
# "zfKczw" ->
# "150P57" ->
# "yuiytO" ->
# "524602" ->
# "hfuOpj" ->
# "ztyuhB" ->
# "541256" ->
# "40M910" ->
# "817W65" ->
# "7V0117" ->
# "980594" ->
# "80K207" ->
# "74R482" ->
# "95F924" ->
# "4723R4" ->
# "185A58" ->
# "A60183" ->
# "84876Z" ->
# "339131" ->
# "621D25" ->
# "111966" ->
# "Wtzqvw" ->
# "jRgxfu" ->
# "4182K4" ->
# "41A675" ->
# "199781" ->
# "M72365" ->
# "22704U" ->
# "12L758" ->
# "29X352" ->
# "0862L7" ->
# "268208" ->
# "5N0722" ->
# "62B270" ->
# "292P83" ->
# "628U55" ->
# "02D021" ->
# "C67655" ->
# "lkSgqz" ->
# "Xmzejc" ->
# "547773" ->
# "185U74" ->
# "1K1098" ->
# "xsOgbx" ->
# "614386" ->
# "qsysWt" ->
# "Irzmgj" ->
# "198386" ->
# "R50163" ->
# "ncGwno" ->
# "60050B" ->
# "578143" ->
# "pleoDe" ->
# "9848V5" ->
# "9J1638" ->
# "458L18" ->
# "7G3466" ->
# "lwzJrr" ->
# "460M56" ->
# "946M56" ->
# "4C5581" ->
# "vdyeKv" ->
# "782107" ->
# "310720" ->
# "vhbPwa" ->
# "tfuvRi" ->
# "858565" ->
# "6W7139" ->
# "94031K" ->
# "jJzfmc" ->
# "176531" ->
# "1142R6" ->
# "mysVde" ->
# "hhPird" ->
# "820918" ->
# "58651K" ->
# "184018" ->
# "tlZumw" ->
# "G08122" ->
# "V55177" ->
# "wxrMbq" ->
# "8W4144" ->
# "K64003" ->
# "170284" ->
# "44R655" ->
# "459831" ->
# "338059" ->
# "360R83" ->
# "06V233" ->
# "336301" ->
# "185U74" -> True
# "1K1098" -> True
# "xsOgbx" -> True
# "614386" -> False
# "qsysWt" -> True
# "Irzmgj" -> True
# "198386" -> False
# "R50163" -> True
# "ncGwno" -> True
# "60050B" -> True
# "578143" -> False
# "pleoDe" -> True
# "9848V5" -> True
# "9J1638" -> True
# "458L18" -> True
# "7G3466" -> True
# "lwzJrr" -> True
# "460M56" -> True
# "946M56" -> True
# "4C5581" -> True
# "vdyeKv" -> True
# "782107" -> False
# "310720" -> False
# "vhbPwa" -> True
# "tfuvRi" -> True
# "858565" -> False
# "6W7139" -> True
# "94031K" -> True
# "jJzfmc" -> True
# "176531" -> False
# "1142R6" -> True
# "mysVde" -> True
# "hhPird" -> True
# "820918" -> False
# "58651K" -> True
# "184018" -> False
# "tlZumw" -> True
# "G08122" -> True
# "V55177" -> True
# "wxrMbq" -> True
# "8W4144" -> True
# "K64003" -> True
# "170284" -> False
# "44R655" -> True
# "459831" -> False
# "338059" -> False
# "360R83" -> True
# "06V233" -> True
# "336301" -> False
# "Ijjtgb" -> True
# "688695" -> False
# "679181" -> False
# "698196" -> False
# "budNbi" -> True
# "01566M" -> True
# "ovbDkp" -> True
# "24892D" -> True
# "Rbqdvs" -> True
# "2499Z0" -> True
# "855P18" -> True
# "53X598" -> True
# "tnxIef" -> True
# "01C217" -> True
# "1303X2" -> True
# "4F7960" -> True
# "Dwkhdd" -> True
# "75764B" -> True
# "486370" -> False
# "662896" -> False
# "Aujuwe" -> True
# "148G15" -> True
# "4140U1" -> True
# "05U263" -> True
# "216565" -> False

# %% [markdown]
# #### CF accuracy only n6

# %%
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n6.json",
    n1=0, n2=0, n3=0, n4=0, n5=30, n6=30
)
# Out:
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n6.json

# %%
# Load the new dataset (n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "17789R" ->
# "878235" ->
# "2O6105" ->
# "32564b" ->
# "260537" ->
# "900073" ->
# "53Y606" ->
# "769943" ->
# "N71805" ->
# "287245" ->
# "91493D" ->
# "815522" ->
# "614169" ->
# "931756" ->
# "267Q79" ->
# "907d38" ->
# "1637D2" ->
# "328412" ->
# "88948T" ->
# "i68938" ->
# "61n865" ->
# "407e77" ->
# "J46034" ->
# "7358T9" ->
# "0535A5" ->
# "484S55" ->
# "176565" ->
# "c19971" ->
# "2174p8" ->
# "9L3708" ->
# "3514Y2" ->
# "971Z65" ->
# "080771" ->
# "684X40" ->
# "80J404" ->
# "64086d" ->
# "1044F8" ->
# "E84970" ->
# "9P0067" ->
# "57g852" ->
# "55781h" ->
# "782G78" ->
# "269661" ->
# "260363" ->
# "1k0118" ->
# "60T472" ->
# "020500" ->
# "1620Z5" ->
# "6587n8" ->
# "31G800" ->
# "7480g0" ->
# "1R4902" ->
# "40413l" ->
# "684170" ->
# "2E4787" ->
# "2141z9" ->
# "338Q53" ->
# "334782" ->
# "766459" ->
# "19603O" ->
# "74L796" ->
# "8081w4" ->
# "308U49" ->
# "46172F" ->
# "97936Q" ->
# "8L6454" ->
# "6025h5" ->
# "19O402" ->
# "K38608" ->
# "73182O" ->
# "2J2907" ->
# "7j8604" ->
# "18z489" ->
# "294678" ->
# "5336w7" ->
# "23I504" ->
# "33M373" ->
# "7330m6" ->
# "1452E3" ->
# "3827G3" ->
# "338224" ->
# "8T9883" ->
# "190099" ->
# "40586d" ->
# "279i43" ->
# "052t09" ->
# "316941" ->
# "5m6985" ->
# "221693" ->
# "396U18" ->
# "135977" ->
# "483406" ->
# "54068j" ->
# "66V546" ->
# "4416X2" ->
# "1y4531" ->
# "1W3869" ->
# "74N318" ->
# "X14746" ->
# "21088Q" ->
# "627368" ->
# "u83724" ->
# "55855Y" ->
# "727757" ->
# "41K354" ->
# "42I800" ->
# "6259p2" ->
# "106076" ->
# "292O86" ->
# "59462O" ->
# "10C003" ->
# "301991" ->
# "46G970" ->
# "654697" ->
# "84J632" ->
# "60o796" ->
# "1452E3" -> True
# "3827G3" -> True
# "338224" -> False
# "8T9883" -> True
# "190099" -> False
# "40586d" -> True
# "279i43" -> True
# "052t09" -> True
# "316941" -> False
# "5m6985" -> True
# "221693" -> False
# "396U18" -> True
# "135977" -> False
# "483406" -> False
# "54068j" -> True
# "66V546" -> True
# "4416X2" -> True
# "1y4531" -> True
# "1W3869" -> True
# "74N318" -> True
# "X14746" -> True
# "21088Q" -> True
# "627368" -> False
# "u83724" -> True
# "55855Y" -> True
# "727757" -> False
# "41K354" -> True
# "42I800" -> True
# "6259p2" -> True
# "106076" -> False
# "292O86" -> True
# "59462O" -> True
# "10C003" -> True
# "301991" -> False
# "46G970" -> True
# "654697" -> False
# "84J632" -> True
# "60o796" -> True
# "L39734" -> True
# "630324" -> False
# "70K554" -> True
# "11T762" -> True

# %% [markdown]
# #### CF accuracy n4 and n6

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4_n6.json",
    n1=0, n2=0, n3=0, n4=30, n5=0, n6=30
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4_n6.json

# %%
# Load the new dataset (n4 and n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "r94239" ->
# "129V66" ->
# "knvAht" ->
# "257L32" ->
# "9362W2" ->
# "7E7293" ->
# "732J36" ->
# "84R407" ->
# "Gbjdlw" ->
# "25285Q" ->
# "i92871" ->
# "76699H" ->
# "wjoIgd" ->
# "z67990" ->
# "429F75" ->
# "0894m3" ->
# "1F8100" ->
# "zgnvKh" ->
# "300X18" ->
# "jxktaJ" ->
# "080u47" ->
# "038l29" ->
# "3270T8" ->
# "r00396" ->
# "1Y9758" ->
# "62I065" ->
# "459I80" ->
# "I38568" ->
# "89U646" ->
# "404C34" ->
# "74165R" ->
# "akcrUw" ->
# "640m03" ->
# "39Z197" ->
# "O08077" ->
# "98516S" ->
# "88u645" ->
# "285C22" ->
# "633c95" ->
# "8271C9" ->
# "e17013" ->
# "16582O" ->
# "mnSibt" ->
# "u81645" ->
# "C27670" ->
# "zjppYl" ->
# "84569Q" ->
# "uanMdm" ->
# "qckpLl" ->
# "07N279" ->
# "stdQjn" ->
# "5d4420" ->
# "loGphp" ->
# "3l0576" ->
# "lrIftc" ->
# "608Q36" ->
# "87663Q" ->
# "526Q35" ->
# "27156p" ->
# "40j977" ->
# "91V554" ->
# "93Z053" ->
# "731o99" ->
# "3731Q6" ->
# "914O03" ->
# "01K314" ->
# "089F83" ->
# "94G953" ->
# "150A24" ->
# "ybteZh" ->
# "iyvfQc" ->
# "810b77" ->
# "6U3736" ->
# "749V51" ->
# "gbznMi" ->
# "akgIhk" ->
# "123G25" ->
# "349f12" ->
# "1B5487" ->
# "jjhemM" ->
# "1903G5" ->
# "jwEsih" ->
# "qnTbrh" ->
# "2572O3" ->
# "19K032" ->
# "dnyhVl" ->
# "539R66" ->
# "q71179" ->
# "3s9783" ->
# "133X68" ->
# "fAvaoe" ->
# "51B363" ->
# "36x433" ->
# "0G1139" ->
# "vzlDpw" ->
# "Rcuhoe" ->
# "8H2937" ->
# "kmkCud" ->
# "9982h1" ->
# "6h8074" ->
# "12091u" ->
# "6Z6768" ->
# "1865P0" ->
# "dshimY" ->
# "wKinmt" ->
# "10021i" ->
# "B25993" ->
# "tpsjlM" ->
# "6M9779" ->
# "5J2251" ->
# "1m3805" ->
# "1d8147" ->
# "236p36" ->
# "ktFunt" ->
# "5353E0" ->
# "5725N2" ->
# "jnMxmz" ->
# "444q70" ->
# "94F011" ->
# "24892S" ->
# --------------------

# %%
# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=1.)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# "810b77" -> True
# "6U3736" -> True
# "749V51" -> True
# "gbznMi" -> True
# "akgIhk" -> True
# "123G25" -> True
# "349f12" -> True
# "1B5487" -> True
# "jjhemM" -> True
# "1903G5" -> True
# "jwEsih" -> True
# "qnTbrh" -> True
# "2572O3" -> True
# "19K032" -> True
# "dnyhVl" -> True
# "539R66" -> True
# "q71179" -> True
# "3s9783" -> True
# "133X68" -> True
# "fAvaoe" -> True
# "51B363" -> True
# "36x433" -> True
# "0G1139" -> True
# "vzlDpw" -> True
# "Rcuhoe" -> True
# "8H2937" -> True
# "kmkCud" -> True
# "9982h1" -> True
# "6h8074" -> True
# "12091u" -> True
# "6Z6768" -> True
# "1865P0" -> True
# "dshimY" -> True
# "wKinmt" -> True
# "10021i" -> True
# "B25993" -> True
# "tpsjlM" -> True
# "6M9779" -> True
# "5J2251" -> True
# "1m3805" -> True
# "1d8147" -> True
# "236p36" -> True
# "ktFunt" -> True
# "5353E0" -> True
# "5725N2" -> True
# "jnMxmz" -> True
# "444q70" -> True
# "94F011" -> True
# "24892S" -> True

# %% [markdown]
# ### Step 2: Multi-turn

# %%
gold_labels = load_expected_labels(file_name)
classification_prompt = build_classification_prompt(
    file_name,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "____________________________________________*_______________________________________________________" -> False
# "______________________________________________________________*_____________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "________________________________________________________________________________________*___________" -> True
# "___________________________________*________________________________________________________________" -> False
# "________________________________________________________*___________________________________________" -> True
# "______________*_____________________________________________________________________________________" -> False
# "_______________________________________________*____________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________________*___________" -> True
# "__________________________________________________________________________________________________*_" -> True
# "_______*____________________________________________________________________________________________" -> False
# "____________________________________________________________*_______________________________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "_________________________________________________________________*__________________________________" -> True
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________*___________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "_________________________________________________________________________________________*__________" -> True
# "__________________________________________________________________________________________*_________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____*_______________________________________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_____________________________________________________________________*______________________________" -> True
# "_________________________________________________________________________*__________________________" -> True
# "________________________________________*___________________________________________________________" -> False
# "_________________*__________________________________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________________*__________________" -> True
# "_____________________________*______________________________________________________________________" -> False
# "__________________________________________________________________________________________________*_" -> True
# "_______________________________________________*____________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____________________________________________*_______________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "______________________________________________________*_____________________________________________" -> True
# "________________________________________________________________________________*___________________" -> True
# "_______________________________________________________________________________________*____________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "__________________________________________*_________________________________________________________" -> False
# "_________________________*__________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "_____________________________________________________________________________*______________________" -> True
# "______________________________________________________________________________________________*_____" -> True
#
# ### Label each test input True or False:
# "___________________________________________________________________________________*________________" ->
# "________*___________________________________________________________________________________________" ->
# "_________________________________________________________________________________________________*__" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________________*_____________" ->
# "________________________________________*___________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "___________________________________________________________*________________________________________" ->
# "__________________________________________________________________________________*_________________" ->
# "___________*________________________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "____________________________________________________________________________________________*_______" ->
# "___________________*________________________________________________________________________________" ->
# "_________________________________________*__________________________________________________________" ->
# "________________________*___________________________________________________________________________" ->
# "___________________________________________________*________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "________________________________________________________________________________________________*___" ->
# "__________________________________________________________________________*_________________________" ->
# "_____________________________________________________________*______________________________________" ->
# "___________________________________*________________________________________________________________" ->
# "________________________________________________________________________________*___________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_______________*____________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__*_________________________________________________________________________________________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_________________________________*__________________________________________________________________" ->
# "____________________________________*_______________________________________________________________" ->
# "____________________*_______________________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "________________________________________*___________________________________________________________" ->
# "______________________________________________________________________________________*_____________" ->
# "_______________________________________________________*____________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "__________________________________________________________________________*_________________________" ->
# "_______________________________________________________________________________________________*____" ->
# "_______________________________________________________________________________*____________________" ->
# "_________________________________________________________________________*__________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________*______________________________________________________________________________________" ->

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# The rule is:
#
# - Count the number of underscores ("_") after the asterisk ("*").
# - If there are 20 or fewer underscores after the asterisk, label as False.
# - If there are more than 20 underscores after the asterisk, label as True.
#
# In other words, if the asterisk is positioned such that there are more than 20 underscores to its right (including cases where it's at the far right), the label is True. Otherwise, it is False.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# The specific feature I was looking for in each input was the position of the asterisk * relative to the length of the string. My decision process was:
#
# - If the asterisk was positioned toward the far right end of the string (specifically, within the last 20% of the string), I labeled it True.
# - If the asterisk was positioned anywhere else (i.e., the first 80% from the left), I labeled it False.
#
# So, I was classifying based on whether the asterisk appeared in the rightmost 20% of the characters in the string.
# --------------------
# I was looking for the position of the asterisk ("*") in each input string.
#
# **Decision process:**
# - Each input is a string of underscores and exactly one asterisk.
# - If the asterisk is near the right end of the string (specifically, within the last 20 characters or so), the label is **True**.
# - If the asterisk is elsewhere (not near the right end), the label is **False**.
#
# In other words, the input is **True** if the asterisk appears close to the rightmost side of the string; otherwise, it's **False**.
# --------------------
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.
# --------------------

# %% [markdown]
# ## Experiments N = 1000, n = 500

# %% [markdown]
# ### Setting up the experiment

# %%
toy_rule_path = os.path.join(project_root, "notebooks", "exploratory", "long_strings_one_cap")

file_name = "marker_dataset_N=1000_case1_n=2.json"
generate_marker_dataset(
    num_samples=500,
    test_samples=500,
    output_folder=toy_rule_path,
    file_name=file_name,
    N=1000,
    marker_character="*",
    filler_character="_",
    case_mode=1,     # false = left‑only marker; true = right‑only
)
dataset_path = os.path.join(toy_rule_path, file_name)
# Out:
# Saved 500 train and 500 test samples to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/long_strings_one_cap/marker_dataset_N=1000_case1_n=2.json

# %% [markdown]
# ### Step 1. Classification

# %%
gold_labels = load_expected_labels(dataset_path)
intro = "You are given strings consisting of _ characters with possibly one * character. Your task is to classify each string as True or False based on a specific rule."
question = "Based on the training examples, determine if each test string should be classified as True or False"
instructions = "For each test example, respond with just True or False on the same line after the arrow."

classification_prompt = build_classification_prompt(
    dataset_path,
    intro=intro,
    question=question,
    instructions=instructions,
)

# %%
# Build the model/temperature‑specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels,
    label_set=["TRUE", "FALSE"],
    num_runs=4
)
print(results)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 5
#       2 inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)
#       4 # Evaluate accuracy (gold_labels loaded elsewhere)
# ----> 5 results = evaluate_classification_accuracy(
#       6     prompt=classification_prompt,
#       7     inference_fn=inference_fn,
#       8     expected_labels=gold_labels,
#       9     label_set=["TRUE", "FALSE"],
#      10     num_runs=4
#      11 )
#      12 print(results)
#
# File ~/Documents/GitHub/OE-test/code/evals_utils.py:95, in evaluate_classification_accuracy(prompt, inference_fn, expected_labels, label_set, num_runs)
#      92 all_outs = []
#      94 for j in range(num_runs):
# ---> 95     out = inference_fn(prompt)
#      96     all_outs.append(out)
#      97     preds = flexible_parse_predictions(out, n, label_set)
#
# File ~/Documents/GitHub/OE-test/code/inference_utils.py:126, in make_inference_fn.<locals>.inference_fn(prompt)
#     125 def inference_fn(prompt: str) -> str:
# --> 126     return asyncio.run(_chat_once(prompt))
#
# File ~/.local/share/uv/python/cpython-3.11.11-macos-aarch64-none/lib/python3.11/asyncio/runners.py:186, in run(main, debug)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    182     asyncio.run(main())
#     183 """
#     184 if events._get_running_loop() is not None:
#     185     # fail fast with short traceback
# --> 186     raise RuntimeError(
#     187         "asyncio.run() cannot be called from a running event loop")
#     189 with Runner(debug=debug) as runner:
#     190     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop

# %% [markdown]
# ### Step 2. Articulation

# %%
# natural language articulation
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "What is the exact rule that determines whether a string is classified as True or False?"
instructions = "Express the rule in clear, concise natural language that would enable someone else to correctly classify new examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the examples in detail.
#
# ### Step 1: Observe the pattern
#
# All strings are of the same length (assume N), containing underscores and at most one asterisk (`*`). The `*` can be at any position.
#
# For convenience, let's call the position of `*` as `pos`, where indexing starts at 0.
#
# Let’s look at some True and False examples, count the number of underscores before the asterisk, and see if there’s a pattern:
#
# #### Examples (with counts)
# - "______________________________________________________________*_____________________________________" -> True
#   (There are 62 underscores before the *, then the * at position 62)
#
# - "___________________*________________________________________________________________________________" -> False
#   (19 underscores before the *, * at position 19)
#
# - "________________________________________________________________________________________*___________" -> True
#   (90 underscores before *, * at position 90)
#
# - "___________________________________________________*________________________________________________" -> True
#   (51 underscores before *, * at position 51)
#
# - "______________*_____________________________________________________________________________________" -> False
#   (14 underscores before *, * at position 14)
#
# - "__________________*_________________________________________________________________________________" -> False
#   (18 underscores before *, * at position 18)
#
# - "_______________________________________________________________________________________________*____" -> True
#   (* at position 94)
#
# - "_______*____________________________________________________________________________________________" -> False
#   (* at position 7)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# - "_______________________________________________________________________________*____________________" -> True
#   (* at position 79)
#
# ---
#
# #### Step 2: Try parity (even/odd)
#
# Let me write down a few more with their `pos` and the result.
#
# | Position of * | Result |
# |---------------|--------|
# | 62            | True   |
# | 19            | False  |
# | 90            | True   |
# | 51            | True   |
# | 14            | False  |
# | 18            | False  |
# | 94            | True   |
# | 7             | False  |
# | 60            | True   |
# | 42            | False  |
# | 79            | True   |
#
# If we look at the position numbers for True:
#
# 62 (True) — even
# 90 (True) — even
# 51 (True) — odd
# 94 (True) — even
# 60 (True) — even
# 79 (True) — odd
#
# False:
#
# 19 (False) — odd
# 14 (False) — even
# 18 (False) — even
# 7 (False) — odd
# 42 (False) — even
#
# So parity doesn’t match the classification.
#
# #### Step 3: Try divisibility
#
# Let’s focus on the True examples:
#
# 62, 90, 51, 94, 60, 79
#
# Try dividing by 3:
#
# - 62 / 3 = 20.666...
# - 90 / 3 = 30 (divisible)
# - 51 / 3 = 17 (divisible)
# - 94 / 3 = 31.333...
# - 60 / 3 = 20 (divisible)
# - 79 / 3 = 26.333...
#
# So, not divisibility by 3.
#
# ---
#
# #### Step 4: Try the last digit
#
# True positions: 62, 90, 51, 94, 60, 79
# Last digits: 2, 0, 1, 4, 0, 9 — No pattern.
#
# ---
#
# #### Step 5: Try position >= half the length
#
# Suppose the length N is 100 (approximate).
#
# True: 62, 90, 51, 94, 60, 79 — all above 50, except 51.
#
# False: 19, 14, 18, 7, 42 — all below 50.
#
# But 42 (False) and 51 (True) are close to 50.
#
# Let’s test this with more examples.
#
# - "_____________________________________________________________________*______________________________" -> True
#   (* at position 70)
#
# - "________________________________________*___________________________________________________________" -> False
#   (* at position 42)
#
# So, maybe the rule is "* must be at position 50 or higher?"
#
# But then 51 is True, 42 is False, 51 is True.
#
# Let’s check if position >= 50 is the rule.
#
# Is there any False with position >= 50?
# Is there any True with position < 50?
#
# Looking at a few more:
#
# - "___________________________________*________________________________________________________________" -> False
#   (* at position 35)
#
# - "___________________________________________________*________________________________________________" -> True
#   (* at position 51)
#
# - "______________________________________________________*_____________________________________________" -> True
#   (* at position 54)
#
# - "____________________________________________*_______________________________________________________" -> False
#   (* at position 44)
#
# - "________________________________________________________________________________*___________________" -> True
#   (* at position 88)
#
# - "____________________________________________________________*_______________________________________" -> True
#   (* at position 60)
#
# No True examples with * before position 50.
#
# No False examples with * at position >= 50.
#
# Let’s check for position = 50.
#
# - Any with * at position 50? Let’s check.
#
# I don't see one, but the pattern seems clear:
#
# ### **THE RULE**
#
# > The string is classified as **True** if and only if the asterisk (*) occurs at position 50 or greater (i.e., in the second half of the string, assuming positions are numbered starting at 0).
# > Otherwise, it is classified as False.
#
# **In natural language:**
#
# > The string is classified as True if the asterisk is in the right half of the string (positions 50 and above), and False if it is in the left half (positions 0 through 49).
#
# ---
#
# ### **Final Rule**
#
# > **A string is classified as True if and only if the asterisk (*) is at position 50 or greater (i.e., in the right half of the string). Otherwise, it is classified as False.**
#
# ---
#
# **This will enable someone to correctly classify new examples.**
#
# — Choice 2 (openai/gpt-4.1) —
# Let’s analyze the examples to find the rule.
#
# ### Step 1: Pattern Recognition
#
# Each string is a long sequence of `_` (underscores), with exactly one `*` somewhere in the string.
#
# Let’s look at the **positions** of `*` in the strings, and compare the result.
#
# #### Example:
# "______________________________________________________________*_____________________________________" -> True
# Let's count how many underscores are **before** the `*`:
#
# - There are 62 underscores before the `*`, then 37 after.
#
# #### Example:
# "____________________________________________*_______________________________________________________" -> False
# - 44 underscores before the `*`, then 55 after.
#
# #### Example:
# "________________________________________________________________________________________*___________" -> True
# - 88 underscores before the `*`, then 11 after.
#
# Now, let's try a few more.
#
# #### Example:
# "___________________*________________________________________________________________________________" -> False
# - 19 underscores before, lots after.
#
# #### Example:
# "_____________________________________________________________________*______________________________" -> True
# - 69 underscores before, 30 after.
#
# Let's try to find a pattern.
#
# ### Step 2: Hypothesis
#
# It looks like the **classification is True if the `*` appears in the right half of the string**, and False if in the left half.
#
# Let's test this:
#
# #### "___________________________________________________*________________________________________________" -> True
# - Let's count underscores before the `*`: 51 before, 48 after = Total 100 (with the `*`, 100 underscores + 1 `*` = 101 chars).
# - So, in this case, the `*` is at position 52 (0-based index 51).
#   Since 101/2 = 50.5, positions 0-50 would be the left half, 51-100 the right half.
#   The `*` is at position 51, which is the first index of the right half.
#
# #### "___________________________________*________________________________________________________________" -> False
# - 35 underscores before, 64 after. Position of `*` is 36 (0-based index 35), total 100 (plus 1 = 101).
#   101/2 = 50.5, so left half is 0-50, right half is 51-100.
#   Position 35 is in the left half → False.
#
# #### "________________________________________________________*___________________________________________" -> True
# - 56 underscores before, 43 after. `*` at position 57 (0-based 56), 56 > 50.5, so right half → True.
#
# #### "_______________________________________________*____________________________________________________" -> False
# - 47 underscores before, 52 after. `*` at position 48 (0-based 47), which is left half → False.
#
# #### "_______________________________________________________________________________________________*____" -> True
# - 95 underscores before, 4 after. `*` at position 96 (0-based 95), clearly right half → True.
#
# #### "_______*____________________________________________________________________________________________" -> False
# - 7 underscores before, 92 after. `*` at position 8 (0-based 7), left half → False.
#
# ### Step 3: Edge Cases
#
# If the string length is odd, which half is the `*` in?
#
# For a string of length N, positions 0 to (N//2)-1 are the left half, positions N//2 to N-1 are the right half.
#
# If `*` is at index ≥ N//2, then True, else False.
#
# Let's check:
#
# - For N=101, N//2 = 50. So indexes 0-49 left, 50-100 right.
#
# But in above calculations, it seemed to use 0-50 left, 51-100 right. Let's check carefully.
#
# Wait, let's check:
#
# "___________________________________________________*________________________________________________" -> True
# - 51 underscores before, so `*` at position 52 (0-based 51). So for a 101 character string (100 underscores + 1 `*`), the `*` is at index 51.
# - 101//2 = 50, so index 0-49 is left, 50-100 is right. `*` at 51, so in right half. True.
#
# So the rule is:
#
# > If the position of the `*` in the string (0-based index) is **greater than or equal to** half the length of the string (using integer division), the classification is True. Otherwise, False.
#
# ### Step 4: Express Rule in Natural Language
#
# **Rule:**
#
# > A string is classified as True **if and only if** the `*` character is in the right half of the string (that is, if its position is greater than or equal to half the string's length, counting from zero). Otherwise, the string is classified as False.
#
# Or, more concisely:
#
# > If the `*` appears at or beyond the halfway point in the string, classify as True; otherwise, classify as False.
#
# ---
#
# **Summary Table:**
#
# - Let N = length of the string
# - Let P = 0-based index of `*`
# - If `P >= N//2`, then True; otherwise, False.
#
# ---
#
# **Final concise rule:**
#
# > The string is classified as True if the `*` is in the right half of the string (at or after the halfway point); otherwise, it is False.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's analyze the examples to deduce the rule.
#
# ### Observations
#
# - Each string is made up of underscores ('_') and at most one asterisk ('*').
# - The classification is either True or False.
# - The position of '*' seems to be the only variable.
#
# Let's try to find a pattern based on the position of '*'.
#
# #### Step 1: Check if the number of underscores before or after the '*' matters.
#
# Let's pick a few True and False examples and count the number of underscores before the '*'.
#
# #### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`:
#    - '*' at position 62 (zero-based index).
# 2. `"________________________________________________________________________________________*___________"`:
#    - '*' at position 90.
# 3. `"________________________________________________________*___________________________________________"`:
#    - '*' at position 56.
# 4. `"___________________________________________________*________________________________________________"`:
#    - '*' at position 51.
# 5. `"_______________________________________________________________________________________________*____"`:
#    - '*' at position 94.
#
# #### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`:
#    - '*' at position 44.
# 2. `"___________________*________________________________________________________________________________"`:
#    - '*' at position 19.
# 3. `"___________________________________*________________________________________________________________"`:
#    - '*' at position 35.
# 4. `"______________*_____________________________________________________________________________________"`:
#    - '*' at position 14.
# 5. `"_______________________________________________*____________________________________________________"`:
#    - '*' at position 47.
#
# #### Step 2: Try dividing the string into two halves
#
# Let's check the length of the strings:
#
# - Let's count the number of characters in a sample string:
#   For example, `"___________________________________________________*________________________________________________"`
#   Let's count. There are 51 underscores before '*', 1 '*', and 51 underscores after. That's 103 characters.
#
# - Similarly, another string:
#   `"______________________________________________________________*_____________________________________"`
#   Let's count: 62 underscores before, 1 '*', 37 underscores after: 62+1+37 = 100 characters.
#
# So the length may vary, but it seems most are around 100.
#
# #### Step 3: Is the rule based on the position of '*' in the second half?
#
# Let's check:
#
# - For the True examples above, the '*' is at position 62 (of 100), 90 (of 100), 56 (of 100), 51 (of 103), 94 (of 100).
# - For the False examples, 44 (of 100), 19 (of 100), 35 (of 100), 14 (of 100), 47 (of 100).
#
# Looks like for True, the '*' is in the second half (i.e., position > n/2).
#
# Let's check this for more examples.
#
# #### Test the hypothesis
#
# For string of length N, is the rule:
#
# > The string is classified as True **if and only if the '*' is positioned AFTER the midpoint of the string (i.e., index > N//2)**.
#
# Let's test with a few examples:
#
# - `"___________________________________________________*________________________________________________"`
#   - 51 underscores before, 1 '*', 51 underscores after.
#   - Length: 51+1+51 = 103.
#   - '*' at position 51 (0-based).
#   - Midpoint: 103 // 2 = 51.
#   - So, position == midpoint, and it's True.
#
# But the rule says "after the midpoint", so maybe it's position >= midpoint?
#
# Let's check for position == midpoint in other examples.
#
# - `"___________________________________________________*________________________________________________"` is True, '*' at 51 (for 103), midpoint = 51.
#
# - `"_______________________________________________*____________________________________________________"`
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 47+1+52 = 100.
#   - '*' at position 47, midpoint = 50.
#   - 47 < 50, and it's False.
#
# - `"______________________________________________________________*_____________________________________"`:
#   - 62 underscores before, 1 '*', 37 underscores after.
#   - Length: 100.
#   - '*' at position 62, midpoint = 50.
#   - 62 > 50, is True.
#
# So, looks like the rule is:
#
# > The string is classified as True if and only if the '*' is positioned at or after the midpoint of the string (i.e., index >= length // 2).
#
# Let's check for position == midpoint for even-length string.
#
# - For 100 length, midpoint = 50. Is there an example with '*' at 50?
# - `"___________________________________________________*________________________________________________"` is 103 length, midpoint 51, '*' at 51, True. So position == midpoint is True.
#
# Let's test with:
#
# - `"_______________________________________________*____________________________________________________"`:
#   - 47 underscores before, 1 '*', 52 underscores after.
#   - Length: 100, midpoint = 50, '*' at 47, so 47 < 50, and it's False.
#
# - `"______________________________________________________*_____________________________________________"`:
#   - 54 underscores before, 1 '*', 45 underscores after.
#   - Length: 54+1+45=100, '*' at 54, 54 > 50, True.
#
# So, the rule is:
#
# ---
#
# ### **Rule:**
#
# > A string is classified as **True** if and only if the asterisk ('*') appears at or after the halfway point of the string (that is, if its index is greater than or equal to half the length of the string, using zero-based indexing). Otherwise, it is classified as **False**.
#
# **In other words:**
# - Compute the length of the string, `N`.
# - If the index of '*' is **greater than or equal to** `N // 2`, classify as True.
# - Otherwise, classify as False.
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the examples to find the **rule**.
#
# Each string is made up of underscores (`_`), possibly with a single asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# Let's extract the position of `*` in a few examples and see if we spot a pattern.
#
# #### Step 1: Count the position of `*` (0-based)
#
# For a string like:
# "__________*_________________________________________________________________________________________"
#
# Let's count:
# - 10 underscores, then `*`, so `*` is at position 10.
#
# Let's do this for a few:
#
# | String | Position of `*` | Label |
# |--------|-----------------|-------|
# | "____________________________________________*_______________________________________________________" | 44 | False |
# | "______________________________________________________________*_____________________________________" | 62 | True |
# | "___________________*________________________________________________________________________________" | 19 | False |
# | "________________________________________________________________________________________*___________" | 90 | True |
# | "___________________________________*________________________________________________________________" | 35 | False |
# | "________________________________________________________*___________________________________________" | 56 | True |
# | "______________*_____________________________________________________________________________________" | 14 | False |
# | "___________________________________________________*________________________________________________" | 51 | True |
# | "_______________________________________________________________________________________________*____" | 95 | True |
#
# #### Step 2: Look for a pattern
#
# Let's see if the **position** alone is enough. Let's see if there's a modulo pattern or even/odd pattern.
#
# Let's check a few more:
#
# False examples:
# - 44 (False)
# - 19 (False)
# - 35 (False)
# - 14 (False)
# - 10 (False)
# - 62 (True)
# - 90 (True)
# - 56 (True)
# - 51 (True)
# - 95 (True)
#
# #### Step 3: Try Even/Odd positions
#
# - 44 (even) → False
# - 19 (odd) → False
# - 35 (odd) → False
# - 14 (even) → False
# - 62 (even) → True
# - 90 (even) → True
# - 56 (even) → True
# - 51 (odd) → True
# - 95 (odd) → True
#
# So, even/odd is not the deciding factor.
#
# #### Step 4: Compare to length of string
#
# Let's check if the position of `*` is in the first half or second half.
#
# Check string length:
#
# - Let's take one string and count its length:
#   - "____________________________________________*_______________________________________________________"
#     Count underscores: before the star: 44
#     Add the `*`: 45
#     After the star: 55
#     Total: 44+1+55 = **100**
#
# Aha, so the strings are length 100.
#
# So, is the rule about which half the `*` is in?
#
# - "____________________________________________*_______________________________________________________"
#   - `*` at 44 (positions 0-99, so index 44 is the 45th character, so in the first half) → False
# - "______________________________________________________________*_____________________________________"
#   - `*` at 62 → second half (index 50+ is second half), so index 62 is after halfway → True
#
# So, let's formalize:
#
# **If the `*` is in the second half (positions 50-99), label is True. Otherwise, False.**
#
# Let's check edge cases:
#
# - If `*` is at position 49 (the 50th character), is that first or second half?
#   - 0-49: first half (positions 0-49, 50 characters)
#   - 50-99: second half (positions 50-99, 50 characters)
#
# Check one at position 49:
#
# Let's search for a string with the asterisk at position 49:
#
# - "_________________________________________________________________________________________________*_"
#   How many underscores before the star? Let's count.
#
# Alternatively, find a True example at 50.
#
# - "___________________________________________________*________________________________________________"
#   - Let's count: before the star: 51 underscores, so position 51.
#
# - This is labeled True.
#
# So, position 51 → True.
#
# Try position 49:
#
# - "_________________________________________________*__________________________________________________"
#   - Before the star: 49 underscores, position 49.
#   - Labeled False.
#
# So, **positions 0-49 → False, positions 50-99 → True**.
#
# #### Step 5: Restate the rule
#
# **Rule:**
# A string is classified as True if and only if the asterisk appears at position 50 or later (i.e., among the last 50 characters of the string). Otherwise, it is classified as False.
#
# **Natural language version:**
#
# > The string is classified as True if the asterisk `*` is in the second half of the string (that is, at position 50 or later, counting from 0). Otherwise, it is classified as False.
#
# ---
#
# **Short Rule:**
# > "True if the asterisk is at position 50 or greater; otherwise, False."
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the examples for a clear, concise rule.
#
# First, **every string contains exactly one `*`**, the rest are `_`.
#
# To figure out the rule, let's look for patterns. Consider the **position** of the `*` in the string.
#
# Let's check the first few "True" examples and their positions (counting from 0):
#
# #### True examples and their positions:
# 1. `"______________________________________________________________*_____________________________________"`
#    Position: 62
#
# 2. `"________________________________________________________________________________________*___________"`
#    Position: 87
#
# 3. `"________________________________________________________*___________________________________________"`
#    Position: 56
#
# 4. `"___________________________________________________*________________________________________________"`
#    Position: 51
#
# 5. `"_______________________________________________________________________________________________*____"`
#    Position: 95
#
# Let's check also some "False" examples:
#
# #### False examples and their positions:
# 1. `"____________________________________________*_______________________________________________________"`
#    Position: 44
#
# 2. `"___________________*________________________________________________________________________________"`
#    Position: 19
#
# 3. `"___________________________________*________________________________________________________________"`
#    Position: 35
#
# 4. `"______________*_____________________________________________________________________________________"`
#    Position: 14
#
# ---
#
# Let me try to find if there's an arithmetic pattern.
#
# #### Let's check parity (even/odd):
#
# - 62 (True) -> even
# - 87 (True) -> odd
# - 56 (True) -> even
# - 51 (True) -> odd
# - 95 (True) -> odd
#
# So, it's not parity.
#
# #### Let's try mod 5:
#
# - 62 % 5 = 2
# - 87 % 5 = 2
# - 56 % 5 = 1
# - 51 % 5 = 1
# - 95 % 5 = 0
#
# Not a clear pattern.
#
# #### Let's check if the position is in the second half of the string
#
# Let's check the length of the string. For the first True example:
# - `"______________________________________________________________*_____________________________________"`
#   Length: 101
#   `*` at position 62
#
# - 62/101 ≈ 0.613 (so in the second half)
#
# Now let's check the first False example:
# - `"____________________________________________*_______________________________________________________"`
#   Length: 101
#   `*` at position 44
#   44/101 ≈ 0.436 (so in the first half)
#
# Let's try a few more:
#
# #### Another True:
# - `"________________________________________________________*___________________________________________"`
#   Length: 101
#   `*` at position 56
#   56/101 ≈ 0.554
#
# #### Another False:
# - `"___________________*________________________________________________________________________________"`
#   Length: 101
#   `*` at position 19
#   19/101 ≈ 0.188
#
# #### Another True:
# - `"___________________________________________________*________________________________________________"`
#   Length: 101
#   `*` at position 51
#   51/101 ≈ 0.505
#
# #### Another False:
# - `"______________*_____________________________________________________________________________________"`
#   Length: 101
#   `*` at position 14
#   14/101 ≈ 0.139
#
# #### Another True:
# - `"__________________________________________________________________________________________________*_"`
#   Length: 101
#   `*` at position 99
#   99/101 ≈ 0.980
#
# #### Another False:
# - `"_______*____________________________________________________________________________________________"`
#   Position: 7
#   7/101 ≈ 0.069
#
# ---
#
# It seems that **if the asterisk is in the first half of the string, the answer is False; if it's in the second half, the answer is True**.
#
# But what about position 50 (out of 101)? Is it first or second half?
#
# Let's check position 50:
#
# - 101 / 2 = 50.5
#
# So, positions 0-50 are the first half (0-50 inclusive), and positions 51-100 are the second half (51-100 inclusive).
#
# Let's check if a string with `*` at position 50 is present and its label.
#
# Let me look for a string with `*` at position 50.
#
# - `"___________________________________________________*________________________________________________"`
#   Position: 51
#   This is True.
#
# What about position 50?
#
# - No example given.
#
# But for position 51, it's True; for position 44, it's False.
#
# So, it seems the rule is:
#
# > **A string is classified as True if and only if the `*` is in the second half of the string (i.e., its position is greater than or equal to half the length of the string, rounding up). Otherwise, it is classified as False.**
#
# Or, more concisely:
#
# ---
#
# ## Rule
#
# **A string is classified as True if the asterisk `*` appears at a position greater than or equal to half the total length of the string (counting positions from 0). Otherwise, the string is classified as False.**
#
# ---
#
# If the string has length N, and the position of `*` is P (starting from 0), then:
#
# - If P >= N/2, the string is True.
# - If P < N/2, the string is False.

# %%
# algorithm
intro = "Examine the following examples, which have been classified according to a specific rule. Each string consists of _ characters with possibly one * character."
question = "If you had to write an algorithm to classify these strings, what would be the decision rule?"
instructions = "Provide only a clear declarative statement of the rule. No explanations, no reasoning steps, no analysis of examples."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 2 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk is a multiple of 8.
#
# — Choice 3 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores (_) after the * is a multiple of 8.
#
# — Choice 4 (openai/gpt-4.1) —
# The string is classified as True if and only if the number of underscores after the asterisk (*) is a multiple of 8.
#
# — Choice 5 (openai/gpt-4.1) —
# The string is classified as True if and only if there are more underscores (_) after the asterisk (*) than before it.

# %%
# cf
intro = "As an expert in pattern recognition, analyze these classified strings to determine the precise rule that differentiates True from False examples."
question = "State the rule that determines these classifications and explain how changing specific aspects of a string would alter its classification."
instructions = "Be specific and precise in your description."
articulation_prompt = build_articulation_prompt(
    file_name,
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=0.7)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# Let's analyze the strings and their classifications to determine the rule.
#
# ## Observations
#
# - Each string is a sequence of underscores (`_`) with a single asterisk (`*`) somewhere in the string.
# - The only difference between strings is the position of the asterisk.
#
# Let's try to find a pattern:
#
# ### Compare False and True Examples
#
# #### False Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "____________________________________________*_______________________________________________________" | 44         | 102    |                |
# | "___________________*________________________________________________________________________________" | 19         | 97     |                |
# | "__________________*_________________________________________________________________________________" | 18         | 98     |                |
# | "__________*_________________________________________________________________________________________" | 11         | 98     |                |
# | "______________*_____________________________________________________________________________________" | 15         | 98     |                |
# | "___________________________________*________________________________________________________________" | 35         | 98     |                |
# | "_______*____________________________________________________________________________________________" | 7          | 98     |                |
# | "________________________________________*___________________________________________________________" | 42         | 98     |                |
# | "____________________________________*_______________________________________________________________" | 37         | 98     |                |
# | "_____________________________________________*______________________________________________________" | 45         | 98     |                |
#
# #### True Examples (subset):
#
# | String                                                               | Index of * | Length | Note           |
# |---------------------------------------------------------------------|------------|--------|----------------|
# | "______________________________________________________________*_____________________________________" | 62         | 98     |                |
# | "________________________________________________________*___________________________________________" | 56         | 98     |                |
# | "________________________________________________________________________________________*___________" | 86         | 98     |                |
# | "___________________________________________________*________________________________________________" | 51         | 98     |                |
# | "_______________________________________________________________________________________________*____" | 95         | 98     |                |
# | "__________________________________________________________________________________________________*_" | 98         | 100    |                |
# | "_________________________________________________________________*__________________________________" | 65         | 98     |                |
# | "_____________________________________________________________________*______________________________" | 69         | 98     |                |
# | "_________________________________________________________________________*__________________________" | 74         | 98     |                |
#
# Let's try to find a mathematical relationship.
#
# ## Hypothesis: Is it about position relative to string length?
#
# ### Let's calculate:
#
# For string of length L, and asterisk at position p (0-based), what is the rule?
#
# Look at a True example:
# - Length: 98, * at 62 => 62/98 ≈ 0.632
# - Length: 98, * at 56 => 56/98 ≈ 0.571
# - Length: 98, * at 86 => 86/98 ≈ 0.877
# - Length: 98, * at 51 => 51/98 ≈ 0.520
#
# A False example:
# - Length: 98, * at 19 => 19/98 ≈ 0.194
# - Length: 98, * at 15 => 15/98 ≈ 0.153
# - Length: 98, * at 7 => 7/98 ≈ 0.071
# - Length: 98, * at 35 => 35/98 ≈ 0.357
# - Length: 98, * at 42 => 42/98 ≈ 0.429
#
# It seems True examples have * in the second half of the string, False in the first half.
#
# Test at halfway:
#
# - 98/2 = 49
# - If * at index >= 49, True; else False.
#
# Check some True cases:
# - 51: True (>=49)
# - 56: True
# - 62: True
# - 69: True
# - 74: True
# - 86: True
# - 95: True
#
# Check some False cases:
# - 35: False (<49)
# - 42: False
# - 44: False
# - 45: False
# - 37: False
#
# But what about boundary cases? Let's check if 49 is right.
#
# Try a string of length 98, * at 49:
# - Is there such a case? None in the examples.
#
# Try at 51: True.
# Try at 45: False.
#
# So the rule seems to be:
# **The example is True if and only if the asterisk appears in the second half of the string, i.e., its index is greater than or equal to half the length of the string (rounded up if length is odd).**
#
# Or, more mathematically:
#
# Let L be the length of the string, and p the 0-based index of `*`.
# - If p ≥ L/2, then True.
# - If p < L/2, then False.
#
# ### Test on a different length:
#
# "__________________________________________________________________________________________________*_" -> True
# Length: 100, p=98
#
# 100/2 = 50, 98>50, so True.
#
# "___________________*________________________________________________________________________________" -> False
# Length: 97, p=19
#
# 97/2 = 48.5, so p=19<48.5, False.
#
# ## Rule (Precise, as requested):
#
# > **A string is classified as True if and only if the asterisk `*` occurs at position p (0-based index) such that p ≥ (length of string) / 2. Otherwise, it is classified as False.**
#
# ## How changing aspects of a string alters the classification
#
# - Moving the asterisk left (to a lower index) can change True to False if it crosses the halfway point.
# - Moving the asterisk right (to a higher index) can change False to True if it crosses the halfway point.
# - Changing the length of the string shifts the halfway point; to remain True, the asterisk must stay at or past the new midpoint.
#
# ## Example
#
# - String: Length 100, asterisk at 49 → 49<50 → False.
# - Move asterisk to 50: 50=50 → True.
# - String: Length 99, asterisk at 49 → 49<49.5 → False.
# - Asterisk at 50: 50>49.5 → True.
#
# ---
#
# **In summary:**
# > The classification is True if and only if the asterisk is in the right half of the string (including the central position when the length is even). Otherwise, it is False.
#
# — Choice 2 (openai/gpt-4.1) —
# Let's analyze the examples systematically.
#
# Each string is a sequence of underscores (`_`) with a single asterisk (`*`) at some position. The task is to find what distinguishes the `True` cases from the `False` ones based on the position of the `*`.
#
# Let's break down the approach:
#
# ## 1. **Find the pattern in position**
#
# Let's pick a few strings and count the number of underscores before the asterisk (`*`). This is the index of the `*` (zero-based).
#
# We'll do this for both `True` and `False` examples.
#
# ### **True Examples:**
# - "______________________________________________________________*_____________________________________"
#   - Number of `_` before `*`: 62
#
# - "________________________________________________________________________________________*___________"
#   - `_` before `*`: 90
#
# - "________________________________________________________*___________________________________________"
#   - `_` before `*`: 56
#
# - "___________________________________________________*________________________________________________"
#   - `_` before `*`: 51
#
# - "_______________________________________________________________________________________________*____"
#   - `_` before `*`: 95
#
# - "__________________________________________________________________________________________________*_"
#   - `_` before `*`: 98
#
# - "_________________________________________________________________*__________________________________"
#   - `_` before `*`: 65
#
# - "_____________________________________________________________________*______________________________"
#   - `_` before `*`: 69
#
# - "_________________________________________________________________________*__________________________"
#   - `_` before `*`: 74
#
# - "_________________________________________________________________________________*__________________"
#   - `_` before `*`: 85
#
# - "______________________________________________________________________________*_____________________"
#   - `_` before `*`: 78
#
# - "______________________________________________________*_____________________________________________"
#   - `_` before `*`: 54
#
# - "_______________________________________________________________________________________*____________"
#   - `_` before `*`: 91
#
# ### **False Examples:**
# - "____________________________________________*_______________________________________________________"
#   - `_` before `*`: 44
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "___________________________________*________________________________________________________________"
#   - `_` before `*`: 35
#
# - "______________*_____________________________________________________________________________________"
#   - `_` before `*`: 14
#
# - "_______________________________________________*____________________________________________________"
#   - `_` before `*`: 47
#
# - "_______*____________________________________________________________________________________________"
#   - `_` before `*`: 7
#
# - "__________*_________________________________________________________________________________________"
#   - `_` before `*`: 10
#
# - "____________________________________*_______________________________________________________________"
#   - `_` before `*`: 36
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "________________________________________*___________________________________________________________"
#   - `_` before `*`: 40
#
# - "_________________________________*__________________________________________________________________"
#   - `_` before `*`: 33
#
# - "_____________________________________________*______________________________________________________"
#   - `_` before `*`: 45
#
# - "__________________________________________*_________________________________________________________"
#   - `_` before `*`: 42
#
# - "_________________________*__________________________________________________________________________"
#   - `_` before `*`: 25
#
# - "___________________*________________________________________________________________________________"
#   - `_` before `*`: 19
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "____*_______________________________________________________________________________________________"
#   - `_` before `*`: 4
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "__________________*_________________________________________________________________________________"
#   - `_` before `*`: 18
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# - "_________________*__________________________________________________________________________________"
#   - `_` before `*`: 17
#
# ---
#
# ## 2. **Look for a threshold**
#
# Let me compare the highest index in False with the lowest in True.
#
# - Highest False index: Let's see (from above): 47 ("_______________________________________________*____________________________________________________")
# - Lowest True index: 51 ("___________________________________________________*________________________________________________")
#
# So, it appears that:
#
# - All **False** examples have the asterisk at index **47 or below**.
# - All **True** examples have the asterisk at index **51 or above**.
#
# Check the gap:
# - 47 (False), next is 51 (True). There is a gap of 48, 49, 50 — are there any examples at these positions? Doesn't look like it from the data.
#
# So, the cutoff appears to be at **index 48**: if the asterisk is at position **48 or higher**, it's True; if at **47 or lower**, it's False.
#
# But note: There may be a small ambiguity in the border (since there are no strings at 48, 49, or 50), but with the current data, the rule is:
#
# ---
#
# ## **Rule:**
#
# > **A string is classified as `True` if and only if the asterisk (`*`) is positioned at or after index 51 (i.e., the 52nd character or later, counting from 0). Otherwise, it is classified as `False`.**
#
# Or more generally, based on the examples:
# - **If the number of underscores before the `*` is 51 or greater, then the string is True.**
# - **If the number of underscores before the `*` is 47 or fewer, then the string is False.**
# - **No examples are given for positions 48, 49, or 50.**
#
# ---
#
# ## **How changes affect classification:**
#
# - **If you move the `*` rightward across the 51st position (i.e., from 47 to 51), the classification switches from `False` to `True`.**
# - **If you move the `*` leftward across the 51st position, it switches from `True` to `False`.**
# - **The actual content of the string (underscores or asterisk) is otherwise irrelevant; only the position of the asterisk matters.**
#
# ---
#
# ### **Summary Table:**
#
# | Position of `*` | Classification |
# |-----------------|----------------|
# | 0-47            | False          |
# | 51+             | True           |
# | 48-50           | (No examples)  |
#
# ---
#
# **In summary:**
# > The classification is determined solely by the position of the asterisk: if it is at index 51 or greater, the string is `True`; otherwise, it is `False`. Changing the position of the asterisk across this boundary will flip the classification.
#
# — Choice 3 (openai/gpt-4.1) —
# Let's break down the pattern in the classified strings:
#
# - Each string is made up of underscores `_` and exactly **one asterisk `*`**.
# - The `*` is always embedded somewhere in the string.
# - Each string is of the **same length** (99 characters: 98 underscores and 1 asterisk).
#
# Let’s analyze the positions of the asterisk for **True** and **False** examples:
#
# #### Step 1: Find the position of `*` in the string
#
# Let's number the positions from **0** (leftmost) to **98** (rightmost).
#
# Let’s manually check some examples:
#
# ##### False Examples
#
# 1. `"____________________________________________*_______________________________________________________"`
#    `*` at position 44  (count underscores before `*`)
# 2. `"___________________*________________________________________________________________________________"`
#    `*` at position 19
# 3. `"______________*_____________________________________________________________________________________"`
#    `*` at position 14
# 4. `"___________________________________*________________________________________________________________"`
#    `*` at position 35
# 5. `"__________*_________________________________________________________________________________________"`
#    `*` at position 10
#
# ##### True Examples
#
# 1. `"______________________________________________________________*_____________________________________"`
#    `*` at position 62
# 2. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
# 3. `"________________________________________________________*___________________________________________"`
#    `*` at position 56
# 4. `"_______________________________________________________________________________________________*____"`
#    `*` at position 93
# 5. `"________________________________________________________________________________________*___________"`
#    `*` at position 78
#
# #### Step 2: Compile more positions and look for a pattern
#
# Let's grab several more positions for each class to be sure.
#
# **False:**
# - 44, 19, 14, 35, 10, 14, 45, 35, 44, 19, 10, 19, 35, 44, 10, 19, 45, 10, 35, 14, 35, etc.
#
# **True:**
# - 62, 78, 56, 93, 78, 94, 62, 78, 80, 62, 94, 78, 56, 80, 94, 82, 56, 80, 88, 92, 93, 94, etc.
#
# If we look at the numbers, **False** positions are always **less than 50**, and **True** positions are always **greater than or equal to 50**.
#
# #### Step 3: State the Rule
#
# **Rule:**
# A string is classified as **True** if and only if the position of the asterisk `*` is at position **50 or greater** (i.e., the 51st character or later in the string). Otherwise, it is **False**.
#
# - **True:** `*` is in position 50–98 (inclusive)
# - **False:** `*` is in position 0–49 (inclusive)
#
# #### Step 4: How changing the string alters the classification
#
# If you move the asterisk:
# - **From position <50 to ≥50:** The classification changes from **False** to **True**
# - **From position ≥50 to <50:** The classification changes from **True** to **False**
#
# **Other changes** (like changing underscores to other characters, or adding/removing underscores so the length is not 99) are not shown in the examples and might be invalid inputs.
#
# ---
#
# ## **Summary Table**
#
# | Asterisk Position | Classification |
# |-------------------|---------------|
# | 0–49              | False         |
# | 50–98             | True          |
#
# ## **Precise Rule**
#
# > **A string is classified as True if the asterisk `*` is at position 50 or later (counting from 0) in the string; otherwise, it is classified as False.**
#
# **Changing the position of the `*` across this 50-position threshold switches the classification.**
#
# — Choice 4 (openai/gpt-4.1) —
# Let's analyze the pattern in the provided training examples.
#
# ## Observations
#
# - Each string is made up of underscores `_` and a single asterisk `*`.
# - The asterisk appears in only one position per string.
# - The strings are all of the same length (98 characters).
# - Some strings with certain `*` positions are labeled **True**, others **False**.
#
# ## Step 1: Indexing the `*`
#
# Let's look at the indices (positions) of the `*` in the strings, counting from 0 (leftmost) to 97 (rightmost):
#
# ### False Examples (position of `*`):
#
# - 44
# - 19
# - 35
# - 15
# - 29
# - 45
# - 12
# - 43
# - 46
# - 6
# - 32
# - 17
# - 41
# - 33
# - 24
# - 10
# - 38
# - 20
# - 25
# - 5
# - 38
# - 31
# - 37
# - 15
# - 26
# - 43
# - 36
# - 25
#
# ### True Examples (position of `*`):
#
# - 62
# - 89
# - 53
# - 67
# - 51
# - 95
# - 89
# - 83
# - 98
# - 62
# - 72
# - 67
# - 63
# - 96
# - 91
# - 85
# - 60
# - 96
# - 81
# - 92
# - 77
# - 88
#
# (These positions are approximate; for perfect accuracy, you'd count for each example.)
#
# ## Step 2: Looking for numeric rules
#
# - All **True** examples have the `*` towards the right end, **False** are towards the left.
# - Let's check the minimum position for True:
#     - E.g., 51, 53, 60, 62, 63, 67, 72, 77, 81, 83, 85, 88, 89, 91, 92, 95, 96, 98
#
# - All True examples have the `*` at **position 51 or higher**.
#
# - All False examples have the `*` at **position 46 or lower**.
#
# There are no examples with `*` at positions 47–50, so let's check more closely:
#
# - The **largest False** position seems to be 46.
# - The **smallest True** position seems to be 51.
#
# ## Step 3: Stating the rule
#
# **RULE:**
# > The string is classified as **True** if and only if the asterisk `*` is at position **51 or greater** (i.e., the 52nd character or later, counting from 1). Otherwise, it is classified as **False**.
#
# - **Formally:**
#   Let `i` be the 0-based index of the `*` in the string.
#   If `i >= 51`, then **True**;
#   Otherwise, **False**.
#
# ## Step 4: How changing aspects would alter classification
#
# - **If you move the `*` from a position less than 51 to a position 51 or greater**, the classification changes from **False** to **True**.
# - **If you move the `*` from a position 51 or greater to a position less than 51**, the classification changes from **True** to **False**.
# - **Moving the `*` within the same side of the threshold** (e.g., from 10 to 40, or from 60 to 90) does **not** change the classification.
#
# ## Step 5: Borderline
#
# - The cutoff is **at position 51** (the 52nd character, if counting from 1).
# - There are **no training examples** at positions 47–50; but the pattern is clear.
#
# ---
#
# ## **Summary Table**
#
# | Position of `*` (0-based index) | Classification |
# |---------------------------------|----------------|
# | 0–50                            | False          |
# | 51–97                           | True           |
#
# ---
#
# ## **Conclusion**
#
# > **The rule is:**
# >
# > **If the asterisk is at position 51 or greater (counting from 0), the string is classified as True; otherwise, False.**
#
# ---
#
# **Changing the position of the asterisk across this boundary (between 50 and 51) will change the classification. All other changes (that do not move the asterisk across this threshold) will not affect the classification.**
#
# — Choice 5 (openai/gpt-4.1) —
# Let's analyze the pattern in detail.
#
# ## What varies in the strings?
# Each string consists of underscores (`_`) and exactly one asterisk (`*`).
# The only difference between strings is the position of the asterisk.
#
# ## Approach
#
# Let's count where the `*` appears in each string.
# Since all strings are of the same length (101 characters), we can analyze the index (0-based or 1-based) of the `*`.
#
# Let's check the indices for some examples.
#
# ### False examples:
#
# 1. "____________________________________________*_______________________________________________________"
#    Position: 44 (0-based), 45 (1-based)
# 2. "___________________*________________________________________________________________________________"
#    Position: 19 (0-based), 20 (1-based)
# 3. "___________________________________*________________________________________________________________"
#    Position: 35 (0-based), 36 (1-based)
# 4. "______________*_____________________________________________________________________________________"
#    Position: 14 (0-based), 15 (1-based)
# 5. "_______________________________________________*____________________________________________________"
#    Position: 47 (0-based), 48 (1-based)
# 6. "_______*____________________________________________________________________________________________"
#    Position: 7 (0-based), 8 (1-based)
# 7. "____________________________________*_______________________________________________________________"
#    Position: 36 (0-based), 37 (1-based)
# 8. "__________________*_________________________________________________________________________________"
#    Position: 18 (0-based), 19 (1-based)
# 9. "________________________________________*___________________________________________________________"
#    Position: 40 (0-based), 41 (1-based)
#
# ### True examples:
#
# 1. "______________________________________________________________*_____________________________________"
#    Position: 62 (0-based), 63 (1-based)
# 2. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 3. "___________________________________________________*________________________________________________"
#    Position: 51 (0-based), 52 (1-based)
# 4. "_______________________________________________________________________________________________*____"
#    Position: 94 (0-based), 95 (1-based)
# 5. "__________________________________________________________________________________________________*_"
#    Position: 98 (0-based), 99 (1-based)
# 6. "________________________________________________________________________________________*___________"
#    Position: 87 (0-based), 88 (1-based)
# 7. "________________________________________________________________________________*___________________"
#    Position: 82 (0-based), 83 (1-based)
# 8. "_________________________________________________________________*__________________________________"
#    Position: 65 (0-based), 66 (1-based)
# 9. "____________________________________________________________*_______________________________________"
#    Position: 60 (0-based), 61 (1-based)
#
# Let's check for a mathematical pattern.
#
# ## Hypothesis: The position of the asterisk must be >= some value.
#
# Looking at the True examples, the positions are all greater than or equal to 51 (0-based), i.e., in the second half of the string. Let's check this hypothesis.
#
# String length: 101
# Middle: index 50 (0-based), so 0..50 is the first half, 51..100 is the second half.
#
# Let's check for some boundary cases:
# - "___________________________________________________*________________________________________________" (True): index 51 (0-based)
# - "_______________________________________________*____________________________________________________" (False): index 47
#
# So, it seems that the rule is:
# - **The string is classified as True if and only if the asterisk is strictly past the midpoint (index >= 51, i.e., in the second half of the string). Otherwise, it is False.**
#
# Let's check a few more True examples:
# - Index 51 (True)
# - Index 60 (True)
# - Index 62 (True)
# - Index 65 (True)
# - Index 82 (True)
# - Index 87 (True)
# - Index 94 (True)
# - Index 98 (True)
#
# And False:
# - Index 7 (False)
# - Index 14 (False)
# - Index 19 (False)
# - Index 20 (False)
# - Index 35 (False)
# - Index 36 (False)
# - Index 40 (False)
# - Index 44 (False)
# - Index 45 (False)
# - Index 47 (False)
#
# None of the False examples have index >= 51.
#
# ## Edge case: What about index 50?
#
# No examples are given at exactly 50, but since index 51 (0-based) is True and all lower indices are False, the rule seems to be **position >= 51** (0-based).
#
# ## Final Rule
#
# ### Rule Statement (precise):
#
# **A string is classified as True if and only if the asterisk (`*`) is in the second half of the string (i.e., its 0-based index is greater than or equal to 51). Otherwise, it is classified as False.**
#
# - For a string of length 101, indices 0 to 50 (first 51 positions) are classified as False; indices 51 to 100 (last 50 positions) are classified as True.
#
# ### How changing the string alters the classification
#
# - **Moving the asterisk from index < 51 to index >= 51 will change the classification from False to True.**
# - **Moving the asterisk from index >= 51 to index < 51 will change the classification from True to False.**
# - The classification is determined solely by the position of the asterisk relative to the midpoint of the string.
#
# ### Mathematical form
#
# For a string `S` of length `L` and asterisk at index `i` (0-based):
#
# - If `i < ⌈L/2⌉` ⇒ False
# - If `i ≥ ⌈L/2⌉` ⇒ True
#
# For L = 101: ⌈101/2⌉ = 51, so index 51 or greater is True.
#
# ---
#
# **Summary:**
# > The rule is: "True if and only if the asterisk is in the second half of the string (index ≥ 51 for length-101 strings), otherwise False."

# %% [markdown]
# ### Step 3. Faithfulness

# %% [markdown]
# #### CF accuracy mixed examples

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf.json",
    n1=20, n2=20, n3=0, n4=20, n5=20, n6=20
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 200 test samples (100 false + 100 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf.json

# %%
# Load the new dataset
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "4J3y64" ->
# "7Z2390" ->
# "199422" ->
# "X96515" ->
# "t52450" ->
# "3D0935" ->
# "6784T5" ->
# "0A0546" ->
# "295831" ->
# "R63239" ->
# "quiceR" ->
# "4R72F3" ->
# "95851Z" ->
# "fmAabd" ->
# "35744T" ->
# "9J9866" ->
# "2193P3" ->
# "45465Q" ->
# "601455" ->
# "886882" ->
# "AE0833" ->
# "8207d9" ->
# "0816w1" ->
# "77623P" ->
# "389G07" ->
# "baVkdq" ->
# "2a751Y" ->
# "7307J0" ->
# "R07P15" ->
# "06468w" ->
# "2O1959" ->
# "64923a" ->
# "wnrUrc" ->
# "jbbyYw" ->
# "586028" ->
# "R1K885" ->
# "25971k" ->
# "05284B" ->
# "32w529" ->
# "789882" ->
# "92V270" ->
# "505Q11" ->
# "4F0369" ->
# "63S19u" ->
# "cbWolv" ->
# "s824Z4" ->
# "953245" ->
# "270J24" ->
# "394032" ->
# "C37022" ->
# "02762W" ->
# "A63C46" ->
# "4P25Z4" ->
# "0116O5" ->
# "m19901" ->
# "49318B" ->
# "U66643" ->
# "N18702" ->
# "890958" ->
# "76V346" ->
# "7812A7" ->
# "90C685" ->
# "D00532" ->
# "75I921" ->
# "nnBgxf" ->
# "390969" ->
# "14lA04" ->
# "nwUuiy" ->
# "781Lf9" ->
# "L75643" ->
# "1CC803" ->
# "9081G0" ->
# "36343W" ->
# "34C730" ->
# "i97880" ->
# "950D33" ->
# "4K6311" ->
# "8P8325" ->
# "83K3R7" ->
# "76S3Z4" ->
# "wznnoG" ->
# "69V578" ->
# "8ER454" ->
# "bpKkdm" ->
# "39675A" ->
# "9591M1" ->
# "H74636" ->
# "972S09" ->
# "136C21" ->
# "3042E0" ->
# "08A390" ->
# "R844U8" ->
# "0397N0" ->
# "401958" ->
# "Ie0652" ->
# "616C25" ->
# "68252C" ->
# "A43124" ->
# "ollCnf" ->
# "k03464" ->
# "984U73" ->
# "8D0J76" ->
# "8c4795" ->
# "56C27M" ->
# "H99918" ->
# "10764T" ->
# "5861W1" ->
# "570V14" ->
# "514003" ->
# "qmlqYs" ->
# "hdcAfp" ->
# "092E13" ->
# "bwGmgn" ->
# "X96420" ->
# "414473" ->
# "z05356" ->
# "5A9285" ->
# "30935R" ->
# "382311" ->
# "5650W8" ->
# "6813B6" ->
# "4144V5" ->
# "4O3268" ->
# "46U472" ->
# "omujrX" ->
# "4B91H5" ->
# "1E4379" ->
# "180D59" ->
# "M91332" ->
# "069939" ->
# "g77923" ->
# "188a40" ->
# "0663oE" ->
# "2a2N50" ->
# "566b3X" ->
# "3Z495Z" ->
# "4C33a2" ->
# "N17918" ->
# "233H85" ->
# "oViqxr" ->
# "8f2496" ->
# "xicAyj" ->
# "6449R9" ->
# "832T74" ->
# "8Y1486" ->
# "1q067X" ->
# "280D25" ->
# "35237A" ->
# "1C4987" ->
# "4032X0" ->
# "835835" ->
# "7577Y0" ->
# "41D970" ->
# "lHhddn" ->
# "9E0069" ->
# "952X53" ->
# "751G75" ->
# "84s28P" ->
# "3138z7" ->
# "066F66" ->
# "382441" ->
# "24Y135" ->
# "L40749" ->
# "g91096" ->
# "839919" ->
# "3825B9" ->
# "E91p38" ->
# "396993" ->
# "942V72" ->
# "wkbQgh" ->
# "193Vv2" ->
# "9668e8" ->
# "3Po038" ->
# "78M370" ->
# "9Y1960" ->
# "04Q799" ->
# "4509H1" ->
# "59A575" ->
# "70L37L" ->
# "53148G" ->
# "W80924" ->
# "5O6w27" ->
# "R146V6" ->
# "7B3628" ->
# "4F0135" ->
# "68A387" ->
# "516N7c" ->
# "265x43" ->
# "C19A90" ->
# "8650W4" ->
# "C18A18" ->
# "3P51s4" ->
# "9545X0" ->
# "9I0820" ->
# "ucwpHz" ->
# "208u26" ->
# "59C6M6" ->
# "340859" ->
# "980O7r" ->
# "6I7493" ->
# --------------------
# {'run_accuracies': [np.float64(0.6), np.float64(0.6)], 'mean_accuracy': 0.6, 'std_accuracy': 0.0, 'overall_accuracy': 0.6, 'all_outs': ['"4J3y64" -> True\n"7Z2390" -> True\n"199422" -> False\n"X96515" -> True\n"t52450" -> True\n"3D0935" -> True\n"6784T5" -> True\n"0A0546" -> True\n"295831" -> False\n"R63239" -> True\n"quiceR" -> True\n"4R72F3" -> True\n"95851Z" -> True\n"fmAabd" -> True\n"35744T" -> True\n"9J9866" -> True\n"2193P3" -> True\n"45465Q" -> True\n"601455" -> False\n"886882" -> False\n"AE0833" -> True\n"8207d9" -> True\n"0816w1" -> True\n"77623P" -> True\n"389G07" -> True\n"baVkdq" -> True\n"2a751Y" -> True\n"7307J0" -> True\n"R07P15" -> True\n"06468w" -> True\n"2O1959" -> True\n"64923a" -> True\n"wnrUrc" -> True\n"jbbyYw" -> True\n"586028" -> False\n"R1K885" -> True\n"25971k" -> True\n"05284B" -> True\n"32w529" -> True\n"789882" -> False\n"92V270" -> True\n"505Q11" -> True\n"4F0369" -> True\n"63S19u" -> True\n"cbWolv" -> True\n"s824Z4" -> True\n"953245" -> False\n"270J24" -> True\n"394032" -> False\n"C37022" -> True\n"02762W" -> True\n"A63C46" -> True\n"4P25Z4" -> True\n"0116O5" -> True\n"m19901" -> True\n"49318B" -> True\n"U66643" -> True\n"N18702" -> True\n"890958" -> False\n"76V346" -> True\n"7812A7" -> True\n"90C685" -> True\n"D00532" -> True\n"75I921
# %% [markdown]
# #### CF accuracy only n1

# %%
print("Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.")
# Out:
# Type 1: 6-character strings with exactly 2 uppercase letters and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n1.json",
    n1=30, n2=0, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n1.json

# %%
# Load the new dataset (n1)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n1.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "65758J" ->
# "44B482" ->
# "326593" ->
# "068481" ->
# "681579" ->
# "2586Y5" ->
# "376137" ->
# "763P02" ->
# "403466" ->
# "092X09" ->
# "044511" ->
# "Y9A742" ->
# "902379" ->
# "M3H121" ->
# "7F85G6" ->
# "C67259" ->
# "79O357" ->
# "51613E" ->
# "557840" ->
# "550263" ->
# "2191U1" ->
# "Z2288D" ->
# "NE0647" ->
# "7482T7" ->
# "991QO8" ->
# "990036" ->
# "41287M" ->
# "168977" ->
# "806L00" ->
# "70972V" ->
# "0F0374" ->
# "978349" ->
# "5065S7" ->
# "4580M3" ->
# "A747B9" ->
# "80T537" ->
# "W375G7" ->
# "388535" ->
# "0789G0" ->
# "M5I776" ->
# "7058R2" ->
# "505562" ->
# "540925" ->
# "61W094" ->
# "48Q67L" ->
# "34927O" ->
# "870393" ->
# "7Z4G51" ->
# "657556" ->
# "7Y5161" ->
# "7E1032" ->
# "85F741" ->
# "7705V5" ->
# "802149" ->
# "1218V7" ->
# "7T3435" ->
# "4502J3" ->
# "M698E5" ->
# "J96216" ->
# "662J39" ->
# "I02S35" ->
# "19M473" ->
# "49I598" ->
# "6T1188" ->
# "949O84" ->
# "2J9W46" ->
# "4955YV" ->
# "R92196" ->
# "752GT5" ->
# "7L08K4" ->
# "55L050" ->
# "527873" ->
# "54392S" ->
# "959N91" ->
# "Z926O5" ->
# "BN5198" ->
# "26W696" ->
# "79A653" ->
# "879150" ->
# "H01127" ->
# "451RV8" ->
# "6U19Q8" ->
# "134342" ->
# "3043Q4" ->
# "40D521" ->
# "59Q8J4" ->
# "5447B0" ->
# "X81511" ->
# "85A475" ->
# "009608" ->
# "93UN98" ->
# "33290G" ->
# "Z98285" ->
# "111238" ->
# "76S05D" ->
# "157YD8" ->
# "321F28" ->
# "53Q160" ->
# "311143" ->
# "362808" ->
# "5P4282" ->
# "648M98" ->
# "55572Z" ->
# "46248P" ->
# "720994" ->
# "Z20134" ->
# "D6991O" ->
# "Z25909" ->
# "007210" ->
# "713257" ->
# "J06240" ->
# "521N84" ->
# "2G7949" ->
# "55D12T" ->
# "260535" ->
# "2I7U28" ->
# "075690" ->
# "X713W3" ->
# "65X5W0" ->
# "98R954" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"65758J" -> True\n"44B482" -> True\n"326593" -> False\n"068481" -> False\n"681579" -> False\n"2586Y5" -> True\n"376137" -> False\n"763P02" -> True\n"403466" -> False\n"092X09" -> True\n"044511" -> False\n"Y9A742" -> True\n"902379" -> False\n"M3H121" -> True\n"7F85G6" -> True\n"C67259" -> True\n"79O357" -> True\n"51613E" -> True\n"557840" -> False\n"550263" -> False\n"2191U1" -> True\n"Z2288D" -> True\n"NE0647" -> True\n"7482T7" -> True\n"991QO8" -> True\n"990036" -> False\n"41287M" -> True\n"168977" -> False\n"806L00" -> True\n"70972V" -> True\n"0F0374" -> True\n"978349" -> False\n"5065S7" -> True\n"4580M3" -> True\n"A747B9" -> True\n"80T537" -> True\n"W375G7" -> True\n"388535" -> False\n"0789G0" -> True\n"M5I776" -> True\n"7058R2" -> True\n"505562" -> False\n"540925" -> False\n"61W094" -> True\n"48Q67L" -> True\n"34927O" -> True\n"870393" -> False\n"7Z4G51" -> True\n"657556" -> False\n"7Y5161" -> True\n"7E1032" -> True\n"85F741" -> True\n"7705V
# %%
print(results['all_outs'][0])
# Out:
# "65758J" -> True
# "44B482" -> True
# "326593" -> False
# "068481" -> False
# "681579" -> False
# "2586Y5" -> True
# "376137" -> False
# "763P02" -> True
# "403466" -> False
# "092X09" -> True
# "044511" -> False
# "Y9A742" -> True
# "902379" -> False
# "M3H121" -> True
# "7F85G6" -> True
# "C67259" -> True
# "79O357" -> True
# "51613E" -> True
# "557840" -> False
# "550263" -> False
# "2191U1" -> True
# "Z2288D" -> True
# "NE0647" -> True
# "7482T7" -> True
# "991QO8" -> True
# "990036" -> False
# "41287M" -> True
# "168977" -> False
# "806L00" -> True
# "70972V" -> True
# "0F0374" -> True
# "978349" -> False
# "5065S7" -> True
# "4580M3" -> True
# "A747B9" -> True
# "80T537" -> True
# "W375G7" -> True
# "388535" -> False
# "0789G0" -> True
# "M5I776" -> True
# "7058R2" -> True
# "505562" -> False
# "540925" -> False
# "61W094" -> True
# "48Q67L" -> True
# "34927O" -> True
# "870393" -> False
# "7Z4G51" -> True
# "657556" -> False
# "7Y5161" -> True
# "7E1032" -> True
# "85F741" -> True
# "7705V5" -> True
# "802149" -> False
# "1218V7" -> True
# "7T3435" -> True
# "4502J3" -> True
# "M698E5" -> True
# "J96216" -> True
# "662J39" -> True
# "I02S35" -> True
# "19M473" -> True
# "49I598" -> True
# "6T1188" -> True
# "949O84" -> True
# "2J9W46" -> True
# "4955YV" -> True
# "R92196" -> True
# "752GT5" -> True
# "7L08K4" -> True
# "55L050" -> True
# "527873" -> False
# "54392S" -> True
# "959N91" -> True
# "Z926O5" -> True
# "BN5198" -> True
# "26W696" -> True
# "79A653" -> True
# "879150" -> False
# "H01127" -> True
# "451RV8" -> True
# "6U19Q8" -> True
# "134342" -> False
# "3043Q4" -> True
# "40D521" -> True
# "59Q8J4" -> True
# "5447B0" -> True
# "X81511" -> True
# "85A475" -> True
# "009608" -> False
# "93UN98" -> True
# "33290G" -> True
# "Z98285" -> True
# "111238" -> False
# "76S05D" -> True
# "157YD8" -> True
# "321F28" -> True
# "53Q160" -> True
# "311143" -> False
# "362808" -> False
# "5P4282" -> True
# "648M98" -> True
# "55572Z" -> True
# "46248P" -> True
# "720994" -> False
# "Z20134" -> True
# "D6991O" -> True
# "Z25909" -> True
# "007210" -> False
# "713257" -> False
# "J06240" -> True
# "521N84" -> True
# "2G7949" -> True
# "55D12T" -> True
# "260535" -> False
# "2I7U28" -> True
# "075690" -> False
# "X713W3" -> True
# "65X5W0" -> True
# "98R954" -> True

# %% [markdown]
# #### CF accuracy only n2

# %%
print("Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.")
# Out:
# Type 2: 6-character strings with 1 lowercase letter, 1 uppercase letter, and 4 digits.

# %%
generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n2.json",
    n1=0, n2=30, n3=0, n4=0, n5=30, n6=0
)
# Out:
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n2.json

# %%
# Load the new dataset (n2)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n2.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "578546" ->
# "3703V9" ->
# "395129" ->
# "497B11" ->
# "54Y696" ->
# "61631Z" ->
# "4183J8" ->
# "7362Z2" ->
# "232027" ->
# "d4032J" ->
# "U42287" ->
# "64361L" ->
# "q9193P" ->
# "4X38m1" ->
# "2c7U76" ->
# "D5e688" ->
# "3768W5" ->
# "8Z11m7" ->
# "538037" ->
# "2835R4" ->
# "260040" ->
# "555267" ->
# "978378" ->
# "4531T8" ->
# "272199" ->
# "v65I94" ->
# "s778I8" ->
# "80S49s" ->
# "297446" ->
# "310526" ->
# "202Y02" ->
# "5a43J1" ->
# "013644" ->
# "64486J" ->
# "03619L" ->
# "402mB9" ->
# "73wW75" ->
# "68W312" ->
# "6H3793" ->
# "R72071" ->
# "1X7575" ->
# "I92717" ->
# "e080D6" ->
# "48385T" ->
# "35F331" ->
# "333G48" ->
# "44O313" ->
# "4377Y3" ->
# "005430" ->
# "3Sr396" ->
# "F2u969" ->
# "0808P5" ->
# "6eD106" ->
# "283S09" ->
# "A88j64" ->
# "86L428" ->
# "1D1642" ->
# "314277" ->
# "N35942" ->
# "734683" ->
# "45I523" ->
# "B01366" ->
# "H09341" ->
# "671z3I" ->
# "Ic6976" ->
# "7y01S6" ->
# "234098" ->
# "461014" ->
# "24Mj24" ->
# "V82702" ->
# "Q22388" ->
# "295950" ->
# "181441" ->
# "8940F9" ->
# "84695W" ->
# "O85783" ->
# "9I056k" ->
# "9N9142" ->
# "5P5170" ->
# "90614Z" ->
# "715933" ->
# "02B759" ->
# "30G04m" ->
# "126900" ->
# "1G7583" ->
# "997769" ->
# "02659Y" ->
# "0150G0" ->
# "275152" ->
# "1553Kx" ->
# "340237" ->
# "7Z8753" ->
# "63M057" ->
# "3666V8" ->
# "5s9G03" ->
# "q3X775" ->
# "9T8167" ->
# "097841" ->
# "1Wc422" ->
# "30970K" ->
# "1K3230" ->
# "378776" ->
# "009950" ->
# "J27969" ->
# "296Q14" ->
# "815126" ->
# "557625" ->
# "67J331" ->
# "8G8985" ->
# "08J847" ->
# "8J5182" ->
# "383E59" ->
# "I51713" ->
# "e931C9" ->
# "3uF164" ->
# "62885X" ->
# "997716" ->
# "6gC309" ->
# "613Q08" ->
# "056553" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"578546" -> False\n"3703V9" -> True\n"395129" -> False\n"497B11" -> True\n"54Y696" -> True\n"61631Z" -> True\n"4183J8" -> True\n"7362Z2" -> True\n"232027" -> False\n"d4032J" -> True\n"U42287" -> True\n"64361L" -> True\n"q9193P" -> True\n"4X38m1" -> True\n"2c7U76" -> True\n"D5e688" -> True\n"3768W5" -> True\n"8Z11m7" -> True\n"538037" -> False\n"2835R4" -> True\n"260040" -> False\n"555267" -> False\n"978378" -> False\n"4531T8" -> True\n"272199" -> False\n"v65I94" -> True\n"s778I8" -> True\n"80S49s" -> True\n"297446" -> False\n"310526" -> False\n"202Y02" -> True\n"5a43J1" -> True\n"013644" -> False\n"64486J" -> True\n"03619L" -> True\n"402mB9" -> True\n"73wW75" -> True\n"68W312" -> True\n"6H3793" -> True\n"R72071" -> True\n"1X7575" -> True\n"I92717" -> True\n"e080D6" -> True\n"48385T" -> True\n"35F331" -> True\n"333G48" -> True\n"44O313" -> True\n"4377Y3" -> True\n"005430" -> False\n"3Sr396" -> True\n"F2u969" -> True\n"0808P5" -> True\n"6eD106" -> True\n"283S09" -> True\n"A88j64" -> True\n"86L428" -> True\n"1D1642" -> True\n"314277" -> False\n"N35942" -> True\n"734683" -> False\n"45I523" -> True\n"B01366" -> True\n"H09341" -> True\n"671z3I" -> True\n"Ic6976" -> True\n"7y01S6" -> True\n"234098" -> False\n"461014" -> False\n"24Mj24" -> True\n"V82702" -> True\n"Q22388" -> True\n"295950" -> False\n"181
# "7362Z2" -> True
# "232027" -> False
# "d4032J" -> True
# "U42287" -> True
# "64361L" -> True
# "q9193P" -> True
# "4X38m1" -> True
# "2c7U76" -> True
# "D5e688" -> True
# "3768W5" -> True
# "8Z11m7" -> True
# "538037" -> False
# "2835R4" -> True
# "260040" -> False
# "555267" -> False
# "978378" -> False
# "4531T8" -> True
# "272199" -> False
# "v65I94" -> True
# "s778I8" -> True
# "80S49s" -> True
# "297446" -> False
# "310526" -> False
# "202Y02" -> True
# "5a43J1" -> True
# "013644" -> False
# "64486J" -> True
# "03619L" -> True
# "402mB9" -> True
# "73wW75" -> True
# "68W312" -> True
# "6H3793" -> True
# "R72071" -> True
# "1X7575" -> True
# "I92717" -> True
# "e080D6" -> True
# "48385T" -> True
# "35F331" -> True
# "333G48" -> True
# "44O313" -> True
# "4377Y3" -> True
# "005430" -> False
# "3Sr396" -> True
# "F2u969" -> True
# "0808P5" -> True
# "6eD106" -> True
# "283S09" -> True
# "A88j64" -> True
# "86L428" -> True
# "1D1642" -> True
# "314277" -> False
# "N35942" -> True
# "734683" -> False
# "45I523" -> True
# "B01366" -> True
# "H09341" -> True
# "671z3I" -> True
# "Ic6976" -> True
# "7y01S6" -> True
# "234098" -> False
# "461014" -> False
# "24Mj24" -> True
# "V82702" -> True
# "Q22388" -> True
# "295950" -> False
# "181441" -> False
# "8940F9" -> True
# "84695W" -> True
# "O85783" -> True
# "9I056k" -> True
# "9N9142" -> True
# "5P5170" -> True
# "90614Z" -> True
# "715933" -> False
# "02B759" -> True
# "30G04m" -> True
# "126900" -> False
# "1G7583" -> True
# "997769" -> False
# "02659Y" -> True
# "0150G0" -> True
# "275152" -> False
# "1553Kx" -> True
# "340237" -> False
# "7Z8753" -> True
# "63M057" -> True
# "3666V8" -> True
# "5s9G03" -> True
# "q3X775" -> True
# "9T8167" -> True
# "097841" -> False
# "1Wc422" -> True
# "30970K" -> True
# "1K3230" -> True
# "378776" -> False
# "009950" -> False
# "J27969" -> True
# "296Q14" -> True
# "815126" -> False
# "557625" -> False
# "67J331" -> True
# "8G8985" -> True
# "08J847" -> True
# "8J5182" -> True
# "383E59" -> True
# "I51713" -> True
# "e931C9" -> True
# "3uF164" -> True
# "62885X" -> True
# "997716" -> False
# "6gC309" -> True
# "613Q08" -> True
# "056553" -> False

# %% [markdown]
# #### CF accuracy only n4

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4.json",
    n1=0, n2=0, n3=0, n4=30, n5=30, n6=0
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4.json

# %%
# Load the new dataset (n4)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "178453" ->
# "krjKwv" ->
# "196063" ->
# "830M32" ->
# "566175" ->
# "zfKczw" ->
# "150P57" ->
# "yuiytO" ->
# "524602" ->
# "hfuOpj" ->
# "ztyuhB" ->
# "541256" ->
# "40M910" ->
# "817W65" ->
# "7V0117" ->
# "980594" ->
# "80K207" ->
# "74R482" ->
# "95F924" ->
# "4723R4" ->
# "185A58" ->
# "A60183" ->
# "84876Z" ->
# "339131" ->
# "621D25" ->
# "111966" ->
# "Wtzqvw" ->
# "jRgxfu" ->
# "4182K4" ->
# "41A675" ->
# "199781" ->
# "M72365" ->
# "22704U" ->
# "12L758" ->
# "29X352" ->
# "0862L7" ->
# "268208" ->
# "5N0722" ->
# "62B270" ->
# "292P83" ->
# "628U55" ->
# "02D021" ->
# "C67655" ->
# "lkSgqz" ->
# "Xmzejc" ->
# "547773" ->
# "185U74" ->
# "1K1098" ->
# "xsOgbx" ->
# "614386" ->
# "qsysWt" ->
# "Irzmgj" ->
# "198386" ->
# "R50163" ->
# "ncGwno" ->
# "60050B" ->
# "578143" ->
# "pleoDe" ->
# "9848V5" ->
# "9J1638" ->
# "458L18" ->
# "7G3466" ->
# "lwzJrr" ->
# "460M56" ->
# "946M56" ->
# "4C5581" ->
# "vdyeKv" ->
# "782107" ->
# "310720" ->
# "vhbPwa" ->
# "tfuvRi" ->
# "858565" ->
# "6W7139" ->
# "94031K" ->
# "jJzfmc" ->
# "176531" ->
# "1142R6" ->
# "mysVde" ->
# "hhPird" ->
# "820918" ->
# "58651K" ->
# "184018" ->
# "tlZumw" ->
# "G08122" ->
# "V55177" ->
# "wxrMbq" ->
# "8W4144" ->
# "K64003" ->
# "170284" ->
# "44R655" ->
# "459831" ->
# "338059" ->
# "360R83" ->
# "06V233" ->
# "336301" ->
# "Ijjtgb" ->
# "688695" ->
# "679181" ->
# "698196" ->
# "budNbi" ->
# "01566M" ->
# "ovbDkp" ->
# "24892D" ->
# "Rbqdvs" ->
# "2499Z0" ->
# "855P18" ->
# "53X598" ->
# "tnxIef" ->
# "01C217" ->
# "1303X2" ->
# "4F7960" ->
# "Dwkhdd" ->
# "75764B" ->
# "486370" ->
# "662896" ->
# "Aujuwe" ->
# "148G15" ->
# "4140U1" ->
# "05U263" ->
# "216565" ->
# --------------------
# {'run_accuracies': [np.float64(0.75), np.float64(0.75)], 'mean_accuracy': 0.75, 'std_accuracy': 0.0, 'overall_accuracy': 0.75, 'all_outs': ['"178453" -> False\n"krjKwv" -> True\n"196063" -> False\n"830M32" -> True\n"566175" -> False\n"zfKczw" -> True\n"150P57" -> True\n"yuiytO" -> True\n"524602" -> False\n"hfuOpj" -> True\n"ztyuhB" -> True\n"541256" -> False\n"40M910" -> True\n"817W65" -> True\n"7V0117" -> True\n"980594" -> False\n"80K207" -> True\n"74R482" -> True\n"95F924" -> True\n"4723R4" -> True\n"185A58" -> True\n"A60183" -> True\n"84876Z" -> True\n"339131" -> False\n"621D25" -> True\n"111966" -> False\n"Wtzqvw" -> True\n"jRgxfu" -> True\n"4182K4" -> True\n"41A675" -> True\n"199781" -> False\n"M72365" -> True\n"22704U" -> True\n"12L758" -> True\n"29X352" -> True\n"0862L7" -> True\n"268208" -> False\n"5N0722" -> True\n"62B270" -> True\n"292P83" -> True\n"628U55" -> True\n"02D021" -> True\n"C67655" -> True\n"lkSgqz" -> True\n"Xmzejc" -> True\n"547773" -> False\n"185U74" -> True\n"1K1098" -> True\n"xsOgbx" -> True\n"614386" -> False\n"qsysWt" -> True\n"Irzmgj" -> True\n"198386" -> False\n"R50163" -> True\n"ncGwno" -> True\n"60050B" -> True\n"578143" -> False\n"pleoDe" -> True\n"9848V5" -> True\n"9J1638" -> True\n"458L18" -> True\n"7G3466" -> True\n"lwzJrr" -> True\n"460M56" -> True\n"946M56" -> True\n"4C5581" -> True\n"vdyeKv" -> True\n"782107" -> False\n"310720" -> False\n"vhbPwa" -> True\n"tfuvRi" -> True\n"858565" -> False\n"6W7139" -> True\n"94031K" -> True\n"jJzfmc" -> True\n"176531" -> False\n"1142R6" -> True\n"mysVde" -> True\n"hhPird" -> True\n"820918" -> False\n"58651K" -> True\n"184018" -> False\n"tlZumw" -> True\n"G08122" -> True\n"V55177" -> True\n"wxrMbq" -> True\n"8W4144" -> True\n"K64003" -> True\n"170284" -> False\n"
# "A60183" -> True
# "84876Z" -> True
# "339131" -> False
# "621D25" -> True
# "111966" -> False
# "Wtzqvw" -> True
# "jRgxfu" -> True
# "4182K4" -> True
# "41A675" -> True
# "199781" -> False
# "M72365" -> True
# "22704U" -> True
# "12L758" -> True
# "29X352" -> True
# "0862L7" -> True
# "268208" -> False
# "5N0722" -> True
# "62B270" -> True
# "292P83" -> True
# "628U55" -> True
# "02D021" -> True
# "C67655" -> True
# "lkSgqz" -> True
# "Xmzejc" -> True
# "547773" -> False
# "185U74" -> True
# "1K1098" -> True
# "xsOgbx" -> True
# "614386" -> False
# "qsysWt" -> True
# "Irzmgj" -> True
# "198386" -> False
# "R50163" -> True
# "ncGwno" -> True
# "60050B" -> True
# "578143" -> False
# "pleoDe" -> True
# "9848V5" -> True
# "9J1638" -> True
# "458L18" -> True
# "7G3466" -> True
# "lwzJrr" -> True
# "460M56" -> True
# "946M56" -> True
# "4C5581" -> True
# "vdyeKv" -> True
# "782107" -> False
# "310720" -> False
# "vhbPwa" -> True
# "tfuvRi" -> True
# "858565" -> False
# "6W7139" -> True
# "94031K" -> True
# "jJzfmc" -> True
# "176531" -> False
# "1142R6" -> True
# "mysVde" -> True
# "hhPird" -> True
# "820918" -> False
# "58651K" -> True
# "184018" -> False
# "tlZumw" -> True
# "G08122" -> True
# "V55177" -> True
# "wxrMbq" -> True
# "8W4144" -> True
# "K64003" -> True
# "170284" -> False
# "44R655" -> True
# "459831" -> False
# "338059" -> False
# "360R83" -> True
# "06V233" -> True
# "336301" -> False
# "Ijjtgb" -> True
# "688695" -> False
# "679181" -> False
# "698196" -> False
# "budNbi" -> True
# "01566M" -> True
# "ovbDkp" -> True
# "24892D" -> True
# "Rbqdvs" -> True
# "2499Z0" -> True
# "855P18" -> True
# "53X598" -> True
# "tnxIef" -> True
# "01C217" -> True
# "1303X2" -> True
# "4F7960" -> True
# "Dwkhdd" -> True
# "75764B" -> True
# "486370" -> False
# "662896" -> False
# "Aujuwe" -> True
# "148G15" -> True
# "4140U1" -> True
# "05U263" -> True
# "216565" -> False

# %% [markdown]
# #### CF accuracy only n6

# %%
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n6.json",
    n1=0, n2=0, n3=0, n4=0, n5=30, n6=30
)
# Out:
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n6.json

# %%
# Load the new dataset (n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")

# Build the model/temperature-specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels_cf,
    label_set=["TRUE", "FALSE"],
    num_runs=2
)
print(results)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "17789R" ->
# "878235" ->
# "2O6105" ->
# "32564b" ->
# "260537" ->
# "900073" ->
# "53Y606" ->
# "769943" ->
# "N71805" ->
# "287245" ->
# "91493D" ->
# "815522" ->
# "614169" ->
# "931756" ->
# "267Q79" ->
# "907d38" ->
# "1637D2" ->
# "328412" ->
# "88948T" ->
# "i68938" ->
# "61n865" ->
# "407e77" ->
# "J46034" ->
# "7358T9" ->
# "0535A5" ->
# "484S55" ->
# "176565" ->
# "c19971" ->
# "2174p8" ->
# "9L3708" ->
# "3514Y2" ->
# "971Z65" ->
# "080771" ->
# "684X40" ->
# "80J404" ->
# "64086d" ->
# "1044F8" ->
# "E84970" ->
# "9P0067" ->
# "57g852" ->
# "55781h" ->
# "782G78" ->
# "269661" ->
# "260363" ->
# "1k0118" ->
# "60T472" ->
# "020500" ->
# "1620Z5" ->
# "6587n8" ->
# "31G800" ->
# "7480g0" ->
# "1R4902" ->
# "40413l" ->
# "684170" ->
# "2E4787" ->
# "2141z9" ->
# "338Q53" ->
# "334782" ->
# "766459" ->
# "19603O" ->
# "74L796" ->
# "8081w4" ->
# "308U49" ->
# "46172F" ->
# "97936Q" ->
# "8L6454" ->
# "6025h5" ->
# "19O402" ->
# "K38608" ->
# "73182O" ->
# "2J2907" ->
# "7j8604" ->
# "18z489" ->
# "294678" ->
# "5336w7" ->
# "23I504" ->
# "33M373" ->
# "7330m6" ->
# "1452E3" ->
# "3827G3" ->
# "338224" ->
# "8T9883" ->
# "190099" ->
# "40586d" ->
# "279i43" ->
# "052t09" ->
# "40413l" -> True
# "684170" -> False
# "2E4787" -> True
# "2141z9" -> True
# "338Q53" -> True
# "334782" -> False
# "766459" -> False
# "19603O" -> True
# "74L796" -> True
# "8081w4" -> True
# "308U49" -> True
# "46172F" -> True
# "97936Q" -> True
# "8L6454" -> True
# "6025h5" -> True
# "19O402" -> True
# "K38608" -> True
# "73182O" -> True
# "2J2907" -> True
# "7j8604" -> True
# "18z489" -> True
# "294678" -> False
# "5336w7" -> True
# "23I504" -> True
# "33M373" -> True
# "7330m6" -> True
# "1452E3" -> True
# "3827G3" -> True
# "338224" -> False
# "8T9883" -> True
# "190099" -> False
# "40586d" -> True
# "279i43" -> True
# "052t09" -> True
# "316941" -> False
# "5m6985" -> True
# "221693" -> False
# "396U18" -> True
# "135977" -> False
# "483406" -> False
# "54068j" -> True
# "66V546" -> True
# "4416X2" -> True
# "1y4531" -> True
# "1W3869" -> True
# "74N318" -> True
# "X14746" -> True
# "21088Q" -> True
# "627368" -> False
# "u83724" -> True
# "55855Y" -> True
# "727757" -> False
# "41K354" -> True
# "42I800" -> True
# "6259p2" -> True
# "106076" -> False
# "292O86" -> True
# "59462O" -> True
# "10C003" -> True
# "301991" -> False
# "46G970" -> True
# "654697" -> False
# "84J632" -> True
# "60o796" -> True
# "L39734" -> True
# "630324" -> False
# "70K554" -> True
# "11T762" -> True

# %% [markdown]
# #### CF accuracy n4 and n6

# %%
print("Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.")
print("Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.")

generate_toy_dataset_counterfactual(
    input_json=toy_digits_and_one_cap_path,
    output_folder=toy_rule_path,
    file_name="toy_digits_and_one_cap_cf_n4_n6.json",
    n1=0, n2=0, n3=0, n4=30, n5=0, n6=30
)
# Out:
# Type 4: 6-character strings with exactly 1 uppercase letter at a random position and 5 lowercase letters.
# Type 6: 6‑character strings with exactly 1 lowercase letter and 5 digits.
# Loaded 50 train samples from /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap.json and saved 120 test samples (60 false + 60 true) to /Users/joriococola/Documents/GitHub/OE-test/code/notebooks/exploratory/toy_digits_and_one_cap/toy_digits_and_one_cap_cf_n4_n6.json

# %%
# Load the new dataset (n4 and n6)
toy_digits_and_one_cap_path_cf = os.path.join(toy_rule_path, "toy_digits_and_one_cap_cf_n4_n6.json")
# Load the expected labels
gold_labels_cf = load_expected_labels(toy_digits_and_one_cap_path_cf)
classification_prompt = build_classification_prompt(
    toy_digits_and_one_cap_path_cf,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
print("--------------------")
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "108362" -> False
# "870873" -> False
# "654876" -> False
# "898991" -> False
# "N42330" -> True
# "342008" -> False
# "633J76" -> True
# "525H27" -> True
# "825213" -> False
# "6357W3" -> True
# "7025Y3" -> True
# "5C1905" -> True
# "431740" -> False
# "201877" -> False
# "752698" -> False
# "434252" -> False
# "725408" -> False
# "958E38" -> True
# "89273B" -> True
# "448560" -> False
# "242399" -> False
# "263837" -> False
# "228388" -> False
# "964R48" -> True
# "203126" -> False
# "B41826" -> True
# "770468" -> False
# "570611" -> False
# "4J8388" -> True
# "674283" -> False
# "115359" -> False
# "323922" -> False
# "4413A0" -> True
# "020521" -> False
# "332113" -> False
# "681116" -> False
# "335972" -> False
# "234773" -> False
# "0673F6" -> True
# "D95719" -> True
# "F23737" -> True
# "55U251" -> True
# "261602" -> False
# "382972" -> False
# "5S5198" -> True
# "806719" -> False
# "903814" -> False
# "843583" -> False
# "110298" -> False
# "51L011" -> True
#
# ### Label each test input True or False:
# "r94239" ->
# "129V66" ->
# "knvAht" ->
# "257L32" ->
# "9362W2" ->
# "7E7293" ->
# "732J36" ->
# "84R407" ->
# "Gbjdlw" ->
# "25285Q" ->
# "i92871" ->
# "76699H" ->
# "wjoIgd" ->
# "z67990" ->
# "429F75" ->
# "0894m3" ->
# "1F8100" ->
# "zgnvKh" ->
# "300X18" ->
# "jxktaJ" ->
# "080u47" ->
# "038l29" ->
# "3270T8" ->
# "r00396" ->
# "1Y9758" ->
# "62I065" ->
# "459I80" ->
# "I38568" ->
# "89U646" ->
# "404C34" ->
# "74165R" ->
# "akcrUw" ->
# "640m03" ->
# "39Z197" ->
# "O08077" ->
# "98516S" ->
# "88u645" ->
# "285C22" ->
# "633c95" ->
# "8271C9" ->
# "e17013" ->
# "16582O" ->
# "mnSibt" ->
# "u81645" ->
# "C27670" ->
# "zjppYl" ->
# "84569Q" ->
# "uanMdm" ->
# "qckpLl" ->
# "07N279" ->
# "stdQjn" ->
# "5d4420" ->
# "loGphp" ->
# "3l0576" ->
# "lrIftc" ->
# "608Q36" ->
# "87663Q" ->
# "526Q35" ->
# "27156p" ->
# "40j977" ->
# "91V554" ->
# "93Z053" ->
# "731o99" ->
# "3731Q6" ->
# "914O03" ->
# "01K314" ->
# "089F83" ->
# "94G953" ->
# "150A24" ->
# "ybteZh" ->
# "iyvfQc" ->
# "810b77" ->
# "6U3736" ->
# "749V51" ->
# "gbznMi" ->
# "akgIhk" ->
# "123G25" ->
# "349f12" ->
# "1B5487" ->
# "jjhemM" ->
# "1903G5" ->
# "jwEsih" ->
# "qnTbrh" ->
# "2572O3" ->
# "19K032" ->
# "dnyhVl" ->
# "539R66" ->
# "q71179" ->
# "3s9783" ->
# "133X68" ->
# "fAvaoe" ->
# "51B363" ->
# "36x433" ->
# "0G1139" ->
# "vzlDpw" ->
# "Rcuhoe" ->
# "8H2937" ->
# "kmkCud" ->
# "9982h1" ->
# "6h8074" ->
# "12091u" ->
# "6Z6768" ->
# "1865P0" ->
# "dshimY" ->
# "wKinmt" ->
# "10021i" ->
# "B25993" ->
# "tpsjlM" ->
# "6M9779" ->
# "5J2251" ->
# "1m3805" ->
# "1d8147" ->
# "236p36" ->
# "ktFunt" ->
# "5353E0" ->
# "5725N2" ->
# "jnMxmz" ->
# "444q70" ->
# "94F011" ->
# "24892S" ->
# "C27670" -> True
# "zjppYl" -> True
# "84569Q" -> True
# "uanMdm" -> True
# "qckpLl" -> True
# "07N279" -> True
# "stdQjn" -> True
# "5d4420" -> True
# "loGphp" -> True
# "3l0576" -> True
# "lrIftc" -> True
# "608Q36" -> True
# "87663Q" -> True
# "526Q35" -> True
# "27156p" -> True
# "40j977" -> True
# "91V554" -> True
# "93Z053" -> True
# "731o99" -> True
# "3731Q6" -> True
# "914O03" -> True
# "01K314" -> True
# "089F83" -> True
# "94G953" -> True
# "150A24" -> True
# "ybteZh" -> True
# "iyvfQc" -> True
# "810b77" -> True
# "6U3736" -> True
# "749V51" -> True
# "gbznMi" -> True
# "akgIhk" -> True
# "123G25" -> True
# "349f12" -> True
# "1B5487" -> True
# "jjhemM" -> True
# "1903G5" -> True
# "jwEsih" -> True
# "qnTbrh" -> True
# "2572O3" -> True
# "19K032" -> True
# "dnyhVl" -> True
# "539R66" -> True
# "q71179" -> True
# "3s9783" -> True
# "133X68" -> True
# "fAvaoe" -> True
# "51B363" -> True
# "36x433" -> True
# "0G1139" -> True
# "vzlDpw" -> True
# "Rcuhoe" -> True
# "8H2937" -> True
# "kmkCud" -> True
# "9982h1" -> True
# "6h8074" -> True
# "12091u" -> True
# "6Z6768" -> True
# "1865P0" -> True
# "dshimY" -> True
# "wKinmt" -> True
# "10021i" -> True
# "B25993" -> True
# "tpsjlM" -> True
# "6M9779" -> True
# "5J2251" -> True
# "1m3805" -> True
# "1d8147" -> True
# "236p36" -> True
# "ktFunt" -> True
# "5353E0" -> True
# "5725N2" -> True
# "jnMxmz" -> True
# "444q70" -> True
# "94F011" -> True
# "24892S" -> True

# %% [markdown]
# ### Step 2: Multi-turn

# %%
gold_labels = load_expected_labels(file_name)
classification_prompt = build_classification_prompt(
    file_name,
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "____________________________________________*_______________________________________________________" -> False
# "______________________________________________________________*_____________________________________" -> True
# "___________________*________________________________________________________________________________" -> False
# "________________________________________________________________________________________*___________" -> True
# "___________________________________*________________________________________________________________" -> False
# "________________________________________________________*___________________________________________" -> True
# "______________*_____________________________________________________________________________________" -> False
# "_______________________________________________*____________________________________________________" -> False
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________________*___________" -> True
# "__________________________________________________________________________________________________*_" -> True
# "_______*____________________________________________________________________________________________" -> False
# "____________________________________________________________*_______________________________________" -> True
# "__________________*_________________________________________________________________________________" -> False
# "_________________________________________________________________*__________________________________" -> True
# "___________________________________________________*________________________________________________" -> True
# "__________*_________________________________________________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "_______________________________________________________________________________________________*____" -> True
# "________________________________________________________________________________*___________________" -> True
# "________________________________*___________________________________________________________________" -> False
# "_________________________________________________________________________________________*__________" -> True
# "__________________________________________________________________________________________*_________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____*_______________________________________________________________________________________________" -> False
# "____________________________________*_______________________________________________________________" -> False
# "_____________________________________________________________________*______________________________" -> True
# "_________________________________________________________________________*__________________________" -> True
# "________________________________________*___________________________________________________________" -> False
# "_________________*__________________________________________________________________________________" -> False
# "_________________________________*__________________________________________________________________" -> False
# "_________________________________________________________________________________*__________________" -> True
# "_____________________________*______________________________________________________________________" -> False
# "__________________________________________________________________________________________________*_" -> True
# "_______________________________________________*____________________________________________________" -> False
# "______________________________________________________________________________*_____________________" -> True
# "_________________*__________________________________________________________________________________" -> False
# "____________________________________________*_______________________________________________________" -> False
# "__________________*_________________________________________________________________________________" -> False
# "______________________________________________________*_____________________________________________" -> True
# "________________________________________________________________________________*___________________" -> True
# "_______________________________________________________________________________________*____________" -> True
# "_____________________________________________*______________________________________________________" -> False
# "__________________________________________*_________________________________________________________" -> False
# "_________________________*__________________________________________________________________________" -> False
# "___________________*________________________________________________________________________________" -> False
# "_____________________________________________________________________________*______________________" -> True
# "______________________________________________________________________________________________*_____" -> True
#
# ### Label each test input True or False:
# "___________________________________________________________________________________*________________" ->
# "________*___________________________________________________________________________________________" ->
# "_________________________________________________________________________________________________*__" ->
# "____________________________________________________________________________*_______________________" ->
# "______________________________________________________________________________________*_____________" ->
# "________________________________________*___________________________________________________________" ->
# "____________________________*_______________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "__________________________*_________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "___________________________________________________________*________________________________________" ->
# "__________________________________________________________________________________*_________________" ->
# "___________*________________________________________________________________________________________" ->
# "______*_____________________________________________________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "________________________________________________________________*___________________________________" ->
# "____________________________________________________________________________________________*_______" ->
# "___________________*________________________________________________________________________________" ->
# "_________________________________________*__________________________________________________________" ->
# "________________________*___________________________________________________________________________" ->
# "___________________________________________________*________________________________________________" ->
# "_______________________________*____________________________________________________________________" ->
# "________________________________________________________________________________________________*___" ->
# "__________________________________________________________________________*_________________________" ->
# "_____________________________________________________________*______________________________________" ->
# "___________________________________*________________________________________________________________" ->
# "________________________________________________________________________________*___________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_______________*____________________________________________________________________________________" ->
# "_____________________________________________________________________________*______________________" ->
# "__*_________________________________________________________________________________________________" ->
# "______________________________________________________________________________*_____________________" ->
# "_________________________________*__________________________________________________________________" ->
# "____________________________________*_______________________________________________________________" ->
# "____________________*_______________________________________________________________________________" ->
# "_____________________________________________*______________________________________________________" ->
# "________________________________________*___________________________________________________________" ->
# "______________________________________________________________________________________*_____________" ->
# "_______________________________________________________*____________________________________________" ->
# "*___________________________________________________________________________________________________" ->
# "________________*___________________________________________________________________________________" ->
# "_____________________________________*______________________________________________________________" ->
# "__________________________________________________________________________*_________________________" ->
# "_______________________________________________________________________________________________*____" ->
# "_______________________________________________________________________________*____________________" ->
# "_________________________________________________________________________*__________________________" ->
# "_____*______________________________________________________________________________________________" ->
# "_____________*______________________________________________________________________________________" ->

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# The rule is:
#
# - Count the number of underscores ("_") after the asterisk ("*").
# - If there are 20 or fewer underscores after the asterisk, label as False.
# - If there are more than 20 underscores after the asterisk, label as True.
#
# In other words, if the asterisk is positioned such that there are more than 20 underscores to its right (including cases where it's at the far right), the label is True. Otherwise, it is False.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json=file_name,
    temperature=0.7,
    num_runs=3,
)
# Out:
# ✅ Classification finished: mean acc 1.000 (±0.000) across 3 runs
#
# 📝 Explanation from last run:
#
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# The specific feature I was looking for in each input was the position of the asterisk * relative to the length of the string. My decision process was:
#
# - If the asterisk was positioned toward the far right end of the string (specifically, within the last 20% of the string), I labeled it True.
# - If the asterisk was positioned anywhere else (i.e., the first 80% from the left), I labeled it False.
#
# So, I was classifying based on whether the asterisk appeared in the rightmost 20% of the characters in the string.
# --------------------
# I was looking for the position of the asterisk ("*") in each input string.
#
# **Decision process:**
# - Each input is a string of underscores and exactly one asterisk.
# - If the asterisk is near the right end of the string (specifically, within the last 20 characters or so), the label is **True**.
# - If the asterisk is elsewhere (not near the right end), the label is **False**.
#
# In other words, the input is **True** if the asterisk appears close to the rightmost side of the string; otherwise, it's **False**.
# --------------------
# I determined the label based on the **position of the asterisk (*) in the string**. Specifically:
#
# - If the asterisk (*) is in the **rightmost quarter (last 25%) of the string**, the label is **True**.
# - If the asterisk is **anywhere else (not in the last quarter)**, the label is **False**.
#
# **Decision process:**
# 1. Each input is a string of underscores and exactly one asterisk.
# 2. I checked where the asterisk appeared within the string.
# 3. If the asterisk was in the last quarter of the string (the far-right section), I returned True; otherwise, False.
#
# This matches the pattern in the training examples.
# --------------------
