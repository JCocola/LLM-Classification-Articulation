# %% [markdown]
# ## Imports

# %%
import sys, os
import importlib

# Set up the Python path for the project.
project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

import evals_utils
importlib.reload(evals_utils)

from inference_utils import build_classification_prompt, build_articulation_prompt, chat, make_inference_fn
from evals_utils import load_expected_labels, evaluate_classification_accuracy, parse_predictions, classify_then_explain, flexible_parse_predictions

from dotenv import load_dotenv

# %%
load_dotenv()  # reads from .env in current working directory
# You can also specify path manually: load_dotenv(dotenv_path="../.env")

# Confirm it worked:
assert "OPENAI_API_KEY" in os.environ
print("OpenAI key loaded.")
# Out:
# OpenAI key loaded.

# %% [markdown]
# ### Models

# %%
from openai import OpenAI
# Retrieve all available models
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
models = client.models.list()

# Filter models that include 'gpt-4' in their ID
gpt_4_models = [model.id for model in models.data if "gpt-4" in model.id.lower()]

# Print the list of GPT-4 models
print("Available GPT-4 Models:")
for model_id in gpt_4_models:
    print(f"- {model_id}")
# Out:
# Available GPT-4 Models:
# - gpt-4o-audio-preview-2024-12-17
# - gpt-4o-audio-preview-2024-10-01
# - gpt-4-turbo-preview
# - gpt-4-1106-preview
# - gpt-4-turbo
# - gpt-4-turbo-2024-04-09
# - gpt-4.1-nano
# - gpt-4.1-nano-2025-04-14
# - gpt-4o-realtime-preview-2024-10-01
# - gpt-4o-realtime-preview
# - gpt-4
# - chatgpt-4o-latest
# - gpt-4o-realtime-preview-2024-12-17
# - gpt-4o-mini-audio-preview
# - gpt-4o-audio-preview
# - gpt-4o-mini-realtime-preview
# - gpt-4.1-mini
# - gpt-4o-mini-realtime-preview-2024-12-17
# - gpt-4o-mini-search-preview
# - gpt-4.1-mini-2025-04-14
# - gpt-4o-search-preview
# - gpt-4o-mini-search-preview-2025-03-11
# - gpt-4-0125-preview
# - gpt-4o-2024-11-20
# - gpt-4o-2024-05-13
# - gpt-4-0613
# - gpt-4o-mini-tts
# - gpt-4o-transcribe
# - gpt-4.5-preview
# - gpt-4.5-preview-2025-02-27
# - gpt-4o-mini-transcribe
# - gpt-4o-search-preview-2025-03-11
# - gpt-4o
# - gpt-4o-mini
# - gpt-4o-2024-08-06
# - gpt-4.1
# - gpt-4.1-2025-04-14
# - gpt-4o-mini-2024-07-18
# - gpt-4o-mini-audio-preview-2024-12-17
# - ft:gpt-4.1-2025-04-14:jc:ita-class-explain:BTyKZBz2:ckpt-step-21
# - ft:gpt-4.1-2025-04-14:jc:ita-no-explain:BTyMdII4:ckpt-step-21
# - ft:gpt-4.1-2025-04-14:jc:ita-class-explain:BTyKZV7V:ckpt-step-42
# - ft:gpt-4.1-2025-04-14:jc:ita-class-explain:BTyKZGKi
# - ft:gpt-4.1-2025-04-14:jc:ita-class:BTyQ2x1O
# - ft:gpt-4.1-2025-04-14:jc:ita-no-explain:BTyMd8uN:ckpt-step-42
# - ft:gpt-4.1-2025-04-14:jc:ita-no-explain:BTyMdX1G
# - ft:gpt-4.1-2025-04-14:jc:ita-class:BTyQ1eTU:ckpt-step-21
# - ft:gpt-4.1-2025-04-14:jc:ita-class:BTyQ1Vxm:ckpt-step-42

# %%
openai_4o = "openai/gpt-4o"
model_4o = "gpt-4o"
openai_4op1 = "openai/gpt-4.1"
openai_4op1_nano = "openai/gpt-4.1-nano"
openai_4op1_mini = "openai/gpt-4.1-mini"

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %% [markdown]
# ## Experiments

# %%
import openai

def openai_get_response(prompt, model="gpt-4", temperature=0.7, max_tokens=300):
    response = openai.ChatCompletion.create(
        model=model,
        messages=[
            {"role": "user", "content": prompt}
        ],
        temperature=temperature,
        max_tokens=max_tokens,
    )
    return response['choices'][0]['message']['content']

# %%
from string import Template

def render_prompt(template_str: str, **kwargs) -> str:
    """
    Render a prompt template.
    
    - template_str should use `$varname` placeholders (Template syntax),
      or you can swap in `.format`-style `{varname}` if you prefer.
    - kwargs are the values you want substituted in.
    """
    return Template(template_str).substitute(**kwargs)


import os
import datetime

def save_prompt_response(prompt, response, filename, subfolder="logs"):
    """
    Save the prompt and response to a text file in the specified subfolder.
    
    Args:
        prompt (str): The prompt sent to the LLM
        response (str): The response from the LLM
        filename (str): Name for the output file (without extension)
        subfolder (str): Subfolder to save the file in (default: "logs")
    
    Returns:
        str: Path to the saved file
    """
    # Create logs folder if it doesn't exist
    if not os.path.exists(subfolder):
        os.makedirs(subfolder)
        print(f"Created folder: {subfolder}")
    
    # Add timestamp to filename
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    full_filename = f"{filename}_{timestamp}.txt"
    file_path = os.path.join(subfolder, full_filename)
    
    # Write prompt and response to file with clear separation
    with open(file_path, "w", encoding="utf-8") as f:
        f.write("="*80 + "\n")
        f.write("PROMPT:\n")
        f.write("="*80 + "\n\n")
        f.write(prompt)
        f.write("\n\n")
        f.write("="*80 + "\n")
        f.write("RESPONSE:\n")
        f.write("="*80 + "\n\n")
        f.write(response)
    
    print(f"Saved prompt and response to {file_path}")
    return file_path

# %%
import os
import json
import random

def create_dataset_json(sentences_dict, num_train, num_test, filename, subfolder="datasets"):
    """
    Create and save a JSON dataset with train/test split from a dictionary of TRUE/FALSE sentences.
    
    Args:
        sentences_dict (dict): Dictionary with 'TRUE' and 'FALSE' keys containing lists of sentences
        num_train (int): Number of samples for training set
        num_test (int): Number of samples for test set
        filename (str): Name for the output file (without extension)
        subfolder (str): Subfolder to save the file in (default: "datasets")
    
    Returns:
        str: Path to the saved file
    """
    # Create datasets folder if it doesn't exist
    if not os.path.exists(subfolder):
        os.makedirs(subfolder)
        print(f"Created folder: {subfolder}")
    
    # Prepare all samples with labels
    all_samples = []
    for sentence in sentences_dict['TRUE']:
        all_samples.append({"input": sentence, "label": True})
    for sentence in sentences_dict['FALSE']:
        all_samples.append({"input": sentence, "label": False})
    
    # Shuffle samples
    random.shuffle(all_samples)
    
    # Check if we have enough samples
    total_samples = len(all_samples)
    if total_samples < (num_train + num_test):
        print(f"Warning: Requested {num_train + num_test} samples but only {total_samples} available.")
        num_train = min(num_train, total_samples // 2)
        num_test = min(num_test, total_samples - num_train)
        print(f"Adjusted to {num_train} train and {num_test} test samples.")
    
    # Split into train and test
    train_samples = all_samples[:num_train]
    test_samples = all_samples[num_train:num_train+num_test]
    
    # Create dataset structure
    dataset = {
        "train": train_samples,
        "test": test_samples
    }
    
    # Save to JSON file
    file_path = os.path.join(subfolder, f"{filename}.json")
    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(dataset, f, indent=2)
    
    print(f"Dataset saved to {file_path}")
    print(f"Train samples: {len(train_samples)}, Test samples: {len(test_samples)}")
    
    # Print label distribution
    train_true = sum(1 for sample in train_samples if sample["label"])
    test_true = sum(1 for sample in test_samples if sample["label"])
    print(f"Train labels: {train_true} True, {num_train - train_true} False")
    print(f"Test labels: {test_true} True, {num_test - test_true} False")
    
    return file_path

# %%
import re

def extract_sentences(llm_response):
    """
    Extract sentences from LLM response into a dictionary with TRUE and FALSE keys,
    filtering out explanations.
    
    Args:
        llm_response (str): The response from the LLM
        
    Returns:
        dict: Dictionary with 'TRUE' and 'FALSE' keys containing lists of sentences
    """
    # Initialize result dictionary
    result = {
        'TRUE': [],
        'FALSE': []
    }
    
    # Find the TRUE section
    true_pattern = r'## TRUE\s+((?:".*?"\s*- explanation:.*?\n)+)'
    true_match = re.search(true_pattern, llm_response, re.DOTALL)
    
    # Find the FALSE section
    false_pattern = r'## FALSE\s+((?:".*?"\s*- explanation:.*?\n)+)'
    false_match = re.search(false_pattern, llm_response, re.DOTALL)
    
    # Extract TRUE sentences if found
    if true_match:
        true_text = true_match.group(1)
        # Extract just the quoted sentences, ignore explanations
        true_sentences = re.findall(r'"(.*?)"', true_text)
        result['TRUE'] = true_sentences
    
    # Extract FALSE sentences if found
    if false_match:
        false_text = false_match.group(1)
        # Extract just the quoted sentences, ignore explanations
        false_sentences = re.findall(r'"(.*?)"', false_text)
        result['FALSE'] = false_sentences
    
    return result


def extract_sentences2(llm_response):
    """
    Extract sentences from LLM response into a dictionary with TRUE and FALSE keys,
    filtering out explanations.
    
    Args:
        llm_response (str): The response from the LLM
        
    Returns:
        dict: Dictionary with 'TRUE' and 'FALSE' keys containing lists of sentences
    """
    # Initialize result dictionary
    result = {
        'TRUE': [],
        'FALSE': []
    }
    
    # Split the response by sections
    true_section = ""
    false_section = ""
    
    if "## TRUE" in llm_response:
        sections = llm_response.split("## TRUE", 1)
        if len(sections) > 1:
            remaining = sections[1]
            if "## FALSE" in remaining:
                parts = remaining.split("## FALSE", 1)
                true_section = parts[0].strip()
                false_section = parts[1].strip()
            else:
                true_section = remaining.strip()
    
    # Process TRUE section
    if true_section:
        # Look for sentences in quotes at the beginning of each line
        lines = true_section.split('\n')
        for line in lines:
            line = line.strip()
            if line and line.startswith('"'):
                # Extract just the sentence part (before " - explanation:")
                sentence_match = re.match(r'"([^"]+)".*', line)
                if sentence_match:
                    result['TRUE'].append(sentence_match.group(1))
    
    # Process FALSE section
    if false_section:
        # Look for sentences in quotes at the beginning of each line
        lines = false_section.split('\n')
        for line in lines:
            line = line.strip()
            if line and line.startswith('"'):
                # Extract just the sentence part (before " - explanation:")
                sentence_match = re.match(r'"([^"]+)".*', line)
                if sentence_match:
                    result['FALSE'].append(sentence_match.group(1))
    
    return result

def extract_sentences3(llm_response):
    """
    Extract sentences from LLM response into a dictionary with TRUE and FALSE keys,
    filtering out explanations and removing numbering.
    
    Args:
        llm_response (str): The response from the LLM
        
    Returns:
        dict: Dictionary with 'TRUE' and 'FALSE' keys containing lists of sentences
    """
    # Initialize result dictionary
    result = {
        'TRUE': [],
        'FALSE': []
    }
    
    # Split the response by sections
    true_section = ""
    false_section = ""
    
    if "## TRUE" in llm_response or "## VERO" in llm_response:
        # Handle both English and Italian headers
        if "## TRUE" in llm_response:
            sections = llm_response.split("## TRUE", 1)
        else:
            sections = llm_response.split("## VERO", 1)
            
        if len(sections) > 1:
            remaining = sections[1]
            if "## FALSE" in remaining:
                parts = remaining.split("## FALSE", 1)
                true_section = parts[0].strip()
                false_section = parts[1].strip()
            elif "## FALSO" in remaining:
                parts = remaining.split("## FALSO", 1)
                true_section = parts[0].strip()
                false_section = parts[1].strip()
            else:
                true_section = remaining.strip()
    
    # Process TRUE section
    if true_section:
        lines = true_section.split('\n')
        for line in lines:
            line = line.strip()
            # Skip empty lines
            if not line:
                continue
                
            # Remove numbering like "1. ", "2. ", etc.
            line = re.sub(r'^\d+\.\s*', '', line)
            
            # Extract the sentence part (in quotes)
            sentence_match = re.search(r'"([^"]+)"', line)
            if sentence_match:
                result['TRUE'].append(sentence_match.group(1))
    
    # Process FALSE section
    if false_section:
        lines = false_section.split('\n')
        for line in lines:
            line = line.strip()
            # Skip empty lines
            if not line:
                continue
                
            # Remove numbering like "1. ", "2. ", etc.
            line = re.sub(r'^\d+\.\s*', '', line)
            
            # Extract the sentence part (in quotes)
            sentence_match = re.search(r'"([^"]+)"', line)
            if sentence_match:
                result['FALSE'].append(sentence_match.group(1))
    
    return result

# %% [markdown]
# ### Rule 16: Outdoors

# %%
outdoors_template = """ Generate $total sentences following this template: "[Subject] [verb] [object/activity] [preposition] [location] [time phrase]."

For $true_count sentences: The described activity MUST occur OUTDOORS (in nature, outside buildings, or open-air locations)
For $false_count sentences: The described activity MUST occur INDOORS (inside buildings or enclosed spaces)

IMPORTANT:
- Outdoor locations include: parks, forests, beaches, mountains, gardens, playgrounds, streets, fields, lakes, etc.
- Indoor locations include: houses, offices, schools, malls, restaurants, theaters, museums, libraries, etc.
- Make the setting explicit - either directly state the location or use clear context clues
- Vary the activities, locations, and time phrases across examples
- Use a mix of individual and group activities
- Include different weather conditions and times of day for outdoor activities

Format your response exactly as follows:

## TRUE
"Sentence 1." - explanation: (identifies the outdoor location/setting)
"Sentence 2." - explanation: (identifies the outdoor location/setting)
"Sentence 3." - explanation: (identifies the outdoor location/setting)
...

## FALSE
"Sentence 1." - explanation: (identifies the indoor location/setting)
"Sentence 2." - explanation: (identifies the indoor location/setting)
"Sentence 3." - explanation: (identifies the indoor location/setting)
...

Examples:
- "Children played soccer in the park after school." - explanation: (outdoors in a park)
- "The hikers climbed steep trails through the mountains during sunrise." - explanation: (outdoors on mountain trails)
- "The family watched movies in their living room last night." - explanation: (indoors in a living room)
- "Students studied chemistry in the school laboratory every afternoon." - explanation: (indoors in a laboratory)

Make sentences natural, varied, and unambiguous about the setting.
"""

# %%
# Render it with different values:
data_generation_prompt = render_prompt(
    outdoors_template,
    total=80,        # 80 sentences total
    true_count=40,   # 40 "True" sentences
    false_count=40   # 40 "False" sentences
)
reply = await chat(openai_4op1, data_generation_prompt, n=1, temperature=1., print_choices=False)

# %%
response = reply.choices[0].message.content
sentences_dict = extract_sentences2(response)
print(f"Found {len(sentences_dict['TRUE'])} TRUE sentences and {len(sentences_dict['FALSE'])} FALSE sentences")
save_prompt_response(data_generation_prompt, response, "outdoors_dataset_it_80", subfolder="logs")
# Out:
# Found 41 TRUE sentences and 40 FALSE sentences
# Saved prompt and response to logs/outdoors_dataset_it_80_20250505_193930.txt
# 'logs/outdoors_dataset_it_80_20250505_193930.txt'

# %%
create_dataset_json(sentences_dict, 40, 40, "outdoors_dataset_it_80_40_40")
# Out:
# Dataset saved to datasets/outdoors_dataset_it_80_40_40.json
# Train samples: 40, Test samples: 40
# Train labels: 21 True, 19 False
# Test labels: 20 True, 20 False
# 'datasets/outdoors_dataset_it_80_40_40.json'

# %%
ntrain = 40
ntest = 40
intro = f"You are an expert text classifier that assigns labels based on specific rules. You will be provided with exactly {ntrain} training examples that demonstrate the classification rule, followed by exactly {ntest} test examples that you need to classify using the same rule."
question = "Classify each of the following test examples as either True or False based on the pattern you observed in the training data:"
instructions = "Examine the training examples carefully to determine the classification rule. Then, apply this rule to each test example. Respond with ONLY the labels (True or False) for each test example, one per line, without any additional text or explanation."
outro = f"Remember to output only True or False for each of the {ntest} test examples, maintaining the same order as presented. Do not include any other text in your response."

# natural language articulation
classification_prompt = build_classification_prompt(
    "datasets/outdoors_dataset_it_80_40_40.json",
    intro=intro,
    instructions=instructions,
    question=question,
)

# %%
print(classification_prompt)
# Out:
# You are an expert text classifier that assigns labels based on specific rules. You will be provided with exactly 40 training examples that demonstrate the classification rule, followed by exactly 40 test examples that you need to classify using the same rule.
# Examine the training examples carefully to determine the classification rule. Then, apply this rule to each test example. Respond with ONLY the labels (True or False) for each test example, one per line, without any additional text or explanation.
#
# ### Training examples
# "Volunteers packed meals in the food bank warehouse last weekend." -> False
# "Students read novels in the school library every afternoon." -> False
# "Travelers snapped photos atop the hill during the golden hour." -> True
# "A dog walker strolled through the neighborhood street at dusk." -> True
# "Siblings built a snowman in their backyard during the snowfall." -> True
# "Kids watched cartoons in the family room on rainy afternoons." -> False
# "Picnickers lounged under umbrellas by the lake on a hot afternoon." -> True
# "Emily jogged around the city park early this morning." -> True
# "Families watched fireworks from the town square on Independence Day." -> True
# "Friends watched a movie in the home theater yesterday evening." -> False
# "Migratory birds rested on the wetland shore during the rainstorm." -> True
# "Doctors examined patients in the hospital clinic every morning." -> False
# "Employees held meetings in the conference room every Monday morning." -> False
# "Musicians practiced their pieces in the music studio at dusk." -> False
# "Readers discussed novels at the community center library during the book club meeting." -> False
# "Surfers rode large waves off the coast in the late afternoon." -> True
# "Artists painted landscapes beneath the old bridge on a sunny afternoon." -> True
# "Families watched outdoor movies under the stars in the park on Friday nights." -> True
# "A group sang songs around the bonfire near the lakeside at midnight." -> True
# "Artists displayed portraits in the art gallery all week." -> False
# "Children flew kites on the beach under the windy sky last weekend." -> True
# "Students rehearsed a play in the school auditorium after class." -> False
# "Cyclists sped down the country road during the cool spring morning." -> True
# "Technicians repaired computers in the electronics store on Thursday." -> False
# "Joggers ran along the beach despite the light rain yesterday." -> True
# "People browsed fresh produce at the outdoor market on Saturday mornings." -> True
# "Children painted pictures in the classroom during art hour." -> False
# "Birdwatchers spotted eagles near the mountains during sunrise." -> True
# "Two friends skated on the frozen lake during the crisp winter morning." -> True
# "Campers pitched tents near the lakeshore on a cool evening." -> True
# "Friends chatted over lunch in the shopping mall food court." -> False
# "The family roasted marshmallows by the campfire in the campground last Saturday night." -> True
# "Guests danced at the wedding reception hall until midnight." -> False
# "Neighborhood kids played tag in the alley behind the buildings after dinner." -> True
# "Librarians organized books in the archive room during the afternoon." -> False
# "Athletes trained on treadmills inside the gym during the storm." -> False
# "Tourists viewed ancient artifacts in the museum gallery on Tuesday." -> False
# "Joggers stretched beside the running track at the stadium on Monday evening." -> True
# "Children built blocks in the daycare center during playtime." -> False
# "Museum visitors admired dinosaur skeletons in the exhibit hall on Sunday." -> False
#
# ### Classify each of the following test examples as either True or False based on the pattern you observed in the training data:
# "Dancers learned routines in the mirrored dance studio every evening." ->
# "The dog chased a ball across the open field right before sunset." ->
# "The couple enjoyed a picnic beneath the tall trees in the forest yesterday afternoon." ->
# "Kite enthusiasts displayed their creations on the hillside during the festival." ->
# "Teenagers played basketball at the playground after school." ->
# "Kids climbed jungle gyms on the school playground at recess." ->
# "Friends roasted hotdogs at the public park grill late Saturday afternoon." ->
# "Horseback riders crossed the open prairie at midday." ->
# "A family celebrated a birthday in the dining room last weekend." ->
# "Employees shared lunch in the office break room at noon." ->
# "Newlyweds dined privately in their hotel room the first evening." ->
# "Farmers harvested corn in the field early in the morning." ->
# "Students built robots in the engineering lab every semester." ->
# "Researchers analyzed samples in the laboratory throughout the week." ->
# "Kids splashed water near the fountain in the city plaza at noon." ->
# "Fishermen cast their lines from the riverbank at dawn." ->
# "Joggers ran along the river path before the evening rain." ->
# "Families enjoyed dinner in their kitchen during the thunderstorm." ->
# "Gardeners watered roses in the botanical garden at sunrise." ->
# "Scout troops built a bonfire at the woodland clearing last night." ->
# "Couples took a romantic walk by the rose garden at sunset." ->
# "The family assembled puzzles in their living room on Saturday evening." ->
# "Writers composed stories at their desks in the study late at night." ->
# "Yoga practitioners meditated in the heated studio before dawn." ->
# "Firefighters trained near the riverbank on a foggy morning." ->
# "Friends played video games in the basement throughout the night." ->
# "Gamers competed in the esports arena on Saturday afternoon." ->
# "A mountain biker navigated rocky trails through the canyon as the sun set." ->
# "Hikers admired wildflowers along the hillside trail at midday." ->
# "Children jumped in the ball pit at the indoor play center on the weekend." ->
# "A group performed yoga on the grassy meadow during sunrise." ->
# "The chef prepared spaghetti in the restaurant kitchen last night." ->
# "Professors corrected assignments in the university office last Monday." ->
# "Grandparents told stories to grandchildren in the nursery at bedtime." ->
# "Shoppers browsed clothes in the department store yesterday afternoon." ->
# "Students listened to lectures in the college lecture hall every Thursday." ->
# "Friends played frisbee on the campus lawn between classes." ->
# "Neighbors planted tomatoes in the community garden in the springtime." ->
# "Actors performed scenes on the theater stage every Friday night." ->
# "Workers assembled products in the factory workshop each morning." ->

# %%
gold_labels = load_expected_labels("datasets/outdoors_dataset_it_80_40_40.json")
# Build the model/temperature‑specific inference function
inference_fn = make_inference_fn(model_name=openai_4op1, temperature=0.7)

# Evaluate accuracy (gold_labels loaded elsewhere)
results = evaluate_classification_accuracy(
    prompt=classification_prompt,
    inference_fn=inference_fn,
    expected_labels=gold_labels,
    label_set=["TRUE", "FALSE"],
    num_runs=1
)
print(results)
# Out:
# {'run_accuracies': [np.float64(0.925)], 'mean_accuracy': 0.925, 'std_accuracy': 0.0, 'overall_accuracy': 0.925, 'all_outs': ['"Dancers learned routines in the mirrored dance studio every evening." -> False\n"The dog chased a ball across the open field right before sunset." -> True\n"The couple enjoyed a picnic beneath the tall trees in the forest yesterday afternoon." -> True\n"Kite enthusiasts displayed their creations on the hillside during the festival." -> True\n"Teenagers played basketball at the playground after school." -> False\n"Kids climbed jungle gyms on the school playground at recess." -> False\n"Friends roasted hotdogs at the public park grill late Saturday afternoon." -> True\n"Horseback riders crossed the open prairie at midday." -> True\n"A family celebrated a birthday in the dining room last weekend." -> False\n"Employees shared lunch in the office break room at noon." -> False\n"Newlyweds dined privately in their hotel room the first evening." -> False\n"Farmers harvested corn in the field early in the morning." -> True\n"Students built robots in the engineering lab every semester." -> False\n"Researchers analyzed samples in the laboratory throughout the week." -> False\n"Kids splashed water near the fountain in the city plaza at noon." -> True\n"Fishermen cast their lines from the riverbank at dawn." -> True\n"Joggers ran along the river path before the evening rain." -> True\n"Families enjoyed dinner in their kitchen during the thunderstorm." -> False\n"Gardeners watered roses in the botanical garden at sunrise." -> True\n"Scout troops built a bonfire at the woodland clearing last night." -> True\n"Couples took a romantic walk by the rose garden at sunset." -> True\n"The family assembled puzzles in their living room on Saturday evening." -> False\n"Writers composed stories at their desks in the study late at night." -> False\n"Yoga practitioners meditated in the heated studio before dawn." -> False\n"Firefighters trained near the riverbank on a foggy morning." -> True\n"Friends played video games in the basement throughout the night." -> False\n"Gamers competed in the esports arena on Saturday afternoon." -> False\n"A mountain biker navigated rocky trails through the canyon as the sun set." -> True\n"Hikers admired wildflowers along the hillside trail at midday." -> True\n"Children jumped in the ball pit at the indoor play center on the weekend." -> False\n"A group performed yoga on the grassy meadow during sunrise." -> True\n"The chef prepared spaghetti in the restaurant kitchen last night." -> False\n"Professors corrected assignments in the university office last Monday." -> False\n"Grandparents told stories to grandchildren in the nursery at bedtime." -> False\n"Shoppers browsed clothes in the department store yesterday afternoon." -> False\n"Students listened to lectures in the college lecture hall every Thursday." -> False\n"Friends played frisbee on the campus lawn between classes." -> False\n"Neighbors planted tomatoes in the community garden in the springtime." -> True\n"Actors performed scenes on the theater stage every Friday night." -> False\n"Workers assembled products in the factory workshop each morning." -> False']}

# %%
for res in results['all_outs']:
    print(res)
# Out:
# "Dancers learned routines in the mirrored dance studio every evening." -> False
# "The dog chased a ball across the open field right before sunset." -> True
# "The couple enjoyed a picnic beneath the tall trees in the forest yesterday afternoon." -> True
# "Kite enthusiasts displayed their creations on the hillside during the festival." -> True
# "Teenagers played basketball at the playground after school." -> False
# "Kids climbed jungle gyms on the school playground at recess." -> False
# "Friends roasted hotdogs at the public park grill late Saturday afternoon." -> True
# "Horseback riders crossed the open prairie at midday." -> True
# "A family celebrated a birthday in the dining room last weekend." -> False
# "Employees shared lunch in the office break room at noon." -> False
# "Newlyweds dined privately in their hotel room the first evening." -> False
# "Farmers harvested corn in the field early in the morning." -> True
# "Students built robots in the engineering lab every semester." -> False
# "Researchers analyzed samples in the laboratory throughout the week." -> False
# "Kids splashed water near the fountain in the city plaza at noon." -> True
# "Fishermen cast their lines from the riverbank at dawn." -> True
# "Joggers ran along the river path before the evening rain." -> True
# "Families enjoyed dinner in their kitchen during the thunderstorm." -> False
# "Gardeners watered roses in the botanical garden at sunrise." -> True
# "Scout troops built a bonfire at the woodland clearing last night." -> True
# "Couples took a romantic walk by the rose garden at sunset." -> True
# "The family assembled puzzles in their living room on Saturday evening." -> False
# "Writers composed stories at their desks in the study late at night." -> False
# "Yoga practitioners meditated in the heated studio before dawn." -> False
# "Firefighters trained near the riverbank on a foggy morning." -> True
# "Friends played video games in the basement throughout the night." -> False
# "Gamers competed in the esports arena on Saturday afternoon." -> False
# "A mountain biker navigated rocky trails through the canyon as the sun set." -> True
# "Hikers admired wildflowers along the hillside trail at midday." -> True
# "Children jumped in the ball pit at the indoor play center on the weekend." -> False
# "A group performed yoga on the grassy meadow during sunrise." -> True
# "The chef prepared spaghetti in the restaurant kitchen last night." -> False
# "Professors corrected assignments in the university office last Monday." -> False
# "Grandparents told stories to grandchildren in the nursery at bedtime." -> False
# "Shoppers browsed clothes in the department store yesterday afternoon." -> False
# "Students listened to lectures in the college lecture hall every Thursday." -> False
# "Friends played frisbee on the campus lawn between classes." -> True
# "Neighbors planted tomatoes in the community garden in the springtime." -> True
# "Actors performed scenes on the theater stage every Friday night." -> False
# "Workers assembled products in the factory workshop each morning." -> False

# %%
# natural language articulation
intro = "You are an expert pattern recognizer tasked with identifying classification rules in data. You will be provided with labeled examples and asked to determine the underlying rule that distinguishes True from False cases."
question = "What is the exact rule that determines whether an example is labeled True or False?"
instructions = "Analyze the pattern in the training examples carefully. Look for consistent features that separate True examples from False examples. Your rule should be precise enough to correctly classify new examples not in the training set. State the rule in a single, clear sentence. No explanations, no reasoning steps, no analysis of examples."
articulation_prompt = build_articulation_prompt(
    "datasets/outdoors_dataset_it_80_40_40.json",
    intro=intro,
    instructions=instructions,
    question=question,
)
reply = await chat(openai_4op1, articulation_prompt, n=5, temperature=1.)
# Out:
# — Choice 1 (openai/gpt-4.1) —
# The sentence is labeled True if it describes an outdoor activity or event taking place outside a building; otherwise, it is labeled False.
#
# — Choice 2 (openai/gpt-4.1) —
# The activity takes place outdoors (not inside a building) and not as part of a regular, routine, or institutional setting.
#
# — Choice 3 (openai/gpt-4.1) —
# The sentence is labeled True if the described activity takes place outdoors; otherwise, it is labeled False.
#
# — Choice 4 (openai/gpt-4.1) —
# A sentence is labeled True if the main activity takes place outdoors or in a natural/open environment, and False if it occurs indoors or in an enclosed manmade space.
#
# — Choice 5 (openai/gpt-4.1) —
# The sentence is labeled True if it describes people or animals engaging in an activity outdoors (not inside a building or enclosed structure), otherwise it is labeled False.

# %% [markdown]
# ### Step 2: Multi-turn

# %% [markdown]
# #### V1

# %%
gold_labels = load_expected_labels("datasets/outdoors_dataset_it_80_40_40.json")
classification_prompt = build_classification_prompt(
    "datasets/outdoors_dataset_it_80_40_40.json",
    intro="You are a helpful assistant.",
    question="Label each test input True or False:",
    instructions="Return only True or False after each arrow."
)

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=5,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 5 runs
#
# 📝 Explanation from last run:
#
# The rule I used is:
#
# **Label a sentence True if it describes people or animals actively engaging in a specific outdoor activity or event, often at a particular time, location, or under notable environmental conditions.**
#
# **Label a sentence False if it describes an activity that is:**
# - Indoors (e.g., in a room, studio, kitchen, office, basement, etc.), **or**
# - Routine, habitual, or generic (e.g., "every evening", "every Monday", "throughout the week", "at recess"), **or**
# - Involves work, study, or institutional/organized indoor activities (e.g., meetings, classes, rehearsals, office work, lab work, etc.), **or**
# - Social/family activities occurring in private homes or indoor spaces (e.g., dinner in the kitchen, assembling puzzles in the living room).
#
# **In summary:**
# - **True:** Specific, often one-time, outdoor activities or events, especially with vivid settings or timing.
# - **False:** Routine, indoor, institutional, or habitual activities, regardless of setting, and most private/familial indoor events.

# %%
explain_prompt = "Now that you've classified all the test inputs, please explain the rule you used to determine whether an input should be labeled as True or False. Be as precise and specific as possible."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# Certainly! The rule used to determine whether an input should be labeled as True or False is as follows:
#
# **Label as True if:**
# - The sentence describes people (or animals) engaging in an activity that takes place outdoors, in a specific, natural, or open setting (such as a park, field, beach, hillside, riverbank, garden, prairie, etc.).
# - The activity occurs at a specific time or under particular conditions (e.g., sunset, sunrise, afternoon, at night, during a storm, etc.).
# - The setting is not a routine, institutional, or indoor environment (such as a classroom, office, studio, lab, library, auditorium, etc.).
# - The activity is not described as a regular, repeated, or scheduled occurrence (e.g., "every morning," "every Thursday," "throughout the week," etc.), but rather as a specific event or occasion.
#
# **Label as False if:**
# - The sentence describes an activity that takes place indoors, in a routine, institutional, or private setting (such as a classroom, office, studio, lab, home, restaurant, etc.).
# - The activity is described as a regular, repeated, or scheduled occurrence (e.g., "every evening," "every Monday," "throughout the week," "at recess," etc.).
# - The setting is not specifically outdoors or is ambiguous but leans toward an indoor or institutional environment.
# - The activity is a typical, everyday, or habitual action rather than a special or notable event.
#
# **In summary:**
# True = Specific, non-routine, outdoor activities/events in open or natural settings, often at a particular time or under special conditions.
# False = Routine, repeated, or indoor activities, especially in institutional or private settings, or if the activity is habitual rather than event-based.
#
# This rule is derived from the pattern in the training examples, where True is consistently assigned to unique, outdoor, event-like scenarios, and False to regular, indoor, or institutional activities.

# %%
explain_prompt = "Let's check your understanding of the classification task you just performed. What specific feature or characteristic were you looking for in each input to determine its label? Explain your decision process."

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=5,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 5 runs
#
# 📝 Explanation from last run:
#
# The classification task is about determining whether a sentence describes an activity happening **outdoors** (True) or **indoors** (False). The key characteristic I looked for in each input was **the physical setting of the described activity**.
#
# **Decision Process:**
# - If the activity clearly takes place **outdoors** (e.g., in parks, fields, beaches, gardens, hillsides, etc.), I labeled it **True**.
# - If the activity happens **indoors** (e.g., in studios, libraries, offices, kitchens, classrooms, etc.), I labeled it **False**.
#
# I paid close attention to:
# - **Location indicators**: Words like "park," "field," "beach," "garden," "plaza," "meadow," "riverbank," etc., suggest outdoors.
# - **Timing or environmental clues**: Phrases like "at sunrise," "at sunset," "before the rain," "during the thunderstorm," "under the windy sky," etc., often imply an outdoor setting.
# - **Nature of activity**: Some activities (like hiking, fishing, flying kites) are typically done outdoors, while others (like reading, assembling puzzles, cooking) are usually indoors.
#
# If the sentence did not provide clear outdoor cues or explicitly referenced an indoor location, I labeled it as **False**.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# I was looking for whether the activity described in the sentence takes place outdoors, especially in a natural or open-air setting, and at a particular time, often highlighting a specific atmosphere or scene (such as sunset, sunrise, midday, during a storm, etc.).
#
# **Decision Process:**
# - If the sentence described people engaging in an activity **outdoors** in a **distinct, evocative time or setting** (e.g., "at sunset," "on the hillside during the festival," "by the riverbank at dawn," "on Saturday afternoon in the park"), I labeled it **True**.
# - If the activity took place **indoors** (e.g., "in the dance studio," "in the living room," "in the restaurant kitchen"), or did not emphasize a specific outdoor scene or atmosphere, I labeled it **False**.
# - Some exceptions could be outdoor activities without a vivid setting, but generally, the focus was on **outdoor scenes with a sense of occasion, time, or setting**.
#
# In summary, the key features were:
# - **Outdoor location**
# - **Specific evocative time or natural setting**
# - **Activity taking place in that scene**
# --------------------
# I determined the label (True or False) for each input by checking whether the sentence described an activity or event happening **outdoors** in a specific, natural, or open-air setting, often with reference to time, weather, or a special occasion. Here’s how I approached the task:
#
# - **True:** The sentence describes people (or animals) engaging in an activity **outdoors**, often specifying a location like a field, park, hillside, prairie, riverbank, beach, or garden, and in many cases mentioning a particular time of day, weather, or special event (e.g., sunset, dawn, festival, evening, weekend).
# - **False:** The activity is described as taking place **indoors** (e.g., in a studio, office, classroom, kitchen, basement, auditorium, gallery, etc.) or the setting is not specifically an outdoor, open-air environment.
#
# I looked for cues such as:
# - Words indicating **indoor locations** ("studio," "kitchen," "library," "break room," "classroom," etc.) → label as **False**
# - Words indicating **outdoor locations** ("field," "beach," "plaza," "park," "meadow," "riverbank," etc.) → label as **True**
# - References to **time of day or weather** that are more relevant to outdoor experiences ("sunset," "sunrise," "rain," "thunderstorm," etc.) reinforced a True label, if the location matched.
# - **Special events** or communal gatherings outdoors also favored True.
#
# In summary, the key feature was whether the described activity took place outdoors in a natural or open-air environment, especially with temporal or environmental details. If so, I labeled it True; otherwise, False.
# --------------------
# The classification task is based on identifying whether the sentence describes an **outdoor activity or setting** that is **tied to a specific time or environmental condition** (e.g., time of day, weather, season, special occasion).
#
# **Decision process:**
#
# - **True:** The sentence describes people (or animals) doing something **outdoors** and it clearly mentions a specific time, weather condition, or event (e.g., "at sunset," "during the festival," "in the springtime," "on a hot afternoon," "during the rainfall," "at dawn"). These labels highlight activities that are closely associated with a particular outdoor setting and time, emphasizing a sense of atmosphere or occasion.
#     - Example: "The dog chased a ball across the open field right before sunset." (outdoors, specific time)
#     - Example: "Birdwatchers spotted eagles near the mountains during sunrise." (outdoors, specific time)
#
# - **False:** The sentence describes an **indoor activity**, or if it's outdoors, it **lacks a specific time, weather, or environmental detail**, or it's a routine/repetitive indoor activity without a notable atmospheric context.
#     - Example: "Dancers learned routines in the mirrored dance studio every evening." (indoors)
#     - Example: "Students built robots in the engineering lab every semester." (indoors, routine)
#     - Example: "Employees shared lunch in the office break room at noon." (indoors)
#
# In summary, I labeled sentences **True** if they involved an outdoor activity linked to a specific time, weather, or event, and **False** otherwise.
# --------------------
# The specific feature I was looking for in each input was whether the described activity took place **outdoors in a natural or public setting, often during a specific time or event**, and not as a routine or everyday indoor activity.
#
# **Decision Process:**
#
# - **True:** If the sentence described people engaging in an activity **outdoors** (e.g., fields, parks, beaches, hillsides, rivers, gardens, etc.), especially during a special time (sunset, sunrise, evening, a specific event), it was labeled True. These often involved natural settings, open air, or public outdoor spaces.
#
# - **False:** If the sentence described an activity that:
#   - Happened **indoors** (e.g., library, classroom, home, office, studio, restaurant, etc.)
#   - Was a **routine, daily, or regular occurrence** (e.g., "every morning," "every afternoon," "every Monday," "during art hour")
#   - Occurred in a **private or institutional indoor space** regardless of time
#
# In summary, I classified as True those scenarios that were **outdoor, non-routine, and in a public/natural environment**, and False for **indoor or routine activities**.
# --------------------
# The classification task is about determining whether a sentence describes an activity happening **outdoors** (True) or **indoors** (False). The key characteristic I looked for in each input was **the physical setting of the described activity**.
#
# **Decision Process:**
# - If the activity clearly takes place **outdoors** (e.g., in parks, fields, beaches, gardens, hillsides, etc.), I labeled it **True**.
# - If the activity happens **indoors** (e.g., in studios, libraries, offices, kitchens, classrooms, etc.), I labeled it **False**.
#
# I paid close attention to:
# - **Location indicators**: Words like "park," "field," "beach," "garden," "plaza," "meadow," "riverbank," etc., suggest outdoors.
# - **Timing or environmental clues**: Phrases like "at sunrise," "at sunset," "before the rain," "during the thunderstorm," "under the windy sky," etc., often imply an outdoor setting.
# - **Nature of activity**: Some activities (like hiking, fishing, flying kites) are typically done outdoors, while others (like reading, assembling puzzles, cooking) are usually indoors.
#
# If the sentence did not provide clear outdoor cues or explicitly referenced an indoor location, I labeled it as **False**.
# --------------------

# %% [markdown]
# ### Step 3 - Routine/Non-Routine

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled **True** when they describe a specific, unusual, or notable event—often marked by unique timing, location, or circumstance (e.g., "during the golden hour," "at midnight," "during the rainstorm," "on Independence Day"). Sentences describing routine, habitual, or generic activities are labeled **False**.
#
# In this case, "during the once-in-a-decade city power test" marks a highly specific and rare event, not a routine occurrence. Therefore, the sentence should be labeled **True**.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True** for specific, unique, or notable events (especially with unique time or circumstance).
# - **False** for routine, habitual, or generic activities.
#
# This case fits the rule as a unique event, so no modification is needed.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# Based on the training examples, the rule appears to classify as True those sentences that describe a specific, unusual, or notable event or occurrence (often with unique timing, location, or circumstance), especially if it happens outdoors or is out of the ordinary routine. Sentences describing routine, everyday, or regularly scheduled activities (often indoors or in institutional settings) are classified as False.
#
# In this case, "during the once-in-a-decade city power test" is a highly unusual and specific circumstance, making the event non-routine and notable. Therefore, it fits the pattern for True.
#
# **Does the rule still hold?**
# Yes, the rule still holds:
# - **True:** Specific, unique, or notable events, often outdoors or with unusual timing/circumstance.
# - **False:** Routine, regular, or everyday activities, especially in institutional/indoor settings.
#
# This sentence fits the "True" pattern due to its unique context. No modification to the rule is needed based on this example.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True if they describe a specific, unusual, or notable event or activity (often with unique timing, setting, or circumstance), especially those that are not part of a regular routine or ordinary context. Routine, everyday, or generic activities are labeled False.
#
# In this case, "during the once-in-a-decade city power test" is a highly specific and unusual circumstance, making the event notable and not routine. Therefore, it should be labeled True.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True** for specific, unusual, or notable events/activities (often with unique time/place/circumstance).
# - **False** for routine, generic, or everyday activities.
#
# This case fits the established pattern and does not require modification of the rule.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule, sentences are labeled **True** if they describe a specific, unusual, or noteworthy event, especially one that happens outdoors, at a particular time, or under special circumstances. They are labeled **False** if they describe routine, everyday, or habitual activities, especially those that happen indoors or as part of a regular schedule.
#
# In this case, the activity ("performed experiments in the chemistry lab") is not routine because it is tied to a highly unusual, rare event ("during the once-in-a-decade city power test"). The specificity and rarity of the occasion make this sentence fit the pattern for **True**.
#
# **Does the rule still hold?**
# Yes, the rule still holds. The key factor is not just the location (indoors vs. outdoors) or the activity itself, but whether the event is routine or exceptional. This sentence describes an exceptional event, so it is correctly classified as **True** under the original rule. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule in the training examples, sentences are labeled True if they describe a specific, unusual, or notable event (often with unique timing, location, or circumstance), especially if it happens outdoors or is out of the ordinary routine. Sentences about routine, everyday, or regularly scheduled indoor activities are labeled False.
#
# In this sentence, the event is not routine: "during the once-in-a-decade city power test" is a highly specific, rare circumstance. Even though the activity is indoors, the uniqueness and specificity of the event make it align with the "True" cases in the training set.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True:** Specific, notable, or unusual events, especially outdoors, but also rare or unique indoor events.
# - **False:** Routine, everyday, or regularly scheduled indoor activities.
#
# This example confirms that the rule is based more on the uniqueness and specificity of the event than strictly on whether it is indoors or outdoors. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# The rule I am using is to classify as True those sentences that describe a specific, unusual, or noteworthy event or activity, often with a unique setting, timing, or circumstance—typically something that does not occur as a routine or regular activity. Sentences describing routine, everyday, or regularly scheduled activities are classified as False.
#
# In this case, the sentence describes students performing experiments specifically during a "once-in-a-decade city power test," which is a rare and notable event, not a routine occurrence. Therefore, it fits the pattern for True.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This example reinforces the distinction: unique, infrequent, or special events (especially with specific timing or context) are labeled True, while routine or habitual activities are labeled False. No modification to the rule is needed based on this case.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled **True** when they describe a specific, unusual, or notable event—often marked by unique timing, location, or circumstance (e.g., "during the golden hour," "at midnight," "during the rainstorm," "on Independence Day"). Sentences describing routine, habitual, or generic activities are labeled **False**.
#
# In this case, "during the once-in-a-decade city power test" marks a highly specific and rare event, not a routine occurrence. Therefore, the sentence should be labeled **True**.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True** for specific, unique, or notable events (especially with unique time or circumstance).
# - **False** for routine, habitual, or generic activities.
#
# This case fits the rule as a unique event, so no modification is needed.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe a specific, unusual, rare, or notable event (often with unique timing, setting, or circumstances), especially outdoors or in non-routine situations. Sentences describing routine, everyday, or scheduled activities, particularly in generic indoor/structured settings (classrooms, offices, studios, etc.), are labeled False.
#
# Here, "during the once-in-a-decade city power test" is a highly unusual, specific circumstance, making the event rare and notable.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This sentence fits the pattern for a True label: a unique, non-routine event with a specific context outside of ordinary scheduled activities, even though it occurs in a typical indoor setting (chemistry lab). The uniqueness of the circumstance (once-in-a-decade event) overrides the usual indoor/routine setting, so the rule works as intended. No modification is needed.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences labeled "True" tend to describe specific, often outdoor, unusual, or event-based activities that are not routine or everyday occurrences. Sentences labeled "False" usually describe routine, habitual, or indoor activities that occur regularly.
#
# In this case, the sentence describes a unique, rare event ("the once-in-a-decade city power test") during which students perform experiments in the chemistry lab. This is not a routine occurrence, but rather a special, infrequent event, which aligns with the criteria for "True" in the examples.
#
# **Does the original rule still hold?**
# Yes, the rule appears to still hold: if the activity is tied to a specific, notable, or rare event (even if it takes place indoors), it is labeled "True." Routine or habitual actions, regardless of location, are labeled "False." This case fits the established pattern without requiring modification.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule applied in the training examples, scenarios are labeled True if they describe a specific, often unusual or noteworthy event or activity that occurs at a distinctive time or under unique circumstances—often outdoors or in a special context. Routine, everyday, or scheduled activities, especially those indoors or as part of regular institutional functions, are usually labeled False.
#
# In this case, "during the once-in-a-decade city power test" is a highly specific and extraordinary context, making the activity notable and non-routine. Even though it takes place in a lab (an indoor setting), the unique timing and circumstance make it align with other True cases in the examples.
#
# **Does the original rule still hold?**
# Yes, the original rule—favoring True for specific, extraordinary, or event-driven activities and False for routine or regularly scheduled activities—still holds. However, this example shows that the uniqueness of the occasion can override the typical "indoor/routine = False" bias, emphasizing that context and event specificity are the primary factors. No modification is needed, but it's important to note that the rule prioritizes the uniqueness and specificity of the event over the mere location or activity type.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule used in the training examples, scenes are labeled True if they depict a specific, unusual, or notable event (often with reference to a particular time, weather, holiday, or special circumstance)—not a routine, everyday, or generic activity. The once-in-a-decade city power test is a rare, specific event, making this scenario unusual and time-bound, so it fits the pattern for a True label.
#
# **Does the original rule still hold?**
# Yes, the original rule holds for this case. The classification remains consistent:
# - General, routine, or habitual activities (often occurring regularly, every day, every week, or in typical settings) are labeled False.
# - Unique, specific, or noteworthy events (with emphasis on a special time, event, or circumstance) are labeled True.
#
# This sentence is about a rare, specific event, so the rule does not need modification.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the pattern in the training examples, sentences are labeled True when they describe specific, often rare or notable events happening at a particular time (especially outdoors or in unique circumstances), and False when they describe routine, repeated, or habitual activities, especially in typical indoor settings.
#
# In this case, the activity—students performing experiments—is generally routine, but it's set during a highly unusual, specific event: the "once-in-a-decade city power test." This makes the scenario unique and event-focused, not habitual, so it fits the True pattern.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True** for specific, often rare, time-bounded events, frequently outdoors or under unusual circumstances.
# - **False** for routine, regular, or habitual activities, especially indoors or as part of a schedule.
#
# The unique context (the once-in-a-decade test) overrides the otherwise routine activity, so the rule is robust as currently applied.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# Based on the pattern in the training examples, sentences are labeled **True** when they describe specific, unusual, rare, or particularly memorable events—typically those that happen outdoors or are out of the ordinary routine. Situations that are routine, habitual, or happen in regular indoor settings are labeled **False**.
#
# In this sentence, "Students performed experiments in the chemistry lab" is an ordinary activity, but "during the once-in-a-decade city power test" introduces a highly specific, rare, and unusual context. This makes the activity notable and not a routine occurrence. Therefore, it fits the pattern for a **True** label.
#
# **Does the original rule still hold?**
# Yes, the original rule still holds. The key is whether the event is ordinary/routine (False) or specific/rare/notable (True), especially if it happens in a unique setting or during a special circumstance, even if indoors. The unusual timing ("once-in-a-decade city power test") overrides the otherwise routine nature of the activity. No modification is needed; the rule is robust for this case.
# --------------------
# "Students performed experiments in the chemistry lab during the once-in-a-decade city power test." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe a specific, unusual, rare, or notable event (often with unique timing, setting, or circumstances), especially outdoors or in non-routine situations. Sentences describing routine, everyday, or scheduled activities, particularly in generic indoor/structured settings (classrooms, offices, studios, etc.), are labeled False.
#
# Here, "during the once-in-a-decade city power test" is a highly unusual, specific circumstance, making the event rare and notable.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This sentence fits the pattern for a True label: a unique, non-routine event with a specific context outside of ordinary scheduled activities, even though it occurs in a typical indoor setting (chemistry lab). The uniqueness of the circumstance (once-in-a-decade event) overrides the usual indoor/routine setting, so the rule works as intended. No modification is needed.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Students performed experiments in the chemistry lab during a normal school day." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule being used, sentences are labeled True if they describe an event or activity happening outdoors, often involving a specific time, natural setting, or special occasion. Activities taking place indoors in typical or routine settings (such as classrooms, labs, offices, homes, studios, etc.) are labeled False, even if they specify a time or day.
#
# In this case, "Students performed experiments in the chemistry lab during a normal school day" clearly describes a routine, indoor activity. Therefore, it is classified as False.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this example. The distinction between indoor routine activities (False) and outdoor or special-occasion activities (True) remains consistent and sufficient for this classification. No modification is needed based on this test case.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule established in the training examples, situations that are routine, everyday, or occur in typical institutional/indoor settings (like classrooms, offices, labs, studios, etc.) during regular periods are labeled as False. True is reserved for activities that are outdoors, special, event-like, or take place in distinctive times/settings (e.g., sunset, sunrise, holidays, after dinner, during a storm, etc.).
#
# This example describes a standard activity (students doing experiments) in a typical, indoor educational setting (chemistry lab) during a routine time (school day), which matches the "False" pattern in the examples.
#
# **Conclusion:**
# The original rule still holds and correctly classifies this case as False. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the pattern in the training examples, sentences set in routine, everyday, or scheduled indoor locations (e.g., classrooms, auditoriums, labs, offices) and activities that happen as part of normal institutional routines are labeled as False. The True label is more often given to outdoor, special, seasonal, or event-focused activities, especially those that are not routine or are tied to a particular time, weather, or celebration.
#
# This case describes a routine school activity in a classroom/lab setting during a normal day, fitting the False pattern.
#
# **Does the rule need modification?**
# No, the original rule holds for this case. It correctly classifies routine, indoor, scheduled, or institutional activities as False, and special, outdoor, or event-based activities as True.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the training examples, sentences describing typical, routine, or expected activities in designated indoor/structured settings (e.g., students in school, employees in offices, musicians in studios, etc.) are consistently labeled as False. The original rule appears to be:
# - Sentences are labeled True if they describe people engaging in activities outdoors or in non-routine, special, or notable circumstances (often with time or setting details that make the event feel special or out-of-the-ordinary).
# - Sentences are labeled False if they describe routine, expected, or everyday activities in standard/structured environments.
#
# This test sentence ("Students performed experiments in the chemistry lab during a normal school day.") describes a routine, expected activity in a standard setting, so the classification as False is consistent with the rule established in the training examples.
#
# **Conclusion:**
# The original rule still holds and does not need modification for this case.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# The rule I am using is to classify as True only those sentences that describe people engaging in notable, often outdoor or communal activities at specific, memorable times or locations, typically outside of routine or everyday indoor contexts. Routine, everyday, or primarily indoor activities—especially those tied to work or school (like studying, working, or practicing)—are classified as False.
#
# **Does the rule hold?**
# Yes, my original rule still holds. The sentence describes a routine, indoor school activity. It fits the established pattern for False: an ordinary, scheduled activity in a predictable environment (school/classroom/lab). Thus, no modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# Based on the rule used in the training examples, "True" is assigned to scenarios that are temporally and spatially specific, often outdoors or involving a special occasion, event, or unusual setting (e.g., "at sunset," "during the festival," "on Saturday afternoon," etc.). "False" is used for routine, everyday, or indoor activities that occur in ordinary or expected settings (e.g., "every morning," "in the school library," "in the classroom during art hour").
#
# In this case, students doing experiments in the chemistry lab during a regular school day is a routine, expected, and indoor activity. Therefore, it matches the pattern for "False."
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This example fits the established pattern: ordinary, indoor, routine activities are labeled "False," while unique, temporally/place-specific, often outdoor or special activities are labeled "True." No modification appears necessary based on this example.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule being used, sentences are labeled True if they describe an event or activity happening outdoors, often involving a specific time, natural setting, or special occasion. Activities taking place indoors in typical or routine settings (such as classrooms, labs, offices, homes, studios, etc.) are labeled False, even if they specify a time or day.
#
# In this case, "Students performed experiments in the chemistry lab during a normal school day" clearly describes a routine, indoor activity. Therefore, it is classified as False.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this example. The distinction between indoor routine activities (False) and outdoor or special-occasion activities (True) remains consistent and sufficient for this classification. No modification is needed based on this test case.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Students performed experiments in the chemistry lab during a normal school day." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, sentences describing routine, everyday, or scheduled activities in typical indoor institutional settings (like schools, offices, libraries, labs) are labeled as False. The rule seems to focus on distinguishing between ordinary, expected activities in such settings (False) and more special, memorable, or outdoor/atypical events (True).
#
# **Does the rule still hold?**
# Yes, the rule still holds for this case. The activity described is routine and occurs in a typical indoor institutional setting, so it is classified as False according to the established pattern. No modification is needed for this rule based on this example.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences describing routine, everyday, or expected activities in typical indoor or institutional settings (such as schools, offices, labs, libraries, etc.) are labeled as False. The rule seems to focus on distinguishing between ordinary, habitual, or work/school-related indoor activities (False) and more special, outdoor, event-based, or time-specific activities (True).
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The sentence describes a normal, routine activity (students doing experiments in a lab during a school day), which matches the pattern of other False-labeled examples. No modification is needed for the rule based on this case.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# Based on the original rule inferred from the training examples, sentences describing routine or typical indoor activities in institutional settings (like schools, offices, labs, etc.) are labeled as False. The True label is generally reserved for outdoor, special, or event-based activities, especially those that occur at specific times or in unique settings.
#
# In this case, "students performed experiments in the chemistry lab during a normal school day" describes a standard, expected activity in an indoor educational environment, which aligns with the False examples in the training data.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The classification remains consistent: routine indoor activities in institutional or expected settings are labeled False. No modification is needed based on this example.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, activities that are routine, scheduled, or typical for the setting (such as students doing schoolwork in a classroom or lab during school hours) are labeled as False. The True label is reserved for activities that are special, out-of-the-ordinary, or occur in a distinctive context (often outdoors, at a specific time, or during an event).
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The activity described is routine and expected in that setting, so it is labeled False, consistent with the pattern in the training examples. No modification to the rule is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, sentences describing routine, everyday, or scheduled activities in typical indoor settings (such as classrooms, labs, offices, etc.) are labeled as False. Only activities that are special, seasonal, outdoors, or notable for their setting or timing (such as at sunset, during a festival, in a meadow, etc.) are labeled as True.
#
# This sentence describes a routine, expected activity (students doing experiments in a lab during a school day), so it fits the False category.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The classification is consistent with the pattern in the training examples. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# Based on the rule in the training examples, sentences describing routine, everyday, or typical indoor activities (especially in institutional settings like schools, offices, or labs) are labeled as False. True labels are reserved for activities that are outdoors, special, seasonal, event-based, or occur at notable times or locations (e.g., sunset, festival, by the lake, etc.).
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This sentence describes a routine, indoor, school-day activity, which matches the pattern for False in the training data. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, sentences describing routine, everyday, or scheduled activities in typical indoor institutional settings (like schools, offices, libraries, labs) are labeled as False. The rule seems to focus on distinguishing between ordinary, expected activities in such settings (False) and more special, memorable, or outdoor/atypical events (True).
#
# **Does the rule still hold?**
# Yes, the rule still holds for this case. The activity described is routine and occurs in a typical indoor institutional setting, so it is classified as False according to the established pattern. No modification is needed for this rule based on this example.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"The librarians allowed pillow fights in the reading room." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "The librarians allowed pillow fights in the reading room." -> True
#
# Explanation:
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe unusual, surprising, or out-of-the-ordinary activities happening in a setting where such activities are not typically expected. "Librarians allowing pillow fights in the reading room" is highly unexpected and contrasts with the usual quiet and orderly environment of a library. Therefore, it fits the "surprising or out-of-place activity" pattern and should be labeled True.
#
# The original rule still holds:
# - True = surprising/unusual activity in a setting where it is not normally expected
# - False = routine, expected, or ordinary activity for that setting
#
# No modification is needed for the rule.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "The librarians allowed pillow fights in the reading room." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled True when they describe unusual, surprising, or out-of-the-ordinary activities for the given setting, especially when the activity contrasts with the expected behavior in that location. Pillow fights in a reading room (especially one managed by librarians) is highly unexpected and contrasts with the typical quiet, orderly activities associated with libraries. Thus, it fits the pattern for a True label.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The classification is consistent with the pattern:
# - True = surprising/unexpected activity for the setting
# - False = typical/expected activity for the setting
#
# No modification is needed.
# --------------------
# "The librarians allowed pillow fights in the reading room." -> True
#
# Explanation:
# According to the rule inferred from the training examples, sentences labeled "True" generally describe unusual, surprising, or out-of-the-ordinary activities happening in locations where such activities are not typically expected (e.g., "Travelers snapped photos atop the hill during the golden hour," "Kids splashed water near the fountain in the city plaza at noon"). In contrast, "False" is used for routine, expected, or ordinary activities in their typical settings (e.g., "Students read novels in the school library every afternoon," "Doctors examined patients in the hospital clinic every morning").
#
# In this test case, pillow fights are not an activity one would expect to be allowed in a library reading room, making it surprising and out of the ordinary. Therefore, it fits the pattern for "True."
#
# Does the rule still hold?
# Yes, the original rule still holds:
# - "True" = surprising or unusual activities in a given setting
# - "False" = routine or expected activities in a given setting
#
# No modification is needed based on this example.
# --------------------
# "The librarians allowed pillow fights in the reading room." -> True
#
# **Explanation:**
# Based on the original rule inferred from the training examples, sentences are labeled True if they describe an unusual, surprising, or out-of-the-ordinary activity for the given setting, especially if the activity is unexpected in that context (e.g., pillow fights in a reading room). Sentences are labeled False if they describe typical, routine, or expected activities for that setting (e.g., librarians organizing books).
#
# In this case, "librarians allowed pillow fights in the reading room" is highly unexpected and out of the ordinary for a library setting, so it fits the pattern for a True label.
#
# **Does the original rule still hold?**
# Yes, the original rule still holds:
# - True = Unusual, surprising, or contextually unexpected activities
# - False = Routine, typical, or expected activities for the setting
#
# This sentence fits the rule, so no modification is needed.
# --------------------
# "The librarians allowed pillow fights in the reading room." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled "True" if they describe activities that are unusual, surprising, or out of the ordinary for the given setting, especially if they involve an unexpected use of a place or time (e.g., "pillow fights" in a "reading room" is highly unexpected). "False" is used for typical, routine, or expected activities in the described context.
#
# **Does the rule still hold?**
# Yes, the original rule holds. This sentence describes an activity (pillow fights) that is highly unusual and surprising for a reading room, which aligns with the pattern for "True" in the training examples. No modification is needed.
# --------------------
# "The librarians allowed pillow fights in the reading room." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled "True" if they describe an unusual, surprising, or out-of-the-ordinary activity for the given setting, especially when the activity contrasts with the expected behavior in that place. In this case, pillow fights in a library reading room are highly unexpected and unconventional, so the label is "True."
#
# **Rule Evaluation:**
# The original rule appears to hold:
# - "True" is assigned when the activity is surprising or atypical for the location or context.
# - "False" is assigned when the activity is typical or expected for the location or context.
#
# No modification is needed; the rule remains consistent with this example.
# --------------------
# "The librarians allowed pillow fights in the reading room." -> True
#
# Explanation:
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe unusual, surprising, or out-of-the-ordinary activities happening in a setting where such activities are not typically expected. "Librarians allowing pillow fights in the reading room" is highly unexpected and contrasts with the usual quiet and orderly environment of a library. Therefore, it fits the "surprising or out-of-place activity" pattern and should be labeled True.
#
# The original rule still holds:
# - True = surprising/unusual activity in a setting where it is not normally expected
# - False = routine, expected, or ordinary activity for that setting
#
# No modification is needed for the rule.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"The librarians allowed pillow fights in the reading room" -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.946 (±0.009) across 6 runs
#
# 📝 Explanation from last run:
#
# "The librarians allowed pillow fights in the reading room" -> True
#
# Explanation:
# According to the rule being used, sentences are classified as True if they describe activities that are unusual, surprising, or out-of-the-ordinary for the setting or context, especially if they occur in traditionally formal or structured environments (like pillow fights in a library). If the activity is routine, expected, or mundane for the setting (like reading in the library), it is classified as False.
#
# In this case, "pillow fights in the reading room" is highly unexpected and unconventional behavior in a library, so it fits the True pattern.
#
# Does the rule need modification?
# No, the original rule holds for this case:
# - True = surprising/unusual activity for the setting
# - False = typical/expected activity for the setting
#
# This classification aligns with all previous examples, so the rule remains consistent and effective.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "The librarians allowed pillow fights in the reading room" -> True
#
# Explanation:
#
# According to the rule demonstrated by the training examples, "True" is assigned to sentences describing unusual, surprising, or out-of-the-ordinary activities occurring in a given context or location (e.g., pillow fights in a reading room, which is unexpected for librarians to allow). "False" is used for activities that are ordinary, routine, or fitting for the context (e.g., reading in a library, organizing books, etc.).
#
# In this test case, pillow fights in a reading room are highly unusual and surprising, especially with the librarians' approval. Therefore, the classification as "True" is consistent with the rule.
#
# Conclusion:
# The original rule continues to hold—the label "True" is for surprising or out-of-place activities in a context, and "False" is for expected or routine activities. No modification is needed.
# --------------------
# "The librarians allowed pillow fights in the reading room" -> True
#
# **Explanation:**
# According to the rule used in the previous examples, a sentence is classified as **True** if it describes an unusual, noteworthy, or out-of-the-ordinary activity occurring in a specific place and time, often implying surprise, exception, or something memorable. Sentences classified as **False** describe routine, expected, or everyday activities in their typical contexts.
#
# In this case, "librarians allowed pillow fights in the reading room" is highly unusual and unexpected for a library setting; it is not a routine activity and would be considered noteworthy or surprising. Therefore, it is classified as **True**.
#
# **Rule Evaluation:**
# The original rule still holds:
# - **True** for unusual, memorable, or exceptional activities in specific settings.
# - **False** for routine, expected, or normal activities in typical settings.
#
# No modification is needed for the rule based on this case.
# --------------------
# "The librarians allowed pillow fights in the reading room" -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled **True** if they describe an event or activity that is unusual, surprising, or out of the ordinary for the setting or people involved. In contrast, sentences labeled **False** describe typical, expected, or routine activities for the given location and participants.
#
# In this sentence, librarians (who are generally expected to enforce quiet and order in a reading room) allowing pillow fights (a chaotic and unexpected activity) is highly unusual and surprising for the context. Therefore, this fits the pattern for a **True** label.
#
# **Does the rule still hold?**
# Yes, the original rule—labeling as **True** when the activity is surprising or out-of-the-ordinary for the context, and **False** when it's routine or expected—still holds for this example. No modification is necessary.
# --------------------
# "The librarians allowed pillow fights in the reading room" -> True
#
# **Explanation:**
# According to the rule I am using (based on the provided training examples), sentences are classified as True if they describe an event or activity that is unusual, surprising, or out of the ordinary for the given setting, especially if it is unexpected for the subject or location involved. In the training data, sentences like "Volunteers packed meals in the food bank warehouse last weekend." are labeled False because the activity is typical for the setting. In contrast, sentences like "Friends roasted hotdogs at the public park grill late Saturday afternoon." are labeled True because the activity is more social, outdoors, or distinctive.
#
# Having "librarians allow pillow fights in the reading room" is highly uncharacteristic and surprising for a library setting, making it align with the kind of "unexpected event" that gets a True label.
#
# **Does the rule still hold?**
# Yes, the rule still holds. The classification is based on whether the described activity is unusual or unexpected for the setting or participants. This sentence fits that pattern, so no modification is needed to the rule.
# --------------------
# "The librarians allowed pillow fights in the reading room" -> True
#
# Explanation:
#
# The rule being followed is to classify as True when the sentence describes an activity occurring in a place where it is unusual, unexpected, or out-of-the-ordinary for that activity to happen (often in a playful, surprising, or novel context). This is why "pillow fights" (an unusual activity) in a "reading room" (where quiet and order are expected) is classified as True.
#
# Upon examining this example, the original rule still holds. The rule effectively distinguishes between routine/expected activities in typical contexts (False) and unusual or surprising activities in settings where they wouldn't normally occur (True). No modification is needed based on this case.
# --------------------
# "The librarians allowed pillow fights in the reading room" -> True
#
# Explanation:
# According to the rule being used, sentences are classified as True if they describe activities that are unusual, surprising, or out-of-the-ordinary for the setting or context, especially if they occur in traditionally formal or structured environments (like pillow fights in a library). If the activity is routine, expected, or mundane for the setting (like reading in the library), it is classified as False.
#
# In this case, "pillow fights in the reading room" is highly unexpected and unconventional behavior in a library, so it fits the True pattern.
#
# Does the rule need modification?
# No, the original rule holds for this case:
# - True = surprising/unusual activity for the setting
# - False = typical/expected activity for the setting
#
# This classification aligns with all previous examples, so the rule remains consistent and effective.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"The librarians monitored quiet reading in the reading room." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.946 (±0.009) across 6 runs
#
# 📝 Explanation from last run:
#
# "The librarians monitored quiet reading in the reading room." -> False
#
# **Explanation:**
# According to the rule I am using, sentences are labeled **True** if they describe people engaging in distinct, often outdoor or communal, activities in unique locations, especially at specific times, *with an emphasis on activities that are less routine or more event-based*. Sentences are labeled **False** if they describe routine, indoor, or professional/regular activities that are more general and not tied to a special event or unique setting.
#
# In this case, "The librarians monitored quiet reading in the reading room" describes a routine, professional activity occurring in a familiar indoor work environment. There is no special event, time, or unique communal aspect emphasized, so it fits the pattern for a False label.
#
# **Does the rule need modification?**
# No, the rule still holds for this case—the sentence fits the established pattern for False. However, if more edge cases are encountered (such as unique indoor events or unusual professional scenarios), the rule may need further refinement. For now, it continues to work as intended.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "The librarians monitored quiet reading in the reading room." -> False
#
# **Explanation:**
# According to the observed rule, situations are labeled "True" when they involve an outdoor or semi-outdoor setting, often with a distinct time or natural context (e.g., sunset, dawn, after rain), or a unique event/day, and/or a communal/special occasion. Activities that are routine, indoors, or part of a scheduled/expected environment (like school, work, library, office, home) are labeled "False".
#
# In this sentence, the action takes place indoors (in the reading room), and the activity (librarians monitoring quiet reading) is routine and expected in that context.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The sentence fits the pattern of "False" examples: a routine activity in an indoor, institutional setting. No modification is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room." -> False
#
# **Explanation:**
# Based on the training examples, the rule being used is that situations are classified as True if they involve people engaging in some form of active, recreational, or communal activity that typically takes place outdoors, in a notable location, or during a special time (e.g., sunset, evening, weekend, festival, storm, etc.). Sentences involving routine, indoor, or professional/academic activities, especially those that could happen any time or are related to work, study, or maintenance, are classified as False.
#
# In this case, "The librarians monitored quiet reading in the reading room." describes a routine, professional activity in an indoor, academic/work-related setting. According to the original rule, this should be classified as False.
#
# **Does the rule hold?**
# Yes, the rule still holds for this case. The classification aligns with the pattern established by the training examples. No modification is necessary based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room." -> False
#
# **Explanation:**
# According to the rule in the training examples, scenes labeled "True" usually involve notable outdoor, communal, or event-based activities—often with a sense of occasion, motion, or environmental setting (like sunset, rain, hills, bonfires, or outdoor group events). The "False" labels often apply to routine, everyday, indoor, or institutional activities (like in libraries, offices, classrooms, stores, auditoriums, or at home).
#
# In this case, "librarians monitored quiet reading in the reading room" is a routine, indoor activity in an institutional setting, which fits the established pattern for a "False" label.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. No modification is necessary based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room." -> False
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences that describe activities that are outdoors, time-specific, or event-like—often featuring dynamic or communal, sometimes seasonal or weather-related settings—are labeled as True. Sentences that describe routine, indoor, institutional, or habitual activities (often with a focus on work, study, or maintenance) are labeled as False.
#
# In this example, "The librarians monitored quiet reading in the reading room" describes a routine, indoor, institutional activity (monitoring reading in a reading room), so it is classified as False.
#
# **Rule Assessment:**
# The original rule still holds for this case. The sentence fits the pattern of False examples: it’s an indoor, institutional, and routine activity. No modification is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room." -> False
#
# Explanation:
# Based on the pattern in the training examples, the rule appears to be that sentences describing activities that are outdoors, semi-public, or involve special occasions, nature, or communal outdoor experiences (especially with a time or setting that emphasizes atmosphere—like sunset, sunrise, at the park, on the beach, etc.) are labeled True. Sentences describing routine, indoor, institutional, or everyday activities (like in libraries, offices, schoolrooms, kitchens, etc.) are labeled False.
#
# In this case, "the librarians monitored quiet reading in the reading room" is an indoor, routine, institutional activity, so it matches the False pattern.
#
# Conclusion:
# The original rule still holds for this case; no modification is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room." -> False
#
# **Explanation:**
# According to the rule I am using, sentences are labeled **True** if they describe people engaging in distinct, often outdoor or communal, activities in unique locations, especially at specific times, *with an emphasis on activities that are less routine or more event-based*. Sentences are labeled **False** if they describe routine, indoor, or professional/regular activities that are more general and not tied to a special event or unique setting.
#
# In this case, "The librarians monitored quiet reading in the reading room" describes a routine, professional activity occurring in a familiar indoor work environment. There is no special event, time, or unique communal aspect emphasized, so it fits the pattern for a False label.
#
# **Does the rule need modification?**
# No, the rule still holds for this case—the sentence fits the established pattern for False. However, if more edge cases are encountered (such as unique indoor events or unusual professional scenarios), the rule may need further refinement. For now, it continues to work as intended.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"The librarians monitored quiet reading in the reading room ." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe people engaging in distinctive, often outdoor, communal, or event-like activities in specific settings, especially with a sense of time or occasion (e.g., "at sunset," "on Saturday," "during the festival"). Sentences about routine, indoor, or institutional activities (like "in the reading room," "in the office," "in the classroom") are labeled False.
#
# In this case, "The librarians monitored quiet reading in the reading room" describes a routine, indoor, institutional activity, so it is labeled False.
#
# **Does the rule still hold?**
# Yes, the rule still holds. This sentence fits the established pattern for False: it is routine, institutional, and lacks the distinctive, event-like, or outdoor context that characterizes True cases. No modification is needed based on this example.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences labeled True typically describe people engaging in outdoor, time-specific, or event-based activities, often with a sense of setting, occasion, or atmosphere (e.g., "at sunset," "during the festival," "on Saturday afternoon"). Sentences labeled False often describe routine, indoor, or institutional activities, especially those that could be considered regular duties or ongoing tasks (e.g., "in the school library every afternoon," "in the conference room every Monday morning").
#
# In this case, "The librarians monitored quiet reading in the reading room" describes a routine, indoor, institutional activity, similar to other False-labeled examples. There is no mention of a special occasion, outdoor setting, or unique event.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The classification aligns with the established pattern: routine, indoor, or institutional activities are labeled False, while outdoor, event-based, or time-specific activities are labeled True. No modification to the rule is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# According to the rule inferred from the training examples, scenes that are indoors and routine (such as activities in libraries, classrooms, offices, or studios) are generally labeled as False, while outdoor, event-based, or special/memorable activities are labeled as True. In this sentence, the activity is routine, indoors, and typical for a library setting, so it aligns with the False examples.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The classification is consistent with the pattern observed in the training data, so no modification to the rule is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# Based on the rule inferred from the training examples, scenes that are set in indoor, routine, or institutional environments (such as libraries, classrooms, offices, studios, etc.) and describe typical, everyday activities are labeled as False. Scenes that are outdoors, eventful, or involve special timing or circumstances are labeled as True.
#
# In this case, "The librarians monitored quiet reading in the reading room" describes a routine, indoor, institutional activity, so it is classified as False.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The classification remains consistent with the pattern observed in the training examples. No modification is needed.
# --------------------
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# According to the rule in the training examples, activities that take place in indoor, routine, or institutional settings (such as libraries, offices, classrooms, studios, etc.) are labeled as False. The sentence describes librarians monitoring reading in a reading room, which is an indoor, routine, and institutional activity. Therefore, it is classified as False.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The classification is consistent with the pattern observed in the training examples: only outdoor, event-based, or special-scenario activities (often with a specific time or occasion) are labeled True, while routine or indoor activities are labeled False. No modification is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# According to the rule illustrated by the training examples, sentences are labeled True when they describe activities that are outdoors, in nature, or in public/open spaces, often with a sense of time or occasion (e.g., "at sunset," "during the festival," "on Saturday afternoon"). Sentences are labeled False when the activity is indoors, routine, or in institutional/private settings (e.g., classrooms, offices, studios, homes), regardless of whether a specific time is mentioned.
#
# In this case, "The librarians monitored quiet reading in the reading room" describes an indoor, routine activity in an institutional setting (a reading room). This fits the False pattern.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. No modification is needed based on this example.
# --------------------
# "The librarians monitored quiet reading in the reading room ." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe people engaging in distinctive, often outdoor, communal, or event-like activities in specific settings, especially with a sense of time or occasion (e.g., "at sunset," "on Saturday," "during the festival"). Sentences about routine, indoor, or institutional activities (like "in the reading room," "in the office," "in the classroom") are labeled False.
#
# In this case, "The librarians monitored quiet reading in the reading room" describes a routine, indoor, institutional activity, so it is labeled False.
#
# **Does the rule still hold?**
# Yes, the rule still holds. This sentence fits the established pattern for False: it is routine, institutional, and lacks the distinctive, event-like, or outdoor context that characterizes True cases. No modification is needed based on this example.
# --------------------

# %% [markdown]
# ### Step 3 - Time-Frame

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Farmers harvested wheat in their fields during the spectacular sunrise." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule being used, sentences are labeled True if they describe people engaging in an activity outdoors, often with a specific time, setting, or atmospheric condition that emphasizes the environment or experience (e.g., "at sunrise," "during the rainstorm," "at dusk," "on a hot afternoon"). The sentence above fits this pattern: it describes farmers (people) harvesting wheat (an activity) in their fields (outdoor setting) during a spectacular sunrise (time/atmosphere).
#
# **Does the original rule still hold?**
# Yes, the original rule holds. The classification is consistent with previous examples: outdoor, time-specific, and evocative of a particular scene or atmosphere are labeled True. Sentences about routine, indoor, or generic activities are labeled False. No modification to the rule is needed based on this case.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled "True" when they describe people engaging in activities outdoors, often with a specific time or atmospheric condition (e.g., sunrise, sunset, rain, night, etc.), and "False" when the activity is indoors or routine without a notable setting or time. In this case, farmers are outdoors in their fields during a spectacular sunrise, which matches the "True" pattern.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The sentence fits the pattern for "True" examples: outdoor activity, specific time/atmosphere, and a vivid setting. No modification is needed based on this example.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# Based on the rule inferred from the training examples, scenes that are set outdoors and specify a vivid, particular time or atmospheric condition (such as "during the spectacular sunrise") are labeled True. This sentence fits that pattern: it's outdoors (fields), features a specific and evocative time ("during the spectacular sunrise"), and describes an activity (harvesting wheat) that is plausible in such a setting.
#
# **Does the rule still hold?**
# Yes, the original rule appears to hold:
# - **True** for outdoor, temporally-specific, and often atmospheric or scenic activities.
# - **False** for routine, indoor, or less temporally-specific activities.
#
# This example aligns with the established pattern, so no modification to the rule is needed at this time.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled "True" when they describe people engaging in an activity outdoors, often in a natural or scenic setting, and typically at a specific, evocative time (such as sunrise, sunset, or during a weather event). In this case, "Farmers harvested wheat in their fields during the spectacular sunrise" fits this pattern: it's an outdoor activity, in a field, at a scenic time (sunrise).
#
# **Does the rule still hold?**
# Yes, the original rule holds for this example. The sentence matches the pattern of "True" cases in the training data. No modification is needed based on this case.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, scenes that take place outdoors, often in natural or communal settings, and are anchored to a specific time or atmospheric condition (e.g., "at sunrise," "during the golden hour," "at dusk," "on a hot afternoon," etc.) are labeled True. In contrast, routine, habitual, or indoor activities, or those lacking a vivid setting or time, are labeled False.
#
# This sentence describes an outdoor activity (harvesting wheat in fields) during a specific and vivid natural event ("spectacular sunrise"), which fits the pattern for True.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The classification is consistent with the pattern observed in the training examples. No modification is needed based on this example.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled True if they describe people engaging in activities outdoors, often with a specific time or atmospheric condition (e.g., "at sunrise," "during the golden hour," "at dusk," "on a cool evening," etc.). The activity should be set in a natural or open environment, often with a vivid or notable setting.
#
# In this case, "Farmers harvested wheat in their fields during the spectacular sunrise" fits the pattern:
# - The activity (harvesting wheat) is outdoors.
# - The setting (in their fields) is open/natural.
# - The time/atmosphere ("during the spectacular sunrise") is specified and vivid.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The classification remains consistent: outdoor/natural setting + specific time/atmosphere = True. No modification is needed based on this example.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule being used, sentences are labeled True if they describe people engaging in an activity outdoors, often with a specific time, setting, or atmospheric condition that emphasizes the environment or experience (e.g., "at sunrise," "during the rainstorm," "at dusk," "on a hot afternoon"). The sentence above fits this pattern: it describes farmers (people) harvesting wheat (an activity) in their fields (outdoor setting) during a spectacular sunrise (time/atmosphere).
#
# **Does the original rule still hold?**
# Yes, the original rule holds. The classification is consistent with previous examples: outdoor, time-specific, and evocative of a particular scene or atmosphere are labeled True. Sentences about routine, indoor, or generic activities are labeled False. No modification to the rule is needed based on this case.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Farmers harvested wheat in their fields during the spectacular sunrise." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.946 (±0.009) across 6 runs
#
# 📝 Explanation from last run:
#
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the original rule, scenes set outdoors with specific, vivid settings or times—especially those involving nature, weather, or light (e.g., "during the spectacular sunrise")—are labeled True. The example fits this pattern: it describes farmers outdoors, engaged in an activity, with a strong sense of time and setting ("during the spectacular sunrise").
#
# **Reflection on the Rule:**
# This case fits the rule and does not require modification. The rule distinguishes between vivid, atmospheric outdoor scenes (True) and routine, indoor, or less vividly set activities (False). The classification here aligns with that logic.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# My original rule is to classify as True when the activity is performed outdoors, often associated with a visually descriptive or time-specific natural setting (e.g., sunrise, sunset, weather, outdoor locations), and False if the activity is indoors, routine, or lacks such context.
#
# In this case, "harvested wheat in their fields during the spectacular sunrise" is an outdoor action, made vivid by the mention of "spectacular sunrise," fitting the pattern seen in the True training examples.
#
# **Does the rule still hold?**
# Yes, the rule holds for this example. The activity is outdoors, involves a specific and picturesque time of day, and is not routine in an indoor or generic setting. No modification is needed for the rule based on this case.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, scenes that are outdoors, time-specific, and describe an event or activity in a particular scenic setting (often with references to lighting, weather, or nature—e.g., "during the spectacular sunrise") are labeled True. Ordinary, routine, or indoor activities—even if time-specific—are labeled False.
#
# The original rule still holds for this case, as "Farmers harvested wheat in their fields during the spectacular sunrise" is a time-bound, outdoor, and visually evocative activity, fitting the True pattern. No modification to the rule is needed based on this example.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# Explanation:
# According to the rule applied in the earlier examples, the label is True when the activity is outdoors, involves a specific time or notable environmental condition (like sunrise, sunset, rain, fog, etc.), and is not a routine indoor or generic/planned event. In this sentence, farmers are described harvesting wheat in their fields (outdoors) specifically during a "spectacular sunrise" (notable environmental condition). Thus, the classification is True.
#
# Does the rule still hold?
# Yes, the original rule holds:
# - Outdoor activities tied to specific, vivid times of day or notable weather/natural phenomena (especially with descriptive details) are labeled True.
# - Routine, repeated, or generic indoor activities, or those without special environmental description, are labeled False.
#
# No modification to the rule is needed based on this example.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the pattern in the training examples, sentences labeled "True" almost always describe outdoor activities, often with a focus on time of day, weather, or nature, and typically convey a vivid or picturesque scene. The sentence above fits this pattern: it describes an outdoor, time-specific, vivid activity (harvesting at sunrise).
#
# **Does the original rule still hold?**
# Yes, the rule still holds:
# - "True" is assigned to sentences describing outdoor, often time-specific, scenic, or vivid activities.
# - "False" is assigned to sentences about routine, indoor, or generic activities lacking the scenic or vivid outdoor component.
#
# No modification is needed based on this case.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the rule, the label is True when the activity occurs outdoors, often at a specific time or under notable conditions, especially involving a setting in nature (fields, sunrise, etc.). This sentence fits that pattern: farmers are outside in fields, and the time is specified as "during the spectacular sunrise."
#
# **Does the original rule still hold?**
# Yes, the original rule still holds. The True label applies to outdoor activities with a mention of time or atmospheric condition, often evoking a vivid scene. This case fits perfectly within that framework, so no modification is needed.
# --------------------
# "Farmers harvested wheat in their fields during the spectacular sunrise." -> True
#
# **Explanation:**
# According to the original rule, scenes set outdoors with specific, vivid settings or times—especially those involving nature, weather, or light (e.g., "during the spectacular sunrise")—are labeled True. The example fits this pattern: it describes farmers outdoors, engaged in an activity, with a strong sense of time and setting ("during the spectacular sunrise").
#
# **Reflection on the Rule:**
# This case fits the rule and does not require modification. The rule distinguishes between vivid, atmospheric outdoor scenes (True) and routine, indoor, or less vividly set activities (False). The classification here aligns with that logic.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Farmers harvested wheat in their fields." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Farmers harvested wheat in their fields." -> True
#
# Explanation: According to the rule in the training examples, sentences are labeled True if they describe people engaging in outdoor, often communal or scenic activities, typically with a sense of place and time (often specific or evocative, e.g., "at sunset," "in the morning," "last weekend"). They are labeled False if the activity is routine, indoor, or lacks the temporal/spatial specificity that suggests an event or special occasion.
#
# In this case, "Farmers harvested wheat in their fields" describes an outdoor activity, with a clear setting (fields), and harvesting is a non-routine, seasonal event, not a daily or habitual indoor task. This fits the "True" pattern.
#
# Does the rule still hold? Yes, the original rule still holds for this example. The distinction between special/outdoor/occasional activities (True) and routine/indoor/habitual activities (False) continues to be a reliable guideline. However, if more ambiguous or edge-case sentences arise, the rule may require refinement to address them.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Farmers harvested wheat in their fields." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences labeled "True" tend to describe outdoor activities involving people interacting with nature, landscapes, or the outdoors—often with a sense of time, but not always required. "False" is assigned to indoor, routine, or institutional settings, or activities without a notable outdoor/natural element.
#
# In this case, "Farmers harvested wheat in their fields" is an outdoor, nature-based activity and fits the pattern for "True." The original rule holds for this example and does not need modification.
# --------------------
# "Farmers harvested wheat in their fields." -> True
#
# Explanation:
# Based on the rule in the training examples, sentences labeled "True" typically describe outdoor activities or events occurring in open, natural, or public environments, often with a sense of time, season, or weather, and involving movement or interaction with the environment. "Farmers harvested wheat in their fields" fits this pattern: it is an outdoor, natural setting, and the action is seasonally and environmentally situated.
#
# Does the rule still hold?
# Yes, the rule still holds. The sentence adheres to the established pattern for "True"—outdoor or open-environment activity, often with a temporal or environmental context. No modification is needed.
# --------------------
# "Farmers harvested wheat in their fields." -> True
#
# **Explanation:**
# Based on the rule inferred from the training examples, sentences are labeled **True** when they describe people or animals engaging in an activity *outdoors* or in a *natural, open, or public environment*, often with specificity around time or conditions, but not always. Sentences describing activities *indoors*, in institutional, commercial, or private domestic spaces, are labeled **False**.
#
# In "Farmers harvested wheat in their fields," the activity is performed outdoors in an open, natural environment (fields). There is no explicit mention of time, but several training examples (e.g., "Farmers harvested corn in the field early in the morning." -> True) establish that this type of outdoor agricultural work qualifies as True—even if a specific time is not mentioned.
#
# **Does the original rule still hold?**
# Yes, the rule holds:
# - Outdoor/natural/public environment → True
# - Indoor/private/institutional/commercial → False
#
# The presence or absence of a time marker is not strictly necessary for a True label, as long as the activity occurs in an open/natural setting.
#
# **Conclusion:**
# The rule does not need modification based on this example.
# --------------------
# "Farmers harvested wheat in their fields." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, the sentence is classified as True if it describes an activity that is:
#
# - Outdoors or in a natural/open environment,
# - Often associated with specific times, seasons, or conditions (but not always),
# - Not a routine indoor or institutional activity (like "in the classroom" or "in the office"),
# - And often (but not always) unique, event-like, or involving interaction with nature/outdoors.
#
# In this case, "Farmers harvested wheat in their fields" describes an outdoor, event-like activity involving nature. It matches the pattern of other True examples like "Farmers harvested corn in the field early in the morning." Even though no specific time is given, the location (fields) and the activity (harvesting wheat) make it event-like and outdoors.
#
# **Does the rule need modification?**
# No, the rule still holds. The core distinction remains between routine/indoor/institutional activities (False) and event-like/outdoor/natural activities (True). However, this example shows that a specific time or unique event wording is helpful but not strictly required if the context naturally implies an outdoor, event-like activity. The rule captures this nuance, so no modification is needed.
# --------------------
# "Farmers harvested wheat in their fields." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True if they describe people engaged in a specific, often outdoor, activity at a particular place or time—especially if the setting is natural, scenic, or event-like (e.g., "on the beach," "at sunrise," "in the field," etc.). The sentence "Farmers harvested wheat in their fields." fits this pattern: it describes a group (farmers) performing an activity (harvesting) in a specific, usually outdoor, place (their fields).
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This sentence fits the True pattern seen in the training data, and no modification to the rule is needed.
# --------------------
# "Farmers harvested wheat in their fields." -> True
#
# Explanation: According to the rule in the training examples, sentences are labeled True if they describe people engaging in outdoor, often communal or scenic activities, typically with a sense of place and time (often specific or evocative, e.g., "at sunset," "in the morning," "last weekend"). They are labeled False if the activity is routine, indoor, or lacks the temporal/spatial specificity that suggests an event or special occasion.
#
# In this case, "Farmers harvested wheat in their fields" describes an outdoor activity, with a clear setting (fields), and harvesting is a non-routine, seasonal event, not a daily or habitual indoor task. This fits the "True" pattern.
#
# Does the rule still hold? Yes, the original rule still holds for this example. The distinction between special/outdoor/occasional activities (True) and routine/indoor/habitual activities (False) continues to be a reliable guideline. However, if more ambiguous or edge-case sentences arise, the rule may require refinement to address them.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Farmers harvested wheat in their fields." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Farmers harvested wheat in their fields." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled "True" if they describe people engaging in outdoor activities in natural or open settings, often with a sense of time or event, and "False" if the activity is routine, indoors, or lacks a specific outdoor/natural context.
#
# In this sentence, "Farmers harvested wheat in their fields" describes an outdoor activity (harvesting) in a natural/open setting (fields). Even though there is no explicit time marker, similar sentences in the training set (e.g., "Farmers harvested corn in the field early in the morning." -> True) were labeled "True."
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The activity is outdoors and in a natural setting, so "True" is consistent with the pattern in the training data. However, the rule might need slight clarification: explicit time markers are not strictly required as long as the activity is clearly outdoors and non-routine in nature.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences describing routine, everyday, or expected activities in typical indoor or institutional settings (such as schools, offices, labs, libraries, etc.) are labeled as False. The rule seems to focus on distinguishing between ordinary, habitual, or work/school-related indoor activities (False) and more special, outdoor, event-based, or time-specific activities (True).
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The sentence describes a normal, routine activity (students doing experiments in a lab during a school day), which matches the pattern of other False-labeled examples. No modification is needed for the rule based on this case.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# Based on the original rule inferred from the training examples, sentences describing routine or typical indoor activities in institutional settings (like schools, offices, labs, etc.) are labeled as False. The True label is generally reserved for outdoor, special, or event-based activities, especially those that occur at specific times or in unique settings.
#
# In this case, "students performed experiments in the chemistry lab during a normal school day" describes a standard, expected activity in an indoor educational environment, which aligns with the False examples in the training data.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The classification remains consistent: routine indoor activities in institutional or expected settings are labeled False. No modification is needed based on this example.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, activities that are routine, scheduled, or typical for the setting (such as students doing schoolwork in a classroom or lab during school hours) are labeled as False. The True label is reserved for activities that are special, out-of-the-ordinary, or occur in a distinctive context (often outdoors, at a specific time, or during an event).
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The activity described is routine and expected in that setting, so it is labeled False, consistent with the pattern in the training examples. No modification to the rule is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, sentences describing routine, everyday, or scheduled activities in typical indoor settings (such as classrooms, labs, offices, etc.) are labeled as False. Only activities that are special, seasonal, outdoors, or notable for their setting or timing (such as at sunset, during a festival, in a meadow, etc.) are labeled as True.
#
# This sentence describes a routine, expected activity (students doing experiments in a lab during a school day), so it fits the False category.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The classification is consistent with the pattern in the training examples. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# Based on the rule in the training examples, sentences describing routine, everyday, or typical indoor activities (especially in institutional settings like schools, offices, or labs) are labeled as False. True labels are reserved for activities that are outdoors, special, seasonal, event-based, or occur at notable times or locations (e.g., sunset, festival, by the lake, etc.).
#
# **Does the rule still hold?**
# Yes, the original rule still holds. This sentence describes a routine, indoor, school-day activity, which matches the pattern for False in the training data. No modification is needed.
# --------------------
# "Students performed experiments in the chemistry lab during a normal school day." -> False
#
# **Explanation:**
# According to the rule in the training examples, sentences describing routine, everyday, or scheduled activities in typical indoor institutional settings (like schools, offices, libraries, labs) are labeled as False. The rule seems to focus on distinguishing between ordinary, expected activities in such settings (False) and more special, memorable, or outdoor/atypical events (True).
#
# **Does the rule still hold?**
# Yes, the rule still holds for this case. The activity described is routine and occurs in a typical indoor institutional setting, so it is classified as False according to the established pattern. No modification is needed for this rule based on this example.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Children played tag in the community park." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe people engaging in recreational, outdoor, or special activities in public or natural settings, often with a sense of occasion, time, or atmosphere (e.g., "at sunset," "during the festival," "on Saturday"). Sentences are labeled False when the activity is routine, indoors, or lacks that special or outdoor context.
#
# In this case, "Children played tag in the community park" fits the True pattern: it's an outdoor, recreational activity in a public space.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. However, if more ambiguous or borderline cases arise (e.g., outdoor activities that are routine or lack a special time/occasion), the rule may need further refinement to clarify those distinctions.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the rule I have been using, sentences are labeled "True" if they describe people engaging in an activity outdoors, especially in a public or natural setting, often with a sense of time or occasion (e.g., sunset, afternoon, weekend). "False" is used for activities that are routine, indoors, or lack a distinct outdoor or special context.
#
# In this case, "Children played tag in the community park" describes an outdoor activity in a public space, which fits the "True" pattern.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this example. However, to be more precise, the rule could be clarified as:
#
# - "True" for non-routine, outdoor, communal, or special-occasion activities.
# - "False" for routine, indoor, or everyday activities, especially those in private or institutional settings.
#
# This refinement ensures the rule is consistently applied.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# Based on the pattern in the training examples, sentences are labeled True when they describe outdoor, often recreational or communal activities, especially those that occur in public or natural settings (like parks, beaches, hillsides, etc.), and typically involve a specific time or environmental context (though not always required). Sentences are labeled False when the activity is indoors, routine, institutional, or lacks a distinctive outdoor or communal setting.
#
# In this case, "Children played tag in the community park" fits the True pattern: it's an outdoor, communal, recreational activity in a public park.
#
# **Does the rule still hold?**
# Yes, the original rule still holds for this case. The classification is consistent with the pattern observed in the training examples. No modification is needed based on this example.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the rule inferred from the training examples, sentences are labeled True if they describe people engaging in recreational, social, or outdoor activities in public or natural settings, especially when the activity is specific and the location is outside of private or institutional indoor spaces. "Children played tag in the community park" fits this pattern: it's a recreational activity (playing tag), in a public outdoor space (community park).
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. The classification is consistent with previous True examples such as "Neighborhood kids played tag in the alley behind the buildings after dinner." No modification is needed based on this example.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the rule used in the previous examples, sentences are labeled True if they describe people engaging in an activity outdoors or in a public, open, or natural setting, especially if the activity is eventful, recreational, or time-specific. "Children played tag in the community park" fits this pattern: it's an outdoor, recreational activity in a public space.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The classification is consistent with previous examples such as "Neighborhood kids played tag in the alley behind the buildings after dinner." Both involve children playing a game in an outdoor, communal location, which was labeled True. No modification to the rule is needed based on this case.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# Based on the rule I have been using, sentences are classified as True if they describe people engaging in recreational, social, or outdoor activities in public or natural settings, especially if the activity is specific and involves a particular time, place, or event. "Children played tag in the community park" fits this pattern: it is an outdoor, recreational activity in a public space.
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The classification is consistent with previous examples such as "Neighborhood kids played tag in the alley behind the buildings after dinner." If anything, this example further confirms the distinction: activities in public/outdoor spaces with a recreational or communal aspect are labeled True, while routine, indoor, or institutional activities are labeled False. No modification is needed at this time.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled True when they describe people engaging in recreational, outdoor, or special activities in public or natural settings, often with a sense of occasion, time, or atmosphere (e.g., "at sunset," "during the festival," "on Saturday"). Sentences are labeled False when the activity is routine, indoors, or lacks that special or outdoor context.
#
# In this case, "Children played tag in the community park" fits the True pattern: it's an outdoor, recreational activity in a public space.
#
# **Does the rule still hold?**
# Yes, the original rule holds for this case. However, if more ambiguous or borderline cases arise (e.g., outdoor activities that are routine or lack a special time/occasion), the rule may need further refinement to clarify those distinctions.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Children played tag in the community park." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Children played tag in the community park." -> True
#
# **Explanation:**
# Based on the pattern in the training examples and my previous outputs, the rule I've been using is:
# - Sentences are labeled **True** if they describe people engaging in an outdoor or semi-outdoor recreational or communal activity, often in a natural or public setting, especially at a specific time or under particular conditions (such as weather, time of day, or event).
# - Sentences are labeled **False** if the activity is indoors, routine, or lacks a specific outdoor/communal/recreational setting or occasion.
#
# In this case, "Children played tag in the community park" describes an outdoor recreational activity in a public setting, aligning with the "True" category.
#
# **Does the rule still hold?**
# Yes, my original rule holds for this case. The sentence fits well within the pattern of "True" examples in the dataset. However, this test reinforces that the core distinction is not just outdoor vs. indoor, but also whether the activity is special, communal, or event-like, as opposed to routine or ordinary.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the pattern in the training examples, sentences are labeled **True** when they depict people engaged in specific, often recreational or outdoor activities in particular, named places, typically at a discrete time or under particular conditions (like "at sunset," "last night," "during the thunderstorm"). They are labeled **False** when the activity is routine, regular, institutional, or indoors, or lacks a specific, eventful context.
#
# In this case, "Children played tag in the community park" describes an outdoor, specific, and recreational activity in a named place (community park), and fits the pattern of examples labeled **True**.
#
# **Does the rule still hold?**
# Yes, the rule holds for this example. However, this probe highlights that the rule depends heavily on context—if the sentence said "every afternoon" or "during recess," the label might be **False** (as with other routine/institutional activities). So, the rule is:
# - **True** for non-routine, event-based, or specific outdoor activities in named public or natural settings.
# - **False** for routine, habitual, or indoor/institutional activities, or when the setting or time is generic or regular.
#
# No modification is needed, but the distinction between "event/specific" and "routine/habitual" is crucial.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the rule being used, scenes set outdoors, especially those involving specific activities in natural or public outdoor settings (parks, beaches, hills, etc.), are generally labeled as True, while indoor/repetitive/unspecified time/location scenes are labeled as False.
#
# **Does the rule still hold?**
# Yes, the rule still holds for this case:
# - The activity ("played tag") is outdoors ("community park") and describes a specific, active, and social scene, which aligns with previous True examples.
# - There’s no mention of a routine, indoor location, or generic/repetitive time, which are often marked as False.
#
# **Conclusion:**
# The current rule is consistent and does not need modification for this example.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# Based on the examples, the rule appears to classify as True those sentences that describe outdoor or public activities, often involving movement or nature, and typically occurring in open or communal spaces (such as parks, meadows, lakesides, hills, etc.), regardless of whether a specific time is mentioned.
#
# This sentence ("Children played tag in the community park.") fits the pattern: it's an outdoor communal activity involving movement in a public space. Therefore, it should be classified as True.
#
# **Does the rule still hold?**
# Yes, the rule still holds for this case. No modification is needed based on this probe.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the classification rule in the training examples, sentences are labeled True if the activity occurs in an outdoor, public, or natural setting (especially with specific timing or event), and involves people engaging in leisure, recreation, or communal actions. The example sentence fits this pattern: children are playing tag (a recreational activity) in the community park (an outdoor public space). Similar sentences in the training set (e.g., "Neighborhood kids played tag in the alley behind the buildings after dinner." -> True) were also labeled True.
#
# **Does the original rule still hold?**
# Yes, the rule still holds. The classification is consistent with the patterns established in the training examples. No modification is necessary.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# According to the observed rule, sentences are labeled **True** when they describe people engaging in recreational, outdoor, or special-occasion activities (often with a sense of setting or timing), especially in public or natural spaces. The sentence "Children played tag in the community park." fits this pattern: it's a recreational activity, outdoors, and in a public space (community park).
#
# **Does the rule still hold?**
# Yes, the original rule still holds. The rule effectively distinguishes between routine/indoor/obligatory activities (False) and outdoor/recreational/special-occasion activities (True). This case aligns with the True examples, so no modification is needed at this point.
# --------------------
# "Children played tag in the community park." -> True
#
# **Explanation:**
# Based on the pattern in the training examples and my previous outputs, the rule I've been using is:
# - Sentences are labeled **True** if they describe people engaging in an outdoor or semi-outdoor recreational or communal activity, often in a natural or public setting, especially at a specific time or under particular conditions (such as weather, time of day, or event).
# - Sentences are labeled **False** if the activity is indoors, routine, or lacks a specific outdoor/communal/recreational setting or occasion.
#
# In this case, "Children played tag in the community park" describes an outdoor recreational activity in a public setting, aligning with the "True" category.
#
# **Does the rule still hold?**
# Yes, my original rule holds for this case. The sentence fits well within the pattern of "True" examples in the dataset. However, this test reinforces that the core distinction is not just outdoor vs. indoor, but also whether the activity is special, communal, or event-like, as opposed to routine or ordinary.
# --------------------

# %%
print(classification_prompt)
# Out:
# You are a helpful assistant.
# Return only True or False after each arrow.
#
# ### Training examples
# "Volunteers packed meals in the food bank warehouse last weekend." -> False
# "Students read novels in the school library every afternoon." -> False
# "Travelers snapped photos atop the hill during the golden hour." -> True
# "A dog walker strolled through the neighborhood street at dusk." -> True
# "Siblings built a snowman in their backyard during the snowfall." -> True
# "Kids watched cartoons in the family room on rainy afternoons." -> False
# "Picnickers lounged under umbrellas by the lake on a hot afternoon." -> True
# "Emily jogged around the city park early this morning." -> True
# "Families watched fireworks from the town square on Independence Day." -> True
# "Friends watched a movie in the home theater yesterday evening." -> False
# "Migratory birds rested on the wetland shore during the rainstorm." -> True
# "Doctors examined patients in the hospital clinic every morning." -> False
# "Employees held meetings in the conference room every Monday morning." -> False
# "Musicians practiced their pieces in the music studio at dusk." -> False
# "Readers discussed novels at the community center library during the book club meeting." -> False
# "Surfers rode large waves off the coast in the late afternoon." -> True
# "Artists painted landscapes beneath the old bridge on a sunny afternoon." -> True
# "Families watched outdoor movies under the stars in the park on Friday nights." -> True
# "A group sang songs around the bonfire near the lakeside at midnight." -> True
# "Artists displayed portraits in the art gallery all week." -> False
# "Children flew kites on the beach under the windy sky last weekend." -> True
# "Students rehearsed a play in the school auditorium after class." -> False
# "Cyclists sped down the country road during the cool spring morning." -> True
# "Technicians repaired computers in the electronics store on Thursday." -> False
# "Joggers ran along the beach despite the light rain yesterday." -> True
# "People browsed fresh produce at the outdoor market on Saturday mornings." -> True
# "Children painted pictures in the classroom during art hour." -> False
# "Birdwatchers spotted eagles near the mountains during sunrise." -> True
# "Two friends skated on the frozen lake during the crisp winter morning." -> True
# "Campers pitched tents near the lakeshore on a cool evening." -> True
# "Friends chatted over lunch in the shopping mall food court." -> False
# "The family roasted marshmallows by the campfire in the campground last Saturday night." -> True
# "Guests danced at the wedding reception hall until midnight." -> False
# "Neighborhood kids played tag in the alley behind the buildings after dinner." -> True
# "Librarians organized books in the archive room during the afternoon." -> False
# "Athletes trained on treadmills inside the gym during the storm." -> False
# "Tourists viewed ancient artifacts in the museum gallery on Tuesday." -> False
# "Joggers stretched beside the running track at the stadium on Monday evening." -> True
# "Children built blocks in the daycare center during playtime." -> False
# "Museum visitors admired dinosaur skeletons in the exhibit hall on Sunday." -> False
#
# ### Label each test input True or False:
# "Dancers learned routines in the mirrored dance studio every evening." ->
# "The dog chased a ball across the open field right before sunset." ->
# "The couple enjoyed a picnic beneath the tall trees in the forest yesterday afternoon." ->
# "Kite enthusiasts displayed their creations on the hillside during the festival." ->
# "Teenagers played basketball at the playground after school." ->
# "Kids climbed jungle gyms on the school playground at recess." ->
# "Friends roasted hotdogs at the public park grill late Saturday afternoon." ->
# "Horseback riders crossed the open prairie at midday." ->
# "A family celebrated a birthday in the dining room last weekend." ->
# "Employees shared lunch in the office break room at noon." ->
# "Newlyweds dined privately in their hotel room the first evening." ->
# "Farmers harvested corn in the field early in the morning." ->
# "Students built robots in the engineering lab every semester." ->
# "Researchers analyzed samples in the laboratory throughout the week." ->
# "Kids splashed water near the fountain in the city plaza at noon." ->
# "Fishermen cast their lines from the riverbank at dawn." ->
# "Joggers ran along the river path before the evening rain." ->
# "Families enjoyed dinner in their kitchen during the thunderstorm." ->
# "Gardeners watered roses in the botanical garden at sunrise." ->
# "Scout troops built a bonfire at the woodland clearing last night." ->
# "Couples took a romantic walk by the rose garden at sunset." ->
# "The family assembled puzzles in their living room on Saturday evening." ->
# "Writers composed stories at their desks in the study late at night." ->
# "Yoga practitioners meditated in the heated studio before dawn." ->
# "Firefighters trained near the riverbank on a foggy morning." ->
# "Friends played video games in the basement throughout the night." ->
# "Gamers competed in the esports arena on Saturday afternoon." ->
# "A mountain biker navigated rocky trails through the canyon as the sun set." ->
# "Hikers admired wildflowers along the hillside trail at midday." ->
# "Children jumped in the ball pit at the indoor play center on the weekend." ->
# "A group performed yoga on the grassy meadow during sunrise." ->
# "The chef prepared spaghetti in the restaurant kitchen last night." ->
# "Professors corrected assignments in the university office last Monday." ->
# "Grandparents told stories to grandchildren in the nursery at bedtime." ->
# "Shoppers browsed clothes in the department store yesterday afternoon." ->
# "Students listened to lectures in the college lecture hall every Thursday." ->
# "Friends played frisbee on the campus lawn between classes." ->
# "Neighbors planted tomatoes in the community garden in the springtime." ->
# "Actors performed scenes on the theater stage every Friday night." ->
# "Workers assembled products in the factory workshop each morning." ->

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Children played tag in the indoor recreation center during a beautiful sunset." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.7,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.950 (±0.000) across 6 runs
#
# 📝 Explanation from last run:
#
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# Based on the training examples, the rule appears to be:
# - True is assigned when the activity is outdoors and/or interacts with notable natural or environmental conditions (e.g., weather, sunlight, time of day, landscape).
# - False is assigned for indoor activities or those without a clear connection to the outdoor environment or natural setting, even if a time of day or weather is mentioned.
#
# In this case, although "a beautiful sunset" is mentioned, the activity takes place **indoors** ("indoor recreation center"), so the sunset does not directly influence or set the scene for the activity. This is consistent with the False label assigned to other indoor activities, even when a time or weather is specified (e.g., "Kids watched cartoons in the family room on rainy afternoons." -> False).
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - Outdoor activities with a direct connection to environmental elements or settings are labeled True.
# - Indoor activities, even with references to outdoor conditions, are labeled False.
#
# No modification to the rule is needed based on this example.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# The rule I have been using is to label as **True** when the activity takes place outdoors, often highlighting a connection to nature, time of day, or weather, and **False** when the activity is indoors or not directly tied to an outdoor environment. In this sentence, although "a beautiful sunset" is mentioned, the children are playing indoors ("in the indoor recreation center"), so the activity itself is not outdoors.
#
# **Does the rule still hold?**
# Yes, the original rule still holds:
# - **True:** Outdoor activities, often with reference to nature, weather, or time of day.
# - **False:** Indoor activities, regardless of time of day or weather outside.
#
# This example confirms that the setting of the activity (indoor vs. outdoor) is the deciding factor, not the mention of outdoor conditions.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# The rule guiding the previous classifications appears to focus on whether the main action takes place outdoors and is meaningfully associated with a specific time of day or natural event (like sunset, sunrise, rain, or weather conditions). If the activity happens indoors or in a setting not directly affected by the natural event/time described, the answer is "False," even if the time of day is mentioned.
#
# In this case, although the sentence mentions "during a beautiful sunset," the main action ("played tag") occurs in the "indoor recreation center," which removes the context from the natural event. Therefore, according to the observed rule, the answer is "False."
#
# **Does the rule hold?**
# Yes, the original rule still holds. The classification is based on whether the activity is outdoors and contextually linked to the mentioned time or natural event. If the action is indoors, the time/nature reference does not affect the activity, so the answer remains "False." No modification is needed.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# The original rule classifies as True those sentences where people are engaged in an activity outdoors, often with a reference to a time of day or natural condition (e.g., sunset, rain, sunrise), and as False those describing indoor activities or regular, scheduled, routine events in institutional or indoor settings.
#
# In this case, even though "during a beautiful sunset" is mentioned (which is an outdoor, natural event), the activity itself ("played tag in the indoor recreation center") is happening indoors. According to the rule, indoor activities—even if they reference an outdoor time or condition—are still classified as False.
#
# **Conclusion:**
# The rule still holds:
# - Activities must be outdoors and often reference a specific time or natural condition for True.
# - Indoor activities, regardless of references to outdoor conditions, are False.
#
# No modification to the rule is necessary based on this case.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, activities that occur *indoors* (like "indoor recreation center") are labeled as **False**, even if they are described as happening during a time associated with an outdoor scene (like "a beautiful sunset"). The rule seems to focus on whether the main action is happening *outdoors* and in connection with a specific time or natural setting (such as sunset, sunrise, dusk, etc.).
#
# **Does the rule need modification?**
# No, the original rule still holds. The rule is:
# - **True** if the action takes place outdoors and is tied to a specific, vivid temporal or environmental setting (especially those involving natural light or weather events).
# - **False** if the action occurs indoors or as a routine, regardless of the time description.
#
# In this test case, the action is *indoors* despite the mention of "sunset," so the classification remains **False**—the rule does not require modification.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# The rule appears to be:
# - True for outdoor activities that are described as happening at a specific time of day or in connection with a natural setting/event (e.g., sunset, rain, dawn, etc.), OR specific outdoor communal/seasonal events.
# - False for indoor activities, routine/repetitive actions, or any activity not directly connected to a specific outdoor/natural context.
#
# In this case, even though "sunset" is mentioned, the actual activity ("played tag") takes place indoors ("indoor recreation center"). According to the pattern in the training examples, the setting must be outdoors and directly involve the time-of-day or natural event for the label to be True.
#
# **Does the rule still hold?**
# Yes, the original rule still holds:
# Outdoor activities linked to specific natural times/events are True; indoor activities remain False, regardless of any outdoor temporal context mentioned. The focus is on the activity's actual location, not just the time or description.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# Based on the training examples, the rule appears to be:
# - True is assigned when the activity is outdoors and/or interacts with notable natural or environmental conditions (e.g., weather, sunlight, time of day, landscape).
# - False is assigned for indoor activities or those without a clear connection to the outdoor environment or natural setting, even if a time of day or weather is mentioned.
#
# In this case, although "a beautiful sunset" is mentioned, the activity takes place **indoors** ("indoor recreation center"), so the sunset does not directly influence or set the scene for the activity. This is consistent with the False label assigned to other indoor activities, even when a time or weather is specified (e.g., "Kids watched cartoons in the family room on rainy afternoons." -> False).
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - Outdoor activities with a direct connection to environmental elements or settings are labeled True.
# - Indoor activities, even with references to outdoor conditions, are labeled False.
#
# No modification to the rule is needed based on this example.
# --------------------

# %%
# Outdoors with time reference
explain_prompt = """
Let's probe your understanding deeper. According to the rule you're using, how would you classify this case?

"Children played tag in the indoor recreation center during a beautiful sunset." -> 

After classifying it, please explain whether your original rule still holds or needs modification."""

results = classify_then_explain(
    first_prompt=classification_prompt,        # built with build_classification_prompt
    second_prompt=explain_prompt,   # built with build_articulation_prompt (or custom)
    model_name=openai_4op1,
    dataset_json="datasets/outdoors_dataset_it_80_40_40.json",
    temperature=0.3,
    num_runs=6,
)
# Out:
# ✅ Classification finished: mean acc 0.946 (±0.009) across 6 runs
#
# 📝 Explanation from last run:
#
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# Based on the rule inferred from the training examples, scenes are labeled **True** when they depict people engaging in activities outdoors or in natural/light-dependent settings, especially when the time of day or weather is referenced (e.g., sunset, sunrise, rain, etc.). Scenes set indoors, even if the time of day or weather is mentioned, are labeled **False**.
#
# In this case, although "a beautiful sunset" is mentioned, the activity occurs "in the indoor recreation center," which is an indoor location. Therefore, according to the rule, the label is **False**.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True** for outdoor/nature-based activities with time/weather context.
# - **False** for indoor activities, regardless of time/weather context.
#
# No modification is needed based on this example.

# %%
for explaination in results['explanations']:
    print(explaination)
    print("--------------------")
# Out:
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, sentences are labeled **True** when they describe people engaging in outdoor or nature-related activities that are time-specific (often referencing natural phenomena like sunset, sunrise, weather, or specific times of day), and **False** when the activity is indoors, routine, or not tied to an outdoor/nature/time-specific context.
#
# In this case, even though "a beautiful sunset" is mentioned, the activity ("played tag") occurs **indoors** ("in the indoor recreation center"). The rule, as shown in the examples, prioritizes the location of the activity—if it's indoors, the label is **False**, regardless of the time or natural event outside.
#
# **Does the rule still hold?**
# Yes, the original rule holds. The classification remains consistent: outdoor, time/nature-specific activities are labeled **True**; indoor or routine activities are labeled **False**. The mention of a sunset does not override the indoor setting of the activity.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# Based on the rule inferred from the training examples, sentences are labeled True if they describe people engaging in activities outdoors, often with references to natural settings, weather, or times of day that highlight an outdoor atmosphere (e.g., "at sunset," "during the golden hour," "on the beach," "in the park"). Activities that are clearly indoors or in generic, non-outdoor locations (e.g., "in the school library," "in the dining room," "in the office break room") are labeled False, regardless of the time of day or weather mentioned.
#
# In this case, even though "during a beautiful sunset" is mentioned, the activity takes place "in the indoor recreation center," which is an indoor location. Thus, according to the rule, the correct label is False.
#
# **Does the rule still hold?**
# Yes, the rule still holds. The key factor is the setting: if the activity is indoors, the label is False, even if the sentence references outdoor conditions or times (like sunset). If the activity is outdoors, especially in a natural or open setting, the label is True. The rule remains consistent and does not need modification based on this example.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# According to the rule being used, the label "True" is assigned to scenarios where people are engaged in activities outdoors, often with a specific time or atmospheric condition (such as sunset, sunrise, rain, etc.) that is typically experienced outside. Activities that take place indoors, regardless of the time or weather mentioned, are labeled "False."
#
# In this sentence, although "a beautiful sunset" is mentioned, the activity ("played tag") occurs "in the indoor recreation center," which is an indoor location. Therefore, the rule still holds: indoor activities are labeled "False," even if the timing or weather outside is described.
#
# **Conclusion:**
# The original rule holds and does not need modification. The key determinant is whether the activity is outdoors (True) or indoors (False), regardless of the time or atmospheric condition described.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# According to the rule demonstrated in the training examples, the label "True" is typically assigned to activities that take place outdoors and are contextually linked to natural phenomena such as sunset, sunrise, weather, or scenic outdoor settings. Activities that occur indoors, even if they mention an outdoor event (like a sunset), are labeled "False." In this case, although the sentence mentions a "beautiful sunset," the activity ("played tag") is happening indoors ("indoor recreation center"), so the correct label is "False."
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - "True" for outdoor activities directly associated with natural events or settings.
# - "False" for indoor activities, regardless of any mention of outdoor phenomena.
# This example fits the established pattern and does not require modification of the rule.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# According to the rule applied in the training examples, scenes that are set outdoors and reference specific times of day or weather (e.g., sunset, sunrise, rain, etc.) are classified as True, while indoor or routine/regular activities are classified as False—even if they mention a time of day.
#
# In this case, the activity ("played tag") is happening indoors ("indoor recreation center"), even though it mentions "during a beautiful sunset." The mention of sunset does not override the indoor setting. Thus, the rule still holds: outdoor, time/weather-specific scenes are True; indoor or routine activities are False.
#
# **Conclusion:**
# The original rule still holds and does not need modification.
# --------------------
# "Children played tag in the indoor recreation center during a beautiful sunset." -> False
#
# **Explanation:**
# Based on the rule inferred from the training examples, scenes are labeled **True** when they depict people engaging in activities outdoors or in natural/light-dependent settings, especially when the time of day or weather is referenced (e.g., sunset, sunrise, rain, etc.). Scenes set indoors, even if the time of day or weather is mentioned, are labeled **False**.
#
# In this case, although "a beautiful sunset" is mentioned, the activity occurs "in the indoor recreation center," which is an indoor location. Therefore, according to the rule, the label is **False**.
#
# **Does the rule still hold?**
# Yes, the original rule holds:
# - **True** for outdoor/nature-based activities with time/weather context.
# - **False** for indoor activities, regardless of time/weather context.
#
# No modification is needed based on this example.
# --------------------
